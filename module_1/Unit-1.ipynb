# %% [markdown]
# # 1.1. Что нужно знать будущему миллионеру?
#
# ## Где я?
#
# В этом модуле вы:
#
# - Примерите на себя роль аналитика в компании кинопроката.
# - Проведете свой первый анализ данных с помощью Pandas.
# - Примете участие в соревновании.
# - Продолжите собирать портфолио на Github.

# %% [markdown]
# ## Что нужно сделать?
#
# 1. Внимательно изучить детали задачи.
# 2. Прочитать наши советы по выполнению проекта.
# 3. Ознакомиться с дополнительным материалом.
# 4. Скачать датасет и ноутбук-шаблон.
# 5. Ответить на все вопросы по этому датасету и набрать минимум 80 баллов.
# 6. Сдать свой ноутбук с решением на проверку ментору, загрузив его на Git.
# 7. Получить обратную связь от ментора.
#
#
# ### Сколько времени выделяется на прохождение модуля?
#
# В среднем на успешное выполнение заданий проекта вам потребуется 5 часов.

# %% [markdown]
# ## Работа в команде
#
# В этот раз мы также призываем вас работать в командах и использовать ресурс сообщества — так ваше обучение станет ещё более эффективным!
#
# Если вы все ещё не нашли себе команду для работы над модулем, напишите об этом в чате своей группы. Вам обязательно помогут.
#
# Если вам всё ещё непонятно, зачем вам работать в группе, объясняем:
#
# - Вы достигнете лучших индивидуальных результатов — напишете более качественный код и наберёте большее количество баллов.
# - Вы достигнете лучших командных результатов — вместе вы сможете добиться более высокого суммарного балла.

# %% [markdown]
# ## Рекомендации
#
# При обработке сложных запросов бывает проще воспользоваться готовыми библиотеками и функциями, а не изобретать свой велосипед.
#
# ### Например:
#
# Нам дан список текстов. Нужно выбрать тексты, в которых есть слово миллионер. Есть несколько вариантов решения этой задачи.
#
#
# #### Вариант 1
# - Мы можем написать простой цикл и выбрать нужный текст:
# - new_text = []
# - for text in data:
#     - if "миллионер" in text:
#         - new_text.append(text)
#
# #### Вариант 2
#
# Примерно то же самое, только компактно:
# - data[data.map(lambda x: True if "миллионер" in x else False)]
#
# #### Вариант 3
#
# Воспользоваться готовым методом в самом pandas:
#
# - data[data.str.contains("миллионер")]
#
#
# Этот метод предпочтительней. Он более компактный (в отличие от первого) и более понятный (в отличие от второго). А сам метод contains имеет четкую и понятную документацию. В отличие от нашего велосипеда.
#
# ## Полезные библиотеки
#
# - itertools https://docs.python.org/3/library/itertools.html#module-itertools
# - collections https://docs.python.org/3/library/collections.html

# %% [markdown]
# # 1.2. Готовы к викторине?
#
# ## Так что делать-то?
#
# Вводную информацию вы получили. Наконец можно приступить к делу!
#
# В этом модуле вы будете проводить предварительный анализ данных на основе датасета сайта IMBD. Скачать его можно здесь: https://drive.google.com/open?id=1nokVzSNxkUPil3aYRBI_fgzx25gtSEta
#
#
# ## Важно!
#
# 1. На следующей странице вы увидите список вопросов с 4 вариантами ответа.
# 2. **У вас будет только одна попытка ответить на каждый вопрос**.
# 3. Будьте внимательны к формулировкам заданий и своим решениям в ноутбуке.
# 4. Используйте шаблон ноутбука для решения заданий проекта (https://drive.google.com/open?id=1nW9ZlvS2hWHOwkJVhrXB0qr4RaJnQUTl).
# 5. Чтобы успешно пройти модуль, нужно набрать минимум 80 баллов. Максимальное количество баллов — 100.
#
#
# Если что-то не получается
# Помните, что всегда можно задать вопрос вашему ментору в Slack или в канале #0-real_ds.
#
# Готовы? Листайте вперёд!

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
print(os.listdir("../input"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-9edefa0a370a> in <module>
#       5 import os
#       6 from collections import Counter
# ----> 7 print(os.listdir("../input"))
#
# FileNotFoundError: [WinError 3] Системе не удается найти указанный путь: '../input'

# %%
data = pd.read_csv('data.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015        5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015        2947
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015
# 2           6.3          2015
# 3           7.5          2015
# 4           7.3          2015

# %%
len(data)
# Out:
# 1890

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
data.sort_values(by = 'budget', ascending = False).head(5)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 491   tt1032751    0.250540  425000000    11087569
# 724   tt1298650    4.955130  380000000  1021683000
# 1670  tt0449088    4.965391  300000000   961000000
# 14    tt2395427    5.944927  280000000  1405035767
# 1015  tt0401729    1.588457  260000000   284139100
#
#                                    original_title  \
# 491                             The Warrior's Way
# 724   Pirates of the Caribbean: On Stranger Tides
# 1670     Pirates of the Caribbean: At World's End
# 14                        Avengers: Age of Ultron
# 1015                                  John Carter
#
#                                                    cast        director  \
# 491   Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...      Sngmoo Lee
# 724   Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...    Rob Marshall
# 1670  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...  Gore Verbinski
# 14    Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...     Joss Whedon
# 1015  Taylor Kitsch|Lynn Collins|Mark Strong|Willem ...  Andrew Stanton
#
#                                              tagline  \
# 491                          Assassin. Hero. Legend.
# 724                      Live Forever Or Die Trying.
# 1670  At the end of the world, the adventure begins.
# 14                               A New Age Has Come.
# 1015            Lost in Our World. Found in Another.
#
#                                                overview  runtime  \
# 491   An Asian assassin (Dong-gun Jang) is forced to...      100
# 724   Captain Jack Sparrow crosses paths with a woma...      136
# 1670  Captain Barbossa, long believed to be dead, ha...      169
# 14    When Tony Stark tries to jumpstart a dormant p...      141
# 1015  Civil War vet John Carter is transplanted to M...      132
#
#                                          genres  \
# 491   Adventure|Fantasy|Action|Western|Thriller
# 724                    Adventure|Action|Fantasy
# 1670                   Adventure|Fantasy|Action
# 14             Action|Adventure|Science Fiction
# 1015   Action|Adventure|Fantasy|Science Fiction
#
#                                    production_companies release_date  \
# 491                            Boram Entertainment Inc.    12/2/2010
# 724   Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
# 1670  Walt Disney Pictures|Jerry Bruckheimer Films|S...    5/19/2007
# 14    Marvel Studios|Prime Focus|Revolution Sun Studios    4/22/2015
# 1015                               Walt Disney Pictures     3/7/2012
#
#       vote_count  vote_average  release_year
# 491           74           6.4          2010
# 724         3180           6.3          2011
# 1670        2626           6.8          2007
# 14          4304           7.4          2015
# 1015        1479           6.0          2012

# %%
# тут вводим ваш ответ и добавлем в его список ответов (для примера стояло "1")
answer_ls.append(4)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data.sort_values(by = 'runtime', ascending = False).head(10)
# Out:
#         imdb_id  popularity     budget     revenue  \
# 1158  tt0279111    0.469518   56000000    12923936
# 1082  tt0167260    7.122455   94000000  1118888979
# 1737  tt0462322    0.906938   67000000    25037897
# 1337  tt0360717    1.508329  207000000   550000000
# 505   tt0213149    2.478879  140000000   449220945
# 1184  tt0993846    4.877927  100000000   392000694
# 864   tt0167261    8.095275   79000000   926287400
# 497   tt0120737    8.575419   93000000   871368364
# 1602  tt0346491    1.319068  155000000   167298192
# 994   tt1371111    2.478372  102000000   130482868
#
#                                          original_title  \
# 1158                                  Gods and Generals
# 1082      The Lord of the Rings: The Return of the King
# 1737                                         Grindhouse
# 1337                                          King Kong
# 505                                        Pearl Harbor
# 1184                            The Wolf of Wall Street
# 864               The Lord of the Rings: The Two Towers
# 497   The Lord of the Rings: The Fellowship of the Ring
# 1602                                          Alexander
# 994                                         Cloud Atlas
#
#                                                    cast  \
# 1158  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...
# 1082  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 1737  Kurt Russell|ZoÃ« Bell|Rosario Dawson|Vanessa ...
# 1337  Naomi Watts|Jack Black|Adrien Brody|Thomas Kre...
# 505   Ben Affleck|Josh Hartnett|Kate Beckinsale|Cuba...
# 1184  Leonardo DiCaprio|Jonah Hill|Margot Robbie|Kyl...
# 864   Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 497   Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 1602  Colin Farrell|Angelina Jolie|Val Kilmer|Jared ...
# 994   Tom Hanks|Halle Berry|Jim Broadbent|Hugo Weavi...
#
#                                                director  \
# 1158                                  Ronald F. Maxwell
# 1082                                      Peter Jackson
# 1737  Robert Rodriguez|Eli Roth|Quentin Tarantino|Ed...
# 1337                                      Peter Jackson
# 505                                         Michael Bay
# 1184                                    Martin Scorsese
# 864                                       Peter Jackson
# 497                                       Peter Jackson
# 1602                                       Oliver Stone
# 994           Lilly Wachowski|Lana Wachowski|Tom Tykwer
#
#                                                 tagline  \
# 1158                The nations heart was touched by...
# 1082                    The eye of the enemy is moving.
# 1737          A double feature that'll tear you in two!
# 1337                    The eighth wonder of the world.
# 505   December 7, 1941 - A day that shall live in in...
# 1184                                EARN. SPEND. PARTY.
# 864                              A New Power Is Rising.
# 497                           One ring to rule them all
# 1602               The greatest legend of all was real.
# 994                             Everything is Connected
#
#                                                overview  runtime  \
# 1158  The film centers mostly around the personal an...      214
# 1082  Aragorn is revealed as the heir to the ancient...      201
# 1737  Two full length feature horror movies written ...      191
# 1337  In 1933 New York, an overly ambitious movie pr...      187
# 505   The lifelong friendship between Rafe McCawley ...      183
# 1184  A New York stockbroker refuses to cooperate in...      180
# 864   Frodo and Sam are trekking to Mordor to destro...      179
# 497   Young hobbit Frodo Baggins, after inheriting a...      178
# 1602  Alexander, the King of Macedonia, leads his le...      175
# 994   A set of six nested stories spanning time betw...      172
#
#                                   genres  \
# 1158                   Drama|History|War
# 1082            Adventure|Fantasy|Action
# 1737              Thriller|Action|Horror
# 1337              Adventure|Drama|Action
# 505                  History|Romance|War
# 1184                  Crime|Drama|Comedy
# 864             Adventure|Fantasy|Action
# 497             Adventure|Fantasy|Action
# 1602  War|History|Action|Adventure|Drama
# 994                Drama|Science Fiction
#
#                                    production_companies release_date  \
# 1158                 Turner Pictures|Antietam Filmworks    2/21/2003
# 1082                      WingNut Films|New Line Cinema    12/1/2003
# 1737  Big Talk Productions|Yer Dead Productions|Wein...     4/6/2007
# 1337  WingNut Films|Universal Pictures|Big Primate P...   12/14/2005
# 505         Jerry Bruckheimer Films|Touchstone Pictures    5/21/2001
# 1184  Paramount Pictures|Appian Way|EMJAG Production...   12/25/2013
# 864   WingNut Films|New Line Cinema|The Saul Zaentz ...   12/18/2002
# 497   WingNut Films|New Line Cinema|The Saul Zaentz ...   12/18/2001
# 1602  France 3 CinÃ©ma|Intermedia Films|PathÃ© Renn ...   11/21/2004
# 994   Anarchos Productions|X-Filme Creative Pool|Asc...   10/26/2012
#
#       vote_count  vote_average  release_year
# 1158          23           5.8          2003
# 1082        5636           7.9          2003
# 1737         197           6.5          2007
# 1337        1289           6.4          2005
# 505         1044           6.6          2001
# 1184        4027           7.9          2013
# 864         5114           7.8          2002
# 497         6079           7.8          2001
# 1602         519           5.6          2004
# 994         2162           6.5          2012

# %%
answer_ls.append(2)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data.sort_values(by = 'runtime', ascending = True).head(5)
# Out:
#         imdb_id  popularity     budget    revenue        original_title  \
# 769   tt1449283    1.425344   30000000   14460000       Winnie the Pooh
# 931   tt0280030    0.678896   20000000  109862682  Return to Never Land
# 1098  tt0283426    1.781615   20000000  135680000     The Jungle Book 2
# 1627  tt0299172    0.837906  110000000  103951461     Home on the Range
# 1409  tt0361089    0.558258   35000000   19478106               Valiant
#
#                                                    cast  \
# 769   Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
# 931   Harriet Owen|Blayne Weaver|Jeff Bennett|Kath S...
# 1098  John Goodman|Haley Joel Osment|Mae Whitman|Phi...
# 1627  Randy Quaid|Steve Buscemi|Judi Dench|Cuba Good...
# 1409  Ewan McGregor|Ricky Gervais|Tim Curry|Jim Broa...
#
#                        director  \
# 769   Stephen Anderson|Don Hall
# 931     Robin Budd|Donovan Cook
# 1098            Steve Trenbirth
# 1627     Will Finn|John Sanford
# 1409               Gary Chapman
#
#                                             tagline  \
# 769                                        Oh Pooh.
# 931                           The Classic Continues
# 1098                           Feel the jungle beat
# 1627                                    Bust a Moo.
# 1409  Some pigeons eat crumbs, others make history.
#
#                                                overview  runtime  \
# 769   During an ordinary day in Hundred Acre Wood, W...       63
# 931   The classic tale of 'Peter Pan' continues in D...       72
# 1098  Mowgli, missing the jungle and his old friends...       72
# 1627  The Little Piece of Heaven family farm is abou...       76
# 1409  The animated comedy tells the story of a lowly...       76
#
#                                      genres  \
# 769                        Animation|Family
# 931      Adventure|Fantasy|Animation|Family
# 1098             Family|Animation|Adventure
# 1627  Western|Animation|Family|Comedy|Music
# 1409             Animation|Family|Adventure
#
#                                    production_companies release_date  \
# 769   Walt Disney Pictures|Walt Disney Animation Stu...    4/13/2011
# 931   Walt Disney Pictures|Walt Disney Television An...    2/14/2002
# 1098  Walt Disney Pictures|Walt Disney Television An...     2/7/2003
# 1627  Walt Disney Pictures|Walt Disney Feature Anima...     4/2/2004
# 1409                             Vanguard Films|Scanbox    3/25/2005
#
#       vote_count  vote_average  release_year
# 769          174           6.8          2011
# 931          174           6.2          2002
# 1098         156           5.6          2003
# 1627         210           5.8          2004
# 1409         138           5.3          2005

# %%
answer_ls.append(3)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
data.runtime.mean()
# Out:
# 109.65343915343915

# %%
answer_ls.append(2)

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
sorted_data = data.sort_values(by = 'runtime')
lenght = len(sorted_data)
if lenght%2 == 0:
    median = (sorted_data.runtime[lenght//2] + sorted_data.runtime[lenght//2 - 1]) / 2
else:
    median = sorted_data.runtime[lenght//2]
print(median)
# Out:
# 1
# 115.5

# %%
len(sorted_data)/2
# Out:
# 945.0

# %%
sorted_data.iloc[945].runtime
# Out:
# 107

# %%
sorted_data.iloc[944].runtime
# Out:
# 106

# %%
(107 + 106) / 2
# Out:
# 106.5

# %%
sorted_data = data.sort_values(by = 'runtime')
lenght = len(sorted_data)
if lenght%2 == 0:
    #print(lenght, lenght//2, lenght//2-1, sorted_data.iloc(lenght//2).runtime,sorted_data.iloc(lenght//2 - 1).runtime)
    median = (sorted_data.iloc[lenght//2].runtime + sorted_data.iloc[lenght//2 - 1].runtime) / 2
else:
    median = sorted_data.iloc[lenght//2].runtime
print(median)
# Out:
# 106.5

# %%
sorted_data.iloc[lenght//2 - 1].runtime
# Out:
# 106

# %%
sorted_data.runtime[lenght//2 - 1]
# Out:
# 99

# %%
sorted_data.head(2)
# Out:
#        imdb_id  popularity    budget    revenue        original_title  \
# 769  tt1449283    1.425344  30000000   14460000       Winnie the Pooh
# 931  tt0280030    0.678896  20000000  109862682  Return to Never Land
#
#                                                   cast  \
# 769  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
# 931  Harriet Owen|Blayne Weaver|Jeff Bennett|Kath S...
#
#                       director                tagline  \
# 769  Stephen Anderson|Don Hall               Oh Pooh.
# 931    Robin Budd|Donovan Cook  The Classic Continues
#
#                                               overview  runtime  \
# 769  During an ordinary day in Hundred Acre Wood, W...       63
# 931  The classic tale of 'Peter Pan' continues in D...       72
#
#                                  genres  \
# 769                    Animation|Family
# 931  Adventure|Fantasy|Animation|Family
#
#                                   production_companies release_date  \
# 769  Walt Disney Pictures|Walt Disney Animation Stu...    4/13/2011
# 931  Walt Disney Pictures|Walt Disney Television An...    2/14/2002
#
#      vote_count  vote_average  release_year
# 769         174           6.8          2011
# 931         174           6.2          2002

# %%
sorted_data.runtime.head(10)
# Out:
# 769     63
# 931     72
# 1098    72
# 1627    76
# 1409    76
# 1349    77
# 885     78
# 1808    78
# 252     79
# 1769    80
# Name: runtime, dtype: int64

# %%
sorted_data.iloc[2].runtime
# Out:
# 72

# %%
sorted_data.runtime[931]
# Out:
# 72

# %%
sorted_data.runtime[0]
# Out:
# 124

# %%
answer_ls.append(1)

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
#
# **Внимание!** Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма.
#
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data.head()
data2 = data
data2['profit'] = data.revenue - data.budget
data2.head()
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015        5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015        2947
#
#    vote_average  release_year      profit
# 0           6.5          2015  1363528810
# 1           7.1          2015   228436354
# 2           6.3          2015   185238201
# 3           7.5          2015  1868178225
# 4           7.3          2015  1316249360

# %% [markdown]
# Revenue is the total amount of income generated by the sale of goods or services related to the company's primary operations. Profit, typically called net profit or the bottom line, is the amount of income that remains after accounting for all expenses, debts, additional income streams and operating costs.

# %%
data2[data2.profit == data2.profit.max()]
# Out:
#        imdb_id  popularity     budget     revenue original_title  \
# 239  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_count  vote_average  release_year      profit
# 239        8458           7.1          2009  2544505847

# %%
answer_ls.append(5)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
#
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
data2[data2.profit == data2.profit.min()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     profit
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
answer_ls.append(2)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
data2[data2.profit > 0].profit.count()
# Out:
# 1478

# %%
answer_ls.append(1)

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data2_2008 = data2[data2.release_year == 2008]
data2_2008.head()
# Out:
#        imdb_id  popularity     budget     revenue  \
# 600  tt0468569    8.466668  185000000  1001921825
# 601  tt0910970    5.678119  180000000   521311860
# 602  tt0371746    4.977955  140000000   585174222
# 603  tt0936501    3.647612   25000000   226830568
# 604  tt0367882    3.161670  185000000   786636033
#
#                                         original_title  \
# 600                                    The Dark Knight
# 601                                            WALLÂ·E
# 602                                           Iron Man
# 603                                              Taken
# 604  Indiana Jones and the Kingdom of the Crystal S...
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
# 601  Ben Burtt|Elissa Knight|Jeff Garlin|Fred Willa...     Andrew Stanton
# 602  Robert Downey Jr.|Terrence Howard|Jeff Bridges...        Jon Favreau
# 603  Liam Neeson|Famke Janssen|Maggie Grace|Katie C...       Pierre Morel
# 604  Harrison Ford|Cate Blanchett|Shia LaBeouf|Ray ...   Steven Spielberg
#
#                                               tagline  \
# 600                                   Why So Serious?
# 601                An adventure beyond the ordinar-E.
# 602                Heroes aren't born. They're built.
# 603  They took his daughter.  He'll take their lives.
# 604                     The adventure continues . . .
#
#                                               overview  runtime  \
# 600  Batman raises the stakes in his war on crime. ...      152
# 601  WALLÂ·E is the last robot left on an Earth tha...       98
# 602  After being held captive in an Afghan cave, bi...      126
# 603  While vacationing with a friend in Paris, an A...       93
# 604  Set during the Cold War, the Soviets â€“ led b...      122
#
#                                genres  \
# 600       Drama|Action|Crime|Thriller
# 601                  Animation|Family
# 602  Action|Science Fiction|Adventure
# 603             Action|Thriller|Crime
# 604                  Adventure|Action
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
# 601       Walt Disney Pictures|Pixar Animation Studios    6/22/2008
# 602                                     Marvel Studios    4/30/2008
# 603  Twentieth Century Fox Film Corporation|M6 Film...    2/18/2008
# 604                       Lucasfilm|Paramount Pictures    5/21/2008
#
#      vote_count  vote_average  release_year     profit
# 600        8432           8.1          2008  816921825
# 601        4209           7.6          2008  341311860
# 602        6220           7.3          2008  445174222
# 603        3075           7.2          2008  201830568
# 604        1537           5.6          2008  601636033

# %%
data2_2008[data2_2008.profit == data2_2008.profit.max()]
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year     profit
# 600        8432           8.1          2008  816921825

# %%
data2[(data2.release_year == 2008) & (data2.profit == data2.profit.max())]
# Out:
# Empty DataFrame
# Columns: [imdb_id, popularity, budget, revenue, original_title, cast, director, tagline, overview, runtime, genres, production_companies, release_date, vote_count, vote_average, release_year, profit]
# Index: []

# %%
answer_ls.append(4)

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data2_12_14 = data2[(data2.release_year >= 2012) & (data2.release_year <= 2014)]
data2_12_14.release_year.unique()
# Out:
# array([2014, 2012, 2013], dtype=int64)

# %%
data2_12_14[data2_12_14.profit == data2_12_14.profit.min()]
# Out:
#         imdb_id  popularity     budget   revenue   original_title  \
# 1246  tt1210819     1.21451  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1246  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1246  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1246  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1246  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1246  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_count  vote_average  release_year     profit
# 1246        1607           6.0          2013 -165710090

# %%
data2[data2.release_year in [2012,2013,2014]].profit.min()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-98a60f3a0bc7> in <module>
# ----> 1 data2[data2.release_year in [2012,2013,2014]].profit.min()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
answer_ls.append(5)

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
cnt = Counter()
genres = data2.genres
for item in genres:
    temp = item.split('|') 
    for genre in temp:
        cnt[genre] += 1
cnt
# Out:
# Counter({'Action': 583,
#          'Adventure': 416,
#          'Science Fiction': 248,
#          'Thriller': 597,
#          'Fantasy': 223,
#          'Crime': 315,
#          'Western': 20,
#          'Drama': 782,
#          'Family': 260,
#          'Animation': 139,
#          'Comedy': 683,
#          'Mystery': 168,
#          'Romance': 308,
#          'War': 58,
#          'History': 62,
#          'Music': 64,
#          'Horror': 176,
#          'Documentary': 8,
#          'Foreign': 2})

# %%
cnt.most_common()[0]
# Out:
# ('Drama', 782)

# %%
answer_ls.append(3)

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
cnt = Counter()
for item in data2[data2.profit > 0].genres:
    temp = item.split('|') 
    for genre in temp:
        cnt[genre] += 1
cnt.most_common()
# Out:
# [('Drama', 560),
#  ('Comedy', 551),
#  ('Thriller', 446),
#  ('Action', 444),
#  ('Adventure', 337),
#  ('Romance', 242),
#  ('Crime', 231),
#  ('Family', 226),
#  ('Science Fiction', 195),
#  ('Fantasy', 188),
#  ('Horror', 150),
#  ('Animation', 120),
#  ('Mystery', 119),
#  ('Music', 47),
#  ('History', 46),
#  ('War', 41),
#  ('Western', 12),
#  ('Documentary', 7)]

# %%
answer_ls.append(1)

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
cnt = Counter()
for item in data2.director:
    temp = item.split('|') 
    for genre in temp:
        cnt[genre] += 1
cnt.most_common()[0]
# Out:
# [('Steven Soderbergh', 13),
#  ('Ridley Scott', 12),
#  ('Clint Eastwood', 12),
#  ('Robert Rodriguez', 11),
#  ('Steven Spielberg', 10),
#  ('Shawn Levy', 10),
#  ('Peter Farrelly', 10),
#  ('Bobby Farrelly', 9),
#  ('Tim Burton', 9),
#  ('Antoine Fuqua', 8),
#  ('Ron Howard', 8),
#  ('M. Night Shyamalan', 8),
#  ('Christopher Nolan', 8),
#  ('Peter Jackson', 8),
#  ('Michael Bay', 8),
#  ('Brett Ratner', 8),
#  ('Todd Phillips', 8),
#  ('Adam Shankman', 8),
#  ('Gore Verbinski', 8),
#  ('Quentin Tarantino', 7),
#  ('Paul W.S. Anderson', 7),
#  ('Lasse HallstrÃ¶m', 7),
#  ('Dennis Dugan', 7),
#  ('Marc Forster', 7),
#  ('Francis Lawrence', 6),
#  ('Adam McKay', 6),
#  ('Robert Zemeckis', 6),
#  ('Andy Fickman', 6),
#  ('David Fincher', 6),
#  ('Tim Story', 6),
#  ('Zack Snyder', 6),
#  ('Robert Luketic', 6),
#  ('Steve Carr', 6),
#  ('Sam Raimi', 6),
#  ('Tony Scott', 6),
#  ('Joel Coen', 6),
#  ('Martin Scorsese', 6),
#  ('Danny Boyle', 6),
#  ('Louis Leterrier', 6),
#  ('Brian Robbins', 6),
#  ('Rob Cohen', 6),
#  ('Peter Berg', 6),
#  ('Peter Segal', 6),
#  ('Raja Gosnell', 6),
#  ('J.J. Abrams', 5),
#  ('Sam Mendes', 5),
#  ('Lana Wachowski', 5),
#  ('Lilly Wachowski', 5),
#  ('Chris Columbus', 5),
#  ('Peyton Reed', 5),
#  ('Jaume Collet-Serra', 5),
#  ('F. Gary Gray', 5),
#  ('Guy Ritchie', 5),
#  ('Nancy Meyers', 5),
#  ('Michael Mann', 5),
#  ('Judd Apatow', 5),
#  ('Joe Wright', 5),
#  ('Guillermo del Toro', 5),
#  ('Jay Roach', 5),
#  ('Cameron Crowe', 5),
#  ('Ken Kwapis', 5),
#  ('Bryan Singer', 5),
#  ('Wes Anderson', 5),
#  ('Doug Liman', 5),
#  ('Jon Favreau', 5),
#  ('David Dobkin', 5),
#  ('Carlos Saldanha', 5),
#  ('Renny Harlin', 5),
#  ('Roland Emmerich', 5),
#  ('David R. Ellis', 5),
#  ('Paul Weitz', 5),
#  ('Justin Lin', 5),
#  ('Andrzej Bartkowiak', 5),
#  ('Jon Turteltaub', 5),
#  ('James Mangold', 5),
#  ('Paul Greengrass', 5),
#  ('Jason Friedberg', 5),
#  ('Aaron Seltzer', 5),
#  ('Wes Craven', 5),
#  ('Oliver Stone', 5),
#  ('Martin Campbell', 5),
#  ('Simon West', 5),
#  ('John Moore', 5),
#  ('Lee Tamahori', 5),
#  ('Mark Waters', 5),
#  ('John Singleton', 5),
#  ('D.J. Caruso', 5),
#  ('Joel Schumacher', 5),
#  ('Robert Schwentke', 4),
#  ('James Wan', 4),
#  ('Alejandro GonzÃ¡lez IÃ±Ã¡rritu', 4),
#  ('Olivier Megaton', 4),
#  ('Brad Bird', 4),
#  ('Matthew Vaughn', 4),
#  ('Rob Letterman', 4),
#  ('Tarsem Singh', 4),
#  ('Gavin Hood', 4),
#  ('Brian Helgeland', 4),
#  ('John Erick Dowdle', 4),
#  ('Boaz Yakin', 4),
#  ('Anne Fletcher', 4),
#  ('Paul McGuigan', 4),
#  ('David Gordon Green', 4),
#  ('Barry Levinson', 4),
#  ('Jon M. Chu', 4),
#  ('David Ayer', 4),
#  ('Phil Lord', 4),
#  ('Christopher Miller', 4),
#  ('Luke Greenfield', 4),
#  ('Eric Darnell', 4),
#  ('Rob Marshall', 4),
#  ('Darren Aronofsky', 4),
#  ('Frank Coraci', 4),
#  ('Nicholas Stoller', 4),
#  ('Nick Cassavetes', 4),
#  ('Rob Minkoff', 4),
#  ('George Clooney', 4),
#  ('David Yates', 4),
#  ('McG', 4),
#  ('John Lee Hancock', 4),
#  ('Mark Neveldine', 4),
#  ('Brian Taylor', 4),
#  ('Ethan Coen', 4),
#  ('David Twohy', 4),
#  ('Dominic Sena', 4),
#  ('James McTeigue', 4),
#  ('NimrÃ³d Antal', 4),
#  ('Jason Reitman', 4),
#  ('David Bowers', 4),
#  ('Rob Zombie', 4),
#  ('Donald Petrie', 4),
#  ('Marcus Nispel', 4),
#  ('Richard Linklater', 4),
#  ('Tom McGrath', 4),
#  ('Edward Zwick', 4),
#  ('Andy Tennant', 4),
#  ('Garry Marshall', 4),
#  ('Kevin Smith', 4),
#  ('Andrew Adamson', 4),
#  ('Keenen Ivory Wayans', 4),
#  ('Gary Fleder', 4),
#  ('David Frankel', 4),
#  ('Malcolm D. Lee', 4),
#  ('Bill Condon', 4),
#  ('Mikael HÃ¥fstrÃ¶m', 4),
#  ('Alexander Payne', 4),
#  ('David Cronenberg', 4),
#  ('Barry Sonnenfeld', 4),
#  ('Len Wiseman', 4),
#  ('George Miller', 3),
#  ('Pierre Coffin', 3),
#  ('Pete Docter', 3),
#  ('Kenneth Branagh', 3),
#  ('Brad Peyton', 3),
#  ('Neill Blomkamp', 3),
#  ('Breck Eisner', 3),
#  ('Todd Haynes', 3),
#  ('Baltasar KormÃ¡kur', 3),
#  ('John Wells', 3),
#  ('David Koepp', 3),
#  ('Tom Hooper', 3),
#  ('Paul Feig', 3),
#  ('Glenn Ficarra', 3),
#  ('John Requa', 3),
#  ('Steve Martino', 3),
#  ('Jonathan Levine', 3),
#  ('Gil Kenan', 3),
#  ('Sean Anders', 3),
#  ('Scott Cooper', 3),
#  ('Pierre Morel', 3),
#  ('Neil Burger', 3),
#  ('Jonathan Liebesman', 3),
#  ('Jake Kasdan', 3),
#  ('Matt Reeves', 3),
#  ('Marc Webb', 3),
#  ('Roger Donaldson', 3),
#  ('Dean DeBlois', 3),
#  ('Paul Thomas Anderson', 3),
#  ('Frank Miller', 3),
#  ('Will Gluck', 3),
#  ('Bennett Miller', 3),
#  ('Steve Pink', 3),
#  ('Thomas Carter', 3),
#  ('Randall Wallace', 3),
#  ('Ruben Fleischer', 3),
#  ('Chris Weitz', 3),
#  ('Stephen Sommers', 3),
#  ('Burr Steers', 3),
#  ('Jim Sheridan', 3),
#  ('Conrad Vernon', 3),
#  ('Betty Thomas', 3),
#  ('Kevin Macdonald', 3),
#  ('David S. Goyer', 3),
#  ('Patrick Lussier', 3),
#  ('Tom Tykwer', 3),
#  ('Michael Moore', 3),
#  ('Peter Chelsom', 3),
#  ('Tony Gilroy', 3),
#  ('Greg Mottola', 3),
#  ('Jonathan Mostow', 3),
#  ('Thor Freudenthal', 3),
#  ('Vicky Jenson', 3),
#  ('Marc Lawrence', 3),
#  ('Chris Renaud', 3),
#  ('Sylvester Stallone', 3),
#  ('Chris Sanders', 3),
#  ('Lee Unkrich', 3),
#  ('Mike Newell', 3),
#  ('Mike Mitchell', 3),
#  ('Joe Carnahan', 3),
#  ('Allen Hughes', 3),
#  ('Ben Affleck', 3),
#  ('Harald Zwart', 3),
#  ('Roman Polanski', 3),
#  ('Paul Haggis', 3),
#  ('David O. Russell', 3),
#  ('Jimmy Hayward', 3),
#  ('Alexandre Aja', 3),
#  ('Michael Lembeck', 3),
#  ('John Madden', 3),
#  ('Brian Levant', 3),
#  ('Robert Redford', 3),
#  ('Neil LaBute', 3),
#  ('Tom Dey', 3),
#  ('Tyler Perry', 3),
#  ('Baz Luhrmann', 3),
#  ('Ben Stiller', 3),
#  ('Iain Softley', 3),
#  ('Jesse Dylan', 3),
#  ('John Stockwell', 3),
#  ('Tim Hill', 3),
#  ('Joe Johnston', 3),
#  ('Andrew Stanton', 3),
#  ('Catherine Hardwicke', 3),
#  ('Kathryn Bigelow', 3),
#  ('Seth Gordon', 3),
#  ('Woody Allen', 3),
#  ('Brad Anderson', 3),
#  ('Gregory Hoblit', 3),
#  ('Gus Van Sant', 3),
#  ('Sam Fell', 3),
#  ('Andrew Niccol', 3),
#  ('Stephen Daldry', 3),
#  ('Kelly Asbury', 3),
#  ('Craig Brewer', 3),
#  ('William Friedkin', 3),
#  ('Chris Wedge', 3),
#  ('Wayne Wang', 3),
#  ('Steven Brill', 3),
#  ('Jeff Tremaine', 3),
#  ('Walter Hill', 3),
#  ('John Woo', 3),
#  ('Tom Shadyac', 3),
#  ('Ang Lee', 3),
#  ('Uwe Boll', 3),
#  ('Rob Reiner', 3),
#  ('Alfonso CuarÃ³n', 3),
#  ('Stephen Frears', 3),
#  ('Wolfgang Petersen', 3),
#  ('Alan Taylor', 2),
#  ('Kyle Balda', 2),
#  ('Joss Whedon', 2),
#  ('Christopher McQuarrie', 2),
#  ('Seth MacFarlane', 2),
#  ('Wes Ball', 2),
#  ('Elizabeth Banks', 2),
#  ('Tim Johnson', 2),
#  ('Denis Villeneuve', 2),
#  ('Josh Trank', 2),
#  ('George Tillman, Jr.', 2),
#  ('Genndy Tartakovsky', 2),
#  ('Jessie Nelson', 2),
#  ('Daniel Espinosa', 2),
#  ('Mark Osborne', 2),
#  ('Simon Curtis', 2),
#  ('Jason Moore', 2),
#  ('Camille Delamarre', 2),
#  ('Jonathan Demme', 2),
#  ('Ken Scott', 2),
#  ('Mike Binder', 2),
#  ('James Gunn', 2),
#  ('Joe Russo', 2),
#  ('Anthony Russo', 2),
#  ('Don Hall', 2),
#  ('Chris Williams', 2),
#  ('Luc Besson', 2),
#  ('Evan Goldberg', 2),
#  ('Seth Rogen', 2),
#  ('Simon J. Smith', 2),
#  ('Noam Murro', 2),
#  ('Phillip Noyce', 2),
#  ('Scott Frank', 2),
#  ('Daniel Barnz', 2),
#  ('J.C. Chandor', 2),
#  ('Michael Spierig', 2),
#  ('Peter Spierig', 2),
#  ('Scott Waugh', 2),
#  ('Anthony Stacchi', 2),
#  ('Steven Quale', 2),
#  ('Shana Feste', 2),
#  ('Stuart Beattie', 2),
#  ('Miguel Arteta', 2),
#  ('Craig Gillespie', 2),
#  ('Charles Martin Smith', 2),
#  ('James Bobin', 2),
#  ('Rupert Wyatt', 2),
#  ('James Cameron', 2),
#  ('Ron Clements', 2),
#  ('John Musker', 2),
#  ('Henry Selick', 2),
#  ('Christian Alvart', 2),
#  ('Alex Proyas', 2),
#  ('Duncan Jones', 2),
#  ('P.J. Hogan', 2),
#  ('John Hillcoat', 2),
#  ('Nora Ephron', 2),
#  ('Karyn Kusama', 2),
#  ('Gary Winick', 2),
#  ('Lee Daniels', 2),
#  ('John Hamburg', 2),
#  ('Richard Curtis', 2),
#  ('Kevin Greutert', 2),
#  ('Jean-Marc VallÃ©e', 2),
#  ('Brad Silberling', 2),
#  ('Harold Ramis', 2),
#  ('Walt Becker', 2),
#  ('Alejandro AmenÃ¡bar', 2),
#  ('Werner Herzog', 2),
#  ('Lone Scherfig', 2),
#  ('Brian Koppelman', 2),
#  ('David Levien', 2),
#  ('Michael J. Bassett', 2),
#  ('Stewart Hendler', 2),
#  ('Bruce Beresford', 2),
#  ('Joseph Kosinski', 2),
#  ('Byron Howard', 2),
#  ('Michael Apted', 2),
#  ('Edgar Wright', 2),
#  ('Albert Hughes', 2),
#  ('David Slade', 2),
#  ('Peter Weir', 2),
#  ('Jonathan Lynn', 2),
#  ('Scott Stewart', 2),
#  ('Michael Patrick King', 2),
#  ('John Luessenhop', 2),
#  ('Mark Romanek', 2),
#  ('Neil Marshall', 2),
#  ('Roger Michell', 2),
#  ('James L. Brooks', 2),
#  ('Eric Brevig', 2),
#  ('Tom Vaughan', 2),
#  ('Roger Kumble', 2),
#  ('Kevin Munroe', 2),
#  ('David Silverman', 2),
#  ('Jean-Jacques Annaud', 2),
#  ('John A. Davis', 2),
#  ('Peter Howitt', 2),
#  ('Victor Salva', 2),
#  ('Rod Lurie', 2),
#  ('John Dahl', 2),
#  ('Bill Paxton', 2),
#  ('Luis Mandoki', 2),
#  ('Scott Hicks', 2),
#  ('Ivan Reitman', 2),
#  ('Frank Oz', 2),
#  ('Frank Darabont', 2),
#  ('Mike Tollin', 2),
#  ('Peter Hyams', 2),
#  ('Phyllida Lloyd', 2),
#  ('Timur Bekmambetov', 2),
#  ('Scott Derrickson', 2),
#  ('Gabriele Muccino', 2),
#  ('Pete Travis', 2),
#  ('David Wain', 2),
#  ('Mathieu Kassovitz', 2),
#  ('Martin McDonagh', 2),
#  ('Jon Hurwitz', 2),
#  ('Hayden Schlossberg', 2),
#  ('Jon Avnet', 2),
#  ('GÃ¡bor CsupÃ³', 2),
#  ('Gina Prince-Bythewood', 2),
#  ('Julian Jarrold', 2),
#  ('Rian Johnson', 2),
#  ('Kirk De Micco', 2),
#  ('Howard Deutch', 2),
#  ('Joshua Michael Stern', 2),
#  ('John Lasseter', 2),
#  ('Brad Furman', 2),
#  ('Chris Miller', 2),
#  ('Michel Gondry', 2),
#  ('Simon Wells', 2),
#  ('Henry Joost', 2),
#  ('Ariel Schulman', 2),
#  ('Michael Dowse', 2),
#  ('Joe Nussbaum', 2),
#  ('John Whitesell', 2),
#  ('Salim Akil', 2),
#  ('George Lucas', 2),
#  ('Andrew Davis', 2),
#  ('Spike Jonze', 2),
#  ('Brian De Palma', 2),
#  ('Michael Caton-Jones', 2),
#  ('Rob Bowman', 2),
#  ('Carl Franklin', 2),
#  ('Shekhar Kapur', 2),
#  ('Denzel Washington', 2),
#  ('Stephen Gaghan', 2),
#  ('Reginald Hudlin', 2),
#  ('Charles Stone III', 2),
#  ('Gary Ross', 2),
#  ('Kirk Jones', 2),
#  ('Larry Charles', 2),
#  ('Peter Lord', 2),
#  ('Andrew Dominik', 2),
#  ('Walter Salles', 2),
#  ('Mark Steven Johnson', 2),
#  ('David Zucker', 2),
#  ('Bille Woodruff', 2),
#  ('Clark Johnson', 2),
#  ('Richard Donner', 2),
#  ('Nigel Cole', 2),
#  ('Robert Iscove', 2),
#  ('Chris Buck', 2),
#  ('Taylor Hackford', 2),
#  ('Spike Lee', 2),
#  ('Sofia Coppola', 2),
#  ('Oliver Hirschbiegel', 2),
#  ('Courtney Solomon', 2),
#  ('Mark Dindal', 2),
#  ('Nick Park', 2),
#  ('Jay Chandrasekhar', 2),
#  ('Kevin Rodney Sullivan', 2),
#  ('Geoffrey Sax', 2),
#  ('James Wong', 2),
#  ('Mel Gibson', 2),
#  ('Darren Lynn Bousman', 2),
#  ('Nick Hurran', 2),
#  ('Peter Hewitt', 2),
#  ('Takashi Shimizu', 2),
#  ('Richard Loncraine', 2),
#  ('Mira Nair', 2),
#  ('Bibo Bergeron', 2),
#  ('Danny Leiner', 2),
#  ('Mike Nichols', 2),
#  ('Philip Kaufman', 2),
#  ('Jay Russell', 2),
#  ('Richard LaGravenese', 2),
#  ('Kevin Lima', 2),
#  ('Eli Roth', 2),
#  ('Colin Trevorrow', 1),
#  ('Alex Garland', 1),
#  ('Sam Taylor-Johnson', 1),
#  ('Tom McCarthy', 1),
#  ('Lenny Abrahamson', 1),
#  ('Peter Sohn', 1),
#  ('John Crowley', 1),
#  ('Lee Toland Krieger', 1),
#  ('Ilya Naishuller', 1),
#  ('Jake Schreier', 1),
#  ('Ericson Core', 1),
#  ('Aleksander Bach', 1),
#  ('Ryan Coogler', 1),
#  ('Peter Landesman', 1),
#  ('John Francis Daley', 1),
#  ('Jonathan M. Goldstein', 1),
#  ('Joel Edgerton', 1),
#  ('Jocelyn Moorhouse', 1),
#  ('Ari Sandel', 1),
#  ('Ciaran Foy', 1),
#  ('Doug Ellin', 1),
#  ('Jeremy Garelick', 1),
#  ('Michael Dougherty', 1),
#  ('Dean Israelite', 1),
#  ('Gregory Jacobs', 1),
#  ('Gregory Plotkin', 1),
#  ('Billy Ray', 1),
#  ('Paul Tibbitt', 1),
#  ('Leigh Whannell', 1),
#  ('Nicholas Hytner', 1),
#  ('David M. Rosenthal', 1),
#  ('Noah Baumbach', 1),
#  ('Etan Cohen', 1),
#  ('Sarah Gavron', 1),
#  ('Max Joseph', 1),
#  ('Alejandro Monteverde', 1),
#  ('Chad Stahelski', 1),
#  ('David Leitch', 1),
#  ('Morten Tyldum', 1),
#  ('Dan Gilroy', 1),
#  ('Gareth Edwards', 1),
#  ('Robert Stromberg', 1),
#  ('Stiles White', 1),
#  ('Patrick Hughes', 1),
#  ('Sergey Bodrov', 1),
#  ('James Marsh', 1),
#  ('Gary Shore', 1),
#  ('Paul King', 1),
#  ('James DeMonaco', 1),
#  ('Vic Armstrong', 1),
#  ('R.J. Cutler', 1),
#  ('Trish Sie', 1),
#  ('Josh Boone', 1),
#  ('JosÃ© Padilha', 1),
#  ('Wally Pfister', 1),
#  ('Angelina Jolie', 1),
#  ('Ava DuVernay', 1),
#  ('Michael Hoffman', 1),
#  ('Theodore Melfi', 1),
#  ('Graham Annable', 1),
#  ('Brian A Miller', 1),
#  ('Roberts Gannaway', 1),
#  ('Sam Miller', 1),
#  ('David MichÃ´d', 1),
#  ('Saul Dibb', 1),
#  ('John R. Leonetti', 1),
#  ('Tom Gormican', 1),
#  ('Ben Falcone', 1),
#  ('Akiva Goldsman', 1),
#  ('Adam Wingard', 1),
#  ('Russell Crowe', 1),
#  ('Jonathan Glazer', 1),
#  ('Rob Thomas', 1),
#  ('Christopher Spencer', 1),
#  ('GrÃ©gory Levasseur', 1),
#  ('Michael Cuesta', 1),
#  ('Andrew Erwin', 1),
#  ('Jon Erwin', 1),
#  ('Dave Green', 1),
#  ('Don McKellar', 1),
#  ('Harold Cronk', 1),
#  ('Matt Bettinelli-Olpin', 1),
#  ('Tyler Gillett', 1),
#  ('Patrick Tatopoulos', 1),
#  ('Bob Peterson', 1),
#  ('Shane Acker', 1),
#  ('Richard Kelly', 1),
#  ('Hoyt Yeatman', 1),
#  ('Ricky Gervais', 1),
#  ('Matthew Robinson', 1),
#  ('Jaco Van Dormael', 1),
#  ('Peter Billingsley', 1),
#  ('Atom Egoyan', 1),
#  ('Phil Traill', 1),
#  ('Brandon Camp', 1),
#  ('Rajkumar Hirani', 1),
#  ('Grant Heslov', 1),
#  ('Todd Graff', 1),
#  ('Jorge Blanco', 1),
#  ('Javier Abad', 1),
#  ('Marcos MartÃ\xadnez', 1),
#  ('Troy Duffy', 1),
#  ('John Schultz', 1),
#  ('Olatunde Osunsanmi', 1),
#  ('Jane Campion', 1),
#  ('Mike Judge', 1),
#  ('Daniel Barber', 1),
#  ('Steve Shill', 1),
#  ('Jonas Elmer', 1),
#  ('Derrick Borte', 1),
#  ('Toby Wilkins', 1),
#  ('Nathan Greno', 1),
#  ('Florian Henckel von Donnersmarck', 1),
#  ('Ethan Maniquis', 1),
#  ('Miguel Sapochnik', 1),
#  ('Ryan Murphy', 1),
#  ('Anand Tucker', 1),
#  ('Alan Poul', 1),
#  ('Josh Gordon', 1),
#  ('Will Speck', 1),
#  ('Floria Sigismondi', 1),
#  ('Troy Nixey', 1),
#  ('Samuel Bayer', 1),
#  ('Susanna White', 1),
#  ('Steve Antin', 1),
#  ('Nanette Burstein', 1),
#  ('Greg Berlanti', 1),
#  ('John Curran', 1),
#  ('Tony Goldwyn', 1),
#  ('Colin Strause', 1),
#  ('Greg Strause', 1),
#  ('Jorma Taccone', 1),
#  ('Jim Field Smith', 1),
#  ('William Monahan', 1),
#  ('Dan Rush', 1),
#  ('Anthony Bell', 1),
#  ('Ben Gluck', 1),
#  ('Richard J. Lewis', 1),
#  ('William Dear', 1),
#  ('Sngmoo Lee', 1),
#  ('John Landis', 1),
#  ('Vipul Amrutlal Shah', 1),
#  ('David Lynch', 1),
#  ('Sharon Maguire', 1),
#  ('Gary Trousdale', 1),
#  ('Kirk Wise', 1),
#  ('J.B. Rogers', 1),
#  ('Ted Demme', 1),
#  ('Joel Gallen', 1),
#  ('Lawrence Guterman', 1),
#  ('Chris Nahon', 1),
#  ('Hironobu Sakaguchi', 1),
#  ('Motonori Sakakibara', 1),
#  ('Michael Cristofer', 1),
#  ('Jerry Zucker', 1),
#  ('Robert Altman', 1),
#  ('James Isaac', 1),
#  ('Stephen Herek', 1),
#  ('Simon Wincer', 1),
#  ('Daniel Sackheim', 1),
#  ('John Herzfeld', 1),
#  ('Dennie Gordon', 1),
#  ('John Boorman', 1),
#  ("Pat O'Connor", 1),
#  ('Gregory Poirier', 1),
#  ('Demian Lichtenstein', 1),
#  ('John Carpenter', 1),
#  ('Penny Marshall', 1),
#  ('Brendan Malloy', 1),
#  ('Emmett Malloy', 1),
#  ('Les Mayfield', 1),
#  ('Harold Becker', 1),
#  ('Rob Pritts', 1),
#  ('Peter Bogdanovich', 1),
#  ('Francine McDougall', 1),
#  ('Ernest R. Dickerson', 1),
#  ('DJ Pooh', 1),
#  ('John Stevenson', 1),
#  ('Loveleen Tandan', 1),
#  ('Mark Herman', 1),
#  ('Jeff Wadlow', 1),
#  ('Lexi Alexander', 1),
#  ('Peter Sollett', 1),
#  ('Fred Wolf', 1),
#  ('David Hackl', 1),
#  ('Marco Schnabel', 1),
#  ('Bryan Bertino', 1),
#  ('Howard McCain', 1),
#  ('Chris Carter', 1),
#  ('John Patrick Shanley', 1),
#  ('Paul Weiland', 1),
#  ('Marcel Langenegger', 1),
#  ('David Moreau', 1),
#  ('Xavier Palud', 1),
#  ('Oxide Pang Chun', 1),
#  ('Danny Pang', 1),
#  ('Peter Cattaneo', 1),
#  ('Robert Stevenhagen', 1),
#  ('Craig Mazin', 1),
#  ('Michael McCullers', 1),
#  ('RyÃ»hei Kitamura', 1),
#  ('Simon Hunter', 1),
#  ('Jennifer Flackett', 1),
#  ('Mark Levin', 1),
#  ('Anthony Leondis', 1),
#  ('Robert B. Weide', 1),
#  ('Nicolas Winding Refn', 1),
#  ('Jennifer Yuh', 1),
#  ('Brad Lewis', 1),
#  ('Terrence Malick', 1),
#  ('Michel Hazanavicius', 1),
#  ('Gary McKendry', 1),
#  ('Stephen Anderson', 1),
#  ('George Nolfi', 1),
#  ('Tom Hanks', 1),
#  ('Mark Mylod', 1),
#  ('Chris Gorak', 1),
#  ('Tate Taylor', 1),
#  ('Christian E. Christiansen', 1),
#  ('Oliver Parker', 1),
#  ('Todd Strauss-Schulson', 1),
#  ('Matthijs van Heijningen Jr.', 1),
#  ('Gonzalo LÃ³pez-Gallego', 1),
#  ('Joe Cornish', 1),
#  ('Bruce Robinson', 1),
#  ('John Michael McDonagh', 1),
#  ('Jesse Peretz', 1),
#  ('Jason Winer', 1),
#  ('Alister Grierson', 1),
#  ('Douglas McGrath', 1),
#  ('Sean McNamara', 1),
#  ('Mike Disa', 1),
#  ('Benny Chan', 1),
#  ('Thomas Bezucha', 1),
#  ('Paul Johansson', 1),
#  ('Paolo Sorrentino', 1),
#  ('Rodrigo GarcÃ\xada', 1),
#  ('Mark Duplass', 1),
#  ('Jay Duplass', 1),
#  ('Corey Yuen Kwai', 1),
#  ('Curtis Hanson', 1),
#  ('Joel Zwick', 1),
#  ('Stuart Baird', 1),
#  ('Kurt Wimmer', 1),
#  ('Steve Beck', 1),
#  ('Lorna Cook', 1),
#  ('Jim Gillespie', 1),
#  ('Chuck Russell', 1),
#  ('Julie Taymor', 1),
#  ('Barbet Schroeder', 1),
#  ('Ron Shelton', 1),
#  ('Adrian Lyne', 1),
#  ('Michael Rymer', 1),
#  ('Marcus Raboy', 1),
#  ('Robin Budd', 1),
#  ('Donovan Cook', 1),
#  ('Dewey Nicks', 1),
#  ('Mark Pellington', 1),
#  ('Jonathan Frakes', 1),
#  ('Rick Rosenthal', 1),
#  ('Mort Nathan', 1),
#  ('Tamra Davis', 1),
#  ('Ron Underwood', 1),
#  ('Kevin Bray', 1),
#  ('William Malone', 1),
#  ('Paul Schrader', 1),
#  ('MÃ¥ns MÃ¥rlind', 1),
#  ('BjÃ¶rn Stein', 1),
#  ('Mark Andrews', 1),
#  ('Steve Purcell', 1),
#  ('Brenda Chapman', 1),
#  ('Rupert Sanders', 1),
#  ('Mike Thurmeier', 1),
#  ('Juan Antonio Bayona', 1),
#  ('Rich Moore', 1),
#  ('Stephen Chbosky', 1),
#  ('Drew Goddard', 1),
#  ('Peter Ramsey', 1),
#  ('Michael Sucsy', 1),
#  ('Juan Diego Solanas', 1),
#  ('Scott Speer', 1),
#  ('Mike McCoy', 1),
#  ('Nima Nourizadeh', 1),
#  ('Jeff Newitt', 1),
#  ('Stephen St. Leger', 1),
#  ('James Mather', 1),
#  ('James Watkins', 1),
#  ('Asger Leth', 1),
#  ('Henry Alex Rubin', 1),
#  ('Alex Kurtzman', 1),
#  ('John Gulager', 1),
#  ('Ole Bornedal', 1),
#  ('Mabrouk El Mechri', 1),
#  ('Nicholas Jarecki', 1),
#  ('Dan Bradley', 1),
#  ('Julie Anne Robinson', 1),
#  ('Dustin Hoffman', 1),
#  ('Chris Butler', 1),
#  ('Dean Wright', 1),
#  ('Anthony Hemingway', 1),
#  ('Josh Schwartz', 1),
#  ('Brian Klugman', 1),
#  ('Lee Sternthal', 1),
#  ('David Barrett', 1),
#  ('Todd Lincoln ', 1),
#  ('Dan Cutforth', 1),
#  ('Jane Lipsitz', 1),
#  ('Stephen Norrington', 1),
#  ('Steve Trenbirth', 1),
#  ('Terry Zwigoff', 1),
#  ('Jan de Bont', 1),
#  ('Rob Schmidt', 1),
#  ('Jon Amiel', 1),
#  ('Charles Herman-Wurmfeld', 1),
#  ('Anthony Minghella', 1),
#  ('Ronny Yu', 1),
#  ('Joe Dante', 1),
#  ('John McTiernan', 1),
#  ('Kevin Costner', 1),
#  ('Jim Fall', 1),
#  ('Lawrence Kasdan', 1),
#  ('Patty Jenkins', 1),
#  ('Martin Brest', 1),
#  ('Ronald F. Maxwell', 1),
#  ('Troy Miller', 1),
#  ('Alan Parker', 1),
#  ('Chris Koch', 1),
#  ('David Mackenzie', 1),
#  ('FranÃ§ois Ozon', 1),
#  ('Christopher Guest', 1),
#  ('James Cox', 1),
#  ('Christine Jeffs', 1),
#  ('Jennifer Lee', 1),
#  ('Shane Black', 1),
#  ('Steve McQueen', 1),
#  ('Dan Scanlon', 1),
#  ('Tommy Wirkola', 1),
#  ('Carl Rinsch', 1),
#  ('Klay Hall', 1),
#  ('Harmony Korine', 1),
#  ('Fede Alvarez', 1),
#  ('Derek Cianfrance', 1),
#  ('Kimberly Peirce', 1),
#  ('John Carney', 1),
#  ('Justin Zackham', 1),
#  ('Mike Flanagan', 1),
#  ('David Soren', 1),
#  ('Steven Knight', 1),
#  ('Andy Muschietti', 1),
#  ('Rusty Cundieff', 1),
#  ('James Duffy', 1),
#  ('Griffin Dunne', 1),
#  ('Patrik Forsberg', 1),
#  ('Will Graham', 1),
#  ('Jonathan van Tulleken', 1),
#  ('Scott Moore', 1),
#  ('Jon Lucas', 1),
#  ('Callan Brunker', 1),
#  ('Amma Asante', 1),
#  ('Dito Montiel', 1),
#  ('Cody Cameron', 1),
#  ('Kris Pearn', 1),
#  ('Giuseppe Tornatore', 1),
#  ('Don Scardino', 1),
#  ('Jeff Nichols', 1),
#  ('Jonathan Teplitzky', 1),
#  ('Neil Nightingale', 1),
#  ('Barry Cook', 1),
#  ('Scott Walker', 1),
#  ('Guillaume Canet', 1),
#  ('Ric Roman Waugh', 1),
#  ('Keanu Reeves', 1),
#  ('David E. Talbert', 1),
#  ('Christopher B. Landon', 1),
#  ('Benson Lee', 1),
#  ('Anthony Silverston', 1),
#  ('Kasi Lemmons', 1),
#  ('Dan St. Pierre', 1),
#  ('Zal Batmanglij', 1),
#  ('Ed Gass-Donnelly', 1),
#  ('Justin Chadwick', 1),
#  ('Fyodor Bondarchuk', 1),
#  ('Garth Jennings', 1),
#  ('Mike Johnson', 1),
#  ('Steve Box', 1),
#  ('John Maybury', 1),
#  ('Angela Robinson', 1),
#  ('Cory Edwards', 1),
#  ('Todd Edwards', 1),
#  ('Tony Leech', 1),
#  ('John Polson', 1),
#  ('Sydney Pollack', 1),
#  ('Terry Gilliam', 1),
#  ('Florent-Emilio Siri', 1),
#  ('Frederik Du Chau', 1),
#  ('Andrew Douglas', 1),
#  ('Dean Parisot', 1),
#  ('Jean-FranÃ§ois Richet', 1),
#  ('Jim Jarmusch', 1),
#  ('George A. Romero', 1),
#  ('Rupert Wainwright', 1),
#  ('Clare Kilner', 1),
#  ('Richard Shepard', 1),
#  ('Gary Chapman', 1),
#  ('Fernando Meirelles', 1),
#  ('Tommy Lee Jones', 1),
#  ('Danny Cannon', 1),
#  ('Liev Schreiber', 1),
#  ('Stephen Kay', 1),
#  ('Bruce Hunt', 1),
#  ('Niki Caro', 1),
#  ('Joe Ranft', 1),
#  ('Karey Kirkpatrick', 1),
#  ('Frank Marshall', 1),
#  ('Christophe Gans', 1),
#  ("Steve 'Spaz' Williams", 1),
#  ('Stefen Fangmeier', 1),
#  ('Alejandro Agresti', 1),
#  ('Robert De Niro', 1),
#  ('Kevin Reynolds', 1),
#  ("Matthew O'Callaghan", 1),
#  ('Steven Zaillian', 1),
#  ('Joe Roth', 1),
#  ('Jared Hess', 1),
#  ('Steven Shainberg', 1),
#  ('Jonathan Dayton', 1),
#  ('Valerie Faris', 1),
#  ('Greg Coolidge', 1),
#  ('Roger Allers', 1),
#  ('Jill Culton', 1),
#  ('Steve Oedekerk', 1),
#  ('Chris Noonan', 1),
#  ('Jim Sonzero', 1),
#  ('John Bonito', 1),
#  ('Liz Friedlander', 1),
#  ('Elizabeth Allen Rosenbaum', 1),
#  ('Richard Eyre', 1),
#  ('Tony Bill', 1),
#  ('Wayne Kramer', 1),
#  ('Susannah Grant', 1),
#  ('Liam Lynch', 1),
#  ('Sanjay Gadhvi', 1),
#  ('Glen Morgan', 1),
#  ('Phil Joanou', 1),
#  ('Rachid Bouchareb', 1),
#  ('William Brent Bell', 1),
#  ('Asif Kapadia', 1),
#  ('Doug Atchison', 1),
#  ('Beeban Kidron', 1),
#  ('Eric Bress', 1),
#  ('J. Mackye Gruber', 1),
#  ('Alexander Witt', 1),
#  ('Kerry Conran', 1),
#  ('Stephen Hillenburg', 1),
#  ("Tommy O'Haver", 1),
#  ('Mark Rosman', 1),
#  ('Rawson Marshall Thurber', 1),
#  ('Jeff Schaffer', 1),
#  ('Jonathan Hensleigh', 1),
#  ('Pitof', 1),
#  ('Don Mancini', 1),
#  ('Charles Shyer', 1),
#  ('Will Finn', 1),
#  ('John Sanford', 1),
#  ('Terry George', 1),
#  ('Trey Parker', 1),
#  ('Sara Sugarman', 1),
#  ('Guy Ferland', 1),
#  ('Joseph Ruben', 1),
#  ('Nick Hamm', 1),
#  ('Paul Abascal', 1),
#  ('Joseph Kahn', 1),
#  ("Gavin O'Connor", 1),
#  ('E. Elias Merhige', 1),
#  ('George Armitage', 1),
#  ('David Mamet', 1),
#  ('Kevin Allen', 1),
#  ('Christopher Erskin', 1),
#  ('Jan Pinkava', 1),
#  ('Sean Penn', 1),
#  ('Raman Hui', 1),
#  ('Steve Hickner', 1),
#  ('Stephen J. Anderson', 1),
#  ('Juan Carlos Fresnadillo', 1),
#  ('Steve Bendelack', 1),
#  ('Bruce A. Evans', 1),
#  ('Kirsten Sheridan', 1),
#  ('Joby Harold', 1),
#  ('Philip G. Atwell', 1),
#  ('Mennan Yapo', 1),
#  ('Michael Davis', 1),
#  ('Ash Brannon', 1),
#  ('Xavier Gens', 1),
#  ('Jason Eisener', 1),
#  ('David Schwimmer', 1),
#  ('Dave Meyers', 1),
#  ('Chris Sivertson', 1),
#  ('Michael Haneke', 1),
#  ('Sidney Lumet', 1),
#  ('Fred Savage', 1),
#  ('Russell Mulcahy', 1),
#  ('Michael Winterbottom', 1),
#  ('Stephen Hopkins', 1),
#  ('James Foley', 1),
#  ('Mark Helfrich', 1),
#  ('Jon Kasdan', 1),
#  ('Shari Springer Berman', 1),
#  ('Robert Pulcini', 1),
#  ('James Gray', 1),
#  ('Peter Hedges', 1),
#  ('Roland JoffÃ©', 1),
#  ('Amy Heckerling', 1),
#  ('Susanne Bier', 1),
#  ('Alastair Fothergill', 1),
#  ('Mark Linfield', 1),
#  ('Doug Lefler', 1),
#  ('Wong Kar-wai', 1),
#  ('Sylvain White', 1),
#  ('David Leland', 1),
#  ('Chris Rock', 1),
#  ('Peter Webber', 1),
#  ('Feng Xiaogang', 1),
#  ('Ben Garant', 1),
#  ('Ralph Zondag', 1),
#  ('Eric Leighton', 1),
#  ('David McNally', 1),
#  ('Ben Younger', 1),
#  ('Don Michael Paul', 1),
#  ('Mimi Leder', 1),
#  ('Paul Verhoeven', 1),
#  ('Mary Harron', 1),
#  ('Lars von Trier', 1),
#  ('Roger Spottiswoode', 1),
#  ('Antony Hoffman', 1),
#  ('Stephen T. Kay', 1),
#  ('Don Bluth', 1),
#  ('Gary Goldman', 1),
#  ('John Frankenheimer', 1),
#  ('Edward Norton', 1),
#  ('Jack Sholder', 1),
#  ('Christian Duguay', 1),
#  ('David Raynr', 1),
#  ('Douglas Aarniokoski', 1),
#  ('Davis Guggenheim', 1),
#  ('Bonnie Hunt', 1),
#  ('Uli Edel', 1),
#  ('Des McAnuff', 1),
#  ('Diane Keaton', 1),
#  ('Mary Lambert', 1)]

# %%
answer_ls.append(3)

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
cnt = Counter()
for item in data2[data2.profit > 0].director:
    temp = item.split('|') 
    for genre in temp:
        cnt[genre] += 1
cnt.most_common()
# Out:
# [('Ridley Scott', 12),
#  ('Steven Spielberg', 10),
#  ('Clint Eastwood', 10),
#  ('Steven Soderbergh', 10),
#  ('Shawn Levy', 9),
#  ('Tim Burton', 9),
#  ('Antoine Fuqua', 8),
#  ('Christopher Nolan', 8),
#  ('Peter Jackson', 8),
#  ('Michael Bay', 8),
#  ('Brett Ratner', 8),
#  ('Peter Farrelly', 8),
#  ('Robert Rodriguez', 8),
#  ('M. Night Shyamalan', 7),
#  ('Bobby Farrelly', 7),
#  ('Todd Phillips', 7),
#  ('Adam Shankman', 7),
#  ('Quentin Tarantino', 6),
#  ('Francis Lawrence', 6),
#  ('Adam McKay', 6),
#  ('Robert Zemeckis', 6),
#  ('Andy Fickman', 6),
#  ('David Fincher', 6),
#  ('Tim Story', 6),
#  ('Zack Snyder', 6),
#  ('Ron Howard', 6),
#  ('Sam Raimi', 6),
#  ('Joel Coen', 6),
#  ('Louis Leterrier', 6),
#  ('Dennis Dugan', 6),
#  ('Paul W.S. Anderson', 6),
#  ('Gore Verbinski', 6),
#  ('Peter Segal', 6),
#  ('Raja Gosnell', 6),
#  ('J.J. Abrams', 5),
#  ('Sam Mendes', 5),
#  ('Jaume Collet-Serra', 5),
#  ('F. Gary Gray', 5),
#  ('Guy Ritchie', 5),
#  ('Nancy Meyers', 5),
#  ('Guillermo del Toro', 5),
#  ('Bryan Singer', 5),
#  ('Doug Liman', 5),
#  ('Jon Favreau', 5),
#  ('Carlos Saldanha', 5),
#  ('Lasse HallstrÃ¶m', 5),
#  ('Roland Emmerich', 5),
#  ('Robert Luketic', 5),
#  ('Steve Carr', 5),
#  ('Tony Scott', 5),
#  ('Martin Scorsese', 5),
#  ('Danny Boyle', 5),
#  ('Jon Turteltaub', 5),
#  ('James Mangold', 5),
#  ('Oliver Stone', 5),
#  ('John Singleton', 5),
#  ('Marc Forster', 5),
#  ('Peter Berg', 5),
#  ('Alejandro GonzÃ¡lez IÃ±Ã¡rritu', 4),
#  ('Lana Wachowski', 4),
#  ('Lilly Wachowski', 4),
#  ('Chris Columbus', 4),
#  ('Olivier Megaton', 4),
#  ('Peyton Reed', 4),
#  ('Brad Bird', 4),
#  ('Matthew Vaughn', 4),
#  ('Rob Letterman', 4),
#  ('Tarsem Singh', 4),
#  ('Judd Apatow', 4),
#  ('John Erick Dowdle', 4),
#  ('Boaz Yakin', 4),
#  ('Anne Fletcher', 4),
#  ('Ken Kwapis', 4),
#  ('Wes Anderson', 4),
#  ('Phil Lord', 4),
#  ('Christopher Miller', 4),
#  ('Luke Greenfield', 4),
#  ('Eric Darnell', 4),
#  ('Rob Marshall', 4),
#  ('David Dobkin', 4),
#  ('Nicholas Stoller', 4),
#  ('Nick Cassavetes', 4),
#  ('Rob Minkoff', 4),
#  ('George Clooney', 4),
#  ('David Yates', 4),
#  ('David R. Ellis', 4),
#  ('Ethan Coen', 4),
#  ('David Twohy', 4),
#  ('Jason Reitman', 4),
#  ('Justin Lin', 4),
#  ('Donald Petrie', 4),
#  ('Tom McGrath', 4),
#  ('Edward Zwick', 4),
#  ('Andy Tennant', 4),
#  ('Garry Marshall', 4),
#  ('Jason Friedberg', 4),
#  ('Aaron Seltzer', 4),
#  ('Kevin Smith', 4),
#  ('Jay Roach', 4),
#  ('Andrew Adamson', 4),
#  ('Simon West', 4),
#  ('Keenen Ivory Wayans', 4),
#  ('John Moore', 4),
#  ('Rob Cohen', 4),
#  ('D.J. Caruso', 4),
#  ('Mark Waters', 4),
#  ('Malcolm D. Lee', 4),
#  ('Martin Campbell', 4),
#  ('Mikael HÃ¥fstrÃ¶m', 4),
#  ('Alexander Payne', 4),
#  ('Len Wiseman', 4),
#  ('Paul Greengrass', 4),
#  ('George Miller', 3),
#  ('Robert Schwentke', 3),
#  ('James Wan', 3),
#  ('Pierre Coffin', 3),
#  ('Pete Docter', 3),
#  ('Brad Peyton', 3),
#  ('Neill Blomkamp', 3),
#  ('Baltasar KormÃ¡kur', 3),
#  ('Tom Hooper', 3),
#  ('Paul Feig', 3),
#  ('Gavin Hood', 3),
#  ('Brian Helgeland', 3),
#  ('Steve Martino', 3),
#  ('Jonathan Levine', 3),
#  ('David Ayer', 3),
#  ('Neil Burger', 3),
#  ('Jonathan Liebesman', 3),
#  ('Matt Reeves', 3),
#  ('Marc Webb', 3),
#  ('Dean DeBlois', 3),
#  ('Darren Aronofsky', 3),
#  ('Frank Coraci', 3),
#  ('Will Gluck', 3),
#  ('Steve Pink', 3),
#  ('Thomas Carter', 3),
#  ('Randall Wallace', 3),
#  ('McG', 3),
#  ('John Lee Hancock', 3),
#  ('Ruben Fleischer', 3),
#  ('Chris Weitz', 3),
#  ('Stephen Sommers', 3),
#  ('Mark Neveldine', 3),
#  ('Brian Taylor', 3),
#  ('Conrad Vernon', 3),
#  ('Michael Mann', 3),
#  ('Kevin Macdonald', 3),
#  ('James McTeigue', 3),
#  ('NimrÃ³d Antal', 3),
#  ('Tom Tykwer', 3),
#  ('Rob Zombie', 3),
#  ('Peter Chelsom', 3),
#  ('Greg Mottola', 3),
#  ('Jonathan Mostow', 3),
#  ('Thor Freudenthal', 3),
#  ('Marc Lawrence', 3),
#  ('Chris Renaud', 3),
#  ('Sylvester Stallone', 3),
#  ('Chris Sanders', 3),
#  ('Lee Unkrich', 3),
#  ('Paul Weitz', 3),
#  ('Mike Mitchell', 3),
#  ('Joe Carnahan', 3),
#  ('Ben Affleck', 3),
#  ('Jon M. Chu', 3),
#  ('Harald Zwart', 3),
#  ('Roman Polanski', 3),
#  ('Paul Haggis', 3),
#  ('Alexandre Aja', 3),
#  ('Tyler Perry', 3),
#  ('Ben Stiller', 3),
#  ('Dominic Sena', 3),
#  ('Gary Fleder', 3),
#  ('Brian Robbins', 3),
#  ('Andrzej Bartkowiak', 3),
#  ('Jesse Dylan', 3),
#  ('Tim Hill', 3),
#  ('Joe Johnston', 3),
#  ('Andrew Stanton', 3),
#  ('David Frankel', 3),
#  ('Seth Gordon', 3),
#  ('Woody Allen', 3),
#  ('Bill Condon', 3),
#  ('Wes Craven', 3),
#  ('Stephen Daldry', 3),
#  ('Joe Wright', 3),
#  ('Kelly Asbury', 3),
#  ('David Cronenberg', 3),
#  ('Chris Wedge', 3),
#  ('Barry Sonnenfeld', 3),
#  ('Steven Brill', 3),
#  ('Joel Schumacher', 3),
#  ('Jeff Tremaine', 3),
#  ('Ang Lee', 3),
#  ('Stephen Frears', 3),
#  ('Wolfgang Petersen', 3),
#  ('Alan Taylor', 2),
#  ('Kyle Balda', 2),
#  ('Joss Whedon', 2),
#  ('Kenneth Branagh', 2),
#  ('Christopher McQuarrie', 2),
#  ('Seth MacFarlane', 2),
#  ('Wes Ball', 2),
#  ('Elizabeth Banks', 2),
#  ('Breck Eisner', 2),
#  ('Tim Johnson', 2),
#  ('Todd Haynes', 2),
#  ('John Wells', 2),
#  ('Denis Villeneuve', 2),
#  ('Josh Trank', 2),
#  ('Glenn Ficarra', 2),
#  ('John Requa', 2),
#  ('George Tillman, Jr.', 2),
#  ('Genndy Tartakovsky', 2),
#  ('Jessie Nelson', 2),
#  ('Gil Kenan', 2),
#  ('Sean Anders', 2),
#  ('Mark Osborne', 2),
#  ('Scott Cooper', 2),
#  ('Simon Curtis', 2),
#  ('Jason Moore', 2),
#  ('Camille Delamarre', 2),
#  ('Jonathan Demme', 2),
#  ('Mike Binder', 2),
#  ('James Gunn', 2),
#  ('Joe Russo', 2),
#  ('Anthony Russo', 2),
#  ('Chris Williams', 2),
#  ('Luc Besson', 2),
#  ('Jake Kasdan', 2),
#  ('Simon J. Smith', 2),
#  ('Noam Murro', 2),
#  ('Phillip Noyce', 2),
#  ('Scott Waugh', 2),
#  ('Anthony Stacchi', 2),
#  ('Steven Quale', 2),
#  ('Shana Feste', 2),
#  ('Miguel Arteta', 2),
#  ('Craig Gillespie', 2),
#  ('Charles Martin Smith', 2),
#  ('James Bobin', 2),
#  ('Rupert Wyatt', 2),
#  ('James Cameron', 2),
#  ('Burr Steers', 2),
#  ('Alex Proyas', 2),
#  ('Duncan Jones', 2),
#  ('P.J. Hogan', 2),
#  ('Jim Sheridan', 2),
#  ('Nora Ephron', 2),
#  ('Betty Thomas', 2),
#  ('Gary Winick', 2),
#  ('Lee Daniels', 2),
#  ('David S. Goyer', 2),
#  ('John Hamburg', 2),
#  ('Paul McGuigan', 2),
#  ('Kevin Greutert', 2),
#  ('Harold Ramis', 2),
#  ('Patrick Lussier', 2),
#  ('Walt Becker', 2),
#  ('Lone Scherfig', 2),
#  ('Marcus Nispel', 2),
#  ('Joseph Kosinski', 2),
#  ('Byron Howard', 2),
#  ('Michael Apted', 2),
#  ('Mike Newell', 2),
#  ('Albert Hughes', 2),
#  ('Allen Hughes', 2),
#  ('David Slade', 2),
#  ('Scott Stewart', 2),
#  ('Michael Patrick King', 2),
#  ('John Luessenhop', 2),
#  ('Roger Michell', 2),
#  ('Michael Lembeck', 2),
#  ('John Madden', 2),
#  ('Brian Levant', 2),
#  ('Neil LaBute', 2),
#  ('Tom Dey', 2),
#  ('Eric Brevig', 2),
#  ('Roger Kumble', 2),
#  ('David Silverman', 2),
#  ('Vicky Jenson', 2),
#  ('Baz Luhrmann', 2),
#  ('John A. Davis', 2),
#  ('Cameron Crowe', 2),
#  ('Victor Salva', 2),
#  ('Lee Tamahori', 2),
#  ('Iain Softley', 2),
#  ('Ivan Reitman', 2),
#  ('Frank Oz', 2),
#  ('John Stockwell', 2),
#  ('Catherine Hardwicke', 2),
#  ('Phyllida Lloyd', 2),
#  ('Timur Bekmambetov', 2),
#  ('Kathryn Bigelow', 2),
#  ('Scott Derrickson', 2),
#  ('Gabriele Muccino', 2),
#  ('David Gordon Green', 2),
#  ('Mathieu Kassovitz', 2),
#  ('Martin McDonagh', 2),
#  ('Jon Hurwitz', 2),
#  ('Hayden Schlossberg', 2),
#  ('Jimmy Hayward', 2),
#  ('Gus Van Sant', 2),
#  ('Gina Prince-Bythewood', 2),
#  ('Kirk De Micco', 2),
#  ('Andrew Niccol', 2),
#  ('John Lasseter', 2),
#  ('Brad Furman', 2),
#  ('Bennett Miller', 2),
#  ('Chris Miller', 2),
#  ('Michel Gondry', 2),
#  ('David Bowers', 2),
#  ('Craig Brewer', 2),
#  ('Henry Joost', 2),
#  ('Ariel Schulman', 2),
#  ('John Whitesell', 2),
#  ('Salim Akil', 2),
#  ('George Lucas', 2),
#  ('Wayne Wang', 2),
#  ('Spike Jonze', 2),
#  ('Carl Franklin', 2),
#  ('Denzel Washington', 2),
#  ('Tony Gilroy', 2),
#  ('David O. Russell', 2),
#  ('Gary Ross', 2),
#  ('Kirk Jones', 2),
#  ('Larry Charles', 2),
#  ('Peter Lord', 2),
#  ('Mark Steven Johnson', 2),
#  ('David Zucker', 2),
#  ('Bille Woodruff', 2),
#  ('Richard Linklater', 2),
#  ('Clark Johnson', 2),
#  ('John Woo', 2),
#  ('Nigel Cole', 2),
#  ('Chris Buck', 2),
#  ('Alfonso CuarÃ³n', 2),
#  ('Brad Anderson', 2),
#  ('Taylor Hackford', 2),
#  ('Sofia Coppola', 2),
#  ('Mark Dindal', 2),
#  ('Nick Park', 2),
#  ('Rob Reiner', 2),
#  ('Kevin Rodney Sullivan', 2),
#  ('James Wong', 2),
#  ('Mel Gibson', 2),
#  ('Darren Lynn Bousman', 2),
#  ('Takashi Shimizu', 2),
#  ('Richard Loncraine', 2),
#  ('Danny Leiner', 2),
#  ('Mike Nichols', 2),
#  ('Michael Moore', 2),
#  ('Jay Russell', 2),
#  ('Richard LaGravenese', 2),
#  ('Kevin Lima', 2),
#  ('Colin Trevorrow', 1),
#  ('Alex Garland', 1),
#  ('Sam Taylor-Johnson', 1),
#  ('Tom McCarthy', 1),
#  ('Lenny Abrahamson', 1),
#  ('Peter Sohn', 1),
#  ('John Crowley', 1),
#  ('Lee Toland Krieger', 1),
#  ('Ilya Naishuller', 1),
#  ('Jake Schreier', 1),
#  ('Ericson Core', 1),
#  ('Aleksander Bach', 1),
#  ('Ryan Coogler', 1),
#  ('Peter Landesman', 1),
#  ('John Francis Daley', 1),
#  ('Jonathan M. Goldstein', 1),
#  ('Joel Edgerton', 1),
#  ('Jocelyn Moorhouse', 1),
#  ('Ari Sandel', 1),
#  ('Ciaran Foy', 1),
#  ('Doug Ellin', 1),
#  ('Jeremy Garelick', 1),
#  ('Michael Dougherty', 1),
#  ('Dean Israelite', 1),
#  ('Gregory Jacobs', 1),
#  ('Gregory Plotkin', 1),
#  ('Billy Ray', 1),
#  ('Paul Tibbitt', 1),
#  ('Leigh Whannell', 1),
#  ('Nicholas Hytner', 1),
#  ('David M. Rosenthal', 1),
#  ('Etan Cohen', 1),
#  ('Sarah Gavron', 1),
#  ('Max Joseph', 1),
#  ('Chad Stahelski', 1),
#  ('David Leitch', 1),
#  ('Don Hall', 1),
#  ('Morten Tyldum', 1),
#  ('Dan Gilroy', 1),
#  ('Gareth Edwards', 1),
#  ('Robert Stromberg', 1),
#  ('Roger Donaldson', 1),
#  ('Stiles White', 1),
#  ('Patrick Hughes', 1),
#  ('Sergey Bodrov', 1),
#  ('James Marsh', 1),
#  ('Gary Shore', 1),
#  ('Scott Frank', 1),
#  ('Paul King', 1),
#  ('James DeMonaco', 1),
#  ('Vic Armstrong', 1),
#  ('R.J. Cutler', 1),
#  ('Trish Sie', 1),
#  ('Josh Boone', 1),
#  ('JosÃ© Padilha', 1),
#  ('Wally Pfister', 1),
#  ('Angelina Jolie', 1),
#  ('Ava DuVernay', 1),
#  ('Michael Hoffman', 1),
#  ('Theodore Melfi', 1),
#  ('Graham Annable', 1),
#  ('Brian A Miller', 1),
#  ('Roberts Gannaway', 1),
#  ('Sam Miller', 1),
#  ('John R. Leonetti', 1),
#  ('Stuart Beattie', 1),
#  ('Tom Gormican', 1),
#  ('Ben Falcone', 1),
#  ('Christopher Spencer', 1),
#  ('GrÃ©gory Levasseur', 1),
#  ('Andrew Erwin', 1),
#  ('Jon Erwin', 1),
#  ('Dave Green', 1),
#  ('Harold Cronk', 1),
#  ('Matt Bettinelli-Olpin', 1),
#  ('Tyler Gillett', 1),
#  ('Patrick Tatopoulos', 1),
#  ('Bob Peterson', 1),
#  ('Shane Acker', 1),
#  ('Ron Clements', 1),
#  ('John Musker', 1),
#  ('Henry Selick', 1),
#  ('Richard Kelly', 1),
#  ('Hoyt Yeatman', 1),
#  ('Ricky Gervais', 1),
#  ('Matthew Robinson', 1),
#  ('Peter Billingsley', 1),
#  ('Karyn Kusama', 1),
#  ('Phil Traill', 1),
#  ('Christian Alvart', 1),
#  ('Michael Spierig', 1),
#  ('Peter Spierig', 1),
#  ('Brandon Camp', 1),
#  ('Rajkumar Hirani', 1),
#  ('Grant Heslov', 1),
#  ('Jorge Blanco', 1),
#  ('Javier Abad', 1),
#  ('Marcos MartÃ\xadnez', 1),
#  ('Troy Duffy', 1),
#  ('John Schultz', 1),
#  ('Olatunde Osunsanmi', 1),
#  ('Mike Judge', 1),
#  ('Daniel Barber', 1),
#  ('Steve Shill', 1),
#  ('Jonas Elmer', 1),
#  ('Stewart Hendler', 1),
#  ('Toby Wilkins', 1),
#  ('Nathan Greno', 1),
#  ('Florian Henckel von Donnersmarck', 1),
#  ('Ethan Maniquis', 1),
#  ('Ryan Murphy', 1),
#  ('Anand Tucker', 1),
#  ('Alan Poul', 1),
#  ('Josh Gordon', 1),
#  ('Will Speck', 1),
#  ('Troy Nixey', 1),
#  ('Samuel Bayer', 1),
#  ('Susanna White', 1),
#  ('Steve Antin', 1),
#  ('Nanette Burstein', 1),
#  ('Greg Berlanti', 1),
#  ('Colin Strause', 1),
#  ('Greg Strause', 1),
#  ('Jim Field Smith', 1),
#  ('Anthony Bell', 1),
#  ('Ben Gluck', 1),
#  ('David Lynch', 1),
#  ('Sharon Maguire', 1),
#  ('Gary Trousdale', 1),
#  ('Kirk Wise', 1),
#  ('J.B. Rogers', 1),
#  ('Ted Demme', 1),
#  ('Jean-Jacques Annaud', 1),
#  ('Joel Gallen', 1),
#  ('Alejandro AmenÃ¡bar', 1),
#  ('Lawrence Guterman', 1),
#  ('Chris Nahon', 1),
#  ('Jerry Zucker', 1),
#  ('Robert Altman', 1),
#  ('James Isaac', 1),
#  ('John Dahl', 1),
#  ('Simon Wincer', 1),
#  ('Bill Paxton', 1),
#  ('Dennie Gordon', 1),
#  ('John Boorman', 1),
#  ("Pat O'Connor", 1),
#  ('Gregory Poirier', 1),
#  ('Rob Pritts', 1),
#  ('Francine McDougall', 1),
#  ('DJ Pooh', 1),
#  ('Pierre Morel', 1),
#  ('John Stevenson', 1),
#  ('Loveleen Tandan', 1),
#  ('Tom Vaughan', 1),
#  ('Mark Herman', 1),
#  ('Jeff Wadlow', 1),
#  ('Pete Travis', 1),
#  ('David Wain', 1),
#  ('Peter Sollett', 1),
#  ('Fred Wolf', 1),
#  ('David Hackl', 1),
#  ('Jon Avnet', 1),
#  ('Bryan Bertino', 1),
#  ('Chris Carter', 1),
#  ('John Patrick Shanley', 1),
#  ('Paul Weiland', 1),
#  ('David Moreau', 1),
#  ('Xavier Palud', 1),
#  ('Michael McCullers', 1),
#  ('Howard Deutch', 1),
#  ('Jennifer Flackett', 1),
#  ('Mark Levin', 1),
#  ('Anthony Leondis', 1),
#  ('Nicolas Winding Refn', 1),
#  ('Jennifer Yuh', 1),
#  ('Brad Lewis', 1),
#  ('Terrence Malick', 1),
#  ('Michel Hazanavicius', 1),
#  ('George Nolfi', 1),
#  ('Tom Hanks', 1),
#  ('Mark Mylod', 1),
#  ('Chris Gorak', 1),
#  ('Tate Taylor', 1),
#  ('Christian E. Christiansen', 1),
#  ('Oliver Parker', 1),
#  ('Daniel Barnz', 1),
#  ('Todd Strauss-Schulson', 1),
#  ('Gonzalo LÃ³pez-Gallego', 1),
#  ('John Michael McDonagh', 1),
#  ('Jesse Peretz', 1),
#  ('Jason Winer', 1),
#  ('Alister Grierson', 1),
#  ('Douglas McGrath', 1),
#  ('Sean McNamara', 1),
#  ('Joe Nussbaum', 1),
#  ('Benny Chan', 1),
#  ('Corey Yuen Kwai', 1),
#  ('Curtis Hanson', 1),
#  ('Joel Zwick', 1),
#  ('Stuart Baird', 1),
#  ('Steve Beck', 1),
#  ('Lorna Cook', 1),
#  ('Chuck Russell', 1),
#  ('Julie Taymor', 1),
#  ('Barbet Schroeder', 1),
#  ('Simon Wells', 1),
#  ('Adrian Lyne', 1),
#  ('Michael Rymer', 1),
#  ('Marcus Raboy', 1),
#  ('Robin Budd', 1),
#  ('Donovan Cook', 1),
#  ('Mark Romanek', 1),
#  ('Mark Pellington', 1),
#  ('Jonathan Frakes', 1),
#  ('Rick Rosenthal', 1),
#  ('Tamra Davis', 1),
#  ('Charles Stone III', 1),
#  ('Kevin Bray', 1),
#  ('MÃ¥ns MÃ¥rlind', 1),
#  ('BjÃ¶rn Stein', 1),
#  ('Mark Andrews', 1),
#  ('Steve Purcell', 1),
#  ('Brenda Chapman', 1),
#  ('Rupert Sanders', 1),
#  ('Mike Thurmeier', 1),
#  ('Juan Antonio Bayona', 1),
#  ('Rich Moore', 1),
#  ('Stephen Chbosky', 1),
#  ('Drew Goddard', 1),
#  ('Peter Ramsey', 1),
#  ('Michael Sucsy', 1),
#  ('Rian Johnson', 1),
#  ('Scott Speer', 1),
#  ('Mike McCoy', 1),
#  ('Nima Nourizadeh', 1),
#  ('John Hillcoat', 1),
#  ('Jeff Newitt', 1),
#  ('Stephen St. Leger', 1),
#  ('James Mather', 1),
#  ('James Watkins', 1),
#  ('Daniel Espinosa', 1),
#  ('Asger Leth', 1),
#  ('John Gulager', 1),
#  ('Ole Bornedal', 1),
#  ('Michael J. Bassett', 1),
#  ('Andrew Dominik', 1),
#  ('Nicholas Jarecki', 1),
#  ('Dustin Hoffman', 1),
#  ('Sam Fell', 1),
#  ('Chris Butler', 1),
#  ('Brian Klugman', 1),
#  ('Lee Sternthal', 1),
#  ('Dan Cutforth', 1),
#  ('Jane Lipsitz', 1),
#  ('Tom Shadyac', 1),
#  ('Richard Curtis', 1),
#  ('Stephen Norrington', 1),
#  ('Steve Trenbirth', 1),
#  ('Terry Zwigoff', 1),
#  ('Peter Howitt', 1),
#  ('Jan de Bont', 1),
#  ('Rob Schmidt', 1),
#  ('Peter Weir', 1),
#  ('Jon Amiel', 1),
#  ('Charles Herman-Wurmfeld', 1),
#  ('Anthony Minghella', 1),
#  ('Ronny Yu', 1),
#  ('Kevin Costner', 1),
#  ('Jim Fall', 1),
#  ('Lawrence Kasdan', 1),
#  ('Patty Jenkins', 1),
#  ('Troy Miller', 1),
#  ('Uwe Boll', 1),
#  ('Mike Tollin', 1),
#  ('FranÃ§ois Ozon', 1),
#  ('Christopher Guest', 1),
#  ('Christine Jeffs', 1),
#  ('Jennifer Lee', 1),
#  ('Shane Black', 1),
#  ('Steve McQueen', 1),
#  ('Dan Scanlon', 1),
#  ('Tommy Wirkola', 1),
#  ('Jean-Marc VallÃ©e', 1),
#  ('Klay Hall', 1),
#  ('Harmony Korine', 1),
#  ('Fede Alvarez', 1),
#  ('Derek Cianfrance', 1),
#  ('Kimberly Peirce', 1),
#  ('John Carney', 1),
#  ('Ken Scott', 1),
#  ('Seth Rogen', 1),
#  ('Evan Goldberg', 1),
#  ('Mike Flanagan', 1),
#  ('David Soren', 1),
#  ('Andy Muschietti', 1),
#  ('Rusty Cundieff', 1),
#  ('James Duffy', 1),
#  ('Griffin Dunne', 1),
#  ('Patrik Forsberg', 1),
#  ('Will Graham', 1),
#  ('Jonathan van Tulleken', 1),
#  ('Scott Moore', 1),
#  ('Jon Lucas', 1),
#  ('Callan Brunker', 1),
#  ('Amma Asante', 1),
#  ('Cody Cameron', 1),
#  ('Kris Pearn', 1),
#  ('Giuseppe Tornatore', 1),
#  ('Jeff Nichols', 1),
#  ('Jonathan Teplitzky', 1),
#  ('Neil Nightingale', 1),
#  ('Barry Cook', 1),
#  ('Ric Roman Waugh', 1),
#  ('David E. Talbert', 1),
#  ('Christopher B. Landon', 1),
#  ('Joshua Michael Stern', 1),
#  ('Anthony Silverston', 1),
#  ('Ed Gass-Donnelly', 1),
#  ('Oliver Hirschbiegel', 1),
#  ('Fyodor Bondarchuk', 1),
#  ('Frank Miller', 1),
#  ('Garth Jennings', 1),
#  ('Rob Bowman', 1),
#  ('Mike Johnson', 1),
#  ('Steve Box', 1),
#  ('Angela Robinson', 1),
#  ('Cory Edwards', 1),
#  ('Todd Edwards', 1),
#  ('Tony Leech', 1),
#  ('John Polson', 1),
#  ('Sydney Pollack', 1),
#  ('Terry Gilliam', 1),
#  ('Florent-Emilio Siri', 1),
#  ('Jay Chandrasekhar', 1),
#  ('Stephen Gaghan', 1),
#  ('Frederik Du Chau', 1),
#  ('Andrew Douglas', 1),
#  ('Dean Parisot', 1),
#  ('Jean-FranÃ§ois Richet', 1),
#  ('Jim Jarmusch', 1),
#  ('George A. Romero', 1),
#  ('Rupert Wainwright', 1),
#  ('Clare Kilner', 1),
#  ('Richard Shepard', 1),
#  ('Fernando Meirelles', 1),
#  ('Geoffrey Sax', 1),
#  ('Stephen Kay', 1),
#  ('Joe Ranft', 1),
#  ('Spike Lee', 1),
#  ('Karey Kirkpatrick', 1),
#  ('Frank Marshall', 1),
#  ('Christophe Gans', 1),
#  ('Stefen Fangmeier', 1),
#  ('Alejandro Agresti', 1),
#  ("Matthew O'Callaghan", 1),
#  ('Jared Hess', 1),
#  ('Jonathan Dayton', 1),
#  ('Valerie Faris', 1),
#  ('Greg Coolidge', 1),
#  ('Roger Allers', 1),
#  ('Jill Culton', 1),
#  ('Steve Oedekerk', 1),
#  ('Chris Noonan', 1),
#  ('John Bonito', 1),
#  ('Liz Friedlander', 1),
#  ('Elizabeth Allen Rosenbaum', 1),
#  ('Richard Donner', 1),
#  ('Richard Eyre', 1),
#  ('Barry Levinson', 1),
#  ('Renny Harlin', 1),
#  ('Sanjay Gadhvi', 1),
#  ('Glen Morgan', 1),
#  ('Phil Joanou', 1),
#  ('Mira Nair', 1),
#  ('Rachid Bouchareb', 1),
#  ('William Brent Bell', 1),
#  ('Doug Atchison', 1),
#  ('Eric Bress', 1),
#  ('J. Mackye Gruber', 1),
#  ('Alexander Witt', 1),
#  ('Brad Silberling', 1),
#  ('Peter Hewitt', 1),
#  ('Bibo Bergeron', 1),
#  ('Stephen Hillenburg', 1),
#  ('Mark Rosman', 1),
#  ('Rawson Marshall Thurber', 1),
#  ('Jonathan Hensleigh', 1),
#  ('David Koepp', 1),
#  ('Don Mancini', 1),
#  ('Terry George', 1),
#  ('Trey Parker', 1),
#  ('Sara Sugarman', 1),
#  ('Guy Ferland', 1),
#  ('Joseph Ruben', 1),
#  ('Nick Hamm', 1),
#  ('Joseph Kahn', 1),
#  ("Gavin O'Connor", 1),
#  ('Kevin Allen', 1),
#  ('Christopher Erskin', 1),
#  ('Jan Pinkava', 1),
#  ('Frank Darabont', 1),
#  ('Sean Penn', 1),
#  ('GÃ¡bor CsupÃ³', 1),
#  ('Paul Thomas Anderson', 1),
#  ('Raman Hui', 1),
#  ('Steve Hickner', 1),
#  ('Stephen J. Anderson', 1),
#  ('Kevin Munroe', 1),
#  ('Juan Carlos Fresnadillo', 1),
#  ('Steve Bendelack', 1),
#  ('Bruce A. Evans', 1),
#  ('Robert Redford', 1),
#  ('Kirsten Sheridan', 1),
#  ('Philip G. Atwell', 1),
#  ('Mennan Yapo', 1),
#  ('Scott Hicks', 1),
#  ('Ash Brannon', 1),
#  ('Xavier Gens', 1),
#  ('David Schwimmer', 1),
#  ('Eli Roth', 1),
#  ('Dave Meyers', 1),
#  ('Julian Jarrold', 1),
#  ('Shekhar Kapur', 1),
#  ('Sidney Lumet', 1),
#  ('Fred Savage', 1),
#  ('Russell Mulcahy', 1),
#  ('Michael Winterbottom', 1),
#  ('Stephen Hopkins', 1),
#  ('James Foley', 1),
#  ('Mark Helfrich', 1),
#  ('Jon Kasdan', 1),
#  ('Shari Springer Berman', 1),
#  ('Robert Pulcini', 1),
#  ('James Gray', 1),
#  ('Peter Hedges', 1),
#  ('Alastair Fothergill', 1),
#  ('Mark Linfield', 1),
#  ('Wong Kar-wai', 1),
#  ('Sylvain White', 1),
#  ('Chris Rock', 1),
#  ('Peter Webber', 1),
#  ('Feng Xiaogang', 1),
#  ('Ben Garant', 1),
#  ('Ralph Zondag', 1),
#  ('Eric Leighton', 1),
#  ('David McNally', 1),
#  ('Ben Younger', 1),
#  ('Gregory Hoblit', 1),
#  ('Mimi Leder', 1),
#  ('Paul Verhoeven', 1),
#  ('Mary Harron', 1),
#  ('Lars von Trier', 1),
#  ('Roger Spottiswoode', 1),
#  ('Jonathan Lynn', 1),
#  ('William Friedkin', 1),
#  ('Robert Iscove', 1),
#  ('Edward Norton', 1),
#  ('Bonnie Hunt', 1)]

# %%
answer_ls.append(4)

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
cnt = Counter()
for i in range(0,len(data2)):
    temp = data2.iloc[i]['director'].split('|') 
    for director in temp:
        #print(i, director, data2.iloc[i].profit, data2.iloc[i].original_title)
        cnt[director] += data2.iloc[i].profit
cnt.most_common()
# Out:
# [('Peter Jackson', 5202593685),
#  ('David Yates', 3379295625),
#  ('Christopher Nolan', 3162548502),
#  ('J.J. Abrams', 2839169916),
#  ('Michael Bay', 2760938960),
#  ('James Cameron', 2548546718),
#  ('Francis Lawrence', 2476979588),
#  ('Pierre Coffin', 2452006832),
#  ('Steven Spielberg', 2449700791),
#  ('Joss Whedon', 2424593677),
#  ('Gore Verbinski', 2271362290),
#  ('Sam Raimi', 2254066354),
#  ('Lee Unkrich', 2081614145),
#  ('Ridley Scott', 2044035909),
#  ('Andrew Adamson', 1957706346),
#  ('Chris Columbus', 1906968952),
#  ('Carlos Saldanha', 1882719105),
#  ('Tim Burton', 1801663457),
#  ('Eric Darnell', 1755054393),
#  ('Sam Mendes', 1710352791),
#  ('Tom McGrath', 1705388064),
#  ('Pete Docter', 1682867609),
#  ('Chris Renaud', 1648116186),
#  ('James Wan', 1620441367),
#  ('Brad Bird', 1581913958),
#  ('Conrad Vernon', 1578269902),
#  ('Shawn Levy', 1515787063),
#  ('Justin Lin', 1472947074),
#  ('Steven Soderbergh', 1450928588),
#  ('Ron Howard', 1379257991),
#  ('Bill Condon', 1376664544),
#  ('Colin Trevorrow', 1363528810),
#  ('Kyle Balda', 1361571278),
#  ('Clint Eastwood', 1329766334),
#  ('Roland Emmerich', 1310587076),
#  ('Todd Phillips', 1279393447),
#  ('George Lucas', 1266398328),
#  ('Alfonso CuarÃ³n', 1265157010),
#  ('Chris Buck', 1188263522),
#  ('Raja Gosnell', 1188104000),
#  ('M. Night Shyamalan', 1152548638),
#  ('Rob Marshall', 1143605066),
#  ('Steve Martino', 1141615909),
#  ('Andrew Stanton', 1136076938),
#  ('Jennifer Lee', 1124219009),
#  ('Marc Webb', 1096156023),
#  ('Chris Miller', 1063945642),
#  ('Jon Favreau', 1057296331),
#  ('Quentin Tarantino', 1036139583),
#  ('Shane Black', 1015439994),
#  ('Zack Snyder', 992937193),
#  ('David Fincher', 987983520),
#  ('Kelly Asbury', 966114729),
#  ('Jay Roach', 956344409),
#  ('Chris Weitz', 954062326),
#  ('Mike Mitchell', 906666117),
#  ('David Silverman', 899885107),
#  ('Nancy Meyers', 893677472),
#  ('Mike Newell', 890683287),
#  ('Lana Wachowski', 874004266),
#  ('Lilly Wachowski', 874004266),
#  ('Dean DeBlois', 859773334),
#  ('Doug Liman', 854203108),
#  ('Phil Lord', 850176100),
#  ('Christopher Miller', 850176100),
#  ('Chris Sanders', 845829214),
#  ('Brett Ratner', 843419041),
#  ('Tom Hooper', 829212842),
#  ('Marc Forster', 817521590),
#  ('Robert Zemeckis', 813123904),
#  ('Bryan Singer', 811212100),
#  ('Martin Scorsese', 802194907),
#  ('Mike Thurmeier', 782244782),
#  ('Dennis Dugan', 774026753),
#  ('Ang Lee', 761420806),
#  ('Guy Ritchie', 758085675),
#  ('Jon Turteltaub', 751201254),
#  ('Peyton Reed', 745340963),
#  ('Kenneth Branagh', 732015467),
#  ('Peter Berg', 721181428),
#  ('Rob Letterman', 716338428),
#  ('Olivier Megaton', 708858133),
#  ('Vicky Jenson', 708089482),
#  ('Barry Sonnenfeld', 706867642),
#  ('John Lasseter', 701835545),
#  ('Christopher McQuarrie', 690670734),
#  ('Matt Reeves', 688109639),
#  ('Paul Greengrass', 682493340),
#  ('Chris Wedge', 678380764),
#  ('Tim Story', 678087416),
#  ('Gary Ross', 677547137),
#  ('David Slade', 675997320),
#  ('James Mangold', 674085743),
#  ('Martin Campbell', 671862395),
#  ('Brad Peyton', 664667356),
#  ('Mel Gibson', 662074710),
#  ('Phyllida Lloyd', 659798336),
#  ('Genndy Tartakovsky', 659559147),
#  ('Paul W.S. Anderson', 655874490),
#  ('Seth MacFarlane', 647231921),
#  ('Chris Williams', 647085437),
#  ('Matthew Vaughn', 640971176),
#  ('Raman Hui', 638958165),
#  ('Jonathan Liebesman', 635666756),
#  ('Alejandro GonzÃ¡lez IÃ±Ã¡rritu', 633923618),
#  ('James Gunn', 629751387),
#  ('Joe Russo', 621197940),
#  ('Anthony Russo', 621197940),
#  ('Joel Coen', 616968145),
#  ('Stephen Sommers', 602739766),
#  ('Alan Taylor', 595368537),
#  ('Andy Tennant', 585953885),
#  ('Rob Cohen', 580154301),
#  ('Robert Stromberg', 578410378),
#  ('Darren Aronofsky', 571450089),
#  ('Wes Ball', 564576787),
#  ('Bob Peterson', 556342744),
#  ('Wolfgang Petersen', 549841306),
#  ('Danny Boyle', 548659594),
#  ('Peter Segal', 545449931),
#  ('Dan Scanlon', 543559607),
#  ('Paul Feig', 542223922),
#  ('Michael Patrick King', 538600478),
#  ('Mark Osborne', 535315810),
#  ('George Miller', 533178428),
#  ('Sam Taylor-Johnson', 529651467),
#  ('Anne Fletcher', 526509398),
#  ('David Frankel', 526362906),
#  ('Adam McKay', 517576455),
#  ('Jennifer Yuh', 515692281),
#  ('Joe Johnston', 514454033),
#  ('Ethan Coen', 512027330),
#  ('John Stevenson', 501744560),
#  ('Robert Rodriguez', 496768969),
#  ('Antoine Fuqua', 496376048),
#  ('Byron Howard', 491774930),
#  ('Adam Shankman', 486562773),
#  ('Len Wiseman', 482382796),
#  ('Edward Zwick', 479612124),
#  ('Kirk De Micco', 476979273),
#  ('Jan Pinkava', 473722818),
#  ('Don Hall', 471565443),
#  ('Keenen Ivory Wayans', 468922045),
#  ('McG', 461179698),
#  ('Guillermo del Toro', 456999810),
#  ('Robert Luketic', 439591681),
#  ('Garry Marshall', 434014880),
#  ('Peter Farrelly', 433240078),
#  ('Luc Besson', 430254288),
#  ('Tim Hill', 427612737),
#  ('John Woo', 420286182),
#  ('Judd Apatow', 417839316),
#  ('Steve Carr', 414906672),
#  ('F. Gary Gray', 413972930),
#  ('Bobby Farrelly', 406801090),
#  ('Neill Blomkamp', 405029579),
#  ('Rupert Wyatt', 404031315),
#  ('Simon West', 402421114),
#  ('Nicholas Stoller', 399269922),
#  ('Joseph Kosinski', 396231335),
#  ('Tom Shadyac', 394895235),
#  ('Jason Reitman', 391814120),
#  ('Catherine Hardwicke', 391190744),
#  ('Sylvester Stallone', 389435816),
#  ('Neil Burger', 385512367),
#  ('John Moore', 385021803),
#  ('Andy Fickman', 380448412),
#  ('David O. Russell', 380101390),
#  ('Harald Zwart', 379213630),
#  ('Simon J. Smith', 379146671),
#  ('Nick Cassavetes', 375344067),
#  ('Gareth Edwards', 369076069),
#  ('Gabriele Muccino', 365244986),
#  ('Joel Zwick', 363744044),
#  ('Loveleen Tandan', 362910544),
#  ('Lasse HallstrÃ¶m', 361144542),
#  ('Brad Lewis', 359852396),
#  ('Larry Charles', 357952277),
#  ('Betty Thomas', 354710811),
#  ('Kevin Lima', 354099423),
#  ('Mark Andrews', 353983207),
#  ('Steve Purcell', 353983207),
#  ('Brenda Chapman', 353983207),
#  ('Jaume Collet-Serra', 345520013),
#  ('Jonathan Mostow', 343111187),
#  ('Rob Minkoff', 343066126),
#  ('Nick Park', 342287396),
#  ('Joe Ranft', 341983149),
#  ('Jon M. Chu', 339884147),
#  ('Henry Joost', 338521810),
#  ('Ariel Schulman', 338521810),
#  ('David Dobkin', 338508402),
#  ('Alex Proyas', 332681278),
#  ('Alexander Payne', 332234956),
#  ('Nathan Greno', 331794936),
#  ('John Singleton', 329390637),
#  ('Tarsem Singh', 325601608),
#  ('Ben Affleck', 320469963),
#  ('Mark Waters', 310391771),
#  ('Tim Johnson', 308890347),
#  ('Donald Petrie', 307986622),
#  ('Tony Scott', 307816918),
#  ('D.J. Caruso', 306316571),
#  ('Rich Moore', 306222889),
#  ('David Zucker', 305935837),
#  ('Seth Gordon', 304698707),
#  ('Robert Schwentke', 298938962),
#  ('Paul Weitz', 296134283),
#  ('John Lee Hancock', 294169892),
#  ('Josh Boone', 293151265),
#  ('Baz Luhrmann', 292307855),
#  ('Frank Coraci', 290707563),
#  ('Peter Chelsom', 290190043),
#  ('Elizabeth Banks', 284945182),
#  ('Darren Lynn Bousman', 283229448),
#  ('Scott Derrickson', 278310327),
#  ('Michael Apted', 274487404),
#  ('Bibo Bergeron', 273707746),
#  ('Jake Kasdan', 265584152),
#  ('Jeff Tremaine', 257892561),
#  ('J.B. Rogers', 257553595),
#  ('Baltasar KormÃ¡kur', 257467995),
#  ('Sharon Maguire', 256929795),
#  ('Lee Tamahori', 256062835),
#  ('David R. Ellis', 253164703),
#  ('Will Gluck', 251257886),
#  ('John R. Leonetti', 248773813),
#  ('Brian A Miller', 248586800),
#  ('Louis Leterrier', 246091791),
#  ('Michael Mann', 244130185),
#  ('Sean Anders', 243064116),
#  ('Wes Anderson', 238584160),
#  ('Peter Lord', 238172925),
#  ('Paul Tibbitt', 237594032),
#  ('Mikael HÃ¥fstrÃ¶m', 237121418),
#  ('Mark Dindal', 233760352),
#  ('Woody Allen', 231220507),
#  ('Noam Murro', 231150015),
#  ('Jimmy Hayward', 230677014),
#  ('Ben Stiller', 226986952),
#  ('Ralph Zondag', 226748063),
#  ('Eric Leighton', 226748063),
#  ('Rupert Sanders', 226600000),
#  ('Timur Bekmambetov', 226535147),
#  ('Phillip Noyce', 225309529),
#  ('Gavin Hood', 223765839),
#  ('Steven Quale', 221489837),
#  ('Mark Steven Johnson', 219918111),
#  ('Morten Tyldum', 219555708),
#  ('Jon Hurwitz', 216482707),
#  ('Hayden Schlossberg', 216482707),
#  ('Greg Mottola', 215077082),
#  ('Stephen Frears', 213640295),
#  ('David Ayer', 213022677),
#  ('Luke Greenfield', 212707109),
#  ('Dominic Sena', 212588740),
#  ('Jesse Dylan', 206675071),
#  ('Scott Waugh', 206550402),
#  ('Steve Bendelack', 204736344),
#  ('Paul King', 204207227),
#  ('Stephen Daldry', 204093953),
#  ('Jason Friedberg', 199717971),
#  ('Aaron Seltzer', 199717971),
#  ('George Clooney', 199090901),
#  ('Steven Brill', 198339641),
#  ('Ken Kwapis', 198330028),
#  ('Tony Gilroy', 196418121),
#  ('Glenn Ficarra', 194366195),
#  ('John Requa', 194366195),
#  ('Takashi Shimizu', 192618441),
#  ('Richard Curtis', 191280550),
#  ('Wes Craven', 189989623),
#  ('Joel Schumacher', 186642604),
#  ('Oliver Stone', 183398571),
#  ('Thor Freudenthal', 183313709),
#  ('John Hamburg', 180600372),
#  ('Florian Henckel von Donnersmarck', 178346189),
#  ('Eric Brevig', 178286201),
#  ('Josh Trank', 177977595),
#  ('Cameron Crowe', 177138780),
#  ('Joe Wright', 176304564),
#  ('Tommy Wirkola', 174803475),
#  ('Curtis Hanson', 174000000),
#  ('Kevin Greutert', 173384063),
#  ('Jason Moore', 173361479),
#  ('Cody Cameron', 170384621),
#  ('Kris Pearn', 170384621),
#  ('Pierre Morel', 170079448),
#  ('Klay Hall', 169788712),
#  ('Steve McQueen', 167000000),
#  ('Marc Lawrence', 166531590),
#  ('Michael Sucsy', 166114570),
#  ('Michael Lembeck', 163658589),
#  ('Steve Box', 162452832),
#  ('Alejandro AmenÃ¡bar', 161988542),
#  ('Peter Ramsey', 161941670),
#  ('Anthony Stacchi', 160564797),
#  ('Michel Gondry', 160075374),
#  ('Joe Carnahan', 159621022),
#  ('Boaz Yakin', 158115781),
#  ('Peter Sohn', 156926147),
#  ('Randall Wallace', 154245117),
#  ('Alexandre Aja', 151248317),
#  ('James Bobin', 150567350),
#  ('John Whitesell', 149874476),
#  ('Stefen Fangmeier', 149288105),
#  ('Rawson Marshall Thurber', 147722310),
#  ('David Soren', 147570682),
#  ('Richard LaGravenese', 147006123),
#  ('Gary Shore', 145529201),
#  ('Ryan Murphy', 144594016),
#  ('Lee Daniels', 144570008),
#  ('Gary Winick', 144119158),
#  ('Hoyt Yeatman', 142817841),
#  ('Ivan Reitman', 141156732),
#  ('Jonathan Levine', 140564441),
#  ('John Madden', 140007855),
#  ('Thomas Carter', 139836045),
#  ('Juan Antonio Bayona', 138274123),
#  ('Malcolm D. Lee', 138259197),
#  ('Steve Hickner', 137594577),
#  ('Kirk Jones', 137189822),
#  ('John Erick Dowdle', 136957466),
#  ('Ruben Fleischer', 136539725),
#  ('Nora Ephron', 135966668),
#  ('Andrew Niccol', 135385692),
#  ('Rob Reiner', 134674961),
#  ('Mike Nichols', 132505437),
#  ('Ron Clements', 131623880),
#  ('John Musker', 131623880),
#  ('Andy Muschietti', 131497771),
#  ('Denis Villeneuve', 130152503),
#  ('Mark Neveldine', 128537513),
#  ('Brian Taylor', 128537513),
#  ('Peter Hewitt', 128310722),
#  ('Michael Moore', 126089539),
#  ('James Wong', 123021472),
#  ('David S. Goyer', 121229529),
#  ('Tom Tykwer', 120824582),
#  ('Duncan Jones', 120092801),
#  ('Paul Haggis', 119600502),
#  ('JosÃ© Padilha', 119379423),
#  ('Tom Vaughan', 119134293),
#  ('Michel Hazanavicius', 118432856),
#  ('Albert Hughes', 116665870),
#  ('Burr Steers', 116235645),
#  ('Patrick Hughes', 116172544),
#  ('Steve Trenbirth', 115680000),
#  ('Oliver Parker', 115078586),
#  ('Marcus Nispel', 114568588),
#  ('Spike Lee', 114237276),
#  ('Roger Allers', 112309027),
#  ('Jill Culton', 112309027),
#  ('Wayne Wang', 111952200),
#  ('James Watkins', 110730736),
#  ('Stephen Hillenburg', 110161792),
#  ('David Twohy', 110150325),
#  ('Peter Howitt', 108416018),
#  ('Gregory Jacobs', 107613057),
#  ('Scott Speer', 107470746),
#  ('James Marsh', 106201940),
#  ('Chuck Russell', 105333180),
#  ('Mathieu Kassovitz', 103699932),
#  ('David Hackl', 103057533),
#  ('Ryan Coogler', 102935567),
#  ('Roman Polanski', 102897944),
#  ('Russell Mulcahy', 102717833),
#  ('Pete Travis', 102199233),
#  ('Brian Helgeland', 102041486),
#  ('Dean Parisot', 102026112),
#  ('Tyler Perry', 101866560),
#  ('Peter Billingsley', 101844840),
#  ('Stephen Norrington', 101265204),
#  ('Roberts Gannaway', 101165787),
#  ('James DeMonaco', 99782847),
#  ('Nigel Cole', 99428778),
#  ('Tate Taylor', 99272124),
#  ('Angelina Jolie', 98442937),
#  ('John Polson', 97644820),
#  ('Stiles White', 97529779),
#  ('Taylor Hackford', 95948175),
#  ('NimrÃ³d Antal', 95464646),
#  ('Victor Salva', 95320455),
#  ('Paul Verhoeven', 95213455),
#  ('Leigh Whannell', 94303851),
#  ('Anthony Minghella', 94013509),
#  ('Alastair Fothergill', 94000000),
#  ('Mark Linfield', 94000000),
#  ('Jonathan Dayton', 92523181),
#  ('Valerie Faris', 92523181),
#  ('Walt Becker', 90494793),
#  ('Bennett Miller', 90387346),
#  ('P.J. Hogan', 90307754),
#  ('Robin Budd', 89862682),
#  ('Donovan Cook', 89862682),
#  ('Andrew Douglas', 89047131),
#  ('Camille Delamarre', 88526499),
#  ('Gil Kenan', 88482048),
#  ('Nima Nourizadeh', 88000000),
#  ('Andrzej Bartkowiak', 86236439),
#  ('Ronny Yu', 84908830),
#  ('Alexander Witt', 84394835),
#  ('Eric Bress', 83060858),
#  ('J. Mackye Gruber', 83060858),
#  ('Sydney Pollack', 82944923),
#  ('Miguel Arteta', 81510273),
#  ('Christopher B. Landon', 81362372),
#  ('Kevin Rodney Sullivan', 80986300),
#  ('Samuel Bayer', 80664037),
#  ('Steve Pink', 80579955),
#  ('Fede Alvarez', 80542952),
#  ('Ben Falcone', 80525432),
#  ('Frank Marshall', 80455994),
#  ('Allen Hughes', 80367034),
#  ('Charles Herman-Wurmfeld', 79914842),
#  ('Simon Curtis', 79277469),
#  ('Alister Grierson', 78609310),
#  ('Brad Furman', 78029544),
#  ('George Nolfi', 77669379),
#  ('Kevin Smith', 77365452),
#  ('Mike Johnson', 77195061),
#  ('Daniel Espinosa', 76400535),
#  ('Xavier Gens', 75965753),
#  ('Joseph Ruben', 75575636),
#  ('Danny Leiner', 75117631),
#  ('Karey Kirkpatrick', 75019340),
#  ('Richard Linklater', 74852964),
#  ('Alejandro Agresti', 74830111),
#  ('Charles Martin Smith', 74828930),
#  ('Breck Eisner', 74622276),
#  ('Jake Schreier', 73512300),
#  ('Bryan Bertino', 73391145),
#  ('John Francis Daley', 73384188),
#  ('Jonathan M. Goldstein', 73384188),
#  ('GÃ¡bor CsupÃ³', 72657393),
#  ('Scott Cooper', 72638116),
#  ('Jay Russell', 72613150),
#  ('Frank Miller', 72172773),
#  ('Kevin Macdonald', 71934204),
#  ('Ole Bornedal', 71446075),
#  ('Patrick Lussier', 69666456),
#  ('Mike McCoy', 69272766),
#  ('Adrian Lyne', 69137784),
#  ('David McNally', 68916474),
#  ('Roger Michell', 68720944),
#  ('Tom McCarthy', 68346473),
#  ('Gregory Plotkin', 68099553),
#  ('Robert Altman', 67954044),
#  ('R.J. Cutler', 67874843),
#  ('Greg Berlanti', 67610124),
#  ('Etan Cohen', 66511453),
#  ('Gary Trousdale', 66053725),
#  ('Kirk Wise', 66053725),
#  ('Tom Dey', 65218768),
#  ('Geoffrey Sax', 65134289),
#  ('Gus Van Sant', 64775136),
#  ('John Luessenhop', 64297640),
#  ('Mennan Yapo', 64146832),
#  ('Ash Brannon', 64044513),
#  ('Frederik Du Chau', 63772522),
#  ('Jennifer Flackett', 63076342),
#  ('Mark Levin', 63076342),
#  ('Lone Scherfig', 62986285),
#  ('Sylvain White', 62511123),
#  ('MÃ¥ns MÃ¥rlind', 62400000),
#  ('BjÃ¶rn Stein', 62400000),
#  ('Jan de Bont', 61505388),
#  ('Evan Goldberg', 61346497),
#  ('Seth Rogen', 61346497),
#  ('Nicolas Winding Refn', 61175166),
#  ('John A. Davis', 61117361),
#  ('Gary Fleder', 61026626),
#  ('Rajkumar Hirani', 61000000),
#  ('Jonathan Lynn', 60524694),
#  ('Scott Stewart', 60227789),
#  ('Brian Levant', 59623481),
#  ('Chad Stahelski', 58739897),
#  ('David Leitch', 58739897),
#  ('Jeff Newitt', 58338361),
#  ('Susanna White', 58246388),
#  ('Scott Hicks', 57786831),
#  ('Rob Zombie', 57542817),
#  ('Fernando Meirelles', 57466670),
#  ('Jay Chandrasekhar', 57305331),
#  ('Colin Strause', 56821036),
#  ('Greg Strause', 56821036),
#  ('Jeremy Garelick', 56799880),
#  ('Patrick Tatopoulos', 56327197),
#  ('Bille Woodruff', 55998113),
#  ('John Wells', 55678257),
#  ('John Carney', 55464861),
#  ('Kathryn Bigelow', 54989682),
#  ('Clark Johnson', 54563692),
#  ('Garth Jennings', 54478416),
#  ('Joel Edgerton', 53978653),
#  ('Steve Shill', 53830340),
#  ('David Wain', 53540861),
#  ('Terry Zwigoff', 53488889),
#  ('Kimberly Peirce', 52394288),
#  ('Patty Jenkins', 52378584),
#  ('Peter Weir', 52359360),
#  ('John Crowley', 51076141),
#  ('Mark Rosman', 51067909),
#  ('Joel Gallen', 50468332),
#  ('Brad Anderson', 49702023),
#  ('Craig Brewer', 49648810),
#  ('Juan Carlos Fresnadillo', 49238440),
#  ('Tamra Davis', 49141030),
#  ('Iain Softley', 48780332),
#  ('Dustin Hoffman', 48520298),
#  ('Richard Loncraine', 48312007),
#  ('David M. Rosenthal', 48273173),
#  ('Graham Annable', 48255770),
#  ('Jared Hess', 48197993),
#  ('Christophe Gans', 47607453),
#  ('Aleksander Bach', 47347656),
#  ('Stephen Kay', 47192859),
#  ('Chris Butler', 47139399),
#  ('Ava DuVernay', 46787908),
#  ('Michael Dougherty', 46548707),
#  ('Neil Nightingale', 46546518),
#  ('Barry Cook', 46546518),
#  ('Kevin Costner', 46296293),
#  ('Kevin Munroe', 46243057),
#  ('George Tillman, Jr.', 45828190),
#  ('Christopher Spencer', 45800064),
#  ('Fred Wolf', 45442940),
#  ('Harold Ramis', 44741108),
#  ('Grant Heslov', 44729358),
#  ('Paul Weiland', 44601681),
#  ('David Moreau', 44309766),
#  ('Xavier Palud', 44309766),
#  ('Julie Taymor', 44298474),
#  ('Shekhar Kapur', 44120208),
#  ('Peter Hedges', 43377859),
#  ('Ciaran Foy', 42882018),
#  ('Jean-Marc VallÃ©e', 42608174),
#  ('Lorna Cook', 42563539),
#  ('Alan Poul', 42477008),
#  ('Theodore Melfi', 41837234),
#  ('Salim Akil', 41748079),
#  ('Sean Penn', 41255142),
#  ('Trish Sie', 41165646),
#  ('Kirsten Sheridan', 41122026),
#  ('Sam Miller', 40630415),
#  ('David Gordon Green', 39790930),
#  ('Chris Nahon', 39437847),
#  ('Jonathan Demme', 39431292),
#  ('Mike Flanagan', 39030246),
#  ('Paul Thomas Anderson', 38550580),
#  ('Jim Fall', 38534455),
#  ('Chris Carter', 38369434),
#  ('Spike Jonze', 38152424),
#  ('Fyodor Bondarchuk', 38129518),
#  ('Brad Silberling', 37762476),
#  ('James McTeigue', 37702647),
#  ('Jerry Zucker', 37498534),
#  ('Drew Goddard', 36486080),
#  ("Gavin O'Connor", 36445708),
#  ('Cory Edwards', 36053787),
#  ('Todd Edwards', 36053787),
#  ('Tony Leech', 36053787),
#  ('Jim Jarmusch', 35742101),
#  ('Sanjay Gadhvi', 35396427),
#  ('Nicholas Hytner', 35387687),
#  ('Scott Moore', 35065672),
#  ('Jon Lucas', 35065672),
#  ('Ari Sandel', 35028634),
#  ('Jorge Blanco', 34945765),
#  ('Javier Abad', 34945765),
#  ('Marcos MartÃ\xadnez', 34945765),
#  ('Gina Prince-Bythewood', 34833513),
#  ('Mark Romanek', 34678538),
#  ('Chris Gorak', 34626786),
#  ('Callan Brunker', 34597643),
#  ('Steve Antin', 34519773),
#  ('Richard Eyre', 34469904),
#  ('Mark Helfrich', 34192128),
#  ('James Gray', 33926886),
#  ('Michael McCullers', 33833449),
#  ('Toby Wilkins', 33610009),
#  ('Lawrence Guterman', 33375151),
#  ('Steve Beck', 33349884),
#  ('Olatunde Osunsanmi', 32333295),
#  ('Dave Green', 32300000),
#  ('Clare Kilner', 32175038),
#  ('Peter Webber', 32169884),
#  ('George A. Romero', 31770602),
#  ('John Patrick Shanley', 30907234),
#  ('Josh Gordon', 30830607),
#  ('Will Speck', 30830607),
#  ('David Cronenberg', 30378780),
#  ('Ted Demme', 30282296),
#  ('Dan Gilroy', 30197217),
#  ('Roger Kumble', 30036947),
#  ('Jim Field Smith', 29779728),
#  ('Stephen Gaghan', 29719357),
#  ('Matt Bettinelli-Olpin', 29433975),
#  ('Tyler Gillett', 29433975),
#  ('Lenny Abrahamson', 29401758),
#  ('Charles Stone III', 29388787),
#  ('Sean McNamara', 29088990),
#  ('Michael Spierig', 28916464),
#  ('Peter Spierig', 28916464),
#  ('Ericson Core', 28718711),
#  ('Rupert Wainwright', 28201432),
#  ('Todd Haynes', 28001170),
#  ('Shari Springer Berman', 27738099),
#  ('Robert Pulcini', 27738099),
#  ('Carl Franklin', 27277373),
#  ('Mary Harron', 27266564),
#  ('Lars von Trier', 27231879),
#  ('Harmony Korine', 26724284),
#  ('Rusty Cundieff', 26438988),
#  ('James Duffy', 26438988),
#  ('Griffin Dunne', 26438988),
#  ('Patrik Forsberg', 26438988),
#  ('Will Graham', 26438988),
#  ('Jonathan van Tulleken', 26438988),
#  ('Greg Coolidge', 26368909),
#  ('Denzel Washington', 26093730),
#  ('Florent-Emilio Siri', 25944725),
#  ("Pat O'Connor", 25754228),
#  ('Jessie Nelson', 25270895),
#  ('John Stockwell', 25206241),
#  ('Phil Traill', 25105542),
#  ('Rick Rosenthal', 24664855),
#  ('Sofia Coppola', 24620072),
#  ('Christian E. Christiansen', 24492759),
#  ('Peter Sollett', 23973937),
#  ('Nicholas Jarecki', 23485056),
#  ('John Hillcoat', 23311885),
#  ('Mark Pellington', 23157539),
#  ('David Schwimmer', 23000000),
#  ('Corey Yuen Kwai', 22928932),
#  ('Stephen Hopkins', 22771059),
#  ('Terrence Malick', 22674226),
#  ('Alex Garland', 21869414),
#  ('Steve Oedekerk', 21779000),
#  ('Jonathan Hensleigh', 21700105),
#  ('Bruce A. Evans', 21637263),
#  ('Jeff Wadlow', 21627431),
#  ('Daniel Barnz', 21525852),
#  ('Martin McDonagh', 21424799),
#  ('Craig Gillespie', 21229864),
#  ('Jonas Elmer', 21010817),
#  ('Neil LaBute', 20804647),
#  ('Dan Cutforth', 20726956),
#  ('Jane Lipsitz', 20726956),
#  ('Gonzalo LÃ³pez-Gallego', 20562924),
#  ('Joshua Michael Stern', 20531410),
#  ('Terry George', 20500000),
#  ('Derek Cianfrance', 20485608),
#  ('Stephen Chbosky', 20400000),
#  ('Troy Miller', 20267515),
#  ('Dean Israelite', 20248241),
#  ("Matthew O'Callaghan", 19834815),
#  ('Shana Feste', 19607114),
#  ('David Koepp', 19415330),
#  ('Stephen J. Anderson', 19332978),
#  ('Anthony Bell', 19300000),
#  ('Ben Gluck', 19300000),
#  ('Doug Ellin', 19263404),
#  ('Christopher Erskin', 19179516),
#  ('Sergey Bodrov', 19178613),
#  ('Trey Parker', 18907422),
#  ('Feng Xiaogang', 18786960),
#  ('Shane Acker', 18428063),
#  ('Simon Wincer', 18288674),
#  ('Brandon Camp', 18133014),
#  ('William Brent Bell', 18105095),
#  ('Tom Gormican', 18049082),
#  ('Lee Toland Krieger', 17629776),
#  ('Terry Gilliam', 17316267),
#  ('Todd Strauss-Schulson', 16387212),
#  ('Brian Robbins', 16076018),
#  ('Rob Schmidt', 16050575),
#  ('Angela Robinson', 16002004),
#  ('Mimi Leder', 15707411),
#  ('Philip G. Atwell', 15452643),
#  ('Dave Meyers', 15399945),
#  ('Frank Oz', 15069884),
#  ('Mike Binder', 14793497),
#  ('Jean-Jacques Annaud', 14648320),
#  ('FranÃ§ois Ozon', 14641323),
#  ('Scott Frank', 14548630),
#  ('Sara Sugarman', 14331068),
#  ('Jon Amiel', 14208267),
#  ('Roger Spottiswoode', 14085477),
#  ('Julian Jarrold', 14015963),
#  ('Paul McGuigan', 14002735),
#  ('David E. Talbert', 13956509),
#  ('Peter Landesman', 13623572),
#  ('John Michael McDonagh', 13560274),
#  ('Marcus Raboy', 13526835),
#  ('Ricky Gervais', 13412793),
#  ('Matthew Robinson', 13412793),
#  ('Dennie Gordon', 13287695),
#  ('Rob Pritts', 12978402),
#  ('John Schultz', 12881056),
#  ('Don Mancini', 12829644),
#  ('Jonathan Frakes', 12793283),
#  ('Harold Cronk', 12789000),
#  ('Christopher Guest', 12750246),
#  ('Billy Ray', 12689727),
#  ('Bonnie Hunt', 12609995),
#  ('Glen Morgan', 12510851),
#  ('Gregory Poirier', 12430766),
#  ('James Foley', 12295611),
#  ('Jim Sheridan', 12263217),
#  ('Stephen St. Leger', 12204030),
#  ('James Mather', 12204030),
#  ('Fred Savage', 12197398),
#  ('Troy Nixey', 11993168),
#  ('Wong Kar-wai', 11786738),
#  ('Jeff Nichols', 11587700),
#  ('Kevin Bray', 11482931),
#  ('Phil Joanou', 11480851),
#  ('Ethan Maniquis', 11327899),
#  ('Elizabeth Allen Rosenbaum', 11006849),
#  ('Doug Atchison', 10948425),
#  ('Anand Tucker', 10922472),
#  ('Michael Rymer', 10479110),
#  ('Mark Mylod', 10426096),
#  ('Ben Garant', 10342161),
#  ('Ed Gass-Donnelly', 10179302),
#  ('Nanette Burstein', 10045846),
#  ('Michael Hoffman', 9926213),
#  ('Rachid Bouchareb', 8463701),
#  ('Stewart Hendler', 7991317),
#  ('Ric Roman Waugh', 7930462),
#  ('Mark Herman', 7916563),
#  ('Lawrence Kasdan', 7715436),
#  ('Andrew Dominik', 7642258),
#  ('Jon Kasdan', 7500000),
#  ('GrÃ©gory Levasseur', 7365435),
#  ('Stuart Baird', 7312826),
#  ('Richard Shepard', 7297244),
#  ('Jesse Peretz', 7273593),
#  ('Brian Klugman', 7231461),
#  ('Lee Sternthal', 7231461),
#  ('Anthony Silverston', 7187375),
#  ('Edward Norton', 7036004),
#  ('John Boorman', 7008462),
#  ('Sidney Lumet', 7005257),
#  ('Barbet Schroeder', 6714147),
#  ('Douglas McGrath', 6551495),
#  ('Joseph Kahn', 6546197),
#  ('Jocelyn Moorhouse', 6410000),
#  ('Tom Hanks', 6160375),
#  ('Mike Tollin', 5971376),
#  ('Karyn Kusama', 5860062),
#  ('Giuseppe Tornatore', 5755873),
#  ('Jason Winer', 5735397),
#  ('Amma Asante', 5605460),
#  ('Andrew Erwin', 5429707),
#  ('Jon Erwin', 5429707),
#  ('Jean-FranÃ§ois Richet', 5294470),
#  ('Max Joseph', 5122090),
#  ('David Lynch', 5117339),
#  ('Nick Hamm', 5114487),
#  ('Chris Noonan', 5078241),
#  ('James Isaac', 5000000),
#  ('Anthony Leondis', 5000000),
#  ('Liz Friedlander', 4742066),
#  ('Benny Chan', 4662874),
#  ('Ken Scott', 4595359),
#  ('Frank Darabont', 4413748),
#  ('Ilya Naishuller', 4333790),
#  ('Jonathan Teplitzky', 4309223),
#  ('Asger Leth', 4221189),
#  ('Vic Armstrong', 3682924),
#  ('John Gulager', 3493728),
#  ('Richard Kelly', 3333531),
#  ('DJ Pooh', 3229331),
#  ('Wally Pfister', 3039258),
#  ('Daniel Barber', 3029747),
#  ('Christine Jeffs', 3000000),
#  ('Michael Winterbottom', 2928871),
#  ('Mike Judge', 2848783),
#  ('Kevin Allen', 2818995),
#  ('Ben Younger', 2780255),
#  ('Howard Deutch', 2776289),
#  ('Guy Ferland', 2685016),
#  ('Troy Duffy', 2629321),
#  ('Rian Johnson', 2572764),
#  ('Francine McDougall', 2276953),
#  ('Chris Rock', 2196245),
#  ('John Bonito', 2165608),
#  ('Sarah Gavron', 2002420),
#  ('Mira Nair', 1262687),
#  ('David Bowers', 1079953),
#  ('Jon Avnet', 105450),
#  ('Joe Nussbaum', -749925),
#  ('Rodrigo GarcÃ\xada', -2365172),
#  ('Dean Wright', -2377154),
#  ('Chris Sivertson', -2379601),
#  ('Dan Rush', -2385227),
#  ('Danny Cannon', -2389127),
#  ('Noah Baumbach', -2412515),
#  ('Robert Iscove', -2450462),
#  ('Oxide Pang Chun', -2512610),
#  ('Danny Pang', -2512610),
#  ('Rob Thomas', -2514873),
#  ('James Cox', -2533556),
#  ('Michael Cuesta', -2549154),
#  ('Don Scardino', -2562119),
#  ('Chris Koch', -2567837),
#  ('Thomas Bezucha', -2575000),
#  ('Josh Schwartz', -2582638),
#  ('Adam Wingard', -2632839),
#  ('Ernest R. Dickerson', -2683342),
#  ('Tommy Lee Jones', -2963851),
#  ('Derrick Borte', -2977272),
#  ('Kevin Reynolds', -3000000),
#  ('Asif Kapadia', -3007986),
#  ('Julie Anne Robinson', -3106279),
#  ('Gregory Hoblit', -3123301),
#  ('Mabrouk El Mechri', -3136417),
#  ('Rob Bowman', -3256452),
#  ('Peter Bogdanovich', -3353006),
#  ('Paul Abascal', -3394237),
#  ('Benson Lee', -3450523),
#  ('Alex Kurtzman', -3565222),
#  ("Tommy O'Haver", -3611233),
#  ('John Herzfeld', -3640020),
#  ('Jorma Taccone', -3890000),
#  ('David Mackenzie', -3900000),
#  ('Diane Keaton', -3962091),
#  ('Jane Campion', -4059945),
#  ('Zal Batmanglij', -4098490),
#  ('Jeff Schaffer', -4203153),
#  ('Liev Schreiber', -4302070),
#  ('Stuart Beattie', -4340472),
#  ('Michael J. Bassett', -4887204),
#  ('Paul Schrader', -4937934),
#  ('Henry Selick', -4994085),
#  ('Vipul Amrutlal Shah', -5000000),
#  ('David Raynr', -5097885),
#  ('Wayne Kramer', -5500000),
#  ('Mark Duplass', -5582420),
#  ('Jay Duplass', -5582420),
#  ('John Landis', -5650813),
#  ('Ron Shelton', -5762530),
#  ('Tony Goldwyn', -5767020),
#  ('Saul Dibb', -5895284),
#  ('Simon Hunter', -5966835),
#  ('Will Finn', -6048539),
#  ('John Sanford', -6048539),
#  ('Peter Cattaneo', -6237110),
#  ('Daniel Sackheim', -6380391),
#  ('Atom Egoyan', -6540542),
#  ('Henry Alex Rubin', -6571952),
#  ('Michael Cristofer', -6597680),
#  ('Matthijs van Heijningen Jr.', -6871330),
#  ('Russell Crowe', -6979977),
#  ('Floria Sigismondi', -7004189),
#  ('Michael Haneke', -7061128),
#  ('John McTiernan', -7207439),
#  ('Marcel Langenegger', -7258702),
#  ('Dito Montiel', -7360655),
#  ('Todd Lincoln ', -7372508),
#  ('Bill Paxton', -7458375),
#  ('Dewey Nicks', -7586085),
#  ('Anthony Hemingway', -7634623),
#  ('Justin Chadwick', -7670000),
#  ('John Maybury', -7873775),
#  ('Jonathan Glazer', -7919749),
#  ('Jim Sonzero', -8092315),
#  ('Gary McKendry', -8222894),
#  ('Uli Edel', -8444012),
#  ('Liam Lynch', -8594405),
#  ('William Dear', -8621007),
#  ('Susannah Grant', -8841513),
#  ('Davis Guggenheim', -8891180),
#  ('Robert Stevenhagen', -9122855),
#  ('Craig Mazin', -9128166),
#  ('Douglas Aarniokoski', -9156392),
#  ('Brendan Malloy', -9217324),
#  ('Emmett Malloy', -9217324),
#  ('Don McKellar', -9269982),
#  ('Robert B. Weide', -9713701),
#  ('Niki Caro', -9775758),
#  ('Mary Lambert', -9782502),
#  ('Beeban Kidron', -9796980),
#  ('Christian Duguay', -9800895),
#  ('John Frankenheimer', -9831030),
#  ('David MichÃ´d', -9954577),
#  ('Christian Alvart', -10354673),
#  ('Paul Johansson', -10372625),
#  ('Joe Cornish', -10385849),
#  ('Lexi Alexander', -10410627),
#  ('Kasi Lemmons', -10481811),
#  ('J.C. Chandor', -10884210),
#  ('Alan Parker', -11044402),
#  ('David Mamet', -11137288),
#  ('Mort Nathan', -11413624),
#  ('RyÃ»hei Kitamura', -11466773),
#  ('Joe Dante', -11485156),
#  ('Steven Knight', -11647115),
#  ('Kerry Conran', -12041304),
#  ('Michael Davis', -12179359),
#  ('Penny Marshall', -12256692),
#  ('John Curran', -12520282),
#  ('Neil Marshall', -12973785),
#  ('Brian Koppelman', -12975218),
#  ('David Levien', -12975218),
#  ('Susanne Bier', -13150858),
#  ('Justin Zackham', -13180652),
#  ('Paolo Sorrentino', -13209021),
#  ('Alejandro Monteverde', -13579681),
#  ('Miguel Sapochnik', -13590109),
#  ('John Carpenter', -13989168),
#  ('E. Elias Merhige', -14000000),
#  ('Roland JoffÃ©', -14373200),
#  ('Amy Heckerling', -14423505),
#  ('Steven Shainberg', -14518911),
#  ('Kurt Wimmer', -14640355),
#  ('Todd Graff', -14789012),
#  ('Bruce Hunt', -14992009),
#  ('Michael Dowse', -15224932),
#  ('David Barrett', -15363831),
#  ('Gary Chapman', -15521894),
#  ('Stephen Anderson', -15540000),
#  ('William Friedkin', -16100923),
#  ('Barry Levinson', -16436363),
#  ('Mike Disa', -16478171),
#  ('Eli Roth', -16542582),
#  ('Werner Herzog', -17233755),
#  ('Pitof', -17897621),
#  ('Don Michael Paul', -18567273),
#  ('Marco Schnabel', -20180936),
#  ('Dan Bradley', -20193217),
#  ('William Monahan', -20355892),
#  ('Walter Salles', -20742589),
#  ('Harold Becker', -20750706),
#  ('Bruce Robinson', -21000000),
#  ('Nick Hurran', -21079734),
#  ('William Malone', -21097985),
#  ('Les Mayfield', -21321087),
#  ('Richard J. Lewis', -21545699),
#  ('Andrew Davis', -21605835),
#  ('Scott Walker', -21723049),
#  ('Robert Redford', -21845901),
#  ('Reginald Hudlin', -22369815),
#  ('Keanu Reeves', -22945059),
#  ('Joe Roth', -23009372),
#  ('Guillaume Canet', -23084528),
#  ('Bruce Beresford', -23731349),
#  ('Carl Rinsch', -24037525),
#  ('Robert De Niro', -25091435),
#  ('Uwe Boll', -25333591),
#  ('Courtney Solomon', -27312821),
#  ('Akiva Goldsman', -29199769),
#  ('Philip Kaufman', -31244124),
#  ('Roger Donaldson', -32521337),
#  ('David Leland', -32589251),
#  ('Don Bluth', -38245366),
#  ('Gary Goldman', -38245366),
#  ('Renny Harlin', -38949184),
#  ('Stephen Herek', -40008098),
#  ('Des McAnuff', -40865180),
#  ('Doug Lefler', -41696962),
#  ('Jason Eisener', -41962103),
#  ('Tony Bill', -42200000),
#  ("Steve 'Spaz' Williams", -42615954),
#  ('Howard McCain', -42966317),
#  ('Ronald F. Maxwell', -43076064),
#  ('George Armitage', -43191450),
#  ('Demian Lichtenstein', -43279825),
#  ('Jaco Van Dormael', -43452791),
#  ('Stephen T. Kay', -44187007),
#  ('Steven Zaillian', -45549103),
#  ('Luis Mandoki', -46383131),
#  ('Sam Fell', -46524140),
#  ('Antony Hoffman', -46536031),
#  ('Charles Shyer', -46604061),
#  ('Martin Brest', -46733791),
#  ('Brian De Palma', -47286475),
#  ('Jim Gillespie', -48583698),
#  ('Michael Caton-Jones', -48936607),
#  ('Richard Donner', -49854540),
#  ('Dan St. Pierre', -51337973),
#  ('Hironobu Sakaguchi', -51868170),
#  ('Motonori Sakakibara', -51868170),
#  ('Juan Diego Solanas', -51893525),
#  ('Edgar Wright', -54297544),
#  ('John Dahl', -56190660),
#  ('Oliver Hirschbiegel', -58162215),
#  ('Rod Lurie', -59032852),
#  ('Simon Wells', -67278066),
#  ('Joby Harold', -71626175),
#  ('Jack Sholder', -75171919),
#  ('Peter Hyams', -86956545),
#  ('Ron Underwood', -92896027),
#  ('James L. Brooks', -96289726),
#  ('Walter Hill', -128283462),
#  ('Sngmoo Lee', -413912431)]

# %%
data2[data2.director.str.contains('\|', na = False)]
# Out:
#         imdb_id  popularity     budget     revenue  \
# 8     tt2293640    7.404165   74000000  1156730962
# 11    tt1617661    6.189369  176000003   183987723
# 57    tt2381941    2.395366   50100000   153962963
# 72    tt1524930    2.000338   31000000   104384188
# 120   tt1843866   12.971027  170000000   714766572
# ...         ...         ...        ...         ...
# 1812  tt0120630    1.525559   45000000   224834564
# 1825  tt0138749    1.085408   95000000    76432727
# 1842  tt0183505    0.783530   51000000   149270999
# 1859  tt0120913    0.546560   75000000    36754634
# 1873  tt0134983    0.385350   90000000    14828081
#
#                            original_title  \
# 8                                 Minions
# 11                      Jupiter Ascending
# 57                                  Focus
# 72                               Vacation
# 120   Captain America: The Winter Soldier
# ...                                   ...
# 1812                          Chicken Run
# 1825                The Road to El Dorado
# 1842                   Me, Myself & Irene
# 1859                           Titan A.E.
# 1873                            Supernova
#
#                                                    cast  \
# 8     Sandra Bullock|Jon Hamm|Michael Keaton|Allison...
# 11    Mila Kunis|Channing Tatum|Sean Bean|Eddie Redm...
# 57    Will Smith|Margot Robbie|Rodrigo Santoro|Rober...
# 72    Ed Helms|Christina Applegate|Skyler Gisondo|St...
# 120   Chris Evans|Scarlett Johansson|Sebastian Stan|...
# ...                                                 ...
# 1812  Mel Gibson|Miranda Richardson|Timothy Spall|Im...
# 1825  Kenneth Branagh|Kevin Kline|Rosie Perez|Armand...
# 1842  Jim Carrey|RenÃ©e Zellweger|Anthony Anderson|R...
# 1859  Matt Damon|Bill Pullman|Drew Barrymore|John Le...
# 1873  James Spader|Angela Bassett|Robert Forster|Lou...
#
#                                       director  \
# 8                     Kyle Balda|Pierre Coffin
# 11              Lana Wachowski|Lilly Wachowski
# 57                    Glenn Ficarra|John Requa
# 72    John Francis Daley|Jonathan M. Goldstein
# 120                    Joe Russo|Anthony Russo
# ...                                        ...
# 1812                      Peter Lord|Nick Park
# 1825            Don Michael Paul|Bibo Bergeron
# 1842             Peter Farrelly|Bobby Farrelly
# 1859                    Don Bluth|Gary Goldman
# 1873                  Walter Hill|Jack Sholder
#
#                                                 tagline  \
# 8          Before Gru, they had a history of bad bosses
# 11                                Expand your universe.
# 57                                  Never Drop The Con.
# 72                                 What could go wrong?
# 120                                 In heroes we trust.
# ...                                                 ...
# 1812  This ain't no chick flick. It's poultry in mot...
# 1825  They came for the gold... they stayed for the ...
# 1842                             From gentle to mental.
# 1859             When Earth Ends, The Adventure Begins.
# 1873  In the farthest reaches of space, something ha...
#
#                                                overview  runtime  \
# 8     Minions Stuart, Kevin and Bob are recruited by...       91
# 11    In a universe where human genetic material is ...      124
# 57    A veteran grifter takes a young, attractive wo...      105
# 72    Hoping to bring his family closer together and...       99
# 120   After the cataclysmic events in New York with ...      136
# ...                                                 ...      ...
# 1812  Having been hopelessly repressed and facing ev...       84
# 1825  After a failed swindle, two con-men end up wit...       89
# 1842  Rhode Island State Trooper Charlie Baileygates...      116
# 1859  A young man finds out that he holds the key to...       94
# 1873  Set in the 22nd century, when a battered salva...       91
#
#                                                  genres  \
# 8                     Family|Animation|Adventure|Comedy
# 11             Science Fiction|Fantasy|Action|Adventure
# 57                           Romance|Comedy|Crime|Drama
# 72                                     Adventure|Comedy
# 120                    Action|Adventure|Science Fiction
# ...                                                 ...
# 1812                            Animation|Comedy|Family
# 1825                  Adventure|Animation|Comedy|Family
# 1842                                             Comedy
# 1859  Animation|Action|Science Fiction|Family|Adventure
# 1873                                    Science Fiction
#
#                                    production_companies release_date  \
# 8         Universal Pictures|Illumination Entertainment    6/17/2015
# 11    Village Roadshow Pictures|Dune Entertainment|A...     2/4/2015
# 57    Kramer & Sigman Films|RatPac-Dune Entertainmen...    2/25/2015
# 72    New Line Cinema|BenderSpink|David Dobkin Produ...    7/28/2015
# 120                                      Marvel Studios    3/20/2014
# ...                                                 ...          ...
# 1812  DreamWorks SKG|Aardman Animations|DreamWorks A...    6/21/2000
# 1825                               DreamWorks Animation    3/31/2000
# 1842  Twentieth Century Fox Film Corporation|Conundr...    6/22/2000
# 1859  Twentieth Century Fox Film Corporation|David K...    6/16/2000
# 1873  United Artists|Metro-Goldwyn-Mayer (MGM)|Hamme...    1/14/2000
#
#       vote_count  vote_average  release_year      profit
# 8           2893           6.5          2015  1082730962
# 11          1937           5.2          2015     7987720
# 57          1831           6.7          2015   103862963
# 72           846           6.1          2015    73384188
# 120         3848           7.6          2014   544766572
# ...          ...           ...           ...         ...
# 1812         663           6.3          2000   179834564
# 1825         462           6.8          2000   -18567273
# 1842         521           5.9          2000    98270999
# 1859         184           6.1          2000   -38245366
# 1873          42           4.7          2000   -75171919
#
# [140 rows x 17 columns]

# %%
answer_ls.append(5)

# %%
a = [1,2,3]
a
# Out:
# [1, 2, 3]

# %%
a.pop(-1)
# Out:
# 3

# %%
a
# Out:
# [1, 2]

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
cnt = Counter()
for i in range(0,len(data2)):
    temp = data2.iloc[i]['cast'].split('|') 
    for actor in temp:
        #print(i, director, data2.iloc[i].profit, data2.iloc[i].original_title)
        cnt[actor] += data2.iloc[i].profit
cnt.most_common()
# Out:
# [('Emma Watson', 6666245597),
#  ('Daniel Radcliffe', 6514990281),
#  ('Rupert Grint', 6408638290),
#  ('Ian McKellen', 6087375777),
#  ('Robert Downey Jr.', 5316030161),
#  ('Orlando Bloom', 5148578162),
#  ('Johnny Depp', 4776417000),
#  ('Ralph Fiennes', 4739260140),
#  ('Michelle Rodriguez', 4608031235),
#  ('Anne Hathaway', 4490351538),
#  ('Scarlett Johansson', 4203244858),
#  ('Ben Stiller', 4201954571),
#  ('Cameron Diaz', 4146490085),
#  ('Samuel L. Jackson', 4036974161),
#  ('Vin Diesel', 3923216862),
#  ('Dwayne Johnson', 3899824603),
#  ('Tom Cruise', 3872196893),
#  ('Chris Evans', 3793939244),
#  ('Gary Oldman', 3708823251),
#  ('Zoe Saldana', 3572392568),
#  ('Michael Caine', 3481833508),
#  ('Shia LaBeouf', 3393362177),
#  ('Chris Hemsworth', 3347424695),
#  ('Angelina Jolie', 3345409359),
#  ('Kristen Stewart', 3324049211),
#  ('Helena Bonham Carter', 3289902810),
#  ('Brad Pitt', 3287408957),
#  ('Paul Walker', 3137283755),
#  ('Sam Worthington', 3135365646),
#  ('Daniel Craig', 3133778323),
#  ('Will Smith', 3107921771),
#  ('Tom Hanks', 3078112705),
#  ('Josh Hutcherson', 3047241377),
#  ('Mark Ruffalo', 3045858157),
#  ('Jennifer Lawrence', 3031588432),
#  ('Leonardo DiCaprio', 3029444829),
#  ('Taylor Lautner', 3023620411),
#  ('Robert Pattinson', 3008872499),
#  ('Woody Harrelson', 2988729199),
#  ('Cate Blanchett', 2918861980),
#  ('James Franco', 2901670993),
#  ('Sigourney Weaver', 2895067138),
#  ('Antonio Banderas', 2891623730),
#  ('Sandra Bullock', 2824692940),
#  ('Matt Damon', 2803535866),
#  ('Eddie Murphy', 2797586538),
#  ('Bradley Cooper', 2792958718),
#  ('Elijah Wood', 2787731978),
#  ('Christian Bale', 2741738014),
#  ('Liv Tyler', 2739870270),
#  ('Julie Andrews', 2718858871),
#  ('Viggo Mortensen', 2699098722),
#  ('Harrison Ford', 2696134112),
#  ('Steve Carell', 2668010978),
#  ('Mike Myers', 2634259979),
#  ('Jack Black', 2620004430),
#  ('Liam Neeson', 2536858504),
#  ('Keira Knightley', 2534854685),
#  ('Jason Statham', 2495798922),
#  ('George Clooney', 2477120111),
#  ('Natalie Portman', 2468418555),
#  ('Stephen Lang', 2460224804),
#  ('Elizabeth Banks', 2440975500),
#  ('Liam Hemsworth', 2429092160),
#  ('Adam Sandler', 2387021605),
#  ('Seann William Scott', 2376422215),
#  ('Owen Wilson', 2375025339),
#  ('Mark Wahlberg', 2324586236),
#  ('Michael Keaton', 2316042286),
#  ('Josh Duhamel', 2296594437),
#  ('Richard Armitage', 2291125550),
#  ('Bill Nighy', 2272709441),
#  ('Chris Pratt', 2264031555),
#  ('Kristen Wiig', 2247774460),
#  ('Martin Freeman', 2245427868),
#  ('Tobey Maguire', 2231331790),
#  ('Denis Leary', 2224658555),
#  ('Peter Facinelli', 2222107909),
#  ('Judi Dench', 2203621895),
#  ('John Leguizamo', 2193502213),
#  ('Tom Hardy', 2129641063),
#  ('Steve Buscemi', 2097184654),
#  ('Ewan McGregor', 2090801439),
#  ('Russell Crowe', 2065975814),
#  ('Andy Serkis', 2057975393),
#  ('Gwyneth Paltrow', 2051072268),
#  ('Hugh Jackman', 2043789637),
#  ('Emma Stone', 2023612916),
#  ('Robert De Niro', 1989540634),
#  ('Kirsten Dunst', 1972542719),
#  ('Jonah Hill', 1955372029),
#  ('Tyrese Gibson', 1954038544),
#  ('Guy Pearce', 1953730753),
#  ('Frances McDormand', 1941014837),
#  ('Simon Pegg', 1927222589),
#  ('John Goodman', 1918861833),
#  ('Geoffrey Rush', 1918496931),
#  ('Bryce Dallas Howard', 1917236873),
#  ('Sacha Baron Cohen', 1916134152),
#  ('Michael Gambon', 1906469638),
#  ('Willem Dafoe', 1886667580),
#  ('Ashley Greene', 1885118157),
#  ('Adam Driver', 1884109030),
#  ('Mark Hamill', 1868178225),
#  ('Carrie Fisher', 1868178225),
#  ('Daisy Ridley', 1868178225),
#  ('Irrfan Khan', 1863613082),
#  ('Jamie Foxx', 1860077704),
#  ('Amy Adams', 1819139040),
#  ('Gerard Butler', 1814331972),
#  ('Jackie Chan', 1805945694),
#  ('Jeremy Renner', 1805307161),
#  ('Meryl Streep', 1792276260),
#  ('Colin Firth', 1792021986),
#  ('Dustin Hoffman', 1769635731),
#  ('Megan Fox', 1749357755),
#  ('Robin Williams', 1739802878),
#  ('Chris Rock', 1725577596),
#  ('Kevin James', 1724987946),
#  ('Maggie Smith', 1714286499),
#  ('Don Cheadle', 1698836838),
#  ('Ray Romano', 1687442698),
#  ('Justin Long', 1668080734),
#  ('Zach Galifianakis', 1643064842),
#  ('Russell Brand', 1641894717),
#  ('Hank Azaria', 1628132253),
#  ('Jason Lee', 1604563794),
#  ('Nicolas Cage', 1598427930),
#  ('Jim Carrey', 1579517274),
#  ('Jordana Brewster', 1568762707),
#  ('Seth Rogen', 1532111572),
#  ('John Malkovich', 1528571988),
#  ('Graham McTavish', 1516455355),
#  ('David Schwimmer', 1513502299),
#  ('Keanu Reeves', 1498961637),
#  ('Amanda Seyfried', 1497822181),
#  ('Allison Janney', 1497124685),
#  ('Ken Watanabe', 1495008278),
#  ('Ben Kingsley', 1487684460),
#  ('Morgan Freeman', 1478916574),
#  ('Jason Bateman', 1477790582),
#  ("Vincent D'Onofrio", 1465576509),
#  ('Ken Jeong', 1452196639),
#  ('Ryan Reynolds', 1445757622),
#  ('Jennifer Aniston', 1443185988),
#  ('Ed Harris', 1433643828),
#  ('Christoph Waltz', 1415633955),
#  ('Ken Stott', 1413519788),
#  ('Jack Davenport', 1412846074),
#  ('Mila Kunis', 1411974109),
#  ('Will Arnett', 1411551691),
#  ('Julie Walters', 1404008567),
#  ('Bruce Willis', 1402368647),
#  ('Anthony Hopkins', 1398887962),
#  ('Michael Fassbender', 1396919073),
#  ('Jason Segel', 1381034598),
#  ('Carla Gugino', 1378790398),
#  ('Ben Affleck', 1371296619),
#  ('Jake Gyllenhaal', 1369845596),
#  ('Ving Rhames', 1367591200),
#  ('Nick Robinson', 1363528810),
#  ('Jessica Chastain', 1355397478),
#  ('Aaron Eckhart', 1352459484),
#  ('Vince Vaughn', 1351186518),
#  ('Jude Law', 1347852227),
#  ('Julia Roberts', 1346783045),
#  ('Josh Gad', 1340350280),
#  ('Hayden Christensen', 1336469783),
#  ('Charlize Theron', 1329803370),
#  ('Alan Rickman', 1324666007),
#  ('Leslie Mann', 1314569622),
#  ('Bill Hader', 1314097465),
#  ('Thandie Newton', 1306199066),
#  ('Monica Bellucci', 1286310870),
#  ('Denzel Washington', 1278642199),
#  ('Rachel McAdams', 1275304837),
#  ('Josh Brolin', 1271330619),
#  ('Kristen Bell', 1266445306),
#  ('Ian McDiarmid', 1266398328),
#  ('Jay Baruchel', 1265942894),
#  ('Famke Janssen', 1258361241),
#  ('Javier Bardem', 1257445372),
#  ('Paul Bettany', 1251524842),
#  ('Andrew Garfield', 1250524708),
#  ('David Cross', 1241555575),
#  ('Alfred Molina', 1229444150),
#  ('Tommy Lee Jones', 1216769285),
#  ('Jon Hamm', 1213064725),
#  ('Paul Rudd', 1210975726),
#  ('Channing Tatum', 1209494233),
#  ('Hugo Weaving', 1201151589),
#  ('Stellan SkarsgÃ¥rd', 1199116345),
#  ('Ed Helms', 1195018840),
#  ('Patrick Stewart', 1193273688),
#  ('Christopher Plummer', 1190137280),
#  ('James McAvoy', 1178987928),
#  ('Amanda Peet', 1177312381),
#  ('PenÃ©lope Cruz', 1168450274),
#  ('Steve Coogan', 1166801573),
#  ('Will Ferrell', 1165510652),
#  ('RenÃ©e Zellweger', 1164990827),
#  ('Queen Latifah', 1154625474),
#  ('Rosamund Pike', 1134755001),
#  ('Mark Strong', 1131611562),
#  ('Richard Harris', 1131328909),
#  ('Idina Menzel', 1124219009),
#  ('Jonathan Groff', 1124219009),
#  ('Santino Fontana', 1124219009),
#  ('Thomas Haden Church', 1122456954),
#  ('Jeff Bridges', 1120780625),
#  ('Joaquin Phoenix', 1120274502),
#  ('Andy GarcÃ\xada', 1117749317),
#  ('Heath Ledger', 1111508240),
#  ('Rose Byrne', 1107178907),
#  ('Billy Crystal', 1101686608),
#  ('Justin Bartha', 1097159972),
#  ('Neil Patrick Harris', 1093496678),
#  ('Chiwetel Ejiofor', 1093097183),
#  ('Jesse Eisenberg', 1092766286),
#  ('Anna Faris', 1081636934),
#  ('Mel Gibson', 1079231358),
#  ('Carrie-Anne Moss', 1079169881),
#  ('Michael PeÃ±a', 1074664116),
#  ('Rachel Weisz', 1072009252),
#  ('Brian Cox', 1068874359),
#  ('Jada Pinkett Smith', 1066567624),
#  ('Jason Clarke', 1065051837),
#  ('Martin Sheen', 1055310537),
#  ('Emily Blunt', 1053071561),
#  ('Brad Garrett', 1046311112),
#  ('Billy Burke', 1039021060),
#  ('Sean Bean', 1035597311),
#  ('Jon Voight', 1033061074),
#  ('Jane Lynch', 1031200074),
#  ('John Cusack', 1031032432),
#  ('Sharlto Copley', 1029873565),
#  ('Naomie Harris', 1027867754),
#  ('Skandar Keynes', 1024144587),
#  ('Georgie Henley', 1024144587),
#  ('Ian McShane', 1023678483),
#  ('Benjamin Bratt', 1015810166),
#  ('Elle Fanning', 1013929879),
#  ('Ioan Gruffudd', 1010384046),
#  ('John Cleese', 1009569409),
#  ('Nicole Kidman', 1000969666),
#  ('Matthew McConaughey', 999064410),
#  ('Lucy Liu', 993283774),
#  ('Emma Thompson', 987066274),
#  ('Helen Mirren', 982061005),
#  ('Ned Beatty', 973896514),
#  ('Sylvester Stallone', 970268324),
#  ('Joan Cusack', 966017065),
#  ('Eddie Marsan', 954973067),
#  ('Amy Poehler', 954595982),
#  ('Pierce Brosnan', 952867243),
#  ('Eva Green', 950504033),
#  ('Salma Hayek', 945394032),
#  ('Jennifer Connelly', 942585561),
#  ('Kate Beckinsale', 938034028),
#  ('Luke Evans', 929770819),
#  ('Tim Allen', 928139970),
#  ('Kerry Washington', 923826504),
#  ('Jaden Smith', 922308630),
#  ('Richard Jenkins', 921423264),
#  ('Giovanni Ribisi', 919483785),
#  ('Stanley Tucci', 916891529),
#  ('Laurence Fishburne', 914806127),
#  ('Anil Kapoor', 912623924),
#  ('Arnold Schwarzenegger', 912241043),
#  ('Kenneth Branagh', 912054905),
#  ('Chris Pine', 902838990),
#  ('Halle Berry', 901250736),
#  ('Brendan Gleeson', 900356579),
#  ('Miranda Cosgrove', 894761885),
#  ('Ellen Page', 888883058),
#  ('Timothy Spall', 884640240),
#  ('Craig T. Nelson', 883328576),
#  ('Chris Noth', 878232620),
#  ('Joseph Gordon-Levitt', 877435832),
#  ('Phyllis Smith', 874906101),
#  ('Mia Wasikowska', 870458340),
#  ('Colin Farrell', 865467136),
#  ('Naomi Watts', 864926361),
#  ('Catherine Zeta-Jones', 862954118),
#  ('Reese Witherspoon', 862425360),
#  ('Robbie Coltrane', 860502299),
#  ('Drew Barrymore', 856424409),
#  ('Forest Whitaker', 853551533),
#  ('Paula Patton', 852390780),
#  ('Maggie Grace', 851148760),
#  ('Michael Douglas', 846264947),
#  ('Crispin Glover', 843895173),
#  ('Shailene Woodley', 839380546),
#  ('Christopher Walken', 834792475),
#  ('Adrien Brody', 833276217),
#  ('Kristin Davis', 826406154),
#  ('John Lithgow', 825191875),
#  ('Albert Brooks', 823808214),
#  ('Catherine Keener', 820589644),
#  ('Billy Connolly', 812051007),
#  ('Anna Kendrick', 800607398),
#  ('Zachary Levi', 798194003),
#  ('Vincent Cassel', 795027991),
#  ('David Thewlis', 794194602),
#  ('Sebastian Stan', 791289166),
#  ('Milla Jovovich', 786655780),
#  ('Jim Caviezel', 783829193),
#  ('Chris Wedge', 782244782),
#  ('Judy Greer', 777154799),
#  ('Abigail Breslin', 772064316),
#  ('Ellen DeGeneres', 770625978),
#  ('Alexander Gould', 770625978),
#  ('Dougray Scott', 770598375),
#  ('Scott Glenn', 765359323),
#  ('William Moseley', 763458370),
#  ('Anna Popplewell', 763458370),
#  ('Jon Favreau', 762627789),
#  ('Ashton Kutcher', 761846333),
#  ('Donald Sutherland', 761734071),
#  ('Justin Timberlake', 760455865),
#  ('Patrick Dempsey', 757202471),
#  ('Julia Stiles', 755983128),
#  ('Jae Head', 754237680),
#  ('Freida Pinto', 752770729),
#  ('Eric Bana', 747050749),
#  ('LÃ©a Seydoux', 746344149),
#  ('Dennis Quaid', 745536243),
#  ('Bobby Cannavale', 742563614),
#  ('Vera Farmiga', 739811245),
#  ('Alice Braga', 738196047),
#  ('Tom Hiddleston', 735144708),
#  ('Eva Mendes', 731647728),
#  ('Diane Lane', 730552719),
#  ('Idris Elba', 729513850),
#  ('Ron Perlman', 727076793),
#  ('Jennifer Lopez', 722319779),
#  ('Dakota Fanning', 722124237),
#  ('Marisa Tomei', 720492109),
#  ('Jessica Alba', 718956099),
#  ('Jason Biggs', 718047825),
#  ('Logan Lerman', 716360706),
#  ('Dev Patel', 711318891),
#  ('Jayma Mays', 709799821),
#  ('Richard Roxburgh', 708901267),
#  ('Maria Bello', 707992013),
#  ('Joel Edgerton', 704417211),
#  ('Richard Kind', 703138943),
#  ('Larry the Cable Guy', 701835545),
#  ('Toby Kebbell', 701402999),
#  ('Ray Winstone', 701300816),
#  ('Lewis Black', 699946257),
#  ('Mary Steenburgen', 699297588),
#  ('Keri Russell', 696330761),
#  ('Topher Grace', 693867855),
#  ('Jodie Foster', 692981079),
#  ('Julianne Moore', 691873851),
#  ('Teri Polo', 691336278),
#  ('Helen Hunt', 688540250),
#  ('Michelle Williams', 686220214),
#  ('Cliff Robertson', 682708551),
#  ('Rainn Wilson', 680060118),
#  ('Elizabeth Reaser', 678281159),
#  ('Tom Felton', 676586689),
#  ('Selena Gomez', 676210369),
#  ('Delroy Lindo', 675059230),
#  ('Thomas Kretschmann', 673004361),
#  ('Jeff Daniels', 670281878),
#  ('Bryan Cranston', 668057463),
#  ('Steve Martin', 662007236),
#  ('Sienna Miller', 660670762),
#  ('Terrence Howard', 654463199),
#  ('Zac Efron', 649963240),
#  ('Sarah Jessica Parker', 649315022),
#  ('John C. Reilly', 648400516),
#  ('Barbra Streisand', 647293524),
#  ('Seth MacFarlane', 647231921),
#  ('Katherine Heigl', 647162538),
#  ('Emily Mortimer', 646992715),
#  ('Dane DeHaan', 646176007),
#  ('Kevin McNally', 645340751),
#  ('David Wenham', 645001947),
#  ('Jack Nicholson', 642197880),
#  ('Michael Shannon', 641150621),
#  ('Diane Kruger', 634477126),
#  ('Olga Kurylenko', 633615983),
#  ('Audrey Tautou', 633239851),
#  ('Oliver Platt', 633203913),
#  ('Rowan Atkinson', 632048651),
#  ('Luis GuzmÃ¡n', 630895549),
#  ('Brendan Fraser', 629714029),
#  ('Ellie Kemper', 629450790),
#  ('Cedric the Entertainer', 628899385),
#  ('Michelle Monaghan', 626259328),
#  ('Anton Yelchin', 626210342),
#  ('James Cromwell', 623756015),
#  ('Zooey Deschanel', 623426479),
#  ('Johnny Knoxville', 620515040),
#  ('Kate Winslet', 619303024),
#  ('Ed Asner', 619115486),
#  ('Thomas Ian Nicholas', 618992382),
#  ('Henry Cavill', 616758227),
#  ('Dave Franco', 613786961),
#  ('Karl Urban', 613344026),
#  ('Isla Fisher', 612590868),
#  ('Orto Ignatiussen', 611392705),
#  ('Phaldut Sharma', 611392705),
#  ('Sienna Guillory', 611264335),
#  ('Jennifer Garner', 608226957),
#  ('Philip Seymour Hoffman', 608117250),
#  ('Juno Temple', 606545351),
#  ('Alexandra Daddario', 603808737),
#  ('Dave Bautista', 603312399),
#  ('Karen Allen', 601636033),
#  ('Paul Giamatti', 599499410),
#  ('Kelly Macdonald', 598073029),
#  ('Rhys Ifans', 594437873),
#  ('Rachael Taylor', 594336566),
#  ('Corey Stoll', 593427556),
#  ('Robert Redford', 593392802),
#  ('Alec Baldwin', 591993156),
#  ('John Hannah', 591141913),
#  ('Edward Norton', 589530364),
#  ('Amy Sedaris', 589420142),
#  ('Helmut Bakaitis', 588599701),
#  ('Mickey Rourke', 586892036),
#  ('Rosemary Harris', 583766341),
#  ('Patton Oswalt', 582795167),
#  ('Casey Affleck', 582153994),
#  ('Maia Morgenstern', 581899420),
#  ('Christo Jivkov', 581899420),
#  ('Francesco De Vito', 581899420),
#  ('Rebel Wilson', 579280902),
#  ('Isobelle Molloy', 578410378),
#  ('Evangeline Lilly', 577870671),
#  ('Dakota Johnson', 576427145),
#  ('Billy Crudup', 573934412),
#  ('James Marsden', 571809610),
#  ('Holly Hunter', 571476924),
#  ('Andy Samberg', 571426877),
#  ('Kathy Bates', 569019388),
#  ('Bruce Greenwood', 568430075),
#  ('Leslie Bibb', 568035770),
#  ('Alan Cumming', 566683503),
#  ('Terence Stamp', 565203293),
#  ("Dylan O'Brien", 564576787),
#  ('Kaya Scodelario', 564576787),
#  ('Hugh Grant', 564316793),
#  ('Kyle Gallner', 564171460),
#  ('Domhnall Gleeson', 563794227),
#  ('Tim Robbins', 561525781),
#  ('Bonnie Hunt', 561377092),
#  ('Clive Owen', 560641754),
#  ('Zachary Quinto', 560393348),
#  ('Chris Tucker', 560086749),
#  ('Tobin Bell', 559671044),
#  ('Liev Schreiber', 558666747),
#  ('Martin Lawrence', 557993182),
#  ('Jamie Bell', 557647300),
#  ('Jessica Biel', 557197075),
#  ('Mandy Moore', 556520122),
#  ('Jordan Nagai', 556342744),
#  ('Bob Peterson', 556342744),
#  ('Kim Cattrall', 553822776),
#  ('Colm Feore', 552759977),
#  ('ChloÃ« Grace Moretz', 548674908),
#  ('Melissa McCarthy', 547668075),
#  ('Hailee Steinfeld', 543785173),
#  ('Joel Murray', 543559607),
#  ('Cherry Jones', 540519203),
#  ('Dominique Louis', 539442092),
#  ('Cynthia Nixon', 538600478),
#  ('Lena Headey', 537458756),
#  ('AnnaSophia Robb', 536552784),
#  ('Alan Arkin', 534499217),
#  ('Jean Reno', 534052399),
#  ('Mads Mikkelsen', 532613817),
#  ('Rebecca Ferguson', 532330139),
#  ('Mathieu Amalric', 530691045),
#  ('Kyle Chandler', 530568816),
#  ('Bill Paxton', 529840710),
#  ('Jamie Dornan', 529651467),
#  ('Eloise Mumford', 529651467),
#  ('Miles Teller', 529621773),
#  ('Richard Gere', 528795720),
#  ('Jeffrey Wright', 528642754),
#  ('Tilda Swinton', 528344134),
#  ('Jennifer Ehle', 527336389),
#  ('Goran Visnjic', 526565466),
#  ('Sam Elliott', 526347280),
#  ('Emmy Rossum', 525596106),
#  ('Juliette Binoche', 525517827),
#  ('Benedict Cumberbatch', 525471273),
#  ('Dominic West', 524830589),
#  ('Lisa Ann Walter', 524701295),
#  ('Harvey Keitel', 524225881),
#  ('David Spade', 522975263),
#  ('Oded Fehr', 522125942),
#  ('Alfre Woodard', 521936035),
#  ('Christopher Eccleston', 520685031),
#  ('Maya Rudolph', 518434765),
#  ('Victor Rasuk', 518063424),
#  ('Michael Chiklis', 514038655),
#  ('Anthony Mackie', 514005153),
#  ('Ian Holm', 513280933),
#  ('Regina Hall', 512855582),
#  ('Joel McHale', 512793141),
#  ('Freddie Highmore', 509788079),
#  ('Jamie Chung', 505687664),
#  ('Suraj Sharma', 502324192),
#  ('Timothy Olyphant', 500434857),
#  ('Gemma Arterton', 500287903),
#  ('David Andrews', 499692268),
#  ('Alison Brie', 499581896),
#  ('Jai Courtney', 497432334),
#  ('Miranda Otto', 497367502),
#  ('Ice Cube', 494678205),
#  ('Michael Clarke Duncan', 494368059),
#  ('Winona Ryder', 493716892),
#  ('Ayush Tandon', 489016565),
#  ('Gautam Belur', 489016565),
#  ('Adil Hussain', 489016565),
#  ('Jet Li', 487323184),
#  ('Scott Adsit', 487105443),
#  ('Ryan Potter', 487105443),
#  ('Daniel Henney', 487105443),
#  ('T.J. Miller', 487105443),
#  ('Djimon Hounsou', 486979697),
#  ('Olivia Wilde', 486327016),
#  ('Christine Baranski', 483918135),
#  ('Sam Neill', 483823850),
#  ('Cole Konis', 483507423),
#  ('Ben Reed', 483507423),
#  ('Taraji P. Henson', 483329975),
#  ('Rick Yune', 481717388),
#  ('Brian Dennehy', 480565360),
#  ('Ali Larter', 479064187),
#  ('Daryl Sabara', 478903383),
#  ('Ansel Elgort', 478389466),
#  ('Charlie Tahan', 477840078),
#  ('Kris Kristofferson', 477657760),
#  ('Aaron Taylor-Johnson', 475223287),
#  ('Lou Romano', 473722818),
#  ('Peter Sohn', 473722818),
#  ('Rip Torn', 470015453),
#  ('Emily Watson', 466713286),
#  ('Jake Cherry', 464480841),
#  ('Dick Van Dyke', 464480841),
#  ('Carlos Alazraqui', 464466481),
#  ('Lily James', 463958096),
#  ('Heather Graham', 463828734),
#  ('Clint Eastwood', 463805523),
#  ('Diego Luna', 458424322),
#  ('Hayden Panettiere', 457187783),
#  ('Justin Chatwin', 456549492),
#  ('Zach Braff', 456301213),
#  ('Tina Fey', 454873580),
#  ('James Caan', 454771605),
#  ('Nikolaj Coster-Waldau', 454447536),
#  ('J.K. Simmons', 453964231),
#  ('Julian McMahon', 453774314),
#  ('Anthony Anderson', 452314844),
#  ('William Fichtner', 452167599),
#  ('Dan Castellaneta', 452068851),
#  ('Julie Kavner', 452068851),
#  ('Nancy Cartwright', 452068851),
#  ('Yeardley Smith', 452068851),
#  ('Theo James', 451386096),
#  ('Josh Hartnett', 448026707),
#  ('Mary Gibbs', 447816256),
#  ('James Coburn', 447816256),
#  ('Richard Madden', 447351353),
#  ('Holliday Grainger', 447351353),
#  ('Jeff Garlin', 445745727),
#  ('Bernie Mac', 444693491),
#  ('Jim Broadbent', 443352706),
#  ('Paul Newman', 442984627),
#  ('Sarah Michelle Gellar', 442870153),
#  ('Roselyn SÃ¡nchez', 441065487),
#  ('Ryan Gosling', 440211949),
#  ('Brittany Snow', 436873169),
#  ('Noomi Rapace', 436109472),
#  ('Salli Richardson-Whitfield', 435349010),
#  ('Willow Smith', 435349010),
#  ('Chris Klein', 435282191),
#  ('Eddie Kaye Thomas', 434002798),
#  ('John Turturro', 432768918),
#  ('Hilary Swank', 432696905),
#  ('Patrick Wilson', 430331003),
#  ('Katie Holmes', 430070539),
#  ('Adam Scott', 429541084),
#  ('Lainie Kazan', 428606561),
#  ('Michael Ealy', 428540162),
#  ('Amber Valletta', 426295632),
#  ('Cloris Leachman', 425220295),
#  ('Adam Brody', 423513599),
#  ('Michael Stuhlbarg', 423457110),
#  ('Choi Min-sik', 423360063),
#  ('Amr Waked', 423360063),
#  ('Julian Rhind-Tutt', 423360063),
#  ('CiarÃ¡n Hinds', 423311648),
#  ('Matthew Gray Gubler', 421362739),
#  ('Dash Mihok', 419272402),
#  ('Jay O. Sanders', 419272402),
#  ('TÃ©a Leoni', 417593371),
#  ('Pamela Anderson', 416245961),
#  ('Ray Liotta', 415719306),
#  ('Dane Cook', 413151166),
#  ('Cliff Curtis', 412941831),
#  ('Alex Pettyfer', 412826358),
#  ('Craig Berry', 409160692),
#  ('David Burrows', 409160692),
#  ('Bill Murray', 407752684),
#  ('Nicholas Hoult', 407587394),
#  ('Dolph Lundgren', 407043817),
#  ('Arnold Vosloo', 405891190),
#  ('Costas Mandylor', 405794229),
#  ('Betsy Russell', 405794229),
#  ('Marton Csokas', 405228619),
#  ('Philip Baker Hall', 404572835),
#  ('Catherine Bell', 404572835),
#  ('Imelda Staunton', 404212575),
#  ('Paul Dano', 403873413),
#  ('Nick Nolte', 403445301),
#  ('John Travolta', 403405634),
#  ('William Hurt', 403331749),
#  ('Rob Riggle', 402801764),
#  ('Radha Mitchell', 401932263),
#  ('Sarah Silverman', 400313407),
#  ('Taylor Swift', 399385595),
#  ('Will Poulter', 397950503),
#  ('Paul Anderson', 397950503),
#  ('Franka Potente', 397816737),
#  ('Tom Wilkinson', 397238043),
#  ('Margot Robbie', 395863657),
#  ('Will.i.am', 394635760),
#  ('Skylar Astin', 391922292),
#  ('Alyson Hannigan', 389987213),
#  ('Karin Konoval', 389860185),
#  ('Hiroyuki Sanada', 389425381),
#  ('Michael Cera', 387768635),
#  ('Carey Mulligan', 387018110),
#  ('Giancarlo Giannini', 386090727),
#  ('David Strathairn', 385951240),
#  ('Charlie Day', 384294109),
#  ('Eric Dane', 383087803),
#  ('Peter Sarsgaard', 382395787),
#  ('Mireille Enos', 382248361),
#  ('Linda Cardellini', 382011095),
#  ('Sterling Jerins', 381283872),
#  ('Kevin Hart', 377789603),
#  ('Rade Serbedzija', 375451072),
#  ('Nia Long', 375064250),
#  ('Tyler Perry', 373940912),
#  ('BeyoncÃ© Knowles', 372401927),
#  ('Garrett Hedlund', 371812586),
#  ('Cuba Gooding Jr.', 370912485),
#  ('Robert Patrick', 370580110),
#  ('Uma Thurman', 368211132),
#  ('Kate Hudson', 366959265),
#  ('Nat Wolff', 366663565),
#  ('Miley Cyrus', 365967227),
#  ('Christina Applegate', 365757395),
#  ('Victor Garber', 365624623),
#  ('Jonathan Rhys Meyers', 364700455),
#  ('Billy Bob Thornton', 364246828),
#  ('Kevin Bacon', 363771092),
#  ('Brandon T. Jackson', 363764023),
#  ('John Corbett', 363744044),
#  ('Michael Constantine', 363744044),
#  ('Andrea Martin', 363744044),
#  ('Vincent Regan', 363481532),
#  ('Archie Panjabi', 363419703),
#  ('Mia Drake Inderbitzin', 362910544),
#  ('Saurabh Shukla', 362910544),
#  ('Jason Sudeikis', 362232725),
#  ('Joey King', 360366878),
#  ('Al Pacino', 360333201),
#  ('Rami Malek', 359701918),
#  ('Robin Wright', 358996629),
#  ('Nia Vardalos', 358540336),
#  ('Kevin McKidd', 356887926),
#  ('Fred Willard', 355436781),
#  ('Oliver Reed', 354640427),
#  ('Alexa PenaVega', 353669520),
#  ('Scott Speedman', 352866375),
#  ('Max von Sydow', 352453040),
#  ('Alan Ritchson', 352200000),
#  ('Noel Fisher', 352200000),
#  ('Clancy Brown', 348706648),
#  ('Jordi MollÃ\xa0', 348607282),
#  ('Dominic Cooper', 348087876),
#  ('Tom Kenny', 347755824),
#  ('Bill Fagerbakke', 347755824),
#  ('Rodger Bumpass', 347755824),
#  ('Carolyn Lawrence', 347755824),
#  ('Thomas Brodie-Sangster', 347746748),
#  ('Paddy Considine', 346688379),
#  ('William H. Macy', 344483139),
#  ('Katie Cassidy', 344397443),
#  ('Elizabeth Olsen', 343937091),
#  ('America Ferrera', 343931820),
#  ('Ben Burtt', 341311860),
#  ('Elissa Knight', 341311860),
#  ('John Ratzenberger', 341311860),
#  ('Taron Egerton', 340775130),
#  ('Colin Hanks', 340483410),
#  ('Jeffrey Garcia', 340271840),
#  ('Paul Sanchez', 339632142),
#  ('Lari White', 339632142),
#  ('Mary Elizabeth Winstead', 339393405),
#  ('Wendi McLendon-Covey', 339378133),
#  ('Katie Featherston', 338521810),
#  ('Sprague Grayden', 338521810),
#  ('Connie Nielsen', 337764917),
#  ('Marlon Wayans', 337371291),
#  ('John Hurt', 336626586),
#  ('Christine Taylor', 336394656),
#  ('Rory Culkin', 336247917),
#  ('Sebastian Koch', 335264655),
#  ('Jeffrey Tambor', 335133080),
#  ('Zhang Ziyi', 334568764),
#  ('Cheech Marin', 333362142),
#  ('Abigail Hargrove', 331865000),
#  ('Lake Bell', 331830154),
#  ('Donna Murphy', 331794936),
#  ('M.C. Gainey', 331794936),
#  ('Luke Grimes', 331141306),
#  ('Will Patton', 331099921),
#  ('Rob Corddry', 330479849),
#  ('Abbie Cornish', 329521191),
#  ('Chris Cooper', 328901914),
#  ('Rihanna', 327896492),
#  ('Rosario Dawson', 325549017),
#  ('Ike Barinholtz', 325168453),
#  ('Julia Winter', 324968763),
#  ('Kiefer Sutherland', 324558368),
#  ('Christopher Mintz-Plasse', 324114566),
#  ('Ginnifer Goodwin', 320600237),
#  ('Regina King', 320148152),
#  ('Yu Rong-Guang', 317852395),
#  ('Tess Liu', 317852395),
#  ('Alessandro Nivola', 317701448),
#  ('Candice Bergen', 317622424),
#  ('William Atherton', 316758981),
#  ('Chad Lindberg', 316758981),
#  ('Josh Lucas', 316071535),
#  ('Steve Zahn', 315899202),
#  ('Barbara Hershey', 314803731),
#  ('Craig Ferguson', 314338759),
#  ('Ki Hong Lee', 314319861),
#  ('Aml Ameen', 314319861),
#  ('Blake Cooper', 314319861),
#  ('Kathleen Turner', 313919386),
#  ('Eddie Izzard', 313883436),
#  ('Carmen Electra', 313666602),
#  ('Bailee Madison', 313503850),
#  ('Malin Ã…kerman', 311396283),
#  ('Brie Larson', 308954009),
#  ('Carrie Coon', 308330363),
#  ('Amy Smart', 307241727),
#  ('Michael B. Jordan', 307184973),
#  ('Jack McBrayer', 306222889),
#  ('Jamie Elman', 306222889),
#  ('Lili Taylor', 305000141),
#  ('Johnny A. Sanchez', 304742074),
#  ('Ben Whishaw', 304547718),
#  ('Lauren Holly', 304111707),
#  ('Mark Feuerstein', 304111707),
#  ('Lindsay Lohan', 304093222),
#  ('Daryl Hannah', 303335530),
#  ('Cole Hauser', 303071262),
#  ('Bruce McGill', 302157427),
#  ('Laura Dern', 302152061),
#  ('Ron Livingston', 302080819),
#  ('Lara Flynn Boyle', 301818803),
#  ('Cameron Richardson', 301366633),
#  ('Vanessa Hudgens', 300863056),
#  ('Miranda Richardson', 299996214),
#  ('Brittany Murphy', 299458824),
#  ('Kelly Reilly', 298947962),
#  ('Ray Stevenson', 298241422),
#  ('Ken Davitian', 298219575),
#  ('Julie Ann Emery', 298100420),
#  ('Debra Messing', 297604990),
#  ('Benicio del Toro', 295610402),
#  ('Jackie Earle Haley', 295570609),
#  ('Tao Okamoto', 295440673),
#  ('Rila Fukushima', 295440673),
#  ('Svetlana Khodchenkova', 295440673),
#  ('Dan Aykroyd', 293584844),
#  ('Sam Trammell', 293151265),
#  ('Mekhi Phifer', 293003144),
#  ('Piper Perabo', 292553004),
#  ('Rob Reiner', 292000694),
#  ('Toby Stephens', 291971116),
#  ('Maggie Q', 291840595),
#  ('MÃ©lanie Laurent', 291829944),
#  ('Sam Rockwell', 291694934),
#  ('Toni Collette', 290270905),
#  ('Betty White', 289380279),
#  ('Danny DeVito', 289182477),
#  ('Nick Frost', 289106272),
#  ('Aidan Gillen', 285860739),
#  ('Tim McGraw', 285737503),
#  ('Emilia Clarke', 285603537),
#  ('Iain Glen', 285299105),
#  ('Lombardo Boyar', 284335608),
#  ('Eugene Levy', 284226112),
#  ('Morris Chestnut', 283900987),
#  ('Kim Coates', 283829116),
#  ('Selma Blair', 283812094),
#  ('Li Bingbing', 283565879),
#  ('Rhona Mitra', 283330100),
#  ('Rufus Sewell', 283067629),
#  ('John Ortiz', 282906331),
#  ('Matt Dillon', 281560659),
#  ('Hugh Laurie', 281559499),
#  ('Quinton Aaron', 280208309),
#  ('Aaron Paul', 280059764),
#  ('Tim Roth', 279208440),
#  ('Elizabeth Debicki', 279185528),
#  ('Blythe Danner', 278444045),
#  ('Simon Baker', 276785665),
#  ('Jason Isaacs', 275983276),
#  ('Trevor Morgan', 275780809),
#  ('Mary Alice', 274988211),
#  ('Dwight Yoakam', 274658879),
#  ('Claire Danes', 273673663),
#  ('Mike Vogel', 273115409),
#  ('David Carradine', 273108461),
#  ('Sean Penn', 271696359),
#  ('Albert Finney', 271259703),
#  ('Hilary Duff', 270610291),
#  ('RamÃ³n RodrÃ\xadguez', 269744392),
#  ('Maggie Gyllenhaal', 269674681),
#  ('Greg Kinnear', 269235857),
#  ('Jessica Lange', 268946856),
#  ('Christina Ricci', 268257275),
#  ('Courteney Cox', 267852767),
#  ('Jenny Slate', 267695435),
#  ('Andy Buckley', 267695435),
#  ('Amy Ryan', 267684432),
#  ('Haley Joel Osment', 267313963),
#  ('Kurt Russell', 265634340),
#  ('Seth Green', 264975627),
#  ('Jean Smart', 264566577),
#  ('Michelle Pfeiffer', 264177927),
#  ('Dermot Mulroney', 263242401),
#  ('Katy Perry', 263161134),
#  ('Lynn Collins', 262837708),
#  ('Gary Sweet', 260686217),
#  ('Arthur Angel', 260686217),
#  ('Robert Duvall', 260013146),
#  ('Asia Argento', 259693324),
#  ('Dave Sheridan', 259019771),
#  ('Jon Abrahams', 259019771),
#  ('Bridget Moynahan', 258879115),
#  ('Teresa Palmer', 258404013),
#  ('Keith David', 257437977),
#  ('Adam G. Sevani', 257108509),
#  ('Ben Mendelsohn', 256408655),
#  ('Lois Smith', 256372926),
#  ('Luke Ford', 256128639),
#  ('Rachel Covey', 255487652),
#  ('Ernie Reyes, Jr.', 253242294),
#  ('Rebecca Hall', 253067472),
#  ('Brian Howe', 252077295),
#  ('James Karen', 252077295),
#  ('Elisabeth Shue', 252046440),
#  ('Joel Kinnaman', 251968388),
#  ('Eli Roth', 249131050),
#  ('Annabelle Wallis', 248773813),
#  ('Eric Ladin', 248773813),
#  ('Tony Amendola', 248773813),
#  ('Gabriel Bateman', 248773813),
#  ('Jessica Lowndes', 248586800),
#  ('Gia Mantegna', 248586800),
#  ('Tom Welling', 247595375),
#  ('Haley Bennett', 247560950),
#  ('Derek Mears', 247182526),
#  ('Gemma Jones', 247132815),
#  ('David Harbour', 243864415),
#  ('Luenell', 243572744),
#  ('Bob Barr', 243572744),
#  ('Samantha Morton', 241936482),
#  ('Tom McGrath', 241552094),
#  ('Chris Miller', 241552094),
#  ('Christopher Knights', 241552094),
#  ('Conrad Vernon', 241552094),
#  ('Luke Wilson', 238940820),
#  ('Taylor Kitsch', 237787675),
#  ('Mike Epps', 237458441),
#  ('Christopher Carley', 236958228),
#  ('Bee Vang', 236958228),
#  ('Ahney Her', 236958228),
#  ('Brian Haley', 236958228),
#  ('Wentworth Miller', 236221663),
#  ('Kacey Barnfield', 236221663),
#  ('Leonard Nimoy', 235680446),
#  ('Nick Stahl', 235000000),
#  ('D. B. Sweeney', 234970792),
#  ('Raini Rodriguez', 234890373),
#  ('Yaya DaCosta', 234804829),
#  ('Matt Jones', 233871007),
#  ('Michael York', 233633907),
#  ('Mindy Sterling', 233633907),
#  ('Adam Goldberg', 232928991),
#  ('Scott Patterson', 232410166),
#  ('Jessica Lucas', 231736080),
#  ('Kevin Durand', 231187166),
#  ('Charlie Sheen', 231051961),
#  ('Simon Rex', 231051961),
#  ('Patricia Clarkson', 230898767),
#  ('Michael Sheen', 230753273),
#  ('Bruce Boxleitner', 230062763),
#  ('David Koechner', 229048314),
#  ('Hugh Keays-Byrne', 228436354),
#  ('Josh Helman', 228436354),
#  ('Burn Gorman', 227602906),
#  ('Sullivan Stapleton', 227580051),
#  ('Callan Mulvey', 227580051),
#  ('DemiÃ¡n Bichir', 227434297),
#  ('Alan Tudyk', 227234916),
#  ('Marion Cotillard', 227113544),
#  ('Charlie Hunnam', 226961836),
#  ('Ossie Davis', 226748063),
#  ('Max Casella', 226748063),
#  ('Sam Claflin', 226600000),
#  ('Jennifer Coolidge', 226396741),
#  ('Marg Helgenberger', 225908549),
#  ('Jon Bernthal', 225903742),
#  ('Kellan Lutz', 223847506),
#  ('Hayley Atwell', 223774065),
#  ('Harry Connick Jr.', 222675086),
#  ('Taylor Momsen', 222141403),
#  ('Bill Irwin', 222141403),
#  ('Shaun Toub', 221778970),
#  ('Viola Davis', 221393401),
#  ('Camilla Belle', 220432286),
#  ('Ty Burrell', 220321935),
#  ('Stacy Keach', 220102693),
#  ('Rory Kinnear', 219555708),
#  ('Allen Leech', 219555708),
#  ('Cillian Murphy', 219380845),
#  ('Noah Taylor', 218708728),
#  ('Matthew Broderick', 218402345),
#  ('Jeremy Irons', 218347965),
#  ('Odette Annable', 218283324),
#  ('Gabrielle Union', 218048807),
#  ('Meagan Good', 218025354),
#  ('Matthew Goode', 217572727),
#  ('Sanaa Lathan', 217305912),
#  ('John Hawkes', 216909849),
#  ('James Garner', 216541086),
#  ('Kevin Kline', 215296890),
#  ('January Jones', 213924167),
#  ('Ben Barnes', 213830026),
#  ('Gene Hackman', 213193625),
#  ('Yuliya Snigir', 212654182),
#  ('Kristanna Loken', 212405420),
#  ('Matthew Lillard', 210976969),
#  ('Ludacris', 210767566),
#  ('Julia Ormond', 210210178),
#  ('Joel Courtney', 210095987),
#  ('Riley Griffiths', 210095987),
#  ('Ryan Lee', 210095987),
#  ('Jake Johnson', 210087448),
#  ('Shawn Wayans', 209902274),
#  ('Kim Basinger', 209613391),
#  ('Val Kilmer', 209136681),
#  ('Heather Matarazzo', 208904109),
#  ('Susan Sarandon', 208618170),
#  ('Wanda Sykes', 208548258),
#  ('Jared Harris', 208392465),
#  ('Harry Lloyd', 208158639),
#  ('Jennifer Jason Leigh', 208091055),
#  ('Martin Henderson', 207895130),
#  ('Michael Roof', 207448382),
#  ('Rooney Mara', 207201893),
#  ('Ayelet Zurer', 206613439),
#  ('Pierfrancesco Favino', 206613439),
#  ('Tracy Morgan', 205996766),
#  ('T.I.', 205476463),
#  ('Gregor Fisher', 204931766),
#  ('Max Baldry', 204736344),
#  ('Emma de Caunes', 204736344),
#  ('Spencer Breslin', 204577968),
#  ('Peter Capaldi', 204207227),
#  ('Nicola Peltz', 204002923),
#  ('Carol Burnett', 203543259),
#  ('Holly Valance', 201830568),
#  ('David Dorfman', 201348933),
#  ('Shannon Cochran', 201348933),
#  ('Yvan Attal', 200967156),
#  ('Lauren Bittner', 200703818),
#  ('Christopher Nicholas Smith', 200703818),
#  ('Chloe Csengery', 200703818),
#  ('Alan Alda', 200541096),
#  ('Moon Bloodgood', 200396057),
#  ('Jim Parsons', 200319392),
#  ...]

# %%
answer_ls.append(1)

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
cnt = Counter()
#data_17 = data2[(data2.profit > 0) & (data2.release_year == 2012)]#.cast.str.split('|').tolist()
data_17 = data2[data2.release_year == 2012]
for i in range(0,len(data_17)):
   for actor in data_17.iloc[i].cast.split('|'):
    cnt[actor] += data_17.iloc[i].profit
cnt.most_common()[-1]
# Out:
# ('Kirsten Dunst', -68109207)

# %%
def to_dict_from_series(list_to_dict, values):
    dictionary = {}
    for i in range(0,len(list_to_dict)):
        for word in list_to_dict[i]:
            if word in dictionary:
                dictionary[word] += values[i]
            else:
                dictionary[word] = values[i]
    return(dictionary)

actors = to_dict_from_series(data_17.cast.str.split('|').tolist(), data_17.profit.tolist())
actors
# Out:
# {'Robert Downey Jr.': 1299557910,
#  'Chris Evans': 1299557910,
#  'Mark Ruffalo': 1299557910,
#  'Chris Hemsworth': 1542450773,
#  'Scarlett Johansson': 1299557910,
#  'Kate Beckinsale': 174302074,
#  'Stephen Rea': 62400000,
#  'Michael Ealy': 146470507,
#  'Theo James': 62400000,
#  'India Eisley': 62400000,
#  'Christian Bale': 831041287,
#  'Michael Caine': 831041287,
#  'Gary Oldman': 831041287,
#  'Anne Hathaway': 1211851057,
#  'Tom Hardy': 858717867,
#  'Jamie Foxx': 325368238,
#  'Christoph Waltz': 325368238,
#  'Leonardo DiCaprio': 325368238,
#  'Kerry Washington': 307412515,
#  'Samuel L. Jackson': 325368238,
#  'Daniel Craig': 908561013,
#  'Judi Dench': 908561013,
#  'Javier Bardem': 908561013,
#  'Ralph Fiennes': 1059561013,
#  'Naomie Harris': 908561013,
#  'Jeremy Renner': 146572938,
#  'Rachel Weisz': 146572938,
#  'Edward Norton': 198836104,
#  'Scott Glenn': 146572938,
#  'Stacy Keach': 146572938,
#  'Ian McKellen': 767003568,
#  'Martin Freeman': 767003568,
#  'Richard Armitage': 767003568,
#  'Andy Serkis': 767003568,
#  'Cate Blanchett': 767003568,
#  'Noomi Rapace': 273170142,
#  'Michael Fassbender': 283542748,
#  'Charlize Theron': 499770142,
#  'Idris Elba': 273170142,
#  'Guy Pearce': 313050752,
#  'Bradley Cooper': 191970175,
#  'Jennifer Lawrence': 800949406,
#  'Robert De Niro': 184738714,
#  'Jacki Weaver': 184738714,
#  'Chris Tucker': 184738714,
#  'Andrew Garfield': 537215857,
#  'Emma Stone': 537215857,
#  'Rhys Ifans': 561125608,
#  'Denis Leary': 1319460639,
#  'Martin Sheen': 537215857,
#  'Kelly Macdonald': 353983207,
#  'Julie Walters': 353983207,
#  'Billy Connolly': 402503505,
#  'Emma Thompson': 753009983,
#  'Kevin McKidd': 353983207,
#  'Kristen Stewart': 919384318,
#  'Sam Claflin': 226600000,
#  'Ian McShane': 226600000,
#  'Channing Tatum': 496294075,
#  'Jonah Hill': 159585328,
#  'Brie Larson': 159585328,
#  'Dave Franco': 159585328,
#  'Ellie Kemper': 159585328,
#  'Suraj Sharma': 489016565,
#  'Irrfan Khan': 489016565,
#  'Ayush Tandon': 489016565,
#  'Gautam Belur': 489016565,
#  'Adil Hussain': 489016565,
#  'John Leguizamo': 779138503,
#  'Ray Romano': 782244782,
#  'Chris Wedge': 782244782,
#  'Seann William Scott': 967234366,
#  'Mark Wahlberg': 537468315,
#  'Mila Kunis': 499368315,
#  'Seth MacFarlane': 499368315,
#  'Joel McHale': 499368315,
#  'Giovanni Ribisi': 537468315,
#  'Tom Cruise': 142759208,
#  'Rosamund Pike': 309340595,
#  'Richard Jenkins': 158340595,
#  'David Oyelowo': 150705972,
#  'Werner Herzog': 158340595,
#  'Naomi Watts': 138274123,
#  'Ewan McGregor': 148646729,
#  'Tom Holland': 138274123,
#  'Samuel Joslin': 138274123,
#  'Oaklee Pendergast': 138274123,
#  'John C. Reilly': 306222889,
#  'Sarah Silverman': 306222889,
#  'Jane Lynch': 331042190,
#  'Jack McBrayer': 306222889,
#  'Jamie Elman': 306222889,
#  'Anna Kendrick': 226316209,
#  'Skylar Astin': 98350426,
#  'Brittany Snow': 98350426,
#  'Anna Camp': 98350426,
#  'Rebel Wilson': 98350426,
#  'Will Smith': 399026776,
#  'Tommy Lee Jones': 483307827,
#  'Josh Brolin': 399026776,
#  'Michael Stuhlbarg': 399026776,
#  'Josh Hutcherson': 872710235,
#  'Liam Hemsworth': 616210692,
#  'Woody Harrelson': 620632953,
#  'Elizabeth Banks': 656566659,
#  'Colin Farrell': 78224335,
#  'Jessica Biel': 73802074,
#  'Bryan Cranston': 238410192,
#  'Bill Nighy': 73802074,
#  'Tom Hanks': 28482868,
#  'Halle Berry': 28482868,
#  'Jim Broadbent': 28482868,
#  'Hugo Weaving': 28482868,
#  'Jim Sturgess': -23410657,
#  'Sylvester Stallone': 212573423,
#  'Jason Statham': 222919609,
#  'Dolph Lundgren': 212573423,
#  'Bruce Willis': 263378341,
#  'Arnold Schwarzenegger': 212573423,
#  'Liam Neeson': 482141306,
#  'Maggie Grace': 343345336,
#  'Famke Janssen': 331141306,
#  'Rade Serbedzija': 331141306,
#  'Luke Grimes': 331141306,
#  'Johnny Depp': 95527149,
#  'Michelle Pfeiffer': 91961927,
#  'Helena Bonham Carter': 95527149,
#  'Jackie Earle Haley': 95527149,
#  'Jonny Lee Miller': 95527149,
#  'Logan Lerman': 20400000,
#  'Emma Watson': 20400000,
#  'Ezra Miller': 20400000,
#  'Paul Rudd': 62618720,
#  'Nina Dobrev': 20400000,
#  'Ben Affleck': 187824128,
#  'Alan Arkin': 187824128,
#  'John Goodman': 187824128,
#  'Victor Garber': 187824128,
#  'Jason Biggs': 184989584,
#  'Alyson Hannigan': 184989584,
#  'Chris Klein': 184989584,
#  'Thomas Ian Nicholas': 184989584,
#  'Matthew McConaughey': 160221571,
#  'Olivia Munn': 160221571,
#  'Cody Horn': 160221571,
#  'Alex Pettyfer': 160221571,
#  'Kristen Connolly': 36486080,
#  'Anna Hutchison': 36486080,
#  'Fran Kranz': 36486080,
#  'Jesse Williams': 36486080,
#  'Chris Pine': 158376448,
#  'Alec Baldwin': 146360283,
#  'Jude Law': 161941670,
#  'Isla Fisher': 161941670,
#  'Hugh Jackman': 542751440,
#  'Rachel McAdams': 166114570,
#  'Sam Neill': 166114570,
#  'Scott Speedman': 166114570,
#  'Jessica Lange': 166114570,
#  'Dwayne Johnson': 276692760,
#  'Kristin Davis': 276692760,
#  'Vanessa Hudgens': 276692760,
#  'Luis GuzmÃ¡n': 276692760,
#  'Chris Sarandon': 10346186,
#  'James Hong': 10346186,
#  'Catherine Chan': 10346186,
#  'Robert John Burke': 10346186,
#  'Benjamin Walker': 43265139,
#  'Dominic Cooper': 43265139,
#  'Anthony Mackie': 43265139,
#  'Mary Elizabeth Winstead': 43265139,
#  'Rufus Sewell': 43265139,
#  'Kirsten Dunst': -68109207,
#  'Timothy Spall': -51893525,
#  'James Kidnie': -51893525,
#  'Heidi Hawkins': -51893525,
#  'Zac Efron': 278840316,
#  'Danny DeVito': 278840316,
#  'Taylor Swift': 278840316,
#  'Ed Helms': 278840316,
#  'Rob Riggle': 278840316,
#  'Jared Gilman': 52263166,
#  'Kara Hayward': 52263166,
#  'Bill Murray': 52263166,
#  'Karl Urban': -8962258,
#  'Olivia Thirlby': -8962258,
#  'Lena Headey': -8962258,
#  'Wood Harris': -8962258,
#  'Jason Cope': -8962258,
#  'Taylor Kitsch': 120164585,
#  'Alexander SkarsgÃ¥rd': 94025485,
#  'Rihanna': 94025485,
#  'Brooklyn Decker': 133725485,
#  'Tadanobu Asano': 94025485,
#  'Russell Crowe': 380809770,
#  'Amanda Seyfried': 380809770,
#  'Sacha Baron Cohen': 1097110577,
#  'Julia Roberts': 98018522,
#  'Lily Collins': 98018522,
#  'Armie Hammer': 98018522,
#  'Nathan Lane': 98018522,
#  'Martin Klebba': 98018522,
#  'Lynn Collins': 24139100,
#  'Mark Strong': 116959816,
#  'Willem Dafoe': 24139100,
#  'CiarÃ¡n Hinds': 134869836,
#  'Joseph Gordon-Levitt': 13125599,
#  'Emily Blunt': 40951751,
#  'Paul Dano': 17042000,
#  'Noah Segan': 17042000,
#  'Robert Pattinson': 694563556,
#  'Taylor Lautner': 709000000,
#  'Peter Facinelli': 709000000,
#  'Elizabeth Reaser': 709000000,
#  'Jessica Chastain': 120497296,
#  'Jason Clarke': 92820716,
#  'Joel Edgerton': 92820716,
#  'Chris Pratt': 116730467,
#  'Gina Carano': 10372606,
#  'Bill Paxton': 10372606,
#  'Sam Worthington': 155221189,
#  'Edgar RamÃ\xadrez': 151000000,
#  'Kathryn McCormick': 107470746,
#  'Ryan Guzman': 107470746,
#  'Stephen Boss': 107470746,
#  'Megan Boone': 107470746,
#  'Jessica Guadix': 107470746,
#  'Dane DeHaan': 130000000,
#  'Alex Russell': 130000000,
#  'Michael B. Jordan': 130000000,
#  'Michael Kelly': 130000000,
#  'Anna Wood': 130000000,
#  'Roselyn SÃ¡nchez': 69272766,
#  'Emilio Rivera': 69272766,
#  'Nestor Serrano': 69272766,
#  'Gonzalo Menendez': 69272766,
#  'Alexander Asefa': 69272766,
#  'Adam Sandler': 261433970,
#  'Steve Buscemi': 273375603,
#  'David Spade': 273375603,
#  'Kevin James': 273375603,
#  'Selena Gomez': 273375603,
#  'Jake Gyllenhaal': 41126384,
#  'Michael PeÃ±a': 41126384,
#  'Natalie Martinez': 41126384,
#  'David Harbour': 41126384,
#  'Cameron Diaz': 39700000,
#  'Jennifer Lopez': 39700000,
#  'Sayed Badreya': 114379533,
#  'Aasif Mandvi': 114379533,
#  'Megan Fox': 167438319,
#  'Anna Faris': 114379533,
#  'Oliver Cooper': 88000000,
#  'Jonathan Daniel Brown': 88000000,
#  'Thomas Mann': 88000000,
#  'Dax Flame': 88000000,
#  'Kirby Bliss Blanton': 88000000,
#  'Ben Foster': 38100000,
#  'J.K. Simmons': 38100000,
#  'Ben Stiller': 601921274,
#  'David Schwimmer': 601921274,
#  'Frances McDormand': 595060062,
#  'Chris Rock': 601921274,
#  'Shia LaBeouf': 27676580,
#  'Mia Wasikowska': 27676580,
#  'John Cusack': 3657751,
#  'Luke Evans': 3657751,
#  'Alice Eve': 3657751,
#  'Brendan Gleeson': 185072317,
#  'Kevin McNally': 3657751,
#  'Diego Boneta': -15581387,
#  'Julianne Hough': -15581387,
#  'Nicolas Cage': -32893443,
#  'Malin Ã…kerman': -43733509,
#  'Josh Lucas': -32893443,
#  'Sami Gayle': -32893443,
#  'Danny Huston': -32893443,
#  'Hugh Grant': 58338361,
#  'Jeremy Piven': 58338361,
#  'Brian Blessed': 58338361,
#  'Salma Hayek': 60338361,
#  'Joaquin Phoenix': -3741940,
#  'Philip Seymour Hoffman': -3741940,
#  'Amy Adams': -3741940,
#  'Laura Dern': -3741940,
#  'Jesse Plemons': -3741940,
#  'Alison Brie': 23909751,
#  'Jason Segel': 76968537,
#  'Leslie Mann': 53058786,
#  'Maude Apatow': 53058786,
#  'Joseph Gilgun': 12204030,
#  'Lennie James': 12204030,
#  'Peter Stormare': 12204030,
#  'Jennifer Aniston': -10840066,
#  'Justin Theroux': -10840066,
#  'Lauren Ambrose': -10840066,
#  'Daniel Radcliffe': 110730736,
#  'Sidney Johnston': 110730736,
#  'Alisa Khazanova': 110730736,
#  'Mary Stockley': 110730736,
#  'Charlie Tahan': 42491068,
#  'Winona Ryder': 42491068,
#  "Catherine O'Hara": 42491068,
#  'Martin Short': 42491068,
#  'Martin Landau': 42491068,
#  'Susan Sarandon': 11543423,
#  'Eva Amurri Martino': -11941633,
#  'Leighton Meester': -11941633,
#  'Andy Samberg': -11941633,
#  'Denzel Washington': 123076205,
#  'Ryan Reynolds': 123076205,
#  'Vera Farmiga': 123076205,
#  'Joel Kinnaman': 123076205,
#  'Blake Lively': 2000000,
#  'Aaron Taylor-Johnson': 2000000,
#  'Benicio del Toro': 2000000,
#  'Jamie Bell': 4221189,
#  'Ed Harris': 4221189,
#  'Edward Burns': 4221189,
#  'Sam Rockwell': 4422261,
#  'Christopher Walken': 4422261,
#  'Abbie Cornish': 4422261,
#  'Drew Barrymore': -15280785,
#  'John Krasinski': -22141997,
#  'Kristen Bell': -15280785,
#  'Vinessa Shaw': -15280785,
#  'Dermot Mulroney': -15280785,
#  'Jason Bateman': -6571952,
#  'Hope Davis': -6571952,
#  'Frank Grillo': -6571952,
#  'Paula Patton': -6571952,
#  'Michael Nyqvist': -6571952,
#  'Olivia Wilde': 3666239,
#  'Mark Duplass': -3565222,
#  'Danielle Panabaker': 3493728,
#  'Matt Bush': 3493728,
#  'Katrina Bowden': 3493728,
#  'Jean-Luc Bilodeau': 3493728,
#  'David Koechner': 3493728,
#  'Jeffrey Dean Morgan': 51252858,
#  'Natasha Calis': 71446075,
#  'Madison Davenport': 71446075,
#  'Kyra Sedgwick': 71446075,
#  'Rob LaBelle': 71446075,
#  'Adelaide Clemens': 32302796,
#  'Kit Harington': 32302796,
#  'Sean Bean': 32302796,
#  'Carrie-Anne Moss': 32302796,
#  'Radha Mitchell': 32302796,
#  'Brad Pitt': 22930465,
#  'Scoot McNairy': 22930465,
#  'Ben Mendelsohn': 22930465,
#  'James Gandolfini': 22930465,
#  'Ray Liotta': 22930465,
#  'Henry Cavill': -3136417,
#  'VerÃ³nica Echegui': -3136417,
#  'Sigourney Weaver': -3136417,
#  'Caroline Goodall': -3136417,
#  'Richard Gere': 23485056,
#  'Tim Roth': 23485056,
#  'Brit Marling': 23485056,
#  'Monica Raymund': 23485056,
#  'Isabel Lucas': -20193217,
#  'Adrianne Palicki': -20193217,
#  'Sean Hayes': 24819301,
#  'Will Sasso': 24819301,
#  'Chris Diamantopoulos': 24819301,
#  'SofÃ\xada Vergara': 24819301,
#  'Meryl Streep': 84281051,
#  'Steve Carell': 84281051,
#  'Jean Smart': 84281051,
#  'Marin Ireland': 84281051,
#  'Eddie Murphy': -17955723,
#  'Allison Janney': -17955723,
#  'Cliff Curtis': -17955723,
#  'Clark Duke': -17955723,
#  'Tyler Perry': -14646768,
#  'Rachel Nichols': -14646768,
#  'Jean Reno': -14646768,
#  'Matthew Fox': -14646768,
#  'Giancarlo Esposito': -14646768,
#  'Katherine Heigl': -3106279,
#  'Debbie Reynolds': -3106279,
#  'Sherri Shepherd': -3106279,
#  'Patrick Fischler': -3106279,
#  'Maggie Smith': 48520298,
#  'Tom Courtenay': 48520298,
#  'Pauline Collins': 48520298,
#  'Michael Gambon': 48520298,
#  'Kodi Smit-McPhee': 47139399,
#  'Tucker Albrizzi': 47139399,
#  'Jodelle Ferland': 47139399,
#  'Casey Affleck': 47139399,
#  'Matt Damon': -6861212,
#  'Rosemarie DeWitt': -6861212,
#  'Lucas Black': -6861212,
#  'Devon Bostick': 55112176,
#  'Steve Zahn': 55112176,
#  'Peyton List': 55112176,
#  'Rachael Harris': 55112176,
#  'Zachary Gordon': 55112176,
#  'Eva Longoria': -2377154,
#  'Andy GarcÃ\xada': -2377154,
#  'Oscar Isaac': -2377154,
#  "Peter O'Toole": -2377154,
#  'RubÃ©n Blades': -2377154,
#  'Cuba Gooding Jr.': -7634623,
#  'Daniela Ruah': -7634623,
#  'Terrence Howard': -7634623,
#  'Victoria Justice': -2582638,
#  'Jackson Nicoll': -2582638,
#  'Chelsea Handler': -2582638,
#  'Josh Pence': -2582638,
#  'Jane Levy': -2582638,
#  'Michael Shannon': -3916401,
#  'Dania Ramirez': -3916401,
#  'Jamie Chung': -3916401,
#  'WolÃ© Parks': -3916401,
#  'Zoe Saldana': 7231461,
#  'Jeremy Irons': 7231461,
#  'Dennis Quaid': 7231461,
#  'Katie Featherston': 137817992,
#  'Kathryn Newton': 137817992,
#  'Matt Shively': 137817992,
#  'Brady Allen': 137817992,
#  'Sprague Grayden': 137817992,
#  'Garrett Hedlund': -16215682,
#  'Sam Riley': -16215682,
#  'Tom Sturridge': -16215682,
#  'Billy Crystal': 94772232,
#  'Bette Midler': 94772232,
#  'Marisa Tomei': 94772232,
#  'Tom Everett Scott': 94772232,
#  'Bailee Madison': 94772232,
#  'Jerry Ferrara': 84070507,
#  'Meagan Good': 84070507,
#  'Regina Hall': 84070507,
#  'Kevin Hart': 84070507,
#  'Josh Duhamel': -15363831,
#  'Rosario Dawson': -15363831,
#  "Vincent D'Onofrio": -15363831,
#  '50 Cent': -15363831,
#  'Ashley Greene': -7372508,
#  'Sebastian Stan': -7372508,
#  'Tom Felton': -7372508,
#  'Julianna Guill': -7372508,
#  'Luke Pasqualino': -7372508,
#  'Sarah Gadon': -14436444,
#  'Juliette Binoche': -14436444,
#  'Paul Giamatti': -14436444,
#  'Samantha Morton': -14436444,
#  'Milla Jovovich': 175159255,
#  'Sienna Guillory': 175159255,
#  'Michelle Rodriguez': 175159255,
#  'Aryana Engineer': 175159255,
#  'Li Bingbing': 175159255,
#  'Whitney Houston': 10637469,
#  'Cee Lo Green': 10637469,
#  'Derek Luke': 10637469,
#  'Mike Epps': 10637469,
#  'Carmen Ejogo': 10637469,
#  'Katy Perry': 20726956,
#  'Russell Brand': 20726956,
#  'Shannon Woodward': 20726956,
#  'Rachael Markarian': 20726956,
#  'Mia Moretti': 20726956}

# %%
min(actors, key=actors.get)
# Out:
# 'Kirsten Dunst'

# %%
data_17_1 = data2[(data2.release_year == 2012) & (data2.profit > 0)]
data_17_1[data_17_1.profit == data_17_1.profit.min()]
# Out:
#         imdb_id  popularity    budget   revenue original_title  \
# 1045  tt1615065    0.998625  45000000  47000000        Savages
#
#                                                    cast      director  \
# 1045  Blake Lively|Taylor Kitsch|Aaron Taylor-Johnso...  Oliver Stone
#
#                       tagline  \
# 1045  Young Beautiful Deadly.
#
#                                                overview  runtime  \
# 1045  Pot growers Ben and Chon face off against the ...      131
#
#                     genres                        production_companies  \
# 1045  Crime|Drama|Thriller  Ixtlan|Relativity Media|Onda Entertainment
#
#      release_date  vote_count  vote_average  release_year   profit
# 1045     7/6/2012         516           6.2          2012  2000000

# %%
actors_1 = to_dict_from_series(data_17_1.cast.str.split('|').tolist(), data_17_1.profit.tolist())
min(actors_1, key=actors_1.get)
# Out:
# 'Blake Lively'

# %%
actors_1['Blake Lively']
# Out:
# 2000000

# %%
answer_ls.append(3)

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
data_bb = data2[data2['budget']>data2['budget'].mean()]
pd.DataFrame(data_bb.cast.str.split('|').tolist()).stack().value_counts()
# Out:
# Matt Damon        18
# Adam Sandler      17
# Angelina Jolie    16
# Eddie Murphy      15
# Tom Cruise        15
#                   ..
# Vera Farmiga       1
# Dakota Goyo        1
# Will Forte         1
# Diane Keaton       1
# January Jones      1
# Length: 1508, dtype: int64

# %%
answer_ls.append(3)

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
data_nc = data2[data2.cast.str.contains('Nicolas Cage')]
#pd.DataFrame[data_nc.genres.str.split('|').tolist()].stack().value_counts()
pd.DataFrame(data_nc.genres.str.split('|').tolist()).stack().value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Mystery             3
# Animation           3
# Family              3
# History             2
# War                 1
# Horror              1
# Romance             1
# dtype: int64

# %%
answer_ls.append(2)

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
pd.DataFrame(data2.production_companies.str.split('|').tolist()).stack().value_counts()
# Out:
# Universal Pictures                        173
# Warner Bros.                              168
# Paramount Pictures                        122
# Columbia Pictures                         117
# Twentieth Century Fox Film Corporation    109
#                                          ...
# Necropia                                    1
# Square USA                                  1
# Corsan                                      1
# HorrorFlix                                  1
# Lions Gate Family Entertainment             1
# Length: 1772, dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
data_2015 = data2[data2.release_year == 2015]
pd.DataFrame(data_2015.production_companies.str.split('|').tolist()).stack().value_counts()
# Out:
# Warner Bros.                              12
# Universal Pictures                        10
# Twentieth Century Fox Film Corporation     8
# Columbia Pictures                          7
# Paramount Pictures                         7
#                                           ..
# Beagle Pug Films                           1
# Clinica Estetico                           1
# Ahimsa Films                               1
# Thunder Road Pictures                      1
# Gran Via Productions                       1
# Length: 246, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
data_comedies = data2[data2.genres.str.contains('Comedy')]
cnt = Counter()
for i in range (0, len(data_comedies)):
    for company in data_comedies.iloc[i].production_companies.split('|'):
        cnt [company] += data_comedies.iloc[i].profit
cnt.most_common()
# Out:
# [('Universal Pictures', 8961545581),
#  ('Walt Disney Pictures', 7669710326),
#  ('Twentieth Century Fox Film Corporation', 5686960294),
#  ('Columbia Pictures', 5646343696),
#  ('DreamWorks Animation', 4789049764),
#  ('Pixar Animation Studios', 4232507237),
#  ('Warner Bros.', 3894922770),
#  ('New Line Cinema', 3259242692),
#  ('DreamWorks SKG', 3143226857),
#  ('Paramount Pictures', 3055625722),
#  ('Relativity Media', 3036733344),
#  ('Twentieth Century Fox Animation', 3030806037),
#  ('Blue Sky Studios', 3024335014),
#  ('Village Roadshow Pictures', 2383194524),
#  ('Happy Madison Productions', 2196445292),
#  ('Illumination Entertainment', 1977492847),
#  ('Columbia Pictures Corporation', 1817280373),
#  ('Regency Enterprises', 1766412563),
#  ('Dune Entertainment', 1703149736),
#  ('Pacific Data Images (PDI)', 1699136912),
#  ('Sony Pictures Animation', 1686288994),
#  ('Fox 2000 Pictures', 1673413405),
#  ('Apatow Productions', 1419417727),
#  ('21 Laps Entertainment', 1262425642),
#  ('Dimension Films', 1235565030),
#  ('Walt Disney Animation Studios', 1142430016),
#  ('Green Hat Films', 1092507501),
#  ('Legendary Pictures', 1056237337),
#  ('Touchstone Pictures', 1019666722),
#  ('Metro-Goldwyn-Mayer (MGM)', 1005610791),
#  ('Spyglass Entertainment', 971077188),
#  ('Working Title Films', 947760501),
#  ('Amblin Entertainment', 901906115),
#  ('Media Rights Capital', 885155837),
#  ('Mosaic Media Group', 875646074),
#  ('1492 Pictures', 872091430),
#  ('Miramax Films', 870409935),
#  ('Nickelodeon Movies', 830553839),
#  ('Fox Searchlight Pictures', 813485630),
#  ('Revolution Studios', 762936184),
#  ('TSG Entertainment', 761041830),
#  ('Everyman Pictures', 719159797),
#  ('Gold Circle Films', 710871179),
#  ('Original Film', 701365254),
#  ('Kerner Entertainment Company', 696183501),
#  ('Walt Disney Studios Motion Pictures', 678708609),
#  ('Dune Entertainment III', 675931563),
#  ('Bagdasarian Productions', 669506638),
#  ('The Weinstein Company', 653932716),
#  ('Fuzzy Door Productions', 647231921),
#  ('Tribeca Productions', 645636958),
#  ('Hemisphere Media Capital', 641460954),
#  ('Red Granite Pictures', 612198096),
#  ('Gary Sanchez Productions', 594586861),
#  ('Waverly Films', 589565765),
#  ('Studio Canal', 574982363),
#  ('Good Universe', 574316238),
#  ('Parkes/MacDonald Productions', 558444031),
#  ('Internationale Filmproduktion Richter', 557841637),
#  ('Playtone', 557841637),
#  ('Littlestar', 557841637),
#  ('Ingenious Film Partners', 547565770),
#  ('Home Box Office (HBO)', 538600478),
#  ('Imagenation Abu Dhabi FZ', 530203109),
#  ('Mandate Pictures', 528266720),
#  ('Brad Grey Pictures', 527913666),
#  ('Flower Films (II)', 524265840),
#  ('Silver Pictures', 519867028),
#  ('Davis Entertainment', 517206491),
#  ('20th Century Fox', 515090337),
#  ('Gold/Miller Productions', 496638967),
#  ('Summit Entertainment', 487439123),
#  ('Sony Pictures Entertainment (SPE)', 482764187),
#  ('The Zanuck Company', 480959741),
#  ('Weed Road Pictures', 478476270),
#  ('Scott Rudin Productions', 473608359),
#  ('StudioCanal', 469894140),
#  ('Wayans Bros. Entertainment', 468922045),
#  ('Zide-Perry Productions', 467377949),
#  ('Wigram Productions', 467173788),
#  ('Mad Hatter Entertainment', 464123048),
#  ('Warner Bros. Animation', 463037717),
#  ('Tim Burton Productions', 462986980),
#  ('Tapestry Films', 444916367),
#  ('New Regency Pictures', 441364154),
#  ('Castle Rock Entertainment', 440970624),
#  ('Imagine Entertainment', 435291822),
#  ('Plan B Entertainment', 430315269),
#  ('Marc Platt Productions', 425196863),
#  ('IFP Westcoast Erste', 424270619),
#  ('Chernin Entertainment', 422949865),
#  ('Lin Pictures', 422573485),
#  ('Internationale Filmproduktion Blackbird Dritte', 421956747),
#  ('Shady Acres Entertainment', 418077844),
#  ('Vertigo Entertainment', 409160692),
#  ('Pit Bull Productions', 404572835),
#  ('DC Comics', 401856991),
#  ('Storyline Entertainment', 392149234),
#  ('Media Magik Entertainment', 378058113),
#  ('Point Grey Pictures', 371594718),
#  ('Playtone Productions', 369904419),
#  ('Dutch Oven', 368207520),
#  ('New Regency Productions', 368207520),
#  ('Screen Gems', 367745195),
#  ('MPH Entertainment', 363744044),
#  ('Overbrook Entertainment', 359663968),
#  ('Atlas Entertainment', 359652423),
#  ('Brownstone Productions', 356856620),
#  ('Gracie Films', 355779125),
#  ('Platinum Dunes', 352200000),
#  ('Darren Star Productions', 350252786),
#  ('Red Hour Films', 345469304),
#  ('Jerry Bruckheimer Films', 341328095),
#  ('Josephson Entertainment', 335978832),
#  ('Robert Simonds Productions', 329089130),
#  ('Mandeville Films', 323553619),
#  ('Marv Films', 322802136),
#  ('Cloudy Productions', 322802136),
#  ('Wild West Picture Show Productions', 321690887),
#  ('Avery Pix', 321011297),
#  ('Feigco Entertainment', 317899332),
#  ('Aardman Animations', 316085073),
#  ('Major Studio Partners', 314560763),
#  ('Tiger Aspect Productions', 309736344),
#  ('Centropolis Entertainment', 304111707),
#  ('Wind Dancer Productions', 304111707),
#  ('Parkes+MacDonald Image Nation', 301818803),
#  ('Focus Features', 299412300),
#  ('Paramount Animation', 298601627),
#  ('Icon Entertainment International', 295997141),
#  ('MTV Films', 294293135),
#  ('Appian Way', 292000694),
#  ('EMJAG Productions', 292000694),
#  ('Sikelia Productions', 292000694),
#  ('Peninsula Films', 291551094),
#  ('Stuber Productions', 289851496),
#  ('Karz Entertainment', 287464773),
#  ('Kennedy Miller Productions', 284335608),
#  ('Kingdom Feature Productions', 284335608),
#  ('Animal Logic', 284335608),
#  ('Sony Pictures Releasing', 279046309),
#  ('Kurtzman/Orci', 277375031),
#  ('Gunn Films', 276534523),
#  ('De Line Pictures', 276083286),
#  ('Nancy Tenenbaum Films', 275444045),
#  ('Sunswept Entertainment', 272114902),
#  ('Dentsu', 263809199),
#  ('Museum Canada Productions', 263106170),
#  ('BBC Films', 262661625),
#  ('Producers Circle', 261776732),
#  ('BenderSpink', 260701935),
#  ('Conundrum Entertainment', 260460622),
#  ('Rat Entertainment', 257949145),
#  ('Liveplanet', 257553595),
#  ('Little Bird', 256929795),
#  ('Andalasia Productions', 255487652),
#  ('Right Coast Productions', 255487652),
#  ('Rainforest Films', 249571010),
#  ('Four By Two Productions', 243572744),
#  ('NeoReel', 242434178),
#  ("Eric's Boy", 233633907),
#  ('Team Todd', 233633907),
#  ('Moving Pictures', 233633907),
#  ('Gratitude International', 233633907),
#  ('Walt Disney Feature Animation', 227711813),
#  ('Walden Media', 226403025),
#  ('Broken Road Productions', 225810289),
#  ('Fortis Films', 225460460),
#  ('Sony Pictures Entertainment', 222949060),
#  ('Moving Picture Company (MPC)', 222424282),
#  ('Olive Bridge Entertainment', 218938754),
#  ('Big Screen Productions', 213807502),
#  ('TF1 Films Production', 211101452),
#  ('Mike Zoss Productions', 211091218),
#  ('Dreamworks Pictures', 210650585),
#  ('DNA Films', 210112895),
#  ('Indian Paintbrush', 208691114),
#  ('Canal+', 206810296),
#  ('The Montecito Picture Company', 204648705),
#  ('Buena Vista', 204435555),
#  ('Heyday Films', 204207227),
#  ('Alcon Entertainment', 202608219),
#  ('CBS Films', 195330353),
#  ('Cube Vision', 194916482),
#  ('Jersey Films', 191344937),
#  ('Mayhem Pictures', 190343051),
#  ('HBO Films', 188347692),
#  ('GK Films', 185251752),
#  ('WideAwake', 184002198),
#  ('Ingenious Media', 180255887),
#  ('PathÃ©', 179834564),
#  ('Three Strange Angels', 179389434),
#  ('Lakeshore Entertainment', 178081787),
#  ('LivePlanet', 176449203),
#  ('Loumolo & Co.', 176449203),
#  ('Living Films', 174455986),
#  ('Wonderland Sound and Vision', 174204422),
#  ('Tall Trees Productions', 173091676),
#  ('Sony', 170384621),
#  ('Escape Artists', 170110493),
#  ('LStar Capital', 166194717),
#  ('Rice Films', 164485654),
#  ('NPV Entertainment', 163708324),
#  ('Type A Films', 163648539),
#  ('Lucamar Productions', 162902372),
#  ('Nick Wechsler Productions', 160221571),
#  ('Extension 765', 160221571),
#  ('Stephen J. Cannell Productions', 159585328),
#  ('Mad Chance', 157492969),
#  ('Ad Hominem Enterprises', 157243185),
#  ('LBI Productions', 156781193),
#  ('Heyday films', 155990978),
#  ('Spring Creek Productions', 152179800),
#  ('DreamWorks Pictures', 148840295),
#  ('Mediastream Vierte Film GmbH & Co. Vermarktungs KG', 147722310),
#  ('Katalyst Films', 145940403),
#  ('Tree Line Films', 144930431),
#  ('Pink Machine', 144930431),
#  ('Studio Babelsberg', 143484950),
#  ('Don Simpson/Jerry Bruckheimer Films', 143339556),
#  ('Whamaphram Productions', 142817841),
#  ('Montecito Picture Company, The', 141156732),
#  ('Aggregate Films', 138965010),
#  ('DumbDumb', 138965010),
#  ('Cannell Studios', 138441614),
#  ('Columbus 81 Productions', 137594577),
#  ('Internationale Filmproduktion Blackswan', 137259441),
#  ('RatPac-Dune Entertainment', 137008072),
#  ('Dickhouse Productions', 136831537),
#  ('Penn Station Entertainment', 135000000),
#  ('Guy Walks into a Bar Productions', 132048597),
#  ('Zadan / Meron Productions', 130372502),
#  ('Loofah Productions', 129963386),
#  ('BrownHouse Productions', 128335153),
#  ('Bottom of the Ninth Productions', 128335153),
#  ('David Brown Productions', 127500343),
#  ('Fat Free', 127500343),
#  ('Anonymous Content', 126400244),
#  ('Offspring Entertainment', 126313322),
#  ('Monkey Dance Productions', 125880543),
#  ('WV Films III', 125404726),
#  ('Reliance BIG Entertainment', 125205105),
#  ('Miramax', 124722341),
#  ('Troublemaker Studios', 124262079),
#  ('Participant Media', 123603420),
#  ('Bona Fide Productions', 123353788),
#  ('Rhythm and Hues', 121584141),
#  ('Picnic Basket', 121584141),
#  ('Out of the Blue... Entertainment', 121269535),
#  ("It's a Laugh Productions", 120545279),
#  ('Millar Gough Ink', 120545279),
#  ('Genre Films', 119621271),
#  ('France 3 CinÃ©ma', 118432856),
#  ('La Petite Reine', 118432856),
#  ('Studio 37', 118432856),
#  ('uFilm', 118432856),
#  ('Jouror Productions', 118432856),
#  ('Two Ton Films', 117191850),
#  ('Cold Spring Pictures', 114185685),
#  ('Lionsgate', 113731553),
#  ('Color Force', 112117892),
#  ('Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 1 KG', 111749918),
#  ('Blind Wink', 110724603),
#  ('AR-TL', 110268750),
#  ('Callahan Filmworks', 108320568),
#  ('Iron Horse Entertainment (II)', 107613057),
#  ('Outlaw Sinema', 106402450),
#  ('Gidden Media', 106402450),
#  ('Reserve Room', 105896422),
#  ('Fuji Television Network', 105795793),
#  ('Arts Council of England', 105000000),
#  ('Kramer & Sigman Films', 103862963),
#  ('Zaftig Films', 103862963),
#  ('Laurence Mark Productions', 102440359),
#  ('JC 23 Entertainment', 102026112),
#  ('Lions Gate Films', 101866560),
#  ('DisneyToon Studios', 101165787),
#  ('Prana Studios', 101165787),
#  ('Prana Animation Studios', 101165787),
#  ('Management 360', 100901559),
#  ('Hughes Entertainment', 99906693),
#  ('Shoelace Productions', 99906693),
#  ('Cruella Productions', 98611771),
#  ('Firm Films', 98259062),
#  ('Samuel Goldwyn Films', 98133322),
#  ('Misher Films', 98018522),
#  ('Yucaipa Films', 98018522),
#  ('Hyde Park Films', 97309464),
#  ('Internationale Filmproduktion Stella-del-Sud Second', 96072649),
#  ('Epsilon Motion Pictures', 95517678),
#  ('Laika Entertainment', 95395169),
#  ('Goldcrest Pictures', 94676893),
#  ('Michael London Productions', 93502303),
#  ('Sideways Productions Inc.', 93502303),
#  ('Radar Pictures', 92872192),
#  ('Big Beach Films', 92523181),
#  ('Doom Buggy Productions', 92290266),
#  ('Scholastic Entertainment', 92170815),
#  ('Newmarket Capital Group', 90845033),
#  ('Lawrence Bender Productions', 90845033),
#  ('Pistolero Productions LLC', 90845033),
#  ('Deep River Productions', 88909141),
#  ('Harbour Pictures', 86542059),
#  ('Goldmann Pictures', 86533366),
#  ('Worldview Entertainment', 85215094),
#  ('Le Grisbi Productions', 85215094),
#  ('M Productions', 85215094),
#  ('Studio Mir', 84070507),
#  ('Ott Medien', 83733697),
#  ('TriStar Pictures', 83683480),
#  ('Mediastream Dritte Film GmbH & Co. Beteiligungs KG', 83564935),
#  ('Gulfstream Pictures', 83494610),
#  ('Perdido Productions', 79505481),
#  ('Image Entertainment', 77930623),
#  ('Sony Pictures Home Entertainment', 77597242),
#  ('Ruby Films', 77544580),
#  ('Essential Media & Entertainment', 77544580),
#  ('Hopscotch Features', 77544580),
#  ('Kaplan/Perrone Entertainment', 76431368),
#  ('MMCB Film Produktion 2004', 76431368),
#  ('Gone North Productions', 76086475),
#  ('Storefront Pictures', 75607899),
#  ('Little Stranger', 75011053),
#  ('Infinitum Nihil', 74527149),
#  ('Phoenix Pictures', 74007224),
#  ('Bedford Falls Productions', 72820008),
#  ('Jim Henson Company, The', 72654149),
#  ('David Dobkin Productions', 71222537),
#  ('Emmett/Furla Films', 70940411),
#  ('Envision Entertainment Corporation', 70940411),
#  ('LBI Entertainment', 70081841),
#  ('Village Roadshow Pictures Asia', 67610124),
#  ('Universal Studios', 67364881),
#  ('Gerber Pictures', 65710936),
#  ('Junction Entertainment', 65283742),
#  ('ImageMovers', 65175006),
#  ('Nine Yards Productions', 65071651),
#  ('Rational Packaging Company', 65071651),
#  ('Twentieth Century Fox', 64462508),
#  ('Internationale Filmproduktion Stella-del-SÃ¼d', 64380927),
#  ('Intellectual Properties Worldwide', 62681893),
#  ('Beacon Communications', 62449929),
#  ('Imagi Animation Studios', 61608995),
#  ('Mirage Studios', 61608995),
#  ('Imagi Production', 61608995),
#  ('Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 2 KG', 61556420),
#  ('Virgin Produced', 61504660),
#  ('Vidhu Vinod Chopra Productions', 61000000),
#  ('Alphaville Productions', 59940815),
#  ('Constantin Film Produktion', 59877553),
#  ('Intermedia Films', 59728529),
#  ('Dee Gee Entertainment', 59728529),
#  ('Prufrock Pictures', 59728529),
#  ('Thirteen Productions', 59455697),
#  ('Atmosphere Entertainment MM', 59188165),
#  ('Chako Film Company', 59188165),
#  ('American Empirical Pictures', 58734189),
#  ('Big Talk Productions', 57552050),
#  ('Impact Pictures', 57274484),
#  ('Nouvelles Ã‰ditions de Films (NEF)', 57274484),
#  ('New Legacy', 57274484),
#  ('Paul Schiff Productions', 56890346),
#  ('Universal Cartoon Studios', 55936232),
#  ('Likely Story', 55464861),
#  ('Exclusive Media Group', 55464861),
#  ('Sycamore Pictures', 55464861),
#  ('Crescendo Productions', 55397508),
#  ('Reel FX Creative Studios', 55000000),
#  ('Universal', 54625195),
#  ('Hammer & Tongs', 54478416),
#  ('Vinyl Films', 54366750),
#  ('RatPac Entertainment', 53895377),
#  ('Dylan Sellers Productions', 53886904),
#  ('Dimension Films (US version)', 53488889),
#  ('Watermark', 53222734),
#  ('Moonrise', 52263166),
#  ('View Askew Productions', 51781648),
#  ('The Collective Studios', 51615414),
#  ('Max Stronghold Productions Inc.', 51369815),
#  ('Wessler Entertainment', 51258289),
#  ('Gaylord Films', 51067909),
#  ('Bernard Gayle Productions', 50636986),
#  ('Neal H. Moritz Productions', 50468332),
#  ('Simon Fields Productions', 49516304),
#  ('Jean Doumanian Productions', 49188937),
#  ('Playtone Production', 49181539),
#  ('Scion Films', 48991867),
#  ('Headline Pictures', 48520298),
#  ('Black & White Productions', 48197993),
#  ('Clifford Werber Productions', 48187984),
#  ('Saturn Films', 47328019),
#  ('Red Wagon Entertainment', 46426169),
#  ('Bewitched', 46426169),
#  ('Alta Loma Entertainment', 45442940),
#  ('MacDonald/Parkes Productions', 44854431),
#  ('Smoke House', 44729358),
#  ('Participant Productions', 44000410),
#  ('Jon Shestack Productions', 43377859),
#  ('Tim Burton Animation Company', 42491068),
#  ('KirchMedia', 42383208),
#  ('Double Feature Films', 42226116),
#  ('Nina Saxon Film Design', 42226116),
#  ('Goldenlight Films', 41837234),
#  ('The Tyler Perry Company', 40072596),
#  ('What to Expect Productions', 39700000),
#  ('Failure to Launch Productions', 38715192),
#  ('Birnbaum / Barber Productions', 38323487),
#  ('Jackie Chan Films Limited', 38323487),
#  ('All Knight Productions', 38323487),
#  ('Fireworks Pictures', 37498534),
#  ('Alphaville Films', 37498534),
#  ('Clinica Estetico', 37126501),
#  ('Screen Gems, Inc.', 36502684),
#  ('Kanbar Entertainment', 36053787),
#  ('Blue Yonder Films', 36053787),
#  ('Bac Films', 35742101),
#  ('Five Roses', 35742101),
#  ('Morgan Creek Productions', 35676058),
#  ('26 Films', 35630314),
#  ('TriStar Productions', 35387687),
#  ('SkyLand Entertainment', 35065672),
#  ('Vast Entertainment', 35028634),
#  ('Open Road Films', 34967935),
#  ('Aldamisa Entertainment', 34967935),
#  ('Kilburn Media', 34967935),
#  ('Fetisov Teterin Films', 34967935),
#  ('Ilion Animation Studios', 34945765),
#  ('Hand Made Films', 34945765),
#  ('Rainmaker Entertainment', 34597643),
#  ('Mainframe Entertainment', 34597643),
#  ('Weinstein Company, The', 34597643),
#  ('Underground', 34307224),
#  ('3 Arts Entertainment', 33915888),
#  ('Michaels-Goldwyn', 33833449),
#  ('Red Hour Productions', 32780981),
#  ('Section Eight', 32358388),
#  ('Stage 6 Films', 31110610),
#  ('Sony Pictures Worldwide Acquisitions (SPWA)', 31110610),
#  ('TDJ Enterprises / New Dimensions Entertainment', 31110610),
#  ('Our Stories Films', 31110610),
#  ('Echo Films', 30830607),
#  ('Disney', 30383113),
#  ('Mosaic', 29779728),
#  ('New Crime Productions', 28572262),
#  ('Smokehouse Pictures', 28191198),
#  ('Parabolic Pictures', 28050886),
#  ('Wildwood Enterprises', 27991087),
#  ('Route One Films', 27991087),
#  ('FilmColony', 27738099),
#  ('Banter', 27280250),
#  ('O.N.C. Entertainment', 27028752),
#  ('Greenestreet Films', 26438988),
#  ('Witness Protection Films', 26438988),
#  ('Konrad Pictures', 25696770),
#  ('Wild Ocean Films', 24901913),
#  ('2S Films', 24901913),
#  ('United Artists', 24349727),
#  ('Groundswell Productions', 23994790),
#  ('Stoller Global Solutions', 23909751),
#  ('Big Kid Pictures', 23450437),
#  ('Runteldat Entertainment', 23424428),
#  ('Aversano Films', 23159963),
#  ('Landscape Entertainment', 23009669),
#  ('John US Productions', 23009669),
#  ('Entertainment Films', 23000000),
#  ('Material Entertainment', 23000000),
#  ('Beech Hill Films', 23000000),
#  ('Artisan Entertainment', 21861859),
#  ('Tyler Perry Company, The', 21609243),
#  ('Blueprint Pictures', 21424799),
#  ('Tollin/Robbins Productions', 21367498),
#  ('Edmonds Entertainment Group (EEG)', 21010817),
#  ('Epidemic Pictures', 21010817),
#  ('The Safran Company', 21010817),
#  ('Wildgaze Films', 20451307),
#  ('Alan Greenspan Productions', 20451307),
#  ('Mars Media Beteiligungs', 20451307),
#  ('Dr D Studios', 20406466),
#  ('Kennedy Miller Mitchell', 20406466),
#  ('Universal Animation Studios', 19834815),
#  ('Sony Pictures', 19809911),
#  ('Closest to the Hole Productions', 19263404),
#  ('Bird and a Bear Entertainment', 19179516),
#  ('Hallway Pictures', 19179516),
#  ('Catch Productions', 19179516),
#  ('Native Pictures Productions', 19155435),
#  ('Bad Robot', 18785180),
#  ('Room 9 Entertainment', 18293509),
#  ('Bungalow Productions', 18288674),
#  ('Silver Lion Films', 18288674),
#  ('Vision View Entertainment', 18288674),
#  ('Blue Askew', 18105111),
#  ('Treehouse Pictures', 18049082),
#  ('Reforma Films', 17316267),
#  ('Spy Next Door', 17236543),
#  ('GreeneStreet Films', 17095657),
#  ('Twins Financing', 17002538),
#  ('Pacific Standard', 16680201),
#  ('New Wave Entertainment', 16620508),
#  ('Terra Firma Films', 16620508),
#  ('Superfinger Entertainment', 16620508),
#  ('EuropaCorp', 16156226),
#  ('Depth of Field', 14287964),
#  ('Alloy Entertainment', 14053061),
#  ('Sneak Preview Productions', 13956509),
#  ('Beverly Detroit', 13801173),
#  ('Propaganda Films', 13801173),
#  ('Intermedia', 13801173),
#  ('Di Bonaventura Pictures', 13664962),
#  ('DC Entertainment', 13664962),
#  ('Element Pictures', 13560274),
#  ('Irish Film Board', 13560274),
#  ('Jaffe / Braunstein Enterprise', 13424826),
#  ('Wintergreen Productions', 13412793),
#  ('Lynda Obst Productions', 13412793),
#  ('Mile High Productions', 12886719),
#  ('Kevin Messick Productions', 12886719),
#  ('Beacon Pictures', 12886719),
#  ('New Upstairs Productions', 12881056),
#  ('Upstairs Canada Productions', 12881056),
#  ('JLT Productions', 12609995),
#  ('Oops Doughnuts Productions', 12005248),
#  ('Frontier Pictures', 12005248),
#  ('DiNovi Pictures', 11478061),
#  ('Overnight Films', 11327899),
#  ('Boxing Cat Films', 11112916),
#  ('Denver and Delilah Productions', 10939027),
#  ('Octagon Films', 10922472),
#  ('Birnbaum/Barber', 10922472),
#  ('Contrafilm', 10426096),
#  ('Hungry Eye Lowland Pictures B.V.', 8856124),
#  ('Flan de Coco Films', 8856124),
#  ('GHS Productions KG', 8222729),
#  ('Munich Film Partners & Company (MFP) GHS Productions', 8222729),
#  ('Nides/McCormick Productions', 8222729),
#  ('Prescience', 7909461),
#  ('40 Acres & A Mule Filmworks', 7728118),
#  ('This Is That Productions', 7664377),
#  ('Land Films Inc.', 7500000),
#  ('Scott Free Productions', 7064105),
#  ('Triple Threat Talent', 7036004),
#  ('Canal Plus', 6894225),
#  ('Grive Productions', 6894225),
#  ('Vendome Pictures', 6160375),
#  ('Provident Films', 5429707),
#  ('Pure Flix Entertainment', 5429707),
#  ('Affirm Films', 5429707),
#  ('FourBoys Entertainment', 5429707),
#  ('Daybreak', 5411183),
#  ('Exodus Film Group', 5000000),
#  ('Exodus Productions', 5000000),
#  ('Sidney Kimmel Entertainment', 4558098),
#  ('British Film Institute (BFI)', 4422261),
#  ('Furry Vengeance Productions', 4340177),
#  ('Sherazade Film Development', 3569964),
#  ('Corduroy Films', 3569964),
#  ('Mark Canton Productions', 3493728),
#  ('Allied Filmmakers', 3013805),
#  ('Splendid Pictures', 2818995),
#  ('Maverick Films', 2818995),
#  ('Madacy Entertainment', 2818995),
#  ('Wild Bunch', 2603069),
#  ('Zanagar Films', 2603069),
#  ('CinÃ©CinÃ©ma', 2603069),
#  ('Ocean Pictures', 2357900),
#  ('Rickshaw Productions', 2130000),
#  ('Film4', 1325249),
#  ('Rogue Pictures', 757712),
#  ('Fox Atomic', 724196),
#  ('Jessie Nelson Productions', -2161651),
#  ('Birdsong Pictures', -2385227),
#  ('IM Global', -2385227),
#  ('A24', -2412515),
#  ('Warner Bros. Interactive Entertainment', -2514873),
#  ('Rob Thomas Productions', -2514873),
#  ('Benderspink', -2562119),
#  ('Carousel Productions', -2562119),
#  ('David Ladd Films', -2567837),
#  ('Fake Empire', -2582638),
#  ('SW7D Productions', -2879925),
#  ('Echo Lake Productions', -2977272),
#  ('Premiere Picture', -2977272),
#  ('Fastnet Films', -3153000),
#  ('Caramel Film', -3153000),
#  ('No Trace Camping', -3153000),
#  ('Broken Lizard Industries', -3498345),
#  ('Coconut Pete Productions', -3498345),
#  ('Global Entertainment Productions GmbH & Company Medien KG', -3962091),
#  ('Nora Ephron Productions', -3962091),
#  ('WWE Studios', -4083508),
#  ('Blue Sea Productions', -4203153),
#  ('Big Beach Productions', -4302070),
#  ('Warner Independent Pictures (WIP)', -4302070),
#  ('Telegraph Films', -4302070),
#  ('Matador Pictures', -4546957),
#  ('Magic Light Pictures', -4546957),
#  ('Cinema Four', -4546957),
#  ('Cruise/Wagner Productions', -4965111),
#  ('KMP Film Invest', -4965111),
#  ('PVR Cinemas', -5000000),
#  ('Hari Om Entertainment Co.', -5000000),
#  ('Blockbuster Movie Entertainers', -5000000),
#  ('Ealing Studios', -5650813),
#  ('Fragile Films', -5650813),
#  ('Quickfire Films', -5650813),
#  ('Aegis Film Fund', -5650813),
#  ('UK Film Council', -6539276),
#  ('Franchise Pictures', -6683496),
#  ('Empire Pictures', -7368097),
#  ('Hyde Park Entertainment', -7368097),
#  ('Prospero Pictures', -8114566),
#  ('Rocket Pictures', -8114566),
#  ('Alliance Atlantis Motion Picture Production', -8114566),
#  ('Stillking Films', -8324775),
#  ('QED International', -8409372),
#  ('Ghoulardi Film Company', -8889025),
#  ('Universal Pictures Corporation', -9122855),
#  ('Max Films Productions', -9269982),
#  ('Morag Loves Company', -9269982),
#  ('Columbia TriStar', -9369497),
#  ('Intandem Films', -9713701),
#  ('Aramid Entertainment Fund', -9713701),
#  ('Lipsync Productions', -9713701),
#  ('Atlantic Television', -9796980),
#  ('Smartest Man Productions', -9975218),
#  ('Millennium Films', -9975218),
#  ('SNL Studios', -10300000),
#  ('Bristol Bay Productions', -10730514),
#  ('Baldwin Entertainment Group', -10730514),
#  ('Desertlands Entertainment', -10730514),
#  ('Mace Neufeld Productions', -10730514),
#  ('A Hot Dog', -10840066),
#  ('Grosvenor Park Media Ltd.', -10890716),
#  ('LionsGate', -10890716),
#  ('3 in the Box', -10890716),
#  ('Cheyenne Enterprises', -11052411),
#  ('Motion Picture Corporation of America', -11413624),
#  ('Lonely Film Productions GmbH & Co. KG.', -11485156),
#  ('Baltimore Spring Creek Productions', -11485156),
#  ('Dune Films', -11979336),
#  ('Venture Forth', -11979336),
#  ('Angry Films', -12179359),
#  ('Blue Star Pictures', -12965168),
#  ('Millenium Films', -13180652),
#  ('The Mark Gordon Company', -13227539),
#  ('Yari Film Group', -13227539),
#  ('Bob Yari Productions', -13227539),
#  ('Metanoia Films', -13579681),
#  ('Medienproduktion Prometheus Filmgesellschaft', -13651216),
#  ('Portobello Studios', -13651216),
#  ('MHF Zweite Academy Film', -13844219),
#  ('Eclipse Catering', -13844219),
#  ('Nine Yards Two Productions', -13844219),
#  ('I Could Never Ltd.', -14423505),
#  ('Bauer Martinez Studios', -14423505),
#  ('Endgame Entertainment', -14469236),
#  ('Reiner-Greisman', -14631103),
#  ('Mediastream Dritte Film', -14701793),
#  ('Jinks/Cohen Company', -14701793),
#  ('Goldsmith-Thomas Productions', -14789012),
#  ('platinum studios', -15365938),
#  ('Long Distance Films', -15365938),
#  ('Corner Store Entertainment', -15581387),
#  ('Craven-Maddalena Films', -15705099),
#  ('Outerbanks Entertainment', -15705099),
#  ('Kalis Productions GmbH & Co. Zweite KG', -15705099),
#  ('HW Two', -16478171),
#  ('Varsity Pictures', -17955723),
#  ('2929 Productions', -18326578),
#  ('Linson Entertainment', -18326578),
#  ('Art Linson Productions', -18326578),
#  ('Internationale Filmproduktion', -20180936),
#  ('Odd Lot Entertainment', -20968663),
#  ('Dark Lot Entertainment', -20968663),
#  ('FilmEngine', -21000000),
#  ('Serendipity Point Films', -21545699),
#  ('Freestyle Releasing', -22663828),
#  ('Isle of Man Film', -27210785),
#  ('CinemaNX', -27210785),
#  ('OddLot Entertainment', -29581440),
#  ('Huayi Brothers Media', -29581440),
#  ('Sid & Marty Krofft Pictures', -31311169),
#  ('Dino de Laurentiis Cinematografica', -32589251),
#  ('Dino De Laurentiis Company', -32589251),
#  ('Zephyr Films', -32589251),
#  ('Red Lion Sarl', -32589251),
#  ('Deuce Three Productions', -33551615),
#  ('Colombia Pictures', -36438863),
#  ('Babelsberg Film', -37821105),
#  ('Mostow/Lieberman Productions', -37821105),
#  ('80 Days Productions', -37821105),
#  ('Capella International', -40865180),
#  ('KC Medien AG', -40865180),
#  ('Material', -43191450),
#  ('Taormina Productions', -43191450),
#  ('Patalex Productions', -46604061),
#  ('Bel Air Entertainment', -51635688),
#  ('Warner Bros. Pictures', -54738687),
#  ('Shangri-La Entertainment', -55170786),
#  ('Dark Horse Entertainment', -68351500),
#  ('Road Rebel', -71331093),
#  ("Mel's Cite du Cinema", -92896027)]

# %%
answer_ls.append(2)

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
data_2012 = data2[data2.release_year == 2012]
cnt = Counter()
for i in range (0, len(data_2012)):
    for company in data_2012.iloc[i].production_companies.split('|'):
        cnt [company] += data_2012.iloc[i].profit
cnt.most_common()
# Out:
# [('Columbia Pictures', 2501406608),
#  ('Universal Pictures', 1981011579),
#  ('Marvel Studios', 1299557910),
#  ('Warner Bros.', 1258020056),
#  ('Relativity Media', 1032593938),
#  ('New Line Cinema', 1028114941),
#  ('Metro-Goldwyn-Mayer (MGM)', 1010869947),
#  ('Legendary Pictures', 982041287),
#  ('Summit Entertainment', 961582873),
#  ('Dune Entertainment', 892186707),
#  ('DC Entertainment', 831041287),
#  ('Syncopy', 831041287),
#  ('Blue Sky Studios', 782244782),
#  ('Twentieth Century Fox Animation', 782244782),
#  ('WingNut Films', 767003568),
#  ('DreamWorks Animation', 763862944),
#  ('Twentieth Century Fox Film Corporation', 726676825),
#  ('Lionsgate', 709309876),
#  ('Sunswept Entertainment', 709000000),
#  ('Temple Hill Entertainment', 709000000),
#  ('Color Force', 616210692),
#  ('Fox 2000 Pictures', 544128741),
#  ('Laura Ziskin Productions', 537215857),
#  ('Marvel Entertainment', 537215857),
#  ('The Weinstein Company', 534041592),
#  ('Media Rights Capital', 499368315),
#  ('Fuzzy Door Productions', 499368315),
#  ('Ingenious Film Partners', 489016565),
#  ('Ingenious Media', 489016565),
#  ('Big Screen Productions', 489016565),
#  ('Walt Disney Pictures', 420613375),
#  ('Paramount Pictures', 410726715),
#  ('Amblin Entertainment', 399026776),
#  ('Media Magik Entertainment', 399026776),
#  ('Hemisphere Media Capital', 399026776),
#  ('Parkes/MacDonald Productions', 399026776),
#  ('Imagenation Abu Dhabi FZ', 392165564),
#  ('CAMERON MACKINTOSH', 380809770),
#  ('Walden Media', 371464992),
#  ('Working Title Films', 365528985),
#  ('Pixar Animation Studios', 353983207),
#  ('EuropaCorp', 343345336),
#  ('Sony Pictures Animation', 331713964),
#  ('M6 Films', 331141306),
#  ('Grive Productions', 331141306),
#  ('Canal+', 327129654),
#  ('Screen Gems', 312585077),
#  ('Walt Disney Animation Studios', 306222889),
#  ('Dentsu', 293558894),
#  ('GK Films', 283351277),
#  ('Illumination Entertainment', 278840316),
#  ('Scott Free Productions', 273170142),
#  ('Brandywine Productions', 273170142),
#  ('Contrafilm', 256499543),
#  ('Roth Films', 226600000),
#  ('Bluegrass Films', 217101690),
#  ('Davis-Films', 207462051),
#  ('Smokehouse Pictures', 187824128),
#  ('Tim Burton Productions', 181283356),
#  ('Nu Image Films', 179679980),
#  ('Millennium Films', 179679980),
#  ('Spyglass Entertainment', 166114570),
#  ('Nick Wechsler Productions', 160221571),
#  ('Extension 765', 160221571),
#  ('Original Film', 159585328),
#  ('Stephen J. Cannell Productions', 159585328),
#  ('Mutual Film Company', 158340595),
#  ('Skydance Productions', 158340595),
#  ('TC Productions', 158340595),
#  ('Thunder Road Pictures', 151000000),
#  ('Cott Productions', 151000000),
#  ('Furia de Titanes II, A.I.E.', 151000000),
#  ('Kennedy/Marshall Company, The', 146572938),
#  ('Captivate Entertainment', 146572938),
#  ('Annapurna Pictures', 139685821),
#  ('Telecinco Cinema', 138274123),
#  ('Apaches Entertainment', 138274123),
#  ('Canal+ EspaÃ±a', 138274123),
#  ('Instituto de la CinematografÃ\xada y de las Artes Audiovisuales (ICAA)',
#   138274123),
#  ('Blumhouse Productions', 137817992),
#  ('Room 101', 137817992),
#  ('Solana Films', 137817992),
#  ('Davis Entertainment', 130000000),
#  ('Adam Schroeder Productions', 130000000),
#  ('Yucaipa Films', 125695102),
#  ('Hammer Film Productions', 110730736),
#  ('UK Film Council', 110730736),
#  ('Alliance Films', 110730736),
#  ('Film i VÃ¤st', 110730736),
#  ('Talisman Productions', 110730736),
#  ('Brownstone Productions', 98350426),
#  ('Misher Films', 98018522),
#  ('Goldmann Pictures', 98018522),
#  ('Rat Entertainment', 98018522),
#  ('Village Roadshow Pictures', 95527149),
#  ('Infinitum Nihil', 95527149),
#  ('20th Century Fox', 94772232),
#  ('Chernin Entertainment', 94772232),
#  ('Hasbro', 94025485),
#  ('Film 44', 94025485),
#  ('First Light Production', 92820716),
#  ('Silver Pictures', 88000000),
#  ('Green Hat Films', 88000000),
#  ('Mandate Pictures', 84281051),
#  ('Escape Artists', 84281051),
#  ('Management 360', 84281051),
#  ('Rainforest Films', 84070507),
#  ('Studio Mir', 84070507),
#  ('Ghost House Pictures', 71446075),
#  ('North Box Productions', 71446075),
#  ('Bandito Brothers', 69272766),
#  ('Apatow Productions', 66128471),
#  ('Sketch Films', 62400000),
#  ('UW4 Productions', 62400000),
#  ('Lakeshore Entertainment', 59293721),
#  ('Aardman Animations', 58338361),
#  ('Scott Rudin Productions', 52263166),
#  ('Indian Paintbrush', 52263166),
#  ('American Empirical Pictures', 52263166),
#  ('Moonrise', 52263166),
#  ('Phoenix Pictures', 50337469),
#  ('Headline Pictures', 48520298),
#  ('Laika Entertainment', 47139399),
#  ('Bazelevs Production', 43265139),
#  ('Abraham Productions', 43265139),
#  ('Location Gourmet', 43265139),
#  ('Tim Burton Animation Company', 42491068),
#  ('Emmett/Furla Films', 41126384),
#  ('Hedge Fund Film Partners', 41126384),
#  ('Crave Films', 41126384),
#  ('Knightsbridge Entertainment', 41126384),
#  ('Focus Features', 40278187),
#  ('Alcon Entertainment', 39700000),
#  ('What to Expect Productions', 39700000),
#  ('Leverage Management', 38100000),
#  ('Closest to the Hole Productions', 38100000),
#  ('Mutant Enemy Productions', 36486080),
#  ('Exclusive Media Group', 34554432),
#  ('Konami Corporation Ltd.', 32302796),
#  ('StudioCanal', 30727492),
#  ('Anarchos Productions', 28482868),
#  ('X-Filme Creative Pool', 28482868),
#  ('Ascension Pictures', 28482868),
#  ('ARD Degeto Film', 28482868),
#  ('Cloud Atlas Productions', 28482868),
#  ('Benaroya Pictures', 27676580),
#  ('Pie Films Inc.', 27676580),
#  ('Wessler Entertainment', 24819301),
#  ('Stoller Global Solutions', 23909751),
#  ('Artina Films', 23485056),
#  ('Lucky Monkey Pictures', 23485056),
#  ('Green Room Films', 23485056),
#  ('Treehouse Pictures', 23485056),
#  ('Plan B Entertainment', 22930465),
#  ('1984 Private Defense Contractors', 22930465),
#  ('Inferno Entertainment', 22930465),
#  ('Chockstone Pictures', 22930465),
#  ('Imagine Entertainment', 20726956),
#  ('MTV Films', 20726956),
#  ('Insurge Pictures', 20726956),
#  ('Mr. Mudd Production', 20400000),
#  ('Endgame Entertainment', 17042000),
#  ('DMG Entertainment', 17042000),
#  ('Ram Bergman Productions', 17042000),
#  ('CinÃ©+', 12204030),
#  ('CBS Films', 11653722),
#  ('Saturn Films', 11550834),
#  ('TriStar Pictures', 10637469),
#  ('Stage 6 Films', 10637469),
#  ('Akil Production Company', 10637469),
#  ('Irish Film Board', 10372606),
#  ('Lawrence Bender Productions', 10346186),
#  ('Automatik Entertainment', 10346186),
#  ('Trigger Street Productions', 10346186),
#  ('87Eleven', 10346186),
#  ('Serenade Films', 7231461),
#  ('Also Known As Pictures', 7231461),
#  ('Blueprint Pictures', 4422261),
#  ('British Film Institute (BFI)', 4422261),
#  ('Film4', 4422261),
#  ('Di Bonaventura Picture', 4221189),
#  ('Dimension Films', 3493728),
#  ('Mark Canton Productions', 3493728),
#  ('Intellectual Properties Worldwide', 3493728),
#  ('Ixtlan', 2000000),
#  ('Onda Entertainment', 2000000),
#  ('IM Global', 1383928),
#  ('Dos Corazones', -2377154),
#  ('Nickelodeon Movies', -2582638),
#  ('Fake Empire', -2582638),
#  ('Sidney Kimmel Entertainment', -3106279),
#  ('Intrepid Pictures', -3136417),
#  ('Film Rites', -3136417),
#  ('Galavis Film', -3136417),
#  ('Picture Machine', -3136417),
#  ('FilmDistrict', -3151217),
#  ('Touchstone Pictures', -3565222),
#  ('Ghoulardi Film Company', -3741940),
#  ('Pariah Entertainment Group', -3916401),
#  ('Liddell Entertainment', -6571952),
#  ('LD Entertainment', -6571952),
#  ('Wonderful Films PLC', -6571952),
#  ('Participant Media', -6861212),
#  ('Media Farm', -6861212),
#  ('Sunday Night', -6861212),
#  ('Dark Castle Entertainment', -7372508),
#  ('Studio Babelsberg Motion Pictures', -7372508),
#  ('Lucasfilm Ltd.', -7634623),
#  ('Partnership Pictures', -7634623),
#  ('DNA Films', -8962258),
#  ('Reliance BIG Entertainment', -8962258),
#  ('Rena Film', -8962258),
#  ('Peach Trees', -8962258),
#  ('A Hot Dog', -10840066),
#  ('Happy Madison Productions', -11941633),
#  ('TÃ©lÃ©film Canada', -14436444),
#  ('Rai Cinema', -14436444),
#  ('Prospero Pictures', -14436444),
#  ('Alfama Films', -14436444),
#  ('Industry Entertainment', -15363831),
#  ('Grindstone Entertainment Group', -15363831),
#  ('Cheetah Vision', -15363831),
#  ('Mandalay Vision', -15363831),
#  ('Paradox Entertainment', -15363831),
#  ('Corner Store Entertainment', -15581387),
#  ('American Zoetrope', -16215682),
#  ('VideoFilmes', -16215682),
#  ('Vanguard Films', -16215682),
#  ('Anonymous Content', -17863423),
#  ('Varsity Pictures', -17955723),
#  ('DreamWorks SKG', -21520945),
#  ('Onyx Films', -51893525),
#  ('Studio 37', -51893525),
#  ('Jouror Productions', -51893525),
#  ('Transfilm', -51893525),
#  ('France 2 CinÃ©ma', -82545651)]

# %%
answer_ls.append(3)

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
data_pp = data2[data2.production_companies.str.contains('Paramount Pictures')]
data_pp[data_pp.profit == data_pp.profit.min()]
# Out:
#        imdb_id  popularity     budget   revenue        original_title  \
# 926  tt0267626     0.72233  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 926  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 926  Fate has found its hero.
#
#                                               overview  runtime  \
# 926  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 926  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 926  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_count  vote_average  release_year    profit
# 926         146           6.0          2002 -64831034

# %%
answer_ls.append(1)

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data2.groupby('release_year').profit.sum().sort_values(ascending = False)
# Out:
# release_year
# 2015    18668572378
# 2014    16397812953
# 2012    16077001687
# 2013    15243179791
# 2011    14730241341
# 2009    13423744372
# 2010    13117292530
# 2008    11663881990
# 2007    11565911801
# 2004     9634180720
# 2003     9228823312
# 2002     9002361487
# 2005     8981925558
# 2006     8691077320
# 2001     7950614865
# 2000     6101399805
# Name: profit, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
data_wb = data2[data2.production_companies.str.contains('Warner Bros')]
data_wb.groupby('release_year').profit.sum().sort_values(ascending = False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %%
answer_ls.append(1)

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
#month = data2.release_date[data2.release_date.str.split('/')[0]]
month = pd.DataFrame(data2.release_date.str.split('/').tolist()).stack().loc[(slice(None),0)]
data3 = data2
data3['month'] = month
data3.groupby('month').count().genres.sort_values()
# Out:
# month
# 1     110
# 2     135
# 5     140
# 7     142
# 11    146
# 6     147
# 4     149
# 3     156
# 8     161
# 10    186
# 12    191
# 9     227
# Name: genres, dtype: int64

# %%
answer_ls.append(4)

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
data3[data3.month.isin(['6','7','8'])].groupby('month').count().genres.sum()
# Out:
# 450

# %%
answer_ls.append(2)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
data_winter = data3[data3.month.isin(['1','2','12'])]
pd.DataFrame(data_winter.director.str.split('|').tolist()).stack().value_counts()
# Out:
# Peter Jackson        7
# Clint Eastwood       6
# Steven Soderbergh    6
# Adam Shankman        4
# Shawn Levy           4
#                     ..
# Martin McDonagh      1
# Scott Stewart        1
# Kevin Allen          1
# Ben Stiller          1
# Cory Edwards         1
# Length: 359, dtype: int64

# %%
answer_ls.append(5)

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
a = data3.groupby(['release_year','month']).profit.sum()
a
# Out:
# release_year  month
# 2000          1         -26344591
#               10        399938512
#               11        487934818
#               12       1411487999
#               2         310137593
#                           ...
# 2015          5        1103503482
#               6        3757679861
#               7        1552273188
#               8         491699146
#               9        1775686025
# Name: profit, Length: 192, dtype: int64

# %%
b =a.to_frame()
b
# Out:
#                         profit
# release_year month
# 2000         1       -26344591
#              10      399938512
#              11      487934818
#              12     1411487999
#              2       310137593
# ...                        ...
# 2015         5      1103503482
#              6      3757679861
#              7      1552273188
#              8       491699146
#              9      1775686025
#
# [192 rows x 1 columns]

# %%
b.groupby('month').profit.sum().sort_values(ascending = False)
# Out:
# month
# 6     27551262500
# 12    26563071474
# 5     25039516141
# 11    18654155473
# 7     18307895020
# 3     13720216540
# 10    12994907859
# 4     12876005537
# 9     10878921041
# 8      9640610446
# 2      8854574425
# 1      5396885454
# Name: profit, dtype: int64

# %%
data3.groupby(['release_year','month']).profit.sum().to_frame().groupby('month').profit.sum().sort_values(ascending = False)
# Out:
# month
# 6     27551262500
# 12    26563071474
# 5     25039516141
# 11    18654155473
# 7     18307895020
# 3     13720216540
# 10    12994907859
# 4     12876005537
# 9     10878921041
# 8      9640610446
# 2      8854574425
# 1      5396885454
# Name: profit, dtype: int64

# %%
answer_ls.append(2)

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
data3.head(1)
# Out:
#      imdb_id  popularity     budget     revenue  original_title  \
# 0  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#              tagline                                           overview  \
# 0  The park is open.  Twenty-two years after the events of Jurassic ...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
#
#    vote_average  release_year      profit month
# 0           6.5          2015  1363528810     6

# %%
data4 = data3
data4['title_lenght'] = data3.original_title.str.len()
data4.head(1)
# Out:
#      imdb_id  popularity     budget     revenue  original_title  \
# 0  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#              tagline                                           overview  \
# 0  The park is open.  Twenty-two years after the events of Jurassic ...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
#
#    vote_average  release_year      profit month  title_lenght  number_of_words
# 0           6.5          2015  1363528810     6            14                2

# %%
cnt = Counter()
movies_number = Counter()
for i in range (0, len(data4)):
    for company in data4.iloc[i].production_companies.split('|'):
        cnt [company] += data4.iloc[i].title_lenght
        movies_number[company] += 1
mean_films_title = {}
for item in movies_number:
    mean_films_title [item] = cnt [item] / movies_number [item]
#max(mean_films_title, key=mean_films_title.get)
mean_films_title
# Out:
# {'Universal Studios': 14.833333333333334,
#  'Amblin Entertainment': 17.869565217391305,
#  'Legendary Pictures': 13.411764705882353,
#  'Fuji Television Network': 12.666666666666666,
#  'Dentsu': 13.5,
#  'Village Roadshow Pictures': 15.063492063492063,
#  'Kennedy Miller Productions': 14.0,
#  'Summit Entertainment': 14.804878048780488,
#  'Mandeville Films': 10.833333333333334,
#  'Red Wagon Entertainment': 9.833333333333334,
#  'NeoReel': 14.0,
#  'Lucasfilm': 41.5,
#  'Truenorth Productions': 28.0,
#  'Bad Robot': 18.77777777777778,
#  'Universal Pictures': 14.716763005780347,
#  'Original Film': 13.10344827586207,
#  'Media Rights Capital': 9.142857142857142,
#  'One Race Films': 15.0,
#  'Regency Enterprises': 13.408163265306122,
#  'Appian Way': 15.222222222222221,
#  'CatchPlay': 12.0,
#  'Anonymous Content': 13.454545454545455,
#  'New Regency Pictures': 12.607142857142858,
#  'Paramount Pictures': 17.0327868852459,
#  'Skydance Productions': 19.444444444444443,
#  'Twentieth Century Fox Film Corporation': 16.504587155963304,
#  'Scott Free Productions': 14.333333333333334,
#  'Mid Atlantic Films': 15.2,
#  'International Traders': 11.5,
#  'TSG Entertainment': 19.8,
#  'Illumination Entertainment': 9.4,
#  'Walt Disney Pictures': 17.048780487804876,
#  'Pixar Animation Studios': 10.23076923076923,
#  'Walt Disney Studios Motion Pictures': 20.0,
#  'Columbia Pictures': 14.717948717948717,
#  'Danjaq': 7.0,
#  'B24': 7.0,
#  'Dune Entertainment': 17.15909090909091,
#  'Anarchos Productions': 13.4,
#  'Warner Bros.': 15.571428571428571,
#  'DNA Films': 13.7,
#  'Universal Pictures International (UPI)': 10.0,
#  'Film4': 14.307692307692308,
#  'Happy Madison Productions': 13.91304347826087,
#  'Marvel Studios': 17.083333333333332,
#  'Prime Focus': 16.0,
#  'Revolution Sun Studios': 23.5,
#  'Double Feature Films': 14.9,
#  'The Weinstein Company': 14.035714285714286,
#  'FilmColony': 17.0,
#  'M6 Films': 7.75,
#  'Canal+': 10.363636363636363,
#  'EuropaCorp': 13.117647058823529,
#  'CinÃ©+': 8.0,
#  'Genre Films': 10.0,
#  'Beagle Pug Films': 10.0,
#  'Allison Shearmur Productions': 10.0,
#  'Studio Babelsberg': 18.7,
#  'StudioCanal': 13.608695652173912,
#  'Lionsgate': 14.8,
#  'Color Force': 24.625,
#  'Babieka': 17.0,
#  'A113': 12.0,
#  'Escape Artists': 14.307692307692308,
#  'Riche-Ludwig Productions': 8.0,
#  'New Line Cinema': 17.397727272727273,
#  'Flynn Picture Company': 9.5,
#  'Focus Features': 14.0,
#  'Trigger Street Productions': 12.0,
#  'Michael De Luca Productions': 11.666666666666666,
#  'Plan B Entertainment': 18.7,
#  'China Movie Channel': 34.0,
#  'TC Productions': 27.333333333333332,
#  'Fuzzy Door Productions': 4.0,
#  'Marv Films': 13.8,
#  'Cloudy Productions': 28.0,
#  'Participant Media': 14.266666666666667,
#  'Open Road Films': 8.7,
#  'Rocklin / Faust': 9.0,
#  'Entertainment One Features': 9.0,
#  'Gotham Group': 18.0,
#  'Temple Hill Entertainment': 23.125,
#  'Sony Pictures Entertainment (SPE)': 10.0,
#  'Alpha Core': 7.0,
#  'Gold Circle Films': 15.0,
#  'Brownstone Productions': 14.0,
#  'DreamWorks SKG': 13.903225806451612,
#  'Fox 2000 Pictures': 18.542857142857144,
#  'Marc Platt Productions': 14.6,
#  'Scholastic Entertainment': 10.0,
#  'Element Pictures': 6.5,
#  'No Trace Camping': 5.5,
#  'A24': 11.666666666666666,
#  'Duperele Films': 4.0,
#  'Buena Vista': 16.333333333333332,
#  'Vertigo Entertainment': 12.0625,
#  'Energy Entertainment': 15.5,
#  'RatPac-Dune Entertainment': 10.75,
#  'Wildgaze Films': 9.5,
#  'Irish Film Board': 8.0,
#  'Item 7': 8.0,
#  'Parallel Film Productions': 8.0,
#  'Cube Vision': 16.333333333333332,
#  'Broken Chair Flickz': 22.0,
#  'Atmosphere Entertainment MM': 13.571428571428571,
#  'Goldmann Pictures': 20.666666666666668,
#  'Davis Entertainment': 14.555555555555555,
#  'Wigram Productions': 24.0,
#  'Lakeshore Entertainment': 15.208333333333334,
#  'Sidney Kimmel Entertainment': 16.375,
#  'Sierra/Affinity': 18.0,
#  'Bazelevs Production': 15.2,
#  'Versus Pictures': 14.0,
#  'DreamWorks Animation': 16.153846153846153,
#  'Killer Films': 9.5,
#  'Number 9 Films': 5.0,
#  'Waverly Films': 14.75,
#  'Working Title Films': 15.037037037037036,
#  'Walden Media': 23.875,
#  'Cross Creek Pictures': 11.571428571428571,
#  'Free State Pictures': 8.5,
#  'Alcon Entertainment': 16.533333333333335,
#  'DMG Entertainment': 10.0,
#  'Ehman Productions': 11.0,
#  'PeaPie Films': 5.0,
#  '3 Arts Entertainment': 13.4,
#  'Endgame Entertainment': 11.181818181818182,
#  'Ram Bergman Productions': 10.0,
#  'Mad Chance': 14.6,
#  'OddLot Entertainment': 9.0,
#  'Huayi Brothers Media': 6.5,
#  'Pretty Pictures': 15.0,
#  'ArtÃ©mis Productions': 15.0,
#  'Le Tax Shelter du Gouvernement FÃ©dÃ©ral de Belgique': 15.0,
#  'Taxshelter. be': 15.0,
#  'Forward Pass': 10.166666666666666,
#  'Thunder Road Pictures': 12.0,
#  'Black Label Media': 7.0,
#  'Marvel Entertainment': 18.5,
#  'Constantin Film.': 14.0,
#  'Moving Picture Company (MPC)': 21.0,
#  'Chernin Entertainment': 14.142857142857142,
#  'Feigco Entertainment': 10.0,
#  'Kramer & Sigman Films': 5.0,
#  'Zaftig Films': 5.0,
#  'Fox International Productions': 13.5,
#  'Infinite Frameworks Studios': 16.0,
#  'Imagine Entertainment': 15.76,
#  'Spring Creek Productions': 17.5,
#  'Roth Films': 18.714285714285715,
#  'K. JAM Media': 23.0,
#  'Metro-Goldwyn-Mayer (MGM)': 15.0625,
#  'Chartoff-Winkler Productions': 8.5,
#  'Apatow Productions': 18.63157894736842,
#  'Entertainment One': 12.0,
#  'Moonlighting Films': 12.75,
#  'Raindog Films': 14.0,
#  'Anton Capital Entertainment (ACE)': 7.0,
#  'Berlanti Productions': 3.0,
#  'Blue Sky Studios': 12.0,
#  'Twentieth Century Fox Animation': 12.5,
#  'LStar Capital': 12.0,
#  'The Cantillon Company': 10.0,
#  'The Shuman Company': 10.0,
#  'Sony Pictures': 12.8,
#  'Point Grey Pictures': 13.333333333333334,
#  'Good Universe': 10.6,
#  'Sony Pictures Animation': 19.0,
#  'Groundswell Productions': 12.0,
#  'CBS Films': 14.2,
#  'TriStar Pictures': 11.588235294117647,
#  'Sony Pictures Entertainment': 13.0,
#  'ImageMovers': 11.571428571428571,
#  'BenderSpink': 13.0,
#  'David Dobkin Productions': 9.0,
#  'Ghost House Pictures': 12.0,
#  'Worldview Entertainment': 8.333333333333334,
#  'Blumhouse Productions': 17.727272727272727,
#  'Blue-Tongue Films': 8.5,
#  'STX Entertainment': 8.0,
#  'Ahimsa Films': 8.0,
#  'Gary Sanchez Productions': 16.428571428571427,
#  'Red Granite Pictures': 17.75,
#  'Onyx Films': 14.0,
#  'Orange Studios': 17.0,
#  'CityMation': 17.0,
#  'On Entertainment': 17.0,
#  'Zippcast Films': 17.0,
#  'Amazon Studios': 14.0,
#  'Film Art Media': 14.0,
#  'Apollo Media': 14.0,
#  'Wonderland Sound and Vision': 16.8,
#  'Vast Entertainment': 8.0,
#  'Alliance Films': 13.75,
#  'IM Global': 11.857142857142858,
#  'Automatik Entertainment': 10.666666666666666,
#  'Sony Pictures Releasing': 20.0,
#  'Sony Pictures Home Entertainment': 18.0,
#  'Closest to the Hole Productions': 10.75,
#  'Miramax Films': 15.102564102564102,
#  'Screen Gems': 14.64516129032258,
#  'Blinding Edge Pictures': 11.875,
#  'Infinitum Nihil': 10.8,
#  'Head Gear Films': 10.0,
#  'Bold Films': 8.0,
#  'Living Films': 14.5,
#  'Brothers Dowdle Productions': 9.0,
#  'BBC Films': 16.6875,
#  'Origin Pictures': 21.0,
#  'Little Stranger': 7.0,
#  'MTV Films': 17.166666666666668,
#  'Platinum Dunes': 19.833333333333332,
#  'Insurge Pictures': 22.333333333333332,
#  'Iron Horse Entertainment (II)': 15.0,
#  'Inimitable Pictures': 6.0,
#  'ShivHans Pictures': 6.0,
#  'Ingenious Media': 18.0,
#  'Gran Via Productions': 16.8,
#  'Route One Films': 19.5,
#  'Nickelodeon Movies': 20.714285714285715,
#  'Nickelodeon Animation Studios': 40.0,
#  'United Plankton Pictures': 40.0,
#  'Disruption Entertainment': 17.333333333333332,
#  'Sunswept Entertainment': 25.0,
#  'Silver Pictures': 14.823529411764707,
#  'TF1 Films Production': 9.454545454545455,
#  'Instituto de la CinematografÃ\xada y de las Artes Audiovisuales (ICAA)': 11.666666666666666,
#  'Pacific Standard': 10.0,
#  'TriStar Productions': 19.0,
#  'Columbia TriStar': 16.0,
#  'Clinica Estetico': 18.0,
#  'Scott Rudin Productions': 18.291666666666668,
#  'Ruby Films': 13.5,
#  'PathÃ©': 9.166666666666666,
#  'Metanoia Films': 10.0,
#  'Vinyl Films': 11.4,
#  'RatPac Entertainment': 13.0,
#  'Smokehouse Pictures': 15.4,
#  'Shangri-La Entertainment': 13.25,
#  'QED International': 10.5,
#  'Dune Films': 14.0,
#  'Venture Forth': 15.0,
#  'Wildwood Enterprises': 18.75,
#  'Treehouse Pictures': 13.25,
#  'Hasbro Studios': 21.0,
#  'Allspark Pictures': 21.0,
#  'Syncopy': 13.375,
#  'Lynda Obst Productions': 17.0,
#  'Bulletproof Cupid': 23.0,
#  '87Eleven': 6.5,
#  'DefyNite Films': 9.0,
#  'MJW Films': 9.0,
#  'WingNut Films': 29.9,
#  '3Foot7': 41.0,
#  'Walt Disney Animation Studios': 12.0,
#  'Black Bear Pictures': 18.0,
#  'Bristol Automotive': 18.0,
#  'Dayday Films': 15.0,
#  'Le Grisbi Productions': 7.0,
#  'M Productions': 7.0,
#  'Crave Films': 8.0,
#  '1492 Pictures': 28.23076923076923,
#  '21 Laps Entertainment': 27.0,
#  "Donners' Company": 12.88888888888889,
#  'Bad Hat Harry Productions': 10.8,
#  'Sierra / Affinity': 12.0,
#  'Di Bonaventura Pictures': 15.642857142857142,
#  'Hasbro': 20.6,
#  'Fox Searchlight Pictures': 15.208333333333334,
#  'Indian Paintbrush': 18.2,
#  'Mace Neufeld Productions': 13.0,
#  'Marvel Enterprises': 10.461538461538462,
#  'Avi Arad Productions': 24.0,
#  'Matt Tolmach Productions': 24.0,
#  'Viz Media': 16.0,
#  'Province of British Columbia Production Services Tax Credit': 13.0,
#  'Malpaso Productions': 13.0,
#  'Mad Chance Productions': 15.0,
#  'Volcano Films': 22.0,
#  'Toho Company': 8.0,
#  'Irish Dreamtime': 16.0,
#  'Relativity Media': 13.262626262626263,
#  'SPD Films': 16.0,
#  'Mad Hatter Entertainment': 25.0,
#  'Davis-Films': 19.2,
#  'Nu Image Films': 16.454545454545453,
#  'LionsGate': 15.5,
#  'Millennium Films': 15.117647058823529,
#  'Ex3 Productions': 17.0,
#  'DC Comics': 12.11111111111111,
#  'Lin Pictures': 18.2,
#  'Warner Bros. Animation': 15.4,
#  'Outlaw Sinema': 10.5,
#  'Pendle Mountain Productions': 11.0,
#  'WideAwake': 12.0,
#  'Lucamar Productions': 14.0,
#  'Hollywood Gang Productions': 12.5,
#  'Nimar Studios': 12.5,
#  'Tonik Productions': 9.0,
#  'Asis Productions': 9.0,
#  'Cannell Studios': 14.0,
#  'Jersey Films': 14.666666666666666,
#  '1984 Private Defense Contractors': 17.0,
#  'Exclusive Media Group': 13.777777777777779,
#  'Heyday Films': 31.583333333333332,
#  'Echo Films': 7.0,
#  "We're Not Brothers Productions": 4.0,
#  'Cinelou Films': 4.0,
#  'Aldamisa Entertainment': 15.0,
#  'Kilburn Media': 4.0,
#  'Fetisov Teterin Films': 4.0,
#  'Why Not Productions': 20.0,
#  '5150 Action': 18.0,
#  'Stoney Lake Entertainment': 11.0,
#  'Imagenation Abu Dhabi FZ': 16.083333333333332,
#  'FilmNation Entertainment': 11.2,
#  'Before the Door Pictures': 15.0,
#  'Washington Square Films': 15.0,
#  'Radical Studios': 8.0,
#  'Protozoa Pictures': 9.5,
#  'Big Kid Pictures': 14.333333333333334,
#  'Team Downey': 9.0,
#  'Karz Entertainment': 14.0,
#  'Gulfstream Pictures': 7.0,
#  'Offspring Entertainment': 13.333333333333334,
#  'Rainforest Films': 12.4,
#  'Ghoulardi Film Company': 14.0,
#  'Etalon film': 25.0,
#  'Screen Australia': 11.333333333333334,
#  'Screen Queensland': 14.0,
#  'Blacklab Entertainment': 14.0,
#  'Wolfhound Pictures': 14.0,
#  'Strike Entertainment': 10.8,
#  'Straight Up Films': 13.0,
#  'LBI Productions': 15.0,
#  '20th Century Fox': 15.058823529411764,
#  'Troublemaker Studios': 13.714285714285714,
#  'AR Films': 20.5,
#  'Demarest Films': 20.5,
#  'Conundrum Entertainment': 14.666666666666666,
#  'Obelisk Productions': 17.0,
#  'Jolie Pas': 8.0,
#  'Harpo Films': 15.666666666666666,
#  'Celador Films': 11.0,
#  'Cloud Eight Films': 6.666666666666667,
#  'Impact Pictures': 17.22222222222222,
#  'Don Carmody Productions': 14.5,
#  'FilmDistrict': 10.428571428571429,
#  'Constantin Film International': 7.0,
#  'Overbrook Entertainment': 11.0,
#  'Crescendo Productions': 10.0,
#  'Goldenlight Films': 11.0,
#  'Reliance Entertainment': 13.125,
#  'Bandito Brothers': 13.0,
#  'Touchstone Pictures': 13.793103448275861,
#  'Electronic Arts': 14.0,
#  'Laika Entertainment': 10.75,
#  'Silverwood Films': 8.0,
#  'Electric City Entertainment': 17.0,
#  'Tim Burton Productions': 18.272727272727273,
#  'Grindstone Entertainment Group': 13.25,
#  'Emmett/Furla Films': 11.0,
#  'Oasis Films': 10.0,
#  'Aperture Entertainment': 10.0,
#  'Broken Road Productions': 13.0,
#  'DisneyToon Studios': 19.333333333333332,
#  'Prana Studios': 16.5,
#  'Prana Animation Studios': 26.0,
#  'Albert S. Ruddy Productions': 13.5,
#  'Likely Story': 10.5,
#  'Annapurna Pictures': 11.428571428571429,
#  'Fake Empire': 10.0,
#  'Bluegrass Films': 12.5,
#  'Porchlight Films': 9.0,
#  'Screen NSW': 9.0,
#  'Qwerty Films': 16.0,
#  'TF1 Droits Audiovisuels': 16.0,
#  'Scope Pictures': 10.5,
#  'The Safran Company': 11.0,
#  'Evergreen Media Group': 11.0,
#  'Hopscotch Films': 15.0,
#  'D8': 14.0,
#  'Weed Road Pictures': 12.285714285714286,
#  'HanWay Films': 13.333333333333334,
#  'Snoot Entertainment': 9.0,
#  'Hopscotch Features': 16.5,
#  'Seven West Media': 17.0,
#  'Fear of God Films': 17.0,
#  'Seven Group Holdings': 17.0,
#  'Jim Henson Company, The': 59.0,
#  'Screen Gems, Inc.': 14.0,
#  'Olive Bridge Entertainment': 14.333333333333334,
#  'Scottish Screen': 19.5,
#  'UK Film Council': 16.764705882352942,
#  'Nick Wechsler Productions': 11.0,
#  'Creative Scotland': 14.0,
#  'Warner Bros. Interactive Entertainment': 13.0,
#  'Rob Thomas Productions': 13.0,
#  'Hearst Entertainment Productions': 10.0,
#  'LightWorkers Media': 10.0,
#  'Mandalay Pictures': 14.428571428571429,
#  'Affirm Films': 17.0,
#  'Sahara Productions': 11.0,
#  'Silvatar Media': 11.0,
#  'The Combine': 18.0,
#  'Boxing Cat Films': 14.0,
#  'Disney': 19.0,
#  'Provident Films': 15.0,
#  'Pure Flix Entertainment': 14.5,
#  'FourBoys Entertainment': 15.0,
#  'Panay Films': 13.0,
#  'Winkler Films': 9.5,
#  'Max Films Productions': 19.0,
#  'Morag Loves Company': 19.0,
#  'Ingenious Film Partners': 16.0,
#  'Lightstorm Entertainment': 6.5,
#  'A Band Apart': 18.0,
#  'Zehnte Babelsberg': 20.0,
#  'Visiona Romantica': 20.0,
#  'Sketch Films': 25.5,
#  'UW3 Film Productions': 30.0,
#  'Spyglass Entertainment': 13.875,
#  'MavroCine Pictures GmbH & Co. KG': 9.0,
#  'The Halcyon Company': 20.0,
#  'Key Creatives': 13.0,
#  'Block / Hanson': 10.0,
#  'Canadian Film or Video Production Tax Credit (CPTC)': 9.0,
#  'Internationale Filmproduktion Blackbird Dritte': 14.333333333333334,
#  'Watermark': 20.0,
#  'Dune Entertainment III': 16.0,
#  'Green Hat Films': 14.0,
#  'IFP Westcoast Erste': 12.0,
#  'Lawrence Gordon Productions': 18.666666666666668,
#  'Centropolis Entertainment': 12.833333333333334,
#  'The Mark Gordon Company': 8.0,
#  'Farewell Productions': 4.0,
#  'Focus Films': 8.25,
#  'Starz Animation': 9.333333333333334,
#  'Arc Productions': 6.5,
#  'Panorama Films': 15.0,
#  'Skylark Productions': 16.0,
#  'Left Tackle Pictures': 14.0,
#  'Zucker/Netter Productions': 14.0,
#  'Maverick Films': 23.0,
#  'Imprint Entertainment': 20.333333333333332,
#  'Flower Films (II)': 19.8,
#  'Internationale Filmproduktion Blackswan': 27.0,
#  'Kontsept Film Company': 27.0,
#  'Kurtzman/Orci': 17.5,
#  'American Empirical Pictures': 16.5,
#  'Museum Canada Productions': 46.0,
#  'Walt Disney': 32.0,
#  'Goldcrest Pictures': 11.428571428571429,
#  'Grand Army Entertainment': 19.0,
#  'Scion Films': 15.545454545454545,
#  'Inferno Distribution': 13.5,
#  'Stage 6 Films': 18.6,
#  'Hachiko': 19.0,
#  'Film Department, The': 19.0,
#  'Evil Twins': 19.0,
#  'Warp Films': 19.0,
#  'Darko Entertainment': 7.0,
#  'Radar Pictures': 16.77777777777778,
#  'Radical Media': 10.666666666666666,
#  'Constantin Film Produktion': 18.6,
#  'Mandate Pictures': 16.333333333333332,
#  'Buckaroo Entertainment': 9.333333333333334,
#  'Curse Productions': 15.0,
#  'Mystery Clock Cinema': 7.0,
#  'Kaplan/Perrone Entertainment': 12.5,
#  'Liberty Films UK': 4.0,
#  'Lunar Industries': 4.0,
#  'Xingu Films': 4.0,
#  'Limelight Fund': 4.0,
#  'Jerry Bruckheimer Films': 23.57894736842105,
#  'Whamaphram Productions': 7.0,
#  'Wintergreen Productions': 13.0,
#  'Pan EuropÃ©enne Production': 10.0,
#  'Virtual Films': 9.5,
#  'Wild West Picture Show Productions': 13.6,
#  'Stuber Productions': 12.571428571428571,
#  'Sighvatsson Films': 8.0,
#  'Palomar Pictures (II)': 14.0,
#  '2929 Productions': 13.0,
#  'Dimension Films': 14.297297297297296,
#  'Chockstone Pictures': 11.666666666666666,
#  'Easy There Tiger Productions': 13.0,
#  'Montecito Picture Company, The': 10.5,
#  'Outpost Studios': 5.0,
#  'Fox Atomic': 11.4,
#  'Dark Castle Entertainment': 10.333333333333334,
#  'Studio Babelsberg StudioBabelsberg Motion Pictures': 6.0,
#  'Studio Canal': 18.454545454545453,
#  'Fortis Films': 16.0,
#  'Practical Pictures': 20.0,
#  'Parallel Zide': 20.0,
#  'Bagdasarian Productions': 31.0,
#  'Smokewood Entertainment Group': 8.0,
#  'Andell Entertainment': 14.0,
#  'Rogue Pictures': 12.555555555555555,
#  'Phantom Four': 10.0,
#  'The Montecito Picture Company': 10.2,
#  'De Line Pictures': 13.333333333333334,
#  'Bernard Gayle Productions': 15.0,
#  'Section Eight': 12.25,
#  'Jaffe / Braunstein Enterprise': 14.0,
#  'Gunn Films': 16.0,
#  'Paramount Vantage': 12.7,
#  'Misher Films': 10.25,
#  'Case 39 Productions': 7.0,
#  'Medienproduktion Prometheus Filmgesellschaft': 20.0,
#  'Portobello Studios': 20.0,
#  'Furst Films': 11.0,
#  'Pictures in Paradise': 13.0,
#  'Pacific Film and Television Commission': 10.5,
#  'Australian Film Finance Corporation (AFFC)': 11.0,
#  'Camp / Thompson Pictures': 12.0,
#  'Icon Productions': 13.75,
#  'Infinity Features Entertainment': 4.0,
#  'Langley Productions': 17.0,
#  'Thunder Road Productions': 17.0,
#  'Fuqua Films': 17.0,
#  'Twisted Pictures': 7.0,
#  'GK Films': 10.727272727272727,
#  'Mike Zoss Productions': 16.2,
#  'Rogue': 16.0,
#  'Tooley Productions': 17.0,
#  '20th Century Fox Home Entertainment': 9.0,
#  'WWE Studios': 8.8,
#  'Midnight Sun Pictures': 9.0,
#  'Vidhu Vinod Chopra Productions': 8.0,
#  'Smoke House': 26.0,
#  'Goldsmith-Thomas Productions': 8.0,
#  'Mosaic Media Group': 13.0,
#  'Sid & Marty Krofft Pictures': 16.0,
#  'Revelations Entertainment': 8.0,
#  'Ilion Animation Studios': 9.0,
#  'Hand Made Films': 9.0,
#  'Ocean Pictures': 8.0,
#  'Tapestry Films': 17.0,
#  'HimenÃ³ptero': 5.0,
#  'Telecinco Cinema': 10.0,
#  'Mod Producciones': 5.0,
#  'Canal+ EspaÃ±a': 10.75,
#  'Chris Brinker Productions': 38.0,
#  'Saturn Films': 18.615384615384617,
#  'Edward R. Pressman Film': 30.0,
#  'Polsky Films': 46.0,
#  'Stars Road Entertainment': 6.5,
#  'Farah Films & Management': 7.0,
#  'Tezuka Production Company Ltd.': 9.0,
#  'Imagi Animation Studios': 6.5,
#  'Atlas Entertainment': 14.666666666666666,
#  'X-Filme Creative Pool': 14.0,
#  'One Race Productions': 14.2,
#  'Dentsu Inc.': 14.0,
#  'Spectacle Entertainment Group': 14.0,
#  'Trancas International Films': 12.0,
#  "It's a Laugh Productions": 25.0,
#  'Millar Gough Ink': 25.0,
#  'Josephson Entertainment': 14.75,
#  'New Upstairs Productions': 19.0,
#  'Upstairs Canada Productions': 19.0,
#  'Saga Film': 15.0,
#  'Chambara Pictures': 15.0,
#  'Smartest Man Productions': 12.0,
#  'Paul Schiff Productions': 11.0,
#  'Laura Bickford Productions': 9.0,
#  'Medienproduktion Poseidon Filmgesellschaft': 9.0,
#  'PathÃ© Renn Productions': 10.25,
#  'This Is That Productions': 19.333333333333332,
#  '26 Films': 16.0,
#  'Mark Johnson Productions': 18.0,
#  'Curmudgeon Films': 18.0,
#  'DreamWorks': 11.666666666666666,
#  'Top Shelf Productions': 10.0,
#  'Hyde Park Films': 20.8,
#  'Czech Anglo Productions': 12.0,
#  'Wandering Star Pictures': 12.0,
#  'Seed Productions': 16.5,
#  'Edmonds Entertainment Group (EEG)': 11.0,
#  'Epidemic Pictures': 11.0,
#  'Isle of Man Film': 12.8,
#  'Freestyle Releasing': 19.0,
#  'CinemaNX': 15.0,
#  'Warner Bros. Pictures': 11.692307692307692,
#  'Echo Lake Productions': 11.0,
#  'Premiere Picture': 11.0,
#  'Cold Spring Pictures': 12.333333333333334,
#  "Butcher's Run Films": 11.0,
#  'Informant Media': 11.0,
#  'Castle Rock Entertainment': 17.866666666666667,
#  'Banter': 31.0,
#  'Ozla Pictures': 12.0,
#  'Great Scott Productions Pty. Ltd.': 17.0,
#  'Team Todd': 17.666666666666668,
#  'Zanuck Company, The': 27.666666666666668,
#  'Phoenix Pictures': 13.666666666666666,
#  'Sikelia Productions': 18.5,
#  'LivePlanet': 11.0,
#  'Sean Bailey Productions': 12.0,
#  'Darlow Smithson Productions': 9.0,
#  'Lions Gate': 12.5,
#  'Peninsula Films': 12.666666666666666,
#  'Italian Tax Credit': 11.0,
#  'The Zanuck Company': 16.166666666666668,
#  'Junction Entertainment': 25.333333333333332,
#  'Everyman Pictures': 21.25,
#  'Dreamworks Pictures': 14.0,
#  'Firm Films': 15.0,
#  'Prospect Park': 11.0,
#  'Millbrook Farm Productions': 11.0,
#  'DC Entertainment': 12.4,
#  'Overnight Films': 10.0,
#  'Kennedy/Marshall Company, The': 15.375,
#  'Industrial Light & Magic (ILM)': 18.0,
#  'Bedlam Productions': 17.0,
#  'See-Saw Films': 17.0,
#  'Aegis Film Fund': 14.5,
#  'Bedford Falls Productions': 13.333333333333334,
#  'Polish Film Institute': 12.0,
#  'Exclusive Films': 12.0,
#  'Monolith Films': 12.0,
#  'On the Road': 12.0,
#  'Tree Line Films': 13.0,
#  'Pink Machine': 14.0,
#  'Red Om Films': 13.0,
#  'Madhouse Entertainment': 13.0,
#  'Octagon Films': 9.0,
#  'Birnbaum/Barber': 9.0,
#  'Bona Fide Productions': 12.75,
#  'River Road Entertainment': 18.166666666666668,
#  'Road Rebel': 13.5,
#  'Linson Entertainment': 12.333333333333334,
#  'Rice Films': 15.0,
#  'Necropia': 27.0,
#  'Tequila Gang': 27.0,
#  'Serendipity Productions': 6.0,
#  'Jerry Weintraub Productions': 14.5,
#  'China Film Group': 14.0,
#  'Matador Pictures': 11.0,
#  'Magic Light Pictures': 11.0,
#  'Cinema Four': 11.0,
#  'Runteam Ltd.': 16.0,
#  'R.P. Productions': 16.0,
#  'France 2 CinÃ©ma': 13.833333333333334,
#  'FidÃ©litÃ© Films': 19.0,
#  'Hwy61': 19.0,
#  'Katalyst Films': 15.333333333333334,
#  'Aversano Films': 7.0,
#  'Home Box Office (HBO)': 17.0,
#  'HBO Films': 19.5,
#  'Oops Doughnuts Productions': 9.0,
#  'Frontier Pictures': 9.0,
#  'Three Strange Angels': 20.666666666666668,
#  'United Artists': 13.444444444444445,
#  'New Crime Productions': 20.0,
#  'Hammer Film Productions': 13.5,
#  'EFTI': 9.0,
#  'Overture Films': 10.0,
#  'Animal Logic': 27.5,
#  'Cruel and Unusual Films': 21.25,
#  'Battle Mountain Films': 15.0,
#  'Village Roadshow Pictures Asia': 18.0,
#  'PathÃ© Pictures International': 7.666666666666667,
#  'Stone Productions': 5.0,
#  'Mimran Schur Pictures': 5.0,
#  'Chako Film Company': 10.0,
#  'Intellectual Properties Worldwide': 10.5,
#  'Oceana Media Finance': 10.0,
#  'Pantheon Entertainment Corporation': 10.0,
#  'Innocence Productions': 10.0,
#  'Prescience': 10.333333333333334,
#  'Omega Entertainment': 10.0,
#  'Twentieth Century Fox': 11.0,
#  'Mayhem Pictures': 11.666666666666666,
#  'Reliance BIG Entertainment': 14.0,
#  'Hydraulx': 7.0,
#  'Rat Entertainment': 11.5,
#  'Transmission Pictures': 7.0,
#  'Pioneer Pictures': 8.0,
#  'Gracie Films': 14.0,
#  'Robert Simonds Productions': 13.8,
#  'Spy Next Door': 17.0,
#  'Mosaic': 22.0,
#  'Henceforth': 16.0,
#  'Projection Pictures': 16.0,
#  'London Boulevard': 16.0,
#  'American Film Company': 15.0,
#  'Parabolic Pictures': 18.0,
#  'Birdsong Pictures': 18.0,
#  'Penn Station Entertainment': 16.0,
#  'Lions Gate Family Entertainment': 15.0,
#  'Crest Animation Productions': 15.0,
#  'Rhythm and Hues': 9.0,
#  'Picnic Basket': 9.0,
#  'Maguire Entertainment': 14.5,
#  'Omnilab Media': 20.0,
#  'Ambience Entertainment': 20.0,
#  'Night Chronicles': 5.0,
#  'Serendipity Point Films': 16.0,
#  'Furry Vengeance Productions': 15.0,
#  'platinum studios': 20.0,
#  'Long Distance Films': 24.0,
#  'HighRoad Entertainment': 16.0,
#  'Prelude Pictures': 16.0,
#  'Lone Runner Entertainment': 16.0,
#  'Kenio Films': 16.0,
#  'Perfect Game, The': 16.0,
#  'Boram Entertainment Inc.': 17.0,
#  'Ealing Studios': 12.0,
#  'Fragile Films': 12.0,
#  'Quickfire Films': 12.0,
#  'Lions Gate Films': 14.578947368421053,
#  'The Tyler Perry Company': 26.0,
#  'PVR Cinemas': 14.0,
#  'Hari Om Entertainment Co.': 14.0,
#  'Blockbuster Movie Entertainers': 14.0,
#  'Fast Track Productions': 11.0,
#  'The Saul Zaentz Company': 43.0,
#  'Asymmetrical Productions': 16.0,
#  'Les Films Alain Sarde': 16.0,
#  'Babbo Inc.': 16.0,
#  'The Picture Factory': 16.0,
#  'Stanley Kubrick Productions': 28.0,
#  'Pacific Data Images (PDI)': 9.166666666666666,
#  'Little Bird': 19.5,
#  'NPV Entertainment': 14.15,
#  'Alphaville Films': 16.166666666666668,
#  'Imhotep Productions': 17.0,
#  'Walt Disney Feature Animation': 16.571428571428573,
#  'Toho-Towa': 22.25,
#  'Mutual Film Company': 19.2,
#  'British Broadcasting Corporation (BBC)': 32.5,
#  'Liveplanet': 14.0,
#  'Zide-Perry Productions': 16.0,
#  'BrownHouse Productions': 20.0,
#  'Bottom of the Ninth Productions': 20.0,
#  'Bazmark Films': 12.666666666666666,
#  'Swanford Films': 18.0,
#  'KC Medien': 18.0,
#  'Revolution Studios': 11.333333333333334,
#  'Columbia Pictures Corporation': 14.787234042553191,
#  'Black and Blu Entertainment': 15.0,
#  'Finestkind': 15.0,
#  'Red Hour Productions': 9.0,
#  'Neal H. Moritz Productions': 22.0,
#  'Gold/Miller Productions': 9.0,
#  'Wayans Bros. Entertainment': 11.5,
#  'Brad Grey Pictures': 13.0,
#  'Outlaw Productions (I)': 12.0,
#  'WV Films II': 12.0,
#  'Cruise/Wagner Productions': 15.3,
#  'Canal Plus': 10.142857142857142,
#  'Sogecine': 10.0,
#  'Las Producciones del Escorpion': 10.0,
#  'Lucky Red': 16.0,
#  'Universal Cartoon Studios': 25.0,
#  'Paramount Animation': 15.2,
#  'View Askew Productions': 21.666666666666668,
#  'Miramax': 23.25,
#  'Simon Fields Productions': 11.0,
#  'Cruise-Wagner Productions': 11.0,
#  'Current Entertainment': 11.666666666666666,
#  'Immortal Entertainment': 18.0,
#  'Metropolitan Filmexport': 13.0,
#  'Red Wagon Productions': 13.5,
#  'Beacon Communications': 9.333333333333334,
#  'Jonathan Krane Group': 9.0,
#  'Industry Entertainment': 11.0,
#  'Epsilon Motion Pictures': 12.833333333333334,
#  'Square USA': 33.0,
#  'Chris Lee Productions': 20.5,
#  'American Zoetrope': 15.6,
#  'Cinerenta Medienbeteiligungs KG': 10.333333333333334,
#  'Cinerenta-Cinebeta': 16.0,
#  'VCL Communications': 16.0,
#  'Underworld Entertainment': 9.0,
#  'AZL Productions KG': 19.0,
#  'David Brown Productions': 13.5,
#  'MFP Munich Film Partners': 19.0,
#  'Phase 1 Productions': 19.0,
#  'Intermedia Films': 15.0,
#  'Dee Gee Entertainment': 19.0,
#  'Prufrock Pictures': 19.0,
#  'Fireworks Pictures': 8.0,
#  'USA Films': 9.5,
#  'Sean S. Cunningham Films': 11.5,
#  'Crystal Lake Entertainment': 11.5,
#  'Newmarket Capital Group': 9.5,
#  'Lawrence Bender Productions': 14.6,
#  'Pistolero Productions LLC': 11.0,
#  'Bel Air Entertainment': 13.8,
#  'IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG': 18.333333333333332,
#  'Kopelson Entertainment': 11.5,
#  'Bungalow Productions': 31.0,
#  'Silver Lion Films': 31.0,
#  'Vision View Entertainment': 31.0,
#  'American Entertainment Partners L.P.': 7.0,
#  'David Kirschner Productions': 8.5,
#  'Franchise Pictures': 13.76923076923077,
#  'Morgan Creek Productions': 14.5,
#  'Tribeca Productions': 17.333333333333332,
#  'New Redemption Pictures': 10.0,
#  'GHS Productions KG': 8.0,
#  'Munich Film Partners & Company (MFP) GHS Productions': 8.0,
#  'Nides/McCormick Productions': 8.0,
#  'Horseshoe Bay Productions': 9.0,
#  'Merlin Films': 20.0,
#  'Native Pictures Productions': 8.0,
#  'Darkwoods Productions': 10.0,
#  'Storm King Productions': 14.0,
#  'Animationwerks': 14.0,
#  'Ardustry Entertainment': 20.0,
#  'Mediastream Film GmbH & Co. Productions KG': 24.0,
#  'Cort/Madden Productions': 19.0,
#  'Cheyenne Enterprises': 12.625,
#  'Empire Pictures': 7.0,
#  'Hyde Park Entertainment': 17.666666666666668,
#  'Ufland': 15.0,
#  'Trackform Film Productions': 6.0,
#  "Mel's Cite du Cinema": 14.5,
#  'Dino De Laurentiis Company': 11.8,
#  'Tollin/Robbins Productions': 8.75,
#  'Crystal Sky Worldwide': 13.0,
#  'MDP Worldwide': 13.0,
#  'ApolloMedia Distribution': 11.5,
#  'Carousel Picture Company, The': 13.0,
#  'Signature Entertainment': 13.0,
#  'Dan Films': 14.0,
#  'CP Medien AG': 14.0,
#  'TPS Star': 9.0,
#  'Grive Productions': 9.0,
#  'Eon Productions': 15.0,
#  'Internationale Filmproduktion Richter': 10.0,
#  'Playtone': 12.25,
#  'Littlestar': 10.0,
#  'China Film Co-Production Corporation': 24.0,
#  'Sommers Company, The': 24.0,
#  'Valhalla Motion Pictures': 12.5,
#  'MVL Incredible Productions': 19.0,
#  'Gerber Pictures': 14.333333333333334,
#  'Double Nickel Entertainment': 11.0,
#  'Dark Horse Entertainment': 15.4,
#  'Hypnotic': 15.0,
#  'Kickstart Productions': 6.0,
#  'Europa Corp': 13.0,
#  'Achte Babelsberg Film': 8.0,
#  'The Department of Trade and Industry of South Africa': 9.0,
#  'Kingsgate Films': 15.0,
#  'Grosvenor Park Media Ltd.': 17.5,
#  'Voltage Pictures': 15.0,
#  'Film Capital Europe Funds (FCEF )': 15.0,
#  'Stillking Films': 18.5,
#  'Ozumi Films': 40.0,
#  'Propeler': 40.0,
#  'Red Hour Films': 23.75,
#  'Internationale Filmproduktion Stella-del-Sud Second': 14.0,
#  'K/O Paper Products': 11.666666666666666,
#  'KMP Film Invest': 11.0,
#  'Rogue Marble': 8.5,
#  'Earth Canada Productions': 29.0,
#  'Hammerhead Productions': 19.0,
#  'ScreenWest': 9.0,
#  'Heyday films': 7.0,
#  'Internationale Filmproduktion Blackbird Erste': 8.0,
#  'Baumgarten Management and Productions (BMP)': 15.0,
#  'Wild Bunch': 9.666666666666666,
#  'Top Rope': 12.0,
#  'MHF Zweite Academy Film': 18.5,
#  'Marvel Knights': 25.0,
#  'SGF Entertainment': 18.0,
#  'Collision Entertainment': 9.0,
#  'Abandon Entertainment': 9.0,
#  'Foxtor Productions': 9.0,
#  'Castel Film Romania': 10.0,
#  'ASAF': 7.0,
#  'Luna Pictures': 7.0,
#  'Kanzaman': 14.75,
#  'Art In Motion': 13.0,
#  'Blue Askew': 26.0,
#  'Internationale Filmproduktion Stella-del-SÃ¼d': 11.0,
#  'CinÃ©CinÃ©ma': 10.5,
#  'Babylon': 12.0,
#  'Blueprint Pictures': 13.0,
#  'Twins Financing': 9.0,
#  'The Kennedy/Marshall Company': 18.75,
#  'Depth of Field': 22.333333333333332,
#  'Type A Films': 26.5,
#  'Ott Medien': 16.0,
#  'Alta Loma Entertainment': 15.0,
#  'Internationale Filmproduktion': 13.0,
#  'Gravier Productions': 24.0,
#  'Antena 3 Films': 24.0,
#  'TelevisiÃ³ de Catalunya (TV3)': 24.0,
#  'Antena 3 TelevisiÃ³n': 24.0,
#  'Casey Silver Productions': 10.5,
#  'Huayi Brothers': 21.0,
#  'InVenture Entertainment': 14.0,
#  'Nu-Image Films': 14.0,
#  'Lietuvos Kinostudija': 13.0,
#  'Scout Productions': 13.0,
#  'Castelao Producciones': 13.0,
#  'Grosvenor Park Productions': 11.5,
#  'Bedford Falls Company, The': 10.333333333333334,
#  'Defiance Productions': 8.0,
#  'Pistachio Pictures': 8.0,
#  'Cohen/Pearl Productions': 11.0,
#  'Ascendant Pictures': 13.0,
#  'Rising Star': 15.666666666666666,
#  'VIP Medienfonds 4': 20.0,
#  'Outlander Productions': 9.0,
#  'Ten Thirteen Productions': 30.0,
#  'Crying Box Productions': 30.0,
#  'Rifkin-Eberts': 9.0,
#  'Toff Guy Films': 10.0,
#  'VN Productions': 7.0,
#  'Virtual Studios': 16.714285714285715,
#  'Initial Entertainment Group': 17.0,
#  'International Production Company': 22.666666666666668,
#  'Blue Star Pictures': 17.0,
#  'Odd Lot Entertainment': 9.0,
#  'Media Magik Entertainment': 12.0,
#  'Dark Lot Entertainment': 10.0,
#  'UTV Motion Pictures': 13.0,
#  'Intrepid Pictures': 11.2,
#  'South Pacific Pictures': 22.0,
#  'Spice Factory': 22.0,
#  'The Australian Film Commission': 22.0,
#  'Darren Star Productions': 16.0,
#  'Universal Pictures Corporation': 22.0,
#  'Neal Street Productions': 16.5,
#  'Evamere Entertainment': 18.0,
#  'Michaels-Goldwyn': 9.0,
#  'Ecosse Films': 13.25,
#  '2 Entertain': 16.5,
#  'Guy Walks into a Bar Productions': 6.0,
#  'Deep River Productions': 14.0,
#  'Andale Pictures': 10.0,
#  'IDEA Filmproduktions': 11.0,
#  'Starz Media': 12.0,
#  'Odyssey Entertainment': 18.0,
#  'Studiopolis': 12.0,
#  'Vanguard Animation': 12.0,
#  'Art Linson Productions': 12.666666666666666,
#  '3 in the Box': 14.0,
#  'New Wave Entertainment': 21.0,
#  'Management 360': 16.5,
#  'Terra Firma Films': 21.0,
#  'Superfinger Entertainment': 21.0,
#  'GreeneStreet Films': 11.25,
#  'Midnight Picture Show': 23.0,
#  'Paradox Entertainment': 16.75,
#  'First Foot Films': 17.0,
#  'Ixtlan Productions': 2.0,
#  'Emperor Motion Pictures': 8.5,
#  'Global Entertainment Group': 2.0,
#  'Sherazade Film Development': 12.0,
#  'Corduroy Films': 12.0,
#  'Exodus Film Group': 4.0,
#  'Exodus Productions': 4.0,
#  'Intandem Films': 37.0,
#  'Aramid Entertainment Fund': 37.0,
#  'Lipsync Productions': 37.0,
#  'Motel Movies': 5.0,
#  'Scared Productions': 12.0,
#  'Nu Image Entertainment GmbH': 10.5,
#  'Vendome Pictures': 11.5,
#  'Film Rites': 23.0,
#  'Yellow Bird': 31.0,
#  'Virgin Produced': 11.0,
#  'Many Rivers Productions': 9.0,
#  'Boy of the Year': 9.0,
#  'K/O Camera Toys': 7.0,
#  'Lennox House Films': 12.0,
#  'Random Films': 15.0,
#  'Total Entertainment': 41.0,
#  'TSBD Canada Productions': 41.0,
#  'Zohar International': 41.0,
#  'Fox Searchlight': 14.666666666666666,
#  'Bay Films': 16.0,
#  'France 3 CinÃ©ma': 9.5,
#  'La Petite Reine': 10.0,
#  'Studio 37': 10.5,
#  'uFilm': 10.0,
#  'Jouror Productions': 10.5,
#  'Blind Wink': 5.0,
#  'Film 4': 7.0,
#  'Contrafilm': 14.285714285714286,
#  'Hungarian National Film Office': 8.0,
#  'Lazio Film Commission': 8.0,
#  'Nouvelles Ã‰ditions de Films (NEF)': 26.0,
#  'New Legacy': 16.5,
#  'TOKYOPOP': 6.0,
#  'Denver and Delilah Productions': 11.0,
#  'Tailor Made': 9.0,
#  'Mango Farms': 9.0,
#  'Gambit Pictures': 21.0,
#  'Electric Shepherd Productions': 21.0,
#  'Mark Canton Productions': 10.333333333333334,
#  ...}

# %%
max(mean_films_title, key=mean_films_title.get)
# Out:
# 'Four By Two Productions'

# %%
mean_films_title['Four By Two Productions']
# Out:
# 83.0

# %%
cnt['Four By Two Productions']
# Out:
# 83

# %%
movies_number['Four By Two Productions']
# Out:
# 1

# %%
answer_ls.append(5)

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
words_in_title = data3.original_title.str.split(' ').tolist()
words_in_title
# Out:
# [['Jurassic', 'World'],
#  ['Mad', 'Max:', 'Fury', 'Road'],
#  ['Insurgent'],
#  ['Star', 'Wars:', 'The', 'Force', 'Awakens'],
#  ['Furious', '7'],
#  ['The', 'Revenant'],
#  ['Terminator', 'Genisys'],
#  ['The', 'Martian'],
#  ['Minions'],
#  ['Inside', 'Out'],
#  ['Spectre'],
#  ['Jupiter', 'Ascending'],
#  ['Ex', 'Machina'],
#  ['Pixels'],
#  ['Avengers:', 'Age', 'of', 'Ultron'],
#  ['The', 'Hateful', 'Eight'],
#  ['Taken', '3'],
#  ['Ant-Man'],
#  ['Cinderella'],
#  ['The', 'Hunger', 'Games:', 'Mockingjay', '-', 'Part', '2'],
#  ['Tomorrowland'],
#  ['Southpaw'],
#  ['San', 'Andreas'],
#  ['Fifty', 'Shades', 'of', 'Grey'],
#  ['The', 'Big', 'Short'],
#  ['Mission:', 'Impossible', '-', 'Rogue', 'Nation'],
#  ['Ted', '2'],
#  ['Kingsman:', 'The', 'Secret', 'Service'],
#  ['Spotlight'],
#  ['Maze', 'Runner:', 'The', 'Scorch', 'Trials'],
#  ['Chappie'],
#  ['Pitch', 'Perfect', '2'],
#  ['Bridge', 'of', 'Spies'],
#  ['Goosebumps'],
#  ['Room'],
#  ['The', 'Good', 'Dinosaur'],
#  ['Run', 'All', 'Night'],
#  ['Brooklyn'],
#  ['Straight', 'Outta', 'Compton'],
#  ['The', 'Last', 'Witch', 'Hunter'],
#  ['The', 'Man', 'from', 'U.N.C.L.E.'],
#  ['The', 'Age', 'of', 'Adaline'],
#  ['Hardcore', 'Henry'],
#  ['Home'],
#  ['Paper', 'Towns'],
#  ['Carol'],
#  ['The', 'Intern'],
#  ['Everest'],
#  ['Point', 'Break'],
#  ['Burnt'],
#  ['Self/less'],
#  ['Mortdecai'],
#  ['The', 'Danish', 'Girl'],
#  ['Blackhat'],
#  ['Sicario'],
#  ['Fantastic', 'Four'],
#  ['Spy'],
#  ['Focus'],
#  ['Hitman:', 'Agent', '47'],
#  ['In', 'the', 'Heart', 'of', 'the', 'Sea'],
#  ['Creed'],
#  ['Trainwreck'],
#  ['Eye', 'in', 'the', 'Sky'],
#  ['Legend'],
#  ['Pan'],
#  ['The', 'Peanuts', 'Movie'],
#  ['Concussion'],
#  ['The', 'Night', 'Before'],
#  ['The', 'Longest', 'Ride'],
#  ['Hotel', 'Transylvania', '2'],
#  ['Love', 'the', 'Coopers'],
#  ['The', 'Walk'],
#  ['Vacation'],
#  ['Poltergeist'],
#  ['Child', '44'],
#  ['The', 'Gift'],
#  ["Daddy's", 'Home'],
#  ['The', 'Little', 'Prince'],
#  ['The', 'Dressmaker'],
#  ['The', 'DUFF'],
#  ['Sinister', '2'],
#  ['Paul', 'Blart:', 'Mall', 'Cop', '2'],
#  ['Entourage'],
#  ['The', 'Wedding', 'Ringer'],
#  ['The', 'Visit'],
#  ['Black', 'Mass'],
#  ['Krampus'],
#  ['No', 'Escape'],
#  ['Woman', 'in', 'Gold'],
#  ['Sisters'],
#  ['Project', 'Almanac'],
#  ['The', 'Transporter', 'Refueled'],
#  ['Crimson', 'Peak'],
#  ['Magic', 'Mike', 'XXL'],
#  ['Paranormal', 'Activity:', 'The', 'Ghost', 'Dimension'],
#  ['Trumbo'],
#  ['Secret', 'in', 'Their', 'Eyes'],
#  ['The', 'SpongeBob', 'Movie:', 'Sponge', 'Out', 'of', 'Water'],
#  ['Max'],
#  ['The', 'Gunman'],
#  ['Hot', 'Pursuit'],
#  ['Insidious:', 'Chapter', '3'],
#  ['The', 'Lady', 'in', 'the', 'Van'],
#  ['Victor', 'Frankenstein'],
#  ['Ricki', 'and', 'the', 'Flash'],
#  ['The', 'Perfect', 'Guy'],
#  ['While', "We're", 'Young'],
#  ['Get', 'Hard'],
#  ['Suffragette'],
#  ['We', 'Are', 'Your', 'Friends'],
#  ['Little', 'Boy'],
#  ['Aloha'],
#  ['Our', 'Brand', 'Is', 'Crisis'],
#  ['Rock', 'the', 'Kasbah'],
#  ['A', 'Walk', 'in', 'the', 'Woods'],
#  ['Unfinished', 'Business'],
#  ['Black', 'or', 'White'],
#  ['Jem', 'and', 'the', 'Holograms'],
#  ['Interstellar'],
#  ['Guardians', 'of', 'the', 'Galaxy'],
#  ['Captain', 'America:', 'The', 'Winter', 'Soldier'],
#  ['John', 'Wick'],
#  ['The', 'Hunger', 'Games:', 'Mockingjay', '-', 'Part', '1'],
#  ['The', 'Hobbit:', 'The', 'Battle', 'of', 'the', 'Five', 'Armies'],
#  ['Big', 'Hero', '6'],
#  ['The', 'Imitation', 'Game'],
#  ['The', 'Maze', 'Runner'],
#  ['Birdman'],
#  ['Gone', 'Girl'],
#  ['Fury'],
#  ['Night', 'at', 'the', 'Museum:', 'Secret', 'of', 'the', 'Tomb'],
#  ['Divergent'],
#  ['X-Men:', 'Days', 'of', 'Future', 'Past'],
#  ['Lucy'],
#  ['Teenage', 'Mutant', 'Ninja', 'Turtles'],
#  ['Sex', 'Tape'],
#  ['Nightcrawler'],
#  ['Transformers:', 'Age', 'of', 'Extinction'],
#  ['The', 'Grand', 'Budapest', 'Hotel'],
#  ['Dawn', 'of', 'the', 'Planet', 'of', 'the', 'Apes'],
#  ['The', 'Equalizer'],
#  ['Horrible', 'Bosses', '2'],
#  ['The', 'Amazing', 'Spider-Man', '2'],
#  ['Edge', 'of', 'Tomorrow'],
#  ['The', 'Interview'],
#  ['American', 'Sniper'],
#  ['Exodus:', 'Gods', 'and', 'Kings'],
#  ['Godzilla'],
#  ['Maleficent'],
#  ['The', 'November', 'Man'],
#  ['Ouija'],
#  ['How', 'to', 'Train', 'Your', 'Dragon', '2'],
#  ['The', 'Expendables', '3'],
#  ['The', 'Lego', 'Movie'],
#  ['Seventh', 'Son'],
#  ['The', 'Theory', 'of', 'Everything'],
#  ["Let's", 'Be', 'Cops'],
#  ['Dracula', 'Untold'],
#  ['Penguins', 'of', 'Madagascar'],
#  ['Into', 'the', 'Woods'],
#  ['300:', 'Rise', 'of', 'an', 'Empire'],
#  ['The', 'Giver'],
#  ['22', 'Jump', 'Street'],
#  ['A', 'Walk', 'Among', 'the', 'Tombstones'],
#  ['Paddington'],
#  ['Cake'],
#  ['Chef'],
#  ['The', 'Purge:', 'Anarchy'],
#  ['Left', 'Behind'],
#  ['A', 'Most', 'Violent', 'Year'],
#  ['Hercules'],
#  ['Noah'],
#  ['The', 'Judge'],
#  ['Blended'],
#  ['Neighbors'],
#  ['If', 'I', 'Stay'],
#  ['Step', 'Up', 'All', 'In'],
#  ['The', 'Fault', 'in', 'Our', 'Stars'],
#  ['Ride', 'Along'],
#  ['Inherent', 'Vice'],
#  ['Jack', 'Ryan:', 'Shadow', 'Recruit'],
#  ['Non-Stop'],
#  ['Predestination'],
#  ['RoboCop'],
#  ['Transcendence'],
#  ['The', 'Other', 'Woman'],
#  ['Mr.', 'Peabody', '&', 'Sherman'],
#  ['Sin', 'City:', 'A', 'Dame', 'to', 'Kill', 'For'],
#  ['Rio', '2'],
#  ['Dumb', 'and', 'Dumber', 'To'],
#  ['The', 'Monuments', 'Men'],
#  ['Unbroken'],
#  ['Selma'],
#  ['Pompeii'],
#  ['The', 'Best', 'of', 'Me'],
#  ['Annie'],
#  ['St.', 'Vincent'],
#  ['Need', 'for', 'Speed'],
#  ['The', 'Hundred-Foot', 'Journey'],
#  ['The', 'Boxtrolls'],
#  ['Big', 'Eyes'],
#  ['The', 'Prince'],
#  ['Into', 'the', 'Storm'],
#  ['Planes:', 'Fire', '&', 'Rescue'],
#  ['Sabotage'],
#  ['No', 'Good', 'Deed'],
#  ['As', 'Above,', 'So', 'Below'],
#  ['Foxcatcher'],
#  ['Endless', 'Love'],
#  ['The', 'Rover'],
#  ['Suite', 'FranÃ§aise'],
#  ['Annabelle'],
#  ['I,', 'Frankenstein'],
#  ['That', 'Awkward', 'Moment'],
#  ['Brick', 'Mansions'],
#  ['Tammy'],
#  ["Winter's", 'Tale'],
#  ['The', 'Guest'],
#  ['The', 'Water', 'Diviner'],
#  ['Alexander',
#   'and',
#   'the',
#   'Terrible,',
#   'Horrible,',
#   'No',
#   'Good,',
#   'Very',
#   'Bad',
#   'Day'],
#  ['This', 'Is', 'Where', 'I', 'Leave', 'You'],
#  ['About', 'Last', 'Night'],
#  ['Million', 'Dollar', 'Arm'],
#  ['Under', 'the', 'Skin'],
#  ['Veronica', 'Mars'],
#  ['Son', 'of', 'God'],
#  ['When', 'the', 'Game', 'Stands', 'Tall'],
#  ['The', 'Pyramid'],
#  ['Kill', 'the', 'Messenger'],
#  ['Dolphin', 'Tale', '2'],
#  ['Muppets', 'Most', 'Wanted'],
#  ['Heaven', 'is', 'for', 'Real'],
#  ['The', 'Legend', 'of', 'Hercules'],
#  ["Moms'", 'Night', 'Out'],
#  ['Earth', 'to', 'Echo'],
#  ['The', 'Gambler'],
#  ['The', 'Grand', 'Seduction'],
#  ["God's", 'Not', 'Dead'],
#  ["Devil's", 'Due'],
#  ['Avatar'],
#  ['Inglourious', 'Basterds'],
#  ['Underworld:', 'Rise', 'of', 'the', 'Lycans'],
#  ['Harry', 'Potter', 'and', 'the', 'Half-Blood', 'Prince'],
#  ['Up'],
#  ['Star', 'Trek'],
#  ['Terminator', 'Salvation'],
#  ['District', '9'],
#  ['Sherlock', 'Holmes'],
#  ['(500)', 'Days', 'of', 'Summer'],
#  ['The', 'Hangover'],
#  ['Watchmen'],
#  ['2012'],
#  ['9'],
#  ['Angels', '&', 'Demons'],
#  ['The', 'Princess', 'and', 'the', 'Frog'],
#  ['The', 'Blind', 'Side'],
#  ['Zombieland'],
#  ['The', 'Twilight', 'Saga:', 'New', 'Moon'],
#  ["He's", 'Just', 'Not', 'That', 'Into', 'You'],
#  ['G.I.', 'Joe:', 'The', 'Rise', 'of', 'Cobra'],
#  ['The', 'Proposal'],
#  ['The', 'Ugly', 'Truth'],
#  ['Cloudy', 'with', 'a', 'Chance', 'of', 'Meatballs'],
#  ['Fantastic', 'Mr.', 'Fox'],
#  ['Coraline'],
#  ['Night', 'at', 'the', 'Museum:', 'Battle', 'of', 'the', 'Smithsonian'],
#  ['17', 'Again'],
#  ['A', 'Christmas', 'Carol'],
#  ['The', 'Lovely', 'Bones'],
#  ['Paul', 'Blart:', 'Mall', 'Cop'],
#  ['Hachi:', 'A', "Dog's", 'Tale'],
#  ['Law', 'Abiding', 'Citizen'],
#  ['The', 'Box'],
#  ['Crank:', 'High', 'Voltage'],
#  ['Pandorum'],
#  ['Drag', 'Me', 'to', 'Hell'],
#  ['Knowing'],
#  ['Moon'],
#  ['G-Force'],
#  ['The', 'Taking', 'of', 'Pelham', '1', '2', '3'],
#  ['The', 'Invention', 'of', 'Lying'],
#  ['Confessions', 'of', 'a', 'Shopaholic'],
#  ['Gamer'],
#  ['Mr.', 'Nobody'],
#  ['Couples', 'Retreat'],
#  ['Brothers'],
#  ['The', 'Road'],
#  ['Monsters', 'vs', 'Aliens'],
#  ['Julie', '&', 'Julia'],
#  ['Chloe'],
#  ['Public', 'Enemies'],
#  ["Jennifer's", 'Body'],
#  ['Orphan'],
#  ['All', 'About', 'Steve'],
#  ['The', 'Final', 'Destination'],
#  ['Alvin', 'and', 'the', 'Chipmunks:', 'The', 'Squeakquel'],
#  ['Bride', 'Wars'],
#  ['Precious'],
#  ['State', 'of', 'Play'],
#  ['The', 'Unborn'],
#  ['I', 'Love', 'You,', 'Man'],
#  ['The', 'Informant!'],
#  ['Race', 'to', 'Witch', 'Mountain'],
#  ['Case', '39'],
#  ['The', 'Boat', 'That', 'Rocked'],
#  ['Daybreakers'],
#  ['Love', 'Happens'],
#  ['Push'],
#  ["Brooklyn's", 'Finest'],
#  ['Saw', 'VI'],
#  ['The', 'Young', 'Victoria'],
#  ['A', 'Serious', 'Man'],
#  ['A', 'Perfect', 'Getaway'],
#  ['Whiteout'],
#  ['I', 'Love', 'You', 'Phillip', 'Morris'],
#  ['12', 'Rounds'],
#  ['3', 'Idiots'],
#  ['Transformers:', 'Revenge', 'of', 'the', 'Fallen'],
#  ['The', 'Men', 'Who', 'Stare', 'at', 'Goats'],
#  ['Ninja', 'Assassin'],
#  ['Bandslam'],
#  ["It's", 'Complicated'],
#  ['Land', 'of', 'the', 'Lost'],
#  ['Invictus'],
#  ['Planet', '51'],
#  ['Year', 'One'],
#  ['My', 'Bloody', 'Valentine'],
#  ['Old', 'Dogs'],
#  ['Agora'],
#  ['The', 'Boondock', 'Saints', 'II:', 'All', 'Saints', 'Day'],
#  ['The', 'Bad', 'Lieutenant:', 'Port', 'of', 'Call', '-', 'New', 'Orleans'],
#  ['Armored'],
#  ['Cirque', 'du', 'Freak:', 'The', "Vampire's", 'Assistant'],
#  ['An', 'Education'],
#  ['Funny', 'People'],
#  ['Up', 'in', 'the', 'Air'],
#  ['Astro', 'Boy'],
#  ['The', 'International'],
#  ['Fast', '&', 'Furious'],
#  ['Capitalism:', 'A', 'Love', 'Story'],
#  ['Halloween', 'II'],
#  ['Hannah', 'Montana:', 'The', 'Movie'],
#  ['Aliens', 'in', 'the', 'Attic'],
#  ['The', 'Fourth', 'Kind'],
#  ['Solitary', 'Man'],
#  ['Duplicity'],
#  ['Bright', 'Star'],
#  ['Adventureland'],
#  ['Extract'],
#  ['My', 'Life', 'in', 'Ruins'],
#  ['My', "Sister's", 'Keeper'],
#  ['The', 'Soloist'],
#  ['Friday', 'the', '13th'],
#  ['Harry', 'Brown'],
#  ['Surrogates'],
#  ['Street', 'Fighter:', 'The', 'Legend', 'of', 'Chun-Li'],
#  ['Hotel', 'for', 'Dogs'],
#  ['Obsessed'],
#  ['Solomon', 'Kane'],
#  ['X-Men', 'Origins:', 'Wolverine'],
#  ['New', 'in', 'Town'],
#  ['Me', 'and', 'Orson', 'Welles'],
#  ['Shorts'],
#  ['Sorority', 'Row'],
#  ['The', 'Joneses'],
#  ['Post', 'Grad'],
#  ['Crazy', 'Heart'],
#  ['Did', 'You', 'Hear', 'About', 'The', 'Morgans?'],
#  ['The', 'Grudge', '3'],
#  ["Mao's", 'Last', 'Dancer'],
#  ['Inception'],
#  ['Iron', 'Man', '2'],
#  ['Alice', 'in', 'Wonderland'],
#  ['Black', 'Swan'],
#  ['Harry', 'Potter', 'and', 'the', 'Deathly', 'Hallows:', 'Part', '1'],
#  ['Despicable', 'Me'],
#  ['The', 'Expendables'],
#  ['How', 'to', 'Train', 'Your', 'Dragon'],
#  ['Shutter', 'Island'],
#  ['TRON:', 'Legacy'],
#  ['Tangled'],
#  ['Toy', 'Story', '3'],
#  ['Salt'],
#  ['127', 'Hours'],
#  ['Easy', 'A'],
#  ['The',
#   'Chronicles',
#   'of',
#   'Narnia:',
#   'The',
#   'Voyage',
#   'of',
#   'the',
#   'Dawn',
#   'Treader'],
#  ['Kick-Ass'],
#  ['The', 'Tourist'],
#  ['Prince', 'of', 'Persia:', 'The', 'Sands', 'of', 'Time'],
#  ['Robin', 'Hood'],
#  ['True', 'Grit'],
#  ['Clash', 'of', 'the', 'Titans'],
#  ['The', "Sorcerer's", 'Apprentice'],
#  ['The', 'Social', 'Network'],
#  ['Scott', 'Pilgrim', 'vs.', 'the', 'World'],
#  ['Little', 'Fockers'],
#  ['Predators'],
#  ['Percy', 'Jackson', '&', 'the', 'Olympians:', 'The', 'Lightning', 'Thief'],
#  ['Unstoppable'],
#  ['Shrek', 'Forever', 'After'],
#  ['Dear', 'John'],
#  ['The', 'A-Team'],
#  ['RED'],
#  ['Machete'],
#  ['Grown', 'Ups'],
#  ['The', 'Book', 'of', 'Eli'],
#  ['Date', 'Night'],
#  ['The', 'Town'],
#  ['The', 'Twilight', 'Saga:', 'Eclipse'],
#  ['Megamind'],
#  ['The', 'Last', 'Airbender'],
#  ['The', 'Other', 'Guys'],
#  ['Step', 'Up', '3D'],
#  ['The', "King's", 'Speech'],
#  ['Love', '&', 'Other', 'Drugs'],
#  ['The', 'Way', 'Back'],
#  ['Repo', 'Men'],
#  ['Knight', 'and', 'Day'],
#  ['Eat', 'Pray', 'Love'],
#  ['The', 'Bounty', 'Hunter'],
#  ['Leap', 'Year'],
#  ['Green', 'Zone'],
#  ["Gulliver's", 'Travels'],
#  ['The', 'Back-Up', 'Plan'],
#  ['Charlie', 'St.', 'Cloud'],
#  ['The', 'Switch'],
#  ['The', 'Runaways'],
#  ["Valentine's", 'Day'],
#  ["Don't", 'Be', 'Afraid', 'of', 'the', 'Dark'],
#  ['Saw', '3D'],
#  ['The', 'Karate', 'Kid'],
#  ['Due', 'Date'],
#  ['Wild', 'Target'],
#  ['The', 'Ghost', 'Writer'],
#  ['The', 'Next', 'Three', 'Days'],
#  ['A', 'Nightmare', 'on', 'Elm', 'Street'],
#  ['The', 'Fighter'],
#  ['Get', 'Him', 'to', 'the', 'Greek'],
#  ['Jonah', 'Hex'],
#  ['Vampires', 'Suck'],
#  ['Killers'],
#  ['Legion'],
#  ['Sex', 'and', 'the', 'City', '2'],
#  ['You', 'Again'],
#  ['Nanny', 'McPhee', 'and', 'the', 'Big', 'Bang'],
#  ['Hot', 'Tub', 'Time', 'Machine'],
#  ['Let', 'Me', 'In'],
#  ['Legend', 'of', 'the', 'Guardians:', 'The', 'Owls', 'of', "Ga'Hoole"],
#  ['Takers'],
#  ['Burlesque'],
#  ['The', 'Company', 'Men'],
#  ['Going', 'the', 'Distance'],
#  ['Never', 'Let', 'Me', 'Go'],
#  ['Cop', 'Out'],
#  ['Life', 'as', 'We', 'Know', 'It'],
#  ['Centurion'],
#  ['Stone'],
#  ['Diary', 'of', 'a', 'Wimpy', 'Kid'],
#  ['Piranha', '3D'],
#  ['Morning', 'Glory'],
#  ['Conviction'],
#  ['Tooth', 'Fairy'],
#  ['Fair', 'Game'],
#  ['Dinner', 'for', 'Schmucks'],
#  ['Skyline'],
#  ['The', 'Debt'],
#  ['Cats', '&', 'Dogs', '2', ':', 'The', 'Revenge', 'of', 'Kitty', 'Galore'],
#  ['MacGruber'],
#  ['How', 'Do', 'You', 'Know'],
#  ['The', 'Spy', 'Next', 'Door'],
#  ["She's", 'Out', 'of', 'My', 'League'],
#  ['London', 'Boulevard'],
#  ['Hereafter'],
#  ['My', 'Soul', 'to', 'Take'],
#  ['The', 'Conspirator'],
#  ['Death', 'at', 'a', 'Funeral'],
#  ['Marmaduke'],
#  ['Wall', 'Street:', 'Money', 'Never', 'Sleeps'],
#  ['Everything', 'Must', 'Go'],
#  ['The', 'Crazies'],
#  ['Alpha', 'and', 'Omega'],
#  ['Yogi', 'Bear'],
#  ['Country', 'Strong'],
#  ['Tomorrow,', 'When', 'the', 'War', 'Began'],
#  ['Extraordinary', 'Measures'],
#  ['Devil'],
#  ["Barney's", 'Version'],
#  ['Edge', 'of', 'Darkness'],
#  ['Furry', 'Vengeance'],
#  ['Dylan', 'Dog:', 'Dead', 'of', 'Night'],
#  ['The', 'Perfect', 'Game'],
#  ['The', "Warrior's", 'Way'],
#  ['Burke', '&', 'Hare'],
#  ['Why', 'Did', 'I', 'Get', 'Married', 'Too?'],
#  ['Resident', 'Evil:', 'Afterlife'],
#  ['Action', 'Replayy'],
#  ['Secretariat'],
#  ['The',
#   'Lord',
#   'of',
#   'the',
#   'Rings:',
#   'The',
#   'Fellowship',
#   'of',
#   'the',
#   'Ring'],
#  ['Harry', 'Potter', 'and', 'the', "Philosopher's", 'Stone'],
#  ['Mulholland', 'Drive'],
#  ['Monsters,', 'Inc.'],
#  ['A.I.', 'Artificial', 'Intelligence'],
#  ['Shrek'],
#  ['Bridget', "Jones's", 'Diary'],
#  ["Ocean's", 'Eleven'],
#  ['Pearl', 'Harbor'],
#  ['The', 'Mummy', 'Returns'],
#  ['Atlantis:', 'The', 'Lost', 'Empire'],
#  ['Lara', 'Croft:', 'Tomb', 'Raider'],
#  ['A', 'Beautiful', 'Mind'],
#  ['American', 'Pie', '2'],
#  ['The', 'Princess', 'Diaries'],
#  ['Moulin', 'Rouge!'],
#  ['Planet', 'of', 'the', 'Apes'],
#  ['The', 'Royal', 'Tenenbaums'],
#  ['Blow'],
#  ['Enemy', 'at', 'the', 'Gates'],
#  ['Black', 'Hawk', 'Down'],
#  ['Legally', 'Blonde'],
#  ['A', "Knight's", 'Tale'],
#  ['Zoolander'],
#  ['Not', 'Another', 'Teen', 'Movie'],
#  ['Scary', 'Movie', '2'],
#  ['Rush', 'Hour', '2'],
#  ['Training', 'Day'],
#  ['The', 'Others'],
#  ['Jimmy', 'Neutron:', 'Boy', 'Genius'],
#  ['Jay', 'and', 'Silent', 'Bob', 'Strike', 'Back'],
#  ['Serendipity'],
#  ['Cats', '&', 'Dogs'],
#  ['Vanilla', 'Sky'],
#  ['Kiss', 'of', 'the', 'Dragon'],
#  ['Spy', 'Game'],
#  ['Swordfish'],
#  ['Shallow', 'Hal'],
#  ['AntiTrust'],
#  ['Final', 'Fantasy:', 'The', 'Spirits', 'Within'],
#  ['Original', 'Sin'],
#  ['Dr.', 'Dolittle', '2'],
#  ['Behind', 'Enemy', 'Lines'],
#  ['Jeepers', 'Creepers'],
#  ['From', 'Hell'],
#  ['The', 'Last', 'Castle'],
#  ['Along', 'Came', 'a', 'Spider'],
#  ['The', 'Wedding', 'Planner'],
#  ['Rat', 'Race'],
#  ['Gosford', 'Park'],
#  ['Jason', 'X'],
#  ['The', 'Mexican'],
#  ['Joy', 'Ride'],
#  ['I', 'Am', 'Sam'],
#  ['Rock', 'Star'],
#  ['K-PAX'],
#  ["Don't", 'Say', 'a', 'Word'],
#  ['Crocodile', 'Dundee', 'in', 'Los', 'Angeles'],
#  ['Frailty'],
#  ['Angel', 'Eyes'],
#  ['Hearts', 'in', 'Atlantis'],
#  ['The', 'Glass', 'House'],
#  ['15', 'Minutes'],
#  ['Hardball'],
#  ['Evolution'],
#  ['Ali'],
#  ['The', 'Score'],
#  ['Joe', 'Dirt'],
#  ['Exit', 'Wounds'],
#  ['The', 'Tailor', 'of', 'Panama'],
#  ['Sweet', 'November'],
#  ['How', 'High'],
#  ['Tomcats'],
#  ['The', 'Majestic'],
#  ['3000', 'Miles', 'to', 'Graceland'],
#  ['Ghosts', 'of', 'Mars'],
#  ['Saving', 'Silverman'],
#  ['Riding', 'in', 'Cars', 'with', 'Boys'],
#  ['Osmosis', 'Jones'],
#  ['Head', 'Over', 'Heels'],
#  ['The', 'Fast', 'and', 'the', 'Furious'],
#  ['Save', 'the', 'Last', 'Dance'],
#  ['Spy', 'Kids'],
#  ['Bandits'],
#  ['The', 'Animal'],
#  ['Knockaround', 'Guys'],
#  ['Crazy/Beautiful'],
#  ['Driven'],
#  ['Out', 'Cold'],
#  ['American', 'Outlaws'],
#  ['Hannibal'],
#  ['Domestic', 'Disturbance'],
#  ['Summer', 'Catch'],
#  ['Max', "Keeble's", 'Big', 'Move'],
#  ['Monkeybone'],
#  ['Corky', 'Romano'],
#  ['Jurassic', 'Park', 'III'],
#  ['The', 'Musketeer'],
#  ['The', "Cat's", 'Meow'],
#  ['Sugar', '&', 'Spice'],
#  ['Bones'],
#  ['The', 'Wash'],
#  ['Baby', 'Boy'],
#  ['The', 'Dark', 'Knight'],
#  ['WALLÂ·E'],
#  ['Iron', 'Man'],
#  ['Taken'],
#  ['Indiana',
#   'Jones',
#   'and',
#   'the',
#   'Kingdom',
#   'of',
#   'the',
#   'Crystal',
#   'Skull'],
#  ['Twilight'],
#  ['Quantum', 'of', 'Solace'],
#  ['Kung', 'Fu', 'Panda'],
#  ['Mamma', 'Mia!'],
#  ['The', 'Curious', 'Case', 'of', 'Benjamin', 'Button'],
#  ['The', 'Mummy:', 'Tomb', 'of', 'the', 'Dragon', 'Emperor'],
#  ['The', 'Incredible', 'Hulk'],
#  ['Gran', 'Torino'],
#  ['Madagascar:', 'Escape', '2', 'Africa'],
#  ['Hellboy', 'II:', 'The', 'Golden', 'Army'],
#  ['Jumper'],
#  ['Journey', 'to', 'the', 'Center', 'of', 'the', 'Earth'],
#  ['Wanted'],
#  ['Slumdog', 'Millionaire'],
#  ['Transporter', '3'],
#  ['Valkyrie'],
#  ['10,000', 'BC'],
#  ['Hancock'],
#  ['The', 'Hurt', 'Locker'],
#  ['What', 'Happens', 'in', 'Vegas'],
#  ['The', 'Chronicles', 'of', 'Narnia:', 'Prince', 'Caspian'],
#  ['Tropic', 'Thunder'],
#  ['Eagle', 'Eye'],
#  ['The', 'Boy', 'in', 'the', 'Striped', 'Pyjamas'],
#  ['Rambo'],
#  ['Death', 'Race'],
#  ['Step', 'Up', '2:', 'The', 'Streets'],
#  ['The', 'Day', 'the', 'Earth', 'Stood', 'Still'],
#  ['Seven', 'Pounds'],
#  ['Cloverfield'],
#  ['Bolt'],
#  ['Forgetting', 'Sarah', 'Marshall'],
#  ['Australia'],
#  ['Yes', 'Man'],
#  ['Marley', '&', 'Me'],
#  ['Body', 'of', 'Lies'],
#  ['Burn', 'After', 'Reading'],
#  ['27', 'Dresses'],
#  ['Inkheart'],
#  ['21'],
#  ['Step', 'Brothers'],
#  ["Fool's", 'Gold'],
#  ['Never', 'Back', 'Down'],
#  ['Pineapple', 'Express'],
#  ['The', 'Wrestler'],
#  ['Bedtime', 'Stories'],
#  ['Punisher:', 'War', 'Zone'],
#  ['Max', 'Payne'],
#  ['Mirrors'],
#  ['Vantage', 'Point'],
#  ['Zack', 'and', 'Miri', 'Make', 'a', 'Porno'],
#  ['Get', 'Smart'],
#  ['Role', 'Models'],
#  ['Babylon', 'A.D.'],
#  ['In', 'Bruges'],
#  ['Changeling'],
#  ['The', 'Spiderwick', 'Chronicles'],
#  ['Harold', '&', 'Kumar', 'Escape', 'from', 'Guantanamo', 'Bay'],
#  ['Street', 'Kings'],
#  ['Nick', 'and', "Norah's", 'Infinite', 'Playlist'],
#  ['Four', 'Christmases'],
#  ['The', 'House', 'Bunny'],
#  ['Saw', 'V'],
#  ['The', 'Love', 'Guru'],
#  ['Speed', 'Racer'],
#  ['Vicky', 'Cristina', 'Barcelona'],
#  ['Horton', 'Hears', 'a', 'Who!'],
#  ['The', 'Forbidden', 'Kingdom'],
#  ['Righteous', 'Kill'],
#  ['Transsiberian'],
#  ['You', "Don't", 'Mess', 'With', 'the', 'Zohan'],
#  ['Defiance'],
#  ['Untraceable'],
#  ['The', 'Strangers'],
#  ['Milk'],
#  ['Outlander'],
#  ['The', 'X', 'Files:', 'I', 'Want', 'to', 'Believe'],
#  ['Doubt'],
#  ['City', 'of', 'Ember'],
#  ['Made', 'of', 'Honor'],
#  ['Deception'],
#  ['RockNRolla'],
#  ['The', 'Eye'],
#  ['Bangkok', 'Dangerous'],
#  ['Meet', 'the', 'Spartans'],
#  ['The', 'Spirit'],
#  ['The', 'Happening'],
#  ['Doomsday'],
#  ['The', 'Secret', 'of', 'Moonacre'],
#  ['Sex', 'and', 'the', 'City'],
#  ['The', 'Rocker'],
#  ['The', 'Tale', 'of', 'Despereaux'],
#  ['Superhero', 'Movie'],
#  ['The', 'Secret', 'Life', 'of', 'Bees'],
#  ['Beverly', 'Hills', 'Chihuahua'],
#  ['Revolutionary', 'Road'],
#  ['Baby', 'Mama'],
#  ['Brideshead', 'Revisited'],
#  ['The', 'Brothers', 'Bloom'],
#  ['Meet', 'Dave'],
#  ['Quarantine'],
#  ['The', 'Express'],
#  ['Space', 'Chimps'],
#  ['Lakeview', 'Terrace'],
#  ['What', 'Just', 'Happened'],
#  ['Disaster', 'Movie'],
#  ['My', 'Best', "Friend's", 'Girl'],
#  ['The', 'Midnight', 'Meat', 'Train'],
#  ['Mutant', 'Chronicles'],
#  ['Swing', 'Vote'],
#  ['W.'],
#  ['Smart', 'People'],
#  ["Nim's", 'Island'],
#  ['Igor'],
#  ['How', 'to', 'Lose', 'Friends', '&', 'Alienate', 'People'],
#  ['Welcome', 'Home', 'Roscoe', 'Jenkins'],
#  ['Captain', 'America:', 'The', 'First', 'Avenger'],
#  ['Drive'],
#  ['Harry', 'Potter', 'and', 'the', 'Deathly', 'Hallows:', 'Part', '2'],
#  ['Pirates', 'of', 'the', 'Caribbean:', 'On', 'Stranger', 'Tides'],
#  ['Rise', 'of', 'the', 'Planet', 'of', 'the', 'Apes'],
#  ['Thor'],
#  ['In', 'Time'],
#  ['Drive', 'Angry'],
#  ['The', 'Mechanic'],
#  ['Source', 'Code'],
#  ['Mission:', 'Impossible', '-', 'Ghost', 'Protocol'],
#  ['Crazy,', 'Stupid,', 'Love.'],
#  ['The', 'Girl', 'with', 'the', 'Dragon', 'Tattoo'],
#  ['Limitless'],
#  ['Kung', 'Fu', 'Panda', '2'],
#  ['Just', 'Go', 'With', 'It'],
#  ['Horrible', 'Bosses'],
#  ['Real', 'Steel'],
#  ['Friends', 'with', 'Benefits'],
#  ['Bad', 'Teacher'],
#  ['Sherlock', 'Holmes:', 'A', 'Game', 'of', 'Shadows'],
#  ['Cars', '2'],
#  ['Green', 'Lantern'],
#  ['The', 'Hangover', 'Part', 'II'],
#  ['No', 'Strings', 'Attached'],
#  ['The', 'Adventures', 'of', 'Tintin'],
#  ['Bridesmaids'],
#  ['Hall', 'Pass'],
#  ['Super', '8'],
#  ['Sucker', 'Punch'],
#  ['Red', 'Riding', 'Hood'],
#  ['The', 'Twilight', 'Saga:', 'Breaking', 'Dawn', '-', 'Part', '1'],
#  ['The', 'Tree', 'of', 'Life'],
#  ['I', 'Am', 'Number', 'Four'],
#  ['Rio'],
#  ['The', 'Artist'],
#  ['Zookeeper'],
#  ['Cowboys', '&', 'Aliens'],
#  ['War', 'Horse'],
#  ['50/50'],
#  ['Rango'],
#  ['The', 'Change-Up'],
#  ['Hugo'],
#  ['The', 'Lincoln', 'Lawyer'],
#  ['Ghost', 'Rider:', 'Spirit', 'of', 'Vengeance'],
#  ['One', 'Day'],
#  ['Killer', 'Elite'],
#  ['The', 'Rite'],
#  ['Winnie', 'the', 'Pooh'],
#  ['The', 'Three', 'Musketeers'],
#  ['Priest'],
#  ['Young', 'Adult'],
#  ['Abduction'],
#  ['Unknown'],
#  ['The', 'Adjustment', 'Bureau'],
#  ['Immortals'],
#  ['Larry', 'Crowne'],
#  ['Paul'],
#  ['Colombiana'],
#  ['Battle:', 'Los', 'Angeles'],
#  ['Final', 'Destination', '5'],
#  ['Machine', 'Gun', 'Preacher'],
#  ['Jack', 'and', 'Jill'],
#  ["What's", 'Your', 'Number?'],
#  ['Season', 'of', 'the', 'Witch'],
#  ['My', 'Week', 'with', 'Marilyn'],
#  ['We', 'Bought', 'a', 'Zoo'],
#  ['The', 'Darkest', 'Hour'],
#  ['The', 'Help'],
#  ['The', 'Grey'],
#  ['Moneyball'],
#  ['The', 'Roommate'],
#  ['Puss', 'in', 'Boots'],
#  ['The', 'Green', 'Hornet'],
#  ['Something', 'Borrowed'],
#  ['Conan', 'the', 'Barbarian'],
#  ['Johnny', 'English', 'Reborn'],
#  ['Contagion'],
#  ['The', 'Big', 'Year'],
#  ['Beastly'],
#  ['A', 'Very', 'Harold', '&', 'Kumar', 'Christmas'],
#  ['The', 'Thing'],
#  ['Tower', 'Heist'],
#  ['New', "Year's", 'Eve'],
#  ['Your', 'Highness'],
#  ['Apollo', '18'],
#  ['Fright', 'Night'],
#  ['Happy', 'Feet', 'Two'],
#  ['Scream', '4'],
#  ['Mars', 'Needs', 'Moms'],
#  ['Attack', 'the', 'Block'],
#  ['Diary', 'of', 'a', 'Wimpy', 'Kid:', 'Rodrick', 'Rules'],
#  ['Extremely', 'Loud', '&', 'Incredibly', 'Close'],
#  ['Alvin', 'and', 'the', 'Chipmunks:', 'Chipwrecked'],
#  ['Straw', 'Dogs'],
#  ['The', 'Best', 'Exotic', 'Marigold', 'Hotel'],
#  ['The', 'Smurfs'],
#  ['Hanna'],
#  ['Gnomeo', '&', 'Juliet'],
#  ['The', 'Descendants'],
#  ['Hop'],
#  ['The', 'Rum', 'Diary'],
#  ['The', 'Guard'],
#  ['Our', 'Idiot', 'Brother'],
#  ['Footloose'],
#  ['Trespass'],
#  ['Carnage'],
#  ['The', 'Ides', 'of', 'March'],
#  ['Transformers:', 'Dark', 'of', 'the', 'Moon'],
#  ['Paranormal', 'Activity', '3'],
#  ['The', 'Dilemma'],
#  ['Take', 'Me', 'Home', 'Tonight'],
#  ['The', 'Muppets'],
#  ['Seeking', 'Justice'],
#  ['Arthur'],
#  ['The', 'Eagle'],
#  ['The', 'Sitter'],
#  ['J.', 'Edgar'],
#  ['Sanctum'],
#  ['I', "Don't", 'Know', 'How', 'She', 'Does', 'It'],
#  ['A', 'Dangerous', 'Method'],
#  ['Soul', 'Surfer'],
#  ['30', 'Minutes', 'or', 'Less'],
#  ['Hoodwinked', 'Too!', 'Hood', 'VS.', 'Evil'],
#  ['Water', 'for', 'Elephants'],
#  ['Dream', 'House'],
#  ['Prom'],
#  ['Killer', 'Joe'],
#  ['Big', 'Mommas:', 'Like', 'Father,', 'Like', 'Son'],
#  ['Dolphin', 'Tale'],
#  ['Xin', 'shao', 'lin', 'si'],
#  ['Fast', 'Five'],
#  ['Jumping', 'the', 'Broom'],
#  ['Monte', 'Carlo'],
#  ['The', 'Iron', 'Lady'],
#  ['The', "Devil's", 'Double'],
#  ['Shark', 'Night'],
#  ['Atlas', 'Shrugged', 'Part', 'I'],
#  ['This', 'Must', 'Be', 'the', 'Place'],
#  ['Albert', 'Nobbs'],
#  ['Justin', 'Bieber:', 'Never', 'Say', 'Never'],
#  ['Jeff,', 'Who', 'Lives', 'at', 'Home'],
#  ['X-Men:', 'First', 'Class'],
#  ['The', 'Lord', 'of', 'the', 'Rings:', 'The', 'Two', 'Towers'],
#  ['Harry', 'Potter', 'and', 'the', 'Chamber', 'of', 'Secrets'],
#  ['Ice', 'Age'],
#  ['The', 'Bourne', 'Identity'],
#  ['Resident', 'Evil'],
#  ['Spider-Man'],
#  ['Star', 'Wars:', 'Episode', 'II', '-', 'Attack', 'of', 'the', 'Clones'],
#  ['Catch', 'Me', 'If', 'You', 'Can'],
#  ['Men', 'in', 'Black', 'II'],
#  ['The', 'Pianist'],
#  ['Minority', 'Report'],
#  ['Lilo', '&', 'Stitch'],
#  ['The', 'Transporter'],
#  ['xXx'],
#  ['Treasure', 'Planet'],
#  ['Die', 'Another', 'Day'],
#  ['28', 'Days', 'Later...'],
#  ['Maid', 'in', 'Manhattan'],
#  ['Blade', 'II'],
#  ['Gangs', 'of', 'New', 'York'],
#  ['Panic', 'Room'],
#  ['Stuart', 'Little', '2'],
#  ['National', 'Lampoonâ€™s', 'Van', 'Wilder'],
#  ['8', 'Mile'],
#  ['Mr.', 'Deeds'],
#  ['Two', 'Weeks', 'Notice'],
#  ['Signs'],
#  ['The', 'Ring'],
#  ['A', 'Walk', 'to', 'Remember'],
#  ['My', 'Big', 'Fat', 'Greek', 'Wedding'],
#  ['About', 'a', 'Boy'],
#  ['Collateral', 'Damage'],
#  ['Phone', 'Booth'],
#  ['Star', 'Trek:', 'Nemesis'],
#  ['Equilibrium'],
#  ['The', 'Good', 'Girl'],
#  ['The', 'Hours'],
#  ['Road', 'to', 'Perdition'],
#  ['Austin', 'Powers', 'in', 'Goldmember'],
#  ['The', 'Santa', 'Clause', '2'],
#  ['Insomnia'],
#  ['Ghost', 'Ship'],
#  ['Scooby-Doo'],
#  ['Spirit:', 'Stallion', 'of', 'the', 'Cimarron'],
#  ['D-Tox'],
#  ['The', 'Scorpion', 'King'],
#  ['I', 'Spy'],
#  ['We', 'Were', 'Soldiers'],
#  ['Jackass:', 'The', 'Movie'],
#  ['Frida'],
#  ['Murder', 'by', 'Numbers'],
#  ['Adaptation.'],
#  ['Sweet', 'Home', 'Alabama'],
#  ['Barbershop'],
#  ['Dark', 'Blue'],
#  ['The', 'Time', 'Machine'],
#  ['Undisputed'],
#  ['The', 'Sweetest', 'Thing'],
#  ['Windtalkers'],
#  ['John', 'Q'],
#  ['Unfaithful'],
#  ['Changing', 'Lanes'],
#  ['K-19:', 'The', 'Widowmaker'],
#  ['Queen', 'of', 'the', 'Damned'],
#  ['Spy', 'Kids', '2:', 'Island', 'of', 'Lost', 'Dreams'],
#  ['Enough'],
#  ['Friday', 'After', 'Next'],
#  ['Return', 'to', 'Never', 'Land'],
#  ['Slackers'],
#  ['Chicago'],
#  ['One', 'Hour', 'Photo'],
#  ['Femme', 'Fatale'],
#  ['City', 'By', 'The', 'Sea'],
#  ['Reign', 'of', 'Fire'],
#  ['Showtime'],
#  ['High', 'Crimes'],
#  ["Hart's", 'War'],
#  ['About', 'Schmidt'],
#  ['Blue', 'Crush'],
#  ['Blood', 'Work'],
#  ['Solaris'],
#  ['The', 'Four', 'Feathers'],
#  ['The', 'Mothman', 'Prophecies'],
#  ['Far', 'from', 'Heaven'],
#  ['The', 'Rookie'],
#  ['Bad', 'Company'],
#  ['Confessions', 'of', 'a', 'Dangerous', 'Mind'],
#  ['Trapped'],
#  ['Clockstoppers'],
#  ['Halloween:', 'Resurrection'],
#  ['Big', 'Fat', 'Liar'],
#  ['Antwone', 'Fisher'],
#  ['Igby', 'Goes', 'Down'],
#  ['Boat', 'Trip'],
#  ['Crossroads'],
#  ['The', 'Adventures', 'of', 'Pluto', 'Nash'],
#  ['Abandon'],
#  ['Red', 'Dragon'],
#  ['Serving', 'Sara'],
#  ['Dragonfly'],
#  ['Drumline'],
#  ['All', 'About', 'the', 'Benjamins'],
#  ['FearDotCom'],
#  ['Auto', 'Focus'],
#  ['Possession'],
#  ['Big', 'Trouble'],
#  ['Undercover', 'Brother'],
#  ['The', 'Avengers'],
#  ['Underworld:', 'Awakening'],
#  ['The', 'Dark', 'Knight', 'Rises'],
#  ['Django', 'Unchained'],
#  ['Skyfall'],
#  ['The', 'Bourne', 'Legacy'],
#  ['The', 'Hobbit:', 'An', 'Unexpected', 'Journey'],
#  ['Prometheus'],
#  ['Silver', 'Linings', 'Playbook'],
#  ['The', 'Amazing', 'Spider-Man'],
#  ['Brave'],
#  ['Snow', 'White', 'and', 'the', 'Huntsman'],
#  ['21', 'Jump', 'Street'],
#  ['Life', 'of', 'Pi'],
#  ['Ice', 'Age:', 'Continental', 'Drift'],
#  ['Ted'],
#  ['Jack', 'Reacher'],
#  ['Lo', 'imposible'],
#  ['Wreck-It', 'Ralph'],
#  ['Pitch', 'Perfect'],
#  ['Men', 'in', 'Black', '3'],
#  ['The', 'Hunger', 'Games'],
#  ['Total', 'Recall'],
#  ['Cloud', 'Atlas'],
#  ['The', 'Expendables', '2'],
#  ['Taken', '2'],
#  ['Dark', 'Shadows'],
#  ['The', 'Perks', 'of', 'Being', 'a', 'Wallflower'],
#  ['Argo'],
#  ...]

# %%
number_of_words = []
for item in words_in_title:
    number_of_words.append(len(item))
len(number_of_words)
# Out:
# 1890

# %%
data5 = data4
data5['number_of_words'] = number_of_words
data5.head(1)
# Out:
#      imdb_id  popularity     budget     revenue  original_title  \
# 0  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast         director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
#
#              tagline                                           overview  \
# 0  The park is open.  Twenty-two years after the events of Jurassic ...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
#
#    vote_average  release_year      profit month  title_lenght  number_of_words
# 0           6.5          2015  1363528810     6            14                2

# %%
cnt = Counter()
movies_number = Counter()
for i in range (0, len(data5)):
    for company in data5.iloc[i].production_companies.split('|'):
        cnt [company] += data5.iloc[i].number_of_words
        movies_number[company] += 1
mean_words_in_title = {}
for item in movies_number:
    mean_words_in_title [item] = cnt [item] / movies_number [item]
#max(mean_films_title, key=mean_films_title.get)
mean_words_in_title
# Out:
# {'Universal Studios': 2.6666666666666665,
#  'Amblin Entertainment': 3.0434782608695654,
#  'Legendary Pictures': 2.4705882352941178,
#  'Fuji Television Network': 1.6666666666666667,
#  'Dentsu': 2.25,
#  'Village Roadshow Pictures': 2.6825396825396823,
#  'Kennedy Miller Productions': 3.0,
#  'Summit Entertainment': 2.926829268292683,
#  'Mandeville Films': 2.0,
#  'Red Wagon Entertainment': 1.3333333333333333,
#  'NeoReel': 2.6666666666666665,
#  'Lucasfilm': 8.0,
#  'Truenorth Productions': 5.0,
#  'Bad Robot': 3.111111111111111,
#  'Universal Pictures': 2.61271676300578,
#  'Original Film': 2.586206896551724,
#  'Media Rights Capital': 1.7857142857142858,
#  'One Race Films': 3.0,
#  'Regency Enterprises': 2.510204081632653,
#  'Appian Way': 2.888888888888889,
#  'CatchPlay': 2.0,
#  'Anonymous Content': 2.5454545454545454,
#  'New Regency Pictures': 2.3214285714285716,
#  'Paramount Pictures': 2.8688524590163933,
#  'Skydance Productions': 3.111111111111111,
#  'Twentieth Century Fox Film Corporation': 3.0091743119266057,
#  'Scott Free Productions': 2.7083333333333335,
#  'Mid Atlantic Films': 3.4,
#  'International Traders': 2.0,
#  'TSG Entertainment': 3.533333333333333,
#  'Illumination Entertainment': 1.8,
#  'Walt Disney Pictures': 2.951219512195122,
#  'Pixar Animation Studios': 1.7692307692307692,
#  'Walt Disney Studios Motion Pictures': 4.0,
#  'Columbia Pictures': 2.735042735042735,
#  'Danjaq': 1.0,
#  'B24': 1.0,
#  'Dune Entertainment': 3.090909090909091,
#  'Anarchos Productions': 2.2,
#  'Warner Bros.': 2.767857142857143,
#  'DNA Films': 2.8,
#  'Universal Pictures International (UPI)': 2.0,
#  'Film4': 2.6153846153846154,
#  'Happy Madison Productions': 2.8260869565217392,
#  'Marvel Studios': 3.0833333333333335,
#  'Prime Focus': 3.0,
#  'Revolution Sun Studios': 3.75,
#  'Double Feature Films': 2.4,
#  'The Weinstein Company': 2.4285714285714284,
#  'FilmColony': 3.0,
#  'M6 Films': 1.75,
#  'Canal+': 1.7727272727272727,
#  'EuropaCorp': 2.235294117647059,
#  'CinÃ©+': 1.5,
#  'Genre Films': 1.6666666666666667,
#  'Beagle Pug Films': 1.0,
#  'Allison Shearmur Productions': 1.0,
#  'Studio Babelsberg': 3.15,
#  'StudioCanal': 2.260869565217391,
#  'Lionsgate': 2.742857142857143,
#  'Color Force': 4.875,
#  'Babieka': 2.5,
#  'A113': 1.0,
#  'Escape Artists': 2.6923076923076925,
#  'Riche-Ludwig Productions': 1.0,
#  'New Line Cinema': 3.2613636363636362,
#  'Flynn Picture Company': 1.5,
#  'Focus Features': 2.3333333333333335,
#  'Trigger Street Productions': 2.5,
#  'Michael De Luca Productions': 2.0,
#  'Plan B Entertainment': 3.5,
#  'China Movie Channel': 5.0,
#  'TC Productions': 4.0,
#  'Fuzzy Door Productions': 1.5,
#  'Marv Films': 2.2,
#  'Cloudy Productions': 4.0,
#  'Participant Media': 2.3333333333333335,
#  'Open Road Films': 1.5,
#  'Rocklin / Faust': 1.0,
#  'Entertainment One Features': 1.0,
#  'Gotham Group': 3.0,
#  'Temple Hill Entertainment': 4.25,
#  'Sony Pictures Entertainment (SPE)': 2.25,
#  'Alpha Core': 1.0,
#  'Gold Circle Films': 3.3333333333333335,
#  'Brownstone Productions': 2.5,
#  'DreamWorks SKG': 2.5806451612903225,
#  'Fox 2000 Pictures': 3.4857142857142858,
#  'Marc Platt Productions': 2.8,
#  'Scholastic Entertainment': 1.0,
#  'Element Pictures': 1.5,
#  'No Trace Camping': 1.5,
#  'A24': 2.3333333333333335,
#  'Duperele Films': 1.0,
#  'Buena Vista': 2.6666666666666665,
#  'Vertigo Entertainment': 2.1875,
#  'Energy Entertainment': 3.5,
#  'RatPac-Dune Entertainment': 1.875,
#  'Wildgaze Films': 1.5,
#  'Irish Film Board': 1.3333333333333333,
#  'Item 7': 1.0,
#  'Parallel Film Productions': 1.0,
#  'Cube Vision': 3.0,
#  'Broken Chair Flickz': 3.0,
#  'Atmosphere Entertainment MM': 2.857142857142857,
#  'Goldmann Pictures': 3.6666666666666665,
#  'Davis Entertainment': 2.388888888888889,
#  'Wigram Productions': 4.0,
#  'Lakeshore Entertainment': 2.5833333333333335,
#  'Sidney Kimmel Entertainment': 3.0,
#  'Sierra/Affinity': 4.0,
#  'Bazelevs Production': 2.4,
#  'Versus Pictures': 2.0,
#  'DreamWorks Animation': 3.0,
#  'Killer Films': 2.0,
#  'Number 9 Films': 1.0,
#  'Waverly Films': 2.25,
#  'Working Title Films': 2.7037037037037037,
#  'Walden Media': 4.25,
#  'Cross Creek Pictures': 2.2857142857142856,
#  'Free State Pictures': 1.5,
#  'Alcon Entertainment': 2.8666666666666667,
#  'DMG Entertainment': 1.3333333333333333,
#  'Ehman Productions': 2.0,
#  'PeaPie Films': 1.0,
#  '3 Arts Entertainment': 2.6,
#  'Endgame Entertainment': 2.0,
#  'Ram Bergman Productions': 1.3333333333333333,
#  'Mad Chance': 2.6,
#  'OddLot Entertainment': 1.0,
#  'Huayi Brothers Media': 1.0,
#  'Pretty Pictures': 3.0,
#  'ArtÃ©mis Productions': 3.0,
#  'Le Tax Shelter du Gouvernement FÃ©dÃ©ral de Belgique': 3.0,
#  'Taxshelter. be': 3.0,
#  'Forward Pass': 1.6666666666666667,
#  'Thunder Road Pictures': 2.375,
#  'Black Label Media': 1.0,
#  'Marvel Entertainment': 3.0,
#  'Constantin Film.': 2.0,
#  'Moving Picture Company (MPC)': 3.727272727272727,
#  'Chernin Entertainment': 2.7142857142857144,
#  'Feigco Entertainment': 2.0,
#  'Kramer & Sigman Films': 1.0,
#  'Zaftig Films': 1.0,
#  'Fox International Productions': 2.5,
#  'Infinite Frameworks Studios': 3.0,
#  'Imagine Entertainment': 2.92,
#  'Spring Creek Productions': 3.5,
#  'Roth Films': 3.5714285714285716,
#  'K. JAM Media': 6.0,
#  'Metro-Goldwyn-Mayer (MGM)': 2.75,
#  'Chartoff-Winkler Productions': 1.5,
#  'Apatow Productions': 3.1052631578947367,
#  'Entertainment One': 3.0,
#  'Moonlighting Films': 2.5,
#  'Raindog Films': 4.0,
#  'Anton Capital Entertainment (ACE)': 1.0,
#  'Berlanti Productions': 1.0,
#  'Blue Sky Studios': 2.4444444444444446,
#  'Twentieth Century Fox Animation': 2.5,
#  'LStar Capital': 2.1666666666666665,
#  'The Cantillon Company': 1.0,
#  'The Shuman Company': 1.0,
#  'Sony Pictures': 2.2,
#  'Point Grey Pictures': 2.6666666666666665,
#  'Good Universe': 1.8,
#  'Sony Pictures Animation': 3.2222222222222223,
#  'Groundswell Productions': 2.0,
#  'CBS Films': 2.4,
#  'TriStar Pictures': 2.2941176470588234,
#  'Sony Pictures Entertainment': 2.5,
#  'ImageMovers': 2.142857142857143,
#  'BenderSpink': 2.25,
#  'David Dobkin Productions': 1.5,
#  'Ghost House Pictures': 2.4444444444444446,
#  'Worldview Entertainment': 1.6666666666666667,
#  'Blumhouse Productions': 2.8181818181818183,
#  'Blue-Tongue Films': 2.0,
#  'STX Entertainment': 2.0,
#  'Ahimsa Films': 2.0,
#  'Gary Sanchez Productions': 2.857142857142857,
#  'Red Granite Pictures': 3.75,
#  'Onyx Films': 2.5,
#  'Orange Studios': 3.0,
#  'CityMation': 3.0,
#  'On Entertainment': 3.0,
#  'Zippcast Films': 3.0,
#  'Amazon Studios': 2.0,
#  'Film Art Media': 2.0,
#  'Apollo Media': 2.0,
#  'Wonderland Sound and Vision': 2.6,
#  'Vast Entertainment': 2.0,
#  'Alliance Films': 2.5,
#  'IM Global': 2.2857142857142856,
#  'Automatik Entertainment': 2.3333333333333335,
#  'Sony Pictures Releasing': 4.0,
#  'Sony Pictures Home Entertainment': 3.5,
#  'Closest to the Hole Productions': 1.5,
#  'Miramax Films': 2.7435897435897436,
#  'Screen Gems': 2.5483870967741935,
#  'Blinding Edge Pictures': 2.125,
#  'Infinitum Nihil': 2.2,
#  'Head Gear Films': 2.0,
#  'Bold Films': 1.25,
#  'Living Films': 3.0,
#  'Brothers Dowdle Productions': 2.0,
#  'BBC Films': 3.0625,
#  'Origin Pictures': 4.0,
#  'Little Stranger': 1.0,
#  'MTV Films': 3.0833333333333335,
#  'Platinum Dunes': 3.0,
#  'Insurge Pictures': 4.0,
#  'Iron Horse Entertainment (II)': 3.0,
#  'Inimitable Pictures': 1.0,
#  'ShivHans Pictures': 1.0,
#  'Ingenious Media': 3.8181818181818183,
#  'Gran Via Productions': 3.2,
#  'Route One Films': 4.5,
#  'Nickelodeon Movies': 3.357142857142857,
#  'Nickelodeon Animation Studios': 7.0,
#  'United Plankton Pictures': 7.0,
#  'Disruption Entertainment': 3.0,
#  'Sunswept Entertainment': 4.7,
#  'Silver Pictures': 2.6470588235294117,
#  'TF1 Films Production': 1.4545454545454546,
#  'Instituto de la CinematografÃ\xada y de las Artes Audiovisuales (ICAA)': 2.0,
#  'Pacific Standard': 2.0,
#  'TriStar Productions': 5.0,
#  'Columbia TriStar': 3.0,
#  'Clinica Estetico': 2.6666666666666665,
#  'Scott Rudin Productions': 3.0833333333333335,
#  'Ruby Films': 2.0,
#  'PathÃ©': 1.5,
#  'Metanoia Films': 2.0,
#  'Vinyl Films': 2.0,
#  'RatPac Entertainment': 2.3333333333333335,
#  'Smokehouse Pictures': 3.0,
#  'Shangri-La Entertainment': 2.5,
#  'QED International': 1.8333333333333333,
#  'Dune Films': 2.5,
#  'Venture Forth': 3.0,
#  'Wildwood Enterprises': 3.75,
#  'Treehouse Pictures': 2.5,
#  'Hasbro Studios': 4.0,
#  'Allspark Pictures': 4.0,
#  'Syncopy': 2.125,
#  'Lynda Obst Productions': 2.5,
#  'Bulletproof Cupid': 4.0,
#  '87Eleven': 1.5,
#  'DefyNite Films': 2.0,
#  'MJW Films': 2.0,
#  'WingNut Films': 5.8,
#  '3Foot7': 8.0,
#  'Walt Disney Animation Studios': 2.3,
#  'Black Bear Pictures': 3.0,
#  'Bristol Automotive': 3.0,
#  'Dayday Films': 3.0,
#  'Le Grisbi Productions': 1.0,
#  'M Productions': 1.0,
#  'Crave Films': 1.6666666666666667,
#  '1492 Pictures': 5.0,
#  '21 Laps Entertainment': 5.111111111111111,
#  "Donners' Company": 2.111111111111111,
#  'Bad Hat Harry Productions': 2.0,
#  'Sierra / Affinity': 1.0,
#  'Di Bonaventura Pictures': 2.5,
#  'Hasbro': 3.4,
#  'Fox Searchlight Pictures': 2.9583333333333335,
#  'Indian Paintbrush': 3.2,
#  'Mace Neufeld Productions': 2.0,
#  'Marvel Enterprises': 1.6923076923076923,
#  'Avi Arad Productions': 4.0,
#  'Matt Tolmach Productions': 4.0,
#  'Viz Media': 3.0,
#  'Province of British Columbia Production Services Tax Credit': 2.5,
#  'Malpaso Productions': 2.1666666666666665,
#  'Mad Chance Productions': 2.0,
#  'Volcano Films': 4.0,
#  'Toho Company': 1.0,
#  'Irish Dreamtime': 3.0,
#  'Relativity Media': 2.484848484848485,
#  'SPD Films': 3.0,
#  'Mad Hatter Entertainment': 5.5,
#  'Davis-Films': 2.9,
#  'Nu Image Films': 2.8181818181818183,
#  'LionsGate': 2.5,
#  'Millennium Films': 2.5294117647058822,
#  'Ex3 Productions': 3.0,
#  'DC Comics': 2.2222222222222223,
#  'Lin Pictures': 3.4,
#  'Warner Bros. Animation': 3.0,
#  'Outlaw Sinema': 2.0,
#  'Pendle Mountain Productions': 2.0,
#  'WideAwake': 2.5,
#  'Lucamar Productions': 3.0,
#  'Hollywood Gang Productions': 3.0,
#  'Nimar Studios': 2.5,
#  'Tonik Productions': 2.0,
#  'Asis Productions': 2.0,
#  'Cannell Studios': 3.0,
#  'Jersey Films': 2.6666666666666665,
#  '1984 Private Defense Contractors': 3.0,
#  'Exclusive Media Group': 2.6666666666666665,
#  'Heyday Films': 5.666666666666667,
#  'Echo Films': 1.5,
#  "We're Not Brothers Productions": 1.0,
#  'Cinelou Films': 1.0,
#  'Aldamisa Entertainment': 3.3333333333333335,
#  'Kilburn Media': 1.0,
#  'Fetisov Teterin Films': 1.0,
#  'Why Not Productions': 3.5,
#  '5150 Action': 3.0,
#  'Stoney Lake Entertainment': 2.0,
#  'Imagenation Abu Dhabi FZ': 2.8333333333333335,
#  'FilmNation Entertainment': 2.6,
#  'Before the Door Pictures': 3.5,
#  'Washington Square Films': 3.5,
#  'Radical Studios': 1.0,
#  'Protozoa Pictures': 1.75,
#  'Big Kid Pictures': 2.6666666666666665,
#  'Team Downey': 2.0,
#  'Karz Entertainment': 2.4,
#  'Gulfstream Pictures': 1.0,
#  'Offspring Entertainment': 2.8333333333333335,
#  'Rainforest Films': 2.6,
#  'Ghoulardi Film Company': 2.6666666666666665,
#  'Etalon film': 4.0,
#  'Screen Australia': 1.6666666666666667,
#  'Screen Queensland': 1.0,
#  'Blacklab Entertainment': 1.0,
#  'Wolfhound Pictures': 1.0,
#  'Strike Entertainment': 2.4,
#  'Straight Up Films': 1.0,
#  'LBI Productions': 3.0,
#  '20th Century Fox': 2.823529411764706,
#  'Troublemaker Studios': 2.857142857142857,
#  'AR Films': 4.5,
#  'Demarest Films': 4.5,
#  'Conundrum Entertainment': 3.0,
#  'Obelisk Productions': 3.0,
#  'Jolie Pas': 1.0,
#  'Harpo Films': 2.3333333333333335,
#  'Celador Films': 1.3333333333333333,
#  'Cloud Eight Films': 1.3333333333333333,
#  'Impact Pictures': 2.4444444444444446,
#  'Don Carmody Productions': 2.25,
#  'FilmDistrict': 2.142857142857143,
#  'Constantin Film International': 1.0,
#  'Overbrook Entertainment': 1.9,
#  'Crescendo Productions': 2.0,
#  'Goldenlight Films': 2.0,
#  'Reliance Entertainment': 2.375,
#  'Bandito Brothers': 3.0,
#  'Touchstone Pictures': 2.4827586206896552,
#  'Electronic Arts': 3.0,
#  'Laika Entertainment': 1.5,
#  'Silverwood Films': 2.0,
#  'Electric City Entertainment': 3.5,
#  'Tim Burton Productions': 3.090909090909091,
#  'Grindstone Entertainment Group': 2.5,
#  'Emmett/Furla Films': 2.111111111111111,
#  'Oasis Films': 2.0,
#  'Aperture Entertainment': 2.0,
#  'Broken Road Productions': 2.2,
#  'DisneyToon Studios': 4.0,
#  'Prana Studios': 3.0,
#  'Prana Animation Studios': 4.5,
#  'Albert S. Ruddy Productions': 2.0,
#  'Likely Story': 1.5,
#  'Annapurna Pictures': 1.8571428571428572,
#  'Fake Empire': 2.0,
#  'Bluegrass Films': 2.0,
#  'Porchlight Films': 2.0,
#  'Screen NSW': 2.0,
#  'Qwerty Films': 2.0,
#  'TF1 Droits Audiovisuels': 2.0,
#  'Scope Pictures': 1.5,
#  'The Safran Company': 2.0,
#  'Evergreen Media Group': 1.5,
#  'Hopscotch Films': 2.0,
#  'D8': 2.0,
#  'Weed Road Pictures': 2.2857142857142856,
#  'HanWay Films': 2.0,
#  'Snoot Entertainment': 2.0,
#  'Hopscotch Features': 3.0,
#  'Seven West Media': 3.0,
#  'Fear of God Films': 3.0,
#  'Seven Group Holdings': 3.0,
#  'Jim Henson Company, The': 10.0,
#  'Screen Gems, Inc.': 2.5,
#  'Olive Bridge Entertainment': 2.6666666666666665,
#  'Scottish Screen': 4.0,
#  'UK Film Council': 3.0588235294117645,
#  'Nick Wechsler Productions': 2.1666666666666665,
#  'Creative Scotland': 3.0,
#  'Warner Bros. Interactive Entertainment': 2.0,
#  'Rob Thomas Productions': 2.0,
#  'Hearst Entertainment Productions': 3.0,
#  'LightWorkers Media': 3.0,
#  'Mandalay Pictures': 3.0,
#  'Affirm Films': 3.3333333333333335,
#  'Sahara Productions': 2.0,
#  'Silvatar Media': 2.0,
#  'The Combine': 3.0,
#  'Boxing Cat Films': 3.0,
#  'Disney': 3.0,
#  'Provident Films': 3.0,
#  'Pure Flix Entertainment': 3.0,
#  'FourBoys Entertainment': 3.0,
#  'Panay Films': 3.0,
#  'Winkler Films': 1.5,
#  'Max Films Productions': 3.0,
#  'Morag Loves Company': 3.0,
#  'Ingenious Film Partners': 2.8421052631578947,
#  'Lightstorm Entertainment': 1.0,
#  'A Band Apart': 3.3333333333333335,
#  'Zehnte Babelsberg': 2.0,
#  'Visiona Romantica': 2.0,
#  'Sketch Films': 3.5,
#  'UW3 Film Productions': 5.0,
#  'Spyglass Entertainment': 2.4375,
#  'MavroCine Pictures GmbH & Co. KG': 2.0,
#  'The Halcyon Company': 2.0,
#  'Key Creatives': 2.5,
#  'Block / Hanson': 2.0,
#  'Canadian Film or Video Production Tax Credit (CPTC)': 1.5,
#  'Internationale Filmproduktion Blackbird Dritte': 2.3333333333333335,
#  'Watermark': 4.0,
#  'Dune Entertainment III': 2.8823529411764706,
#  'Green Hat Films': 2.8,
#  'IFP Westcoast Erste': 2.0,
#  'Lawrence Gordon Productions': 3.3333333333333335,
#  'Centropolis Entertainment': 2.5,
#  'The Mark Gordon Company': 1.75,
#  'Farewell Productions': 1.0,
#  'Focus Films': 1.75,
#  'Starz Animation': 2.0,
#  'Arc Productions': 1.5,
#  'Panorama Films': 3.0,
#  'Skylark Productions': 3.5,
#  'Left Tackle Pictures': 3.0,
#  'Zucker/Netter Productions': 3.0,
#  'Maverick Films': 3.8,
#  'Imprint Entertainment': 3.3333333333333335,
#  'Flower Films (II)': 3.6,
#  'Internationale Filmproduktion Blackswan': 6.0,
#  'Kontsept Film Company': 6.0,
#  'Kurtzman/Orci': 3.0,
#  'American Empirical Pictures': 2.5,
#  'Museum Canada Productions': 8.0,
#  'Walt Disney': 5.2,
#  'Goldcrest Pictures': 2.0,
#  'Grand Army Entertainment': 4.0,
#  'Scion Films': 2.8181818181818183,
#  'Inferno Distribution': 3.0,
#  'Stage 6 Films': 3.6,
#  'Hachiko': 4.0,
#  'Film Department, The': 3.0,
#  'Evil Twins': 3.0,
#  'Warp Films': 3.0,
#  'Darko Entertainment': 2.0,
#  'Radar Pictures': 2.7777777777777777,
#  'Radical Media': 2.0,
#  'Constantin Film Produktion': 2.9,
#  'Mandate Pictures': 3.111111111111111,
#  'Buckaroo Entertainment': 2.0,
#  'Curse Productions': 4.0,
#  'Mystery Clock Cinema': 1.0,
#  'Kaplan/Perrone Entertainment': 2.5,
#  'Liberty Films UK': 1.0,
#  'Lunar Industries': 1.0,
#  'Xingu Films': 1.0,
#  'Limelight Fund': 1.0,
#  'Jerry Bruckheimer Films': 4.0,
#  'Whamaphram Productions': 1.0,
#  'Wintergreen Productions': 2.6,
#  'Pan EuropÃ©enne Production': 2.0,
#  'Virtual Films': 1.5,
#  'Wild West Picture Show Productions': 2.0,
#  'Stuber Productions': 2.2857142857142856,
#  'Sighvatsson Films': 1.0,
#  'Palomar Pictures (II)': 2.0,
#  '2929 Productions': 2.6666666666666665,
#  'Dimension Films': 2.5675675675675675,
#  'Chockstone Pictures': 2.3333333333333335,
#  'Easy There Tiger Productions': 3.0,
#  'Montecito Picture Company, The': 1.5,
#  'Outpost Studios': 1.0,
#  'Fox Atomic': 2.2,
#  'Dark Castle Entertainment': 1.75,
#  'Studio Babelsberg StudioBabelsberg Motion Pictures': 1.0,
#  'Studio Canal': 3.3636363636363638,
#  'Fortis Films': 2.6666666666666665,
#  'Practical Pictures': 3.0,
#  'Parallel Zide': 3.0,
#  'Bagdasarian Productions': 5.0,
#  'Smokewood Entertainment Group': 1.0,
#  'Andell Entertainment': 3.0,
#  'Rogue Pictures': 2.2222222222222223,
#  'Phantom Four': 2.0,
#  'The Montecito Picture Company': 2.2,
#  'De Line Pictures': 2.7777777777777777,
#  'Bernard Gayle Productions': 4.0,
#  'Section Eight': 1.875,
#  'Jaffe / Braunstein Enterprise': 2.0,
#  'Gunn Films': 2.75,
#  'Paramount Vantage': 2.6,
#  'Misher Films': 1.75,
#  'Case 39 Productions': 2.0,
#  'Medienproduktion Prometheus Filmgesellschaft': 4.0,
#  'Portobello Studios': 4.0,
#  'Furst Films': 1.0,
#  'Pictures in Paradise': 2.0,
#  'Pacific Film and Television Commission': 1.5,
#  'Australian Film Finance Corporation (AFFC)': 1.5,
#  'Camp / Thompson Pictures': 2.0,
#  'Icon Productions': 2.5,
#  'Infinity Features Entertainment': 1.0,
#  'Langley Productions': 2.0,
#  'Thunder Road Productions': 2.0,
#  'Fuqua Films': 2.0,
#  'Twisted Pictures': 2.0,
#  'GK Films': 2.090909090909091,
#  'Mike Zoss Productions': 3.0,
#  'Rogue': 3.5,
#  'Tooley Productions': 3.0,
#  '20th Century Fox Home Entertainment': 2.0,
#  'WWE Studios': 1.8,
#  'Midnight Sun Pictures': 2.0,
#  'Vidhu Vinod Chopra Productions': 2.0,
#  'Smoke House': 6.0,
#  'Goldsmith-Thomas Productions': 1.0,
#  'Mosaic Media Group': 2.3,
#  'Sid & Marty Krofft Pictures': 4.0,
#  'Revelations Entertainment': 1.0,
#  'Ilion Animation Studios': 2.0,
#  'Hand Made Films': 2.0,
#  'Ocean Pictures': 2.0,
#  'Tapestry Films': 2.4,
#  'HimenÃ³ptero': 1.0,
#  'Telecinco Cinema': 1.3333333333333333,
#  'Mod Producciones': 1.0,
#  'Canal+ EspaÃ±a': 1.5,
#  'Chris Brinker Productions': 7.0,
#  'Saturn Films': 3.076923076923077,
#  'Edward R. Pressman Film': 5.0,
#  'Polsky Films': 9.0,
#  'Stars Road Entertainment': 1.0,
#  'Farah Films & Management': 1.0,
#  'Tezuka Production Company Ltd.': 2.0,
#  'Imagi Animation Studios': 1.5,
#  'Atlas Entertainment': 2.3333333333333335,
#  'X-Filme Creative Pool': 2.0,
#  'One Race Productions': 2.8,
#  'Dentsu Inc.': 3.0,
#  'Spectacle Entertainment Group': 2.3333333333333335,
#  'Trancas International Films': 2.0,
#  "It's a Laugh Productions": 4.0,
#  'Millar Gough Ink': 4.0,
#  'Josephson Entertainment': 3.25,
#  'New Upstairs Productions': 4.0,
#  'Upstairs Canada Productions': 4.0,
#  'Saga Film': 3.0,
#  'Chambara Pictures': 3.0,
#  'Smartest Man Productions': 2.0,
#  'Paul Schiff Productions': 2.0,
#  'Laura Bickford Productions': 1.0,
#  'Medienproduktion Poseidon Filmgesellschaft': 1.0,
#  'PathÃ© Renn Productions': 1.75,
#  'This Is That Productions': 3.0,
#  '26 Films': 3.5,
#  'Mark Johnson Productions': 3.0,
#  'Curmudgeon Films': 3.0,
#  'DreamWorks': 2.3333333333333335,
#  'Top Shelf Productions': 1.0,
#  'Hyde Park Films': 3.4,
#  'Czech Anglo Productions': 2.0,
#  'Wandering Star Pictures': 2.0,
#  'Seed Productions': 2.0,
#  'Edmonds Entertainment Group (EEG)': 3.0,
#  'Epidemic Pictures': 3.0,
#  'Isle of Man Film': 2.0,
#  'Freestyle Releasing': 4.0,
#  'CinemaNX': 3.0,
#  'Warner Bros. Pictures': 2.3076923076923075,
#  'Echo Lake Productions': 2.0,
#  'Premiere Picture': 2.0,
#  'Cold Spring Pictures': 2.0,
#  "Butcher's Run Films": 2.0,
#  'Informant Media': 2.0,
#  'Castle Rock Entertainment': 3.066666666666667,
#  'Banter': 6.0,
#  'Ozla Pictures': 3.0,
#  'Great Scott Productions Pty. Ltd.': 3.0,
#  'Team Todd': 2.6666666666666665,
#  'Zanuck Company, The': 5.0,
#  'Phoenix Pictures': 2.4444444444444446,
#  'Sikelia Productions': 3.5,
#  'LivePlanet': 2.0,
#  'Sean Bailey Productions': 2.0,
#  'Darlow Smithson Productions': 2.0,
#  'Lions Gate': 2.0,
#  'Peninsula Films': 2.3333333333333335,
#  'Italian Tax Credit': 2.0,
#  'The Zanuck Company': 3.1666666666666665,
#  'Junction Entertainment': 3.3333333333333335,
#  'Everyman Pictures': 3.5,
#  'Dreamworks Pictures': 2.0,
#  'Firm Films': 2.8333333333333335,
#  'Prospect Park': 1.0,
#  'Millbrook Farm Productions': 1.0,
#  'DC Entertainment': 2.4,
#  'Overnight Films': 1.5,
#  'Kennedy/Marshall Company, The': 2.625,
#  'Industrial Light & Magic (ILM)': 3.0,
#  'Bedlam Productions': 3.0,
#  'See-Saw Films': 3.0,
#  'Aegis Film Fund': 3.0,
#  'Bedford Falls Productions': 2.3333333333333335,
#  'Polish Film Institute': 3.0,
#  'Exclusive Films': 3.0,
#  'Monolith Films': 3.0,
#  'On the Road': 3.0,
#  'Tree Line Films': 3.0,
#  'Pink Machine': 3.0,
#  'Red Om Films': 3.0,
#  'Madhouse Entertainment': 2.0,
#  'Octagon Films': 2.0,
#  'Birnbaum/Barber': 2.0,
#  'Bona Fide Productions': 2.0,
#  'River Road Entertainment': 3.3333333333333335,
#  'Road Rebel': 3.0,
#  'Linson Entertainment': 2.0,
#  'Rice Films': 2.0,
#  'Necropia': 6.0,
#  'Tequila Gang': 6.0,
#  'Serendipity Productions': 2.0,
#  'Jerry Weintraub Productions': 2.25,
#  'China Film Group': 3.0,
#  'Matador Pictures': 2.0,
#  'Magic Light Pictures': 2.0,
#  'Cinema Four': 2.0,
#  'Runteam Ltd.': 3.0,
#  'R.P. Productions': 3.0,
#  'France 2 CinÃ©ma': 2.6666666666666665,
#  'FidÃ©litÃ© Films': 4.0,
#  'Hwy61': 4.0,
#  'Katalyst Films': 2.3333333333333335,
#  'Aversano Films': 1.0,
#  'Home Box Office (HBO)': 4.5,
#  'HBO Films': 4.0,
#  'Oops Doughnuts Productions': 2.0,
#  'Frontier Pictures': 2.0,
#  'Three Strange Angels': 3.6666666666666665,
#  'United Artists': 2.3333333333333335,
#  'New Crime Productions': 4.0,
#  'Hammer Film Productions': 3.5,
#  'EFTI': 3.0,
#  'Overture Films': 2.5,
#  'Animal Logic': 5.0,
#  'Cruel and Unusual Films': 4.25,
#  'Battle Mountain Films': 3.0,
#  'Village Roadshow Pictures Asia': 5.0,
#  'PathÃ© Pictures International': 1.3333333333333333,
#  'Stone Productions': 1.0,
#  'Mimran Schur Pictures': 1.0,
#  'Chako Film Company': 2.0,
#  'Intellectual Properties Worldwide': 2.0,
#  'Oceana Media Finance': 1.0,
#  'Pantheon Entertainment Corporation': 1.0,
#  'Innocence Productions': 1.0,
#  'Prescience': 2.0,
#  'Omega Entertainment': 1.0,
#  'Twentieth Century Fox': 2.0,
#  'Mayhem Pictures': 2.0,
#  'Reliance BIG Entertainment': 2.75,
#  'Hydraulx': 1.0,
#  'Rat Entertainment': 1.75,
#  'Transmission Pictures': 1.0,
#  'Pioneer Pictures': 2.0,
#  'Gracie Films': 2.6666666666666665,
#  'Robert Simonds Productions': 2.6,
#  'Spy Next Door': 4.0,
#  'Mosaic': 5.0,
#  'Henceforth': 2.0,
#  'Projection Pictures': 2.0,
#  'London Boulevard': 2.0,
#  'American Film Company': 2.0,
#  'Parabolic Pictures': 4.0,
#  'Birdsong Pictures': 3.0,
#  'Penn Station Entertainment': 3.0,
#  'Lions Gate Family Entertainment': 3.0,
#  'Crest Animation Productions': 3.0,
#  'Rhythm and Hues': 2.0,
#  'Picnic Basket': 2.0,
#  'Maguire Entertainment': 2.0,
#  'Omnilab Media': 3.5,
#  'Ambience Entertainment': 3.5,
#  'Night Chronicles': 1.0,
#  'Serendipity Point Films': 2.0,
#  'Furry Vengeance Productions': 2.0,
#  'platinum studios': 4.0,
#  'Long Distance Films': 5.0,
#  'HighRoad Entertainment': 3.0,
#  'Prelude Pictures': 3.0,
#  'Lone Runner Entertainment': 3.0,
#  'Kenio Films': 3.0,
#  'Perfect Game, The': 3.0,
#  'Boram Entertainment Inc.': 3.0,
#  'Ealing Studios': 3.0,
#  'Fragile Films': 3.0,
#  'Quickfire Films': 3.0,
#  'Lions Gate Films': 2.6842105263157894,
#  'The Tyler Perry Company': 6.0,
#  'PVR Cinemas': 2.0,
#  'Hari Om Entertainment Co.': 2.0,
#  'Blockbuster Movie Entertainers': 2.0,
#  'Fast Track Productions': 1.0,
#  'The Saul Zaentz Company': 9.0,
#  'Asymmetrical Productions': 2.0,
#  'Les Films Alain Sarde': 2.0,
#  'Babbo Inc.': 2.0,
#  'The Picture Factory': 2.0,
#  'Stanley Kubrick Productions': 3.0,
#  'Pacific Data Images (PDI)': 1.8333333333333333,
#  'Little Bird': 3.5,
#  'NPV Entertainment': 2.35,
#  'Alphaville Films': 3.1666666666666665,
#  'Imhotep Productions': 3.0,
#  'Walt Disney Feature Animation': 2.857142857142857,
#  'Toho-Towa': 4.5,
#  'Mutual Film Company': 3.4,
#  'British Broadcasting Corporation (BBC)': 6.0,
#  'Liveplanet': 3.0,
#  'Zide-Perry Productions': 2.6666666666666665,
#  'BrownHouse Productions': 3.0,
#  'Bottom of the Ninth Productions': 3.0,
#  'Bazmark Films': 2.0,
#  'Swanford Films': 4.0,
#  'KC Medien': 4.0,
#  'Revolution Studios': 2.2,
#  'Columbia Pictures Corporation': 2.702127659574468,
#  'Black and Blu Entertainment': 3.0,
#  'Finestkind': 3.0,
#  'Red Hour Productions': 1.0,
#  'Neal H. Moritz Productions': 4.0,
#  'Gold/Miller Productions': 2.0,
#  'Wayans Bros. Entertainment': 2.25,
#  'Brad Grey Pictures': 3.0,
#  'Outlaw Productions (I)': 2.0,
#  'WV Films II': 1.5,
#  'Cruise/Wagner Productions': 2.5,
#  'Canal Plus': 1.7142857142857142,
#  'Sogecine': 2.0,
#  'Las Producciones del Escorpion': 2.0,
#  'Lucky Red': 3.5,
#  'Universal Cartoon Studios': 4.0,
#  'Paramount Animation': 2.2,
#  'View Askew Productions': 4.666666666666667,
#  'Miramax': 4.75,
#  'Simon Fields Productions': 1.0,
#  'Cruise-Wagner Productions': 2.0,
#  'Current Entertainment': 2.0,
#  'Immortal Entertainment': 4.0,
#  'Metropolitan Filmexport': 2.75,
#  'Red Wagon Productions': 3.0,
#  'Beacon Communications': 2.3333333333333335,
#  'Jonathan Krane Group': 1.0,
#  'Industry Entertainment': 2.2,
#  'Epsilon Motion Pictures': 2.4166666666666665,
#  'Square USA': 5.0,
#  'Chris Lee Productions': 3.0,
#  'American Zoetrope': 2.6,
#  'Cinerenta Medienbeteiligungs KG': 1.6666666666666667,
#  'Cinerenta-Cinebeta': 2.0,
#  'VCL Communications': 2.0,
#  'Underworld Entertainment': 2.0,
#  'AZL Productions KG': 4.0,
#  'David Brown Productions': 2.5,
#  'MFP Munich Film Partners': 4.0,
#  'Phase 1 Productions': 4.0,
#  'Intermedia Films': 2.5833333333333335,
#  'Dee Gee Entertainment': 3.0,
#  'Prufrock Pictures': 3.0,
#  'Fireworks Pictures': 2.0,
#  'USA Films': 1.5,
#  'Sean S. Cunningham Films': 2.5,
#  'Crystal Lake Entertainment': 2.5,
#  'Newmarket Capital Group': 1.75,
#  'Lawrence Bender Productions': 2.4,
#  'Pistolero Productions LLC': 2.0,
#  'Bel Air Entertainment': 2.4,
#  'IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG': 3.3333333333333335,
#  'Kopelson Entertainment': 2.5,
#  'Bungalow Productions': 5.0,
#  'Silver Lion Films': 5.0,
#  'Vision View Entertainment': 5.0,
#  'American Entertainment Partners L.P.': 1.0,
#  'David Kirschner Productions': 1.5,
#  'Franchise Pictures': 2.8461538461538463,
#  'Morgan Creek Productions': 2.9166666666666665,
#  'Tribeca Productions': 3.0,
#  'New Redemption Pictures': 2.0,
#  'GHS Productions KG': 1.0,
#  'Munich Film Partners & Company (MFP) GHS Productions': 1.0,
#  'Nides/McCormick Productions': 1.0,
#  'Horseshoe Bay Productions': 2.0,
#  'Merlin Films': 4.0,
#  'Native Pictures Productions': 2.0,
#  'Darkwoods Productions': 2.0,
#  'Storm King Productions': 3.0,
#  'Animationwerks': 3.0,
#  'Ardustry Entertainment': 4.5,
#  'Mediastream Film GmbH & Co. Productions KG': 5.0,
#  'Cort/Madden Productions': 4.0,
#  'Cheyenne Enterprises': 2.75,
#  'Empire Pictures': 1.0,
#  'Hyde Park Entertainment': 2.6666666666666665,
#  'Ufland': 1.0,
#  'Trackform Film Productions': 1.0,
#  "Mel's Cite du Cinema": 2.5,
#  'Dino De Laurentiis Company': 1.8,
#  'Tollin/Robbins Productions': 1.5,
#  'Crystal Sky Worldwide': 2.0,
#  'MDP Worldwide': 2.0,
#  'ApolloMedia Distribution': 1.5,
#  'Carousel Picture Company, The': 2.0,
#  'Signature Entertainment': 2.0,
#  'Dan Films': 3.0,
#  'CP Medien AG': 3.0,
#  'TPS Star': 1.5,
#  'Grive Productions': 1.6,
#  'Eon Productions': 2.6666666666666665,
#  'Internationale Filmproduktion Richter': 2.0,
#  'Playtone': 2.5,
#  'Littlestar': 2.0,
#  'China Film Co-Production Corporation': 4.0,
#  'Sommers Company, The': 4.5,
#  'Valhalla Motion Pictures': 2.0,
#  'MVL Incredible Productions': 3.0,
#  'Gerber Pictures': 2.6666666666666665,
#  'Double Nickel Entertainment': 2.0,
#  'Dark Horse Entertainment': 2.8,
#  'Hypnotic': 2.3333333333333335,
#  'Kickstart Productions': 1.0,
#  'Europa Corp': 2.0,
#  'Achte Babelsberg Film': 1.0,
#  'The Department of Trade and Industry of South Africa': 2.0,
#  'Kingsgate Films': 3.0,
#  'Grosvenor Park Media Ltd.': 3.25,
#  'Voltage Pictures': 2.6666666666666665,
#  'Film Capital Europe Funds (FCEF )': 3.0,
#  'Stillking Films': 2.875,
#  'Ozumi Films': 6.0,
#  'Propeler': 6.0,
#  'Red Hour Films': 4.25,
#  'Internationale Filmproduktion Stella-del-Sud Second': 2.0,
#  'K/O Paper Products': 2.6666666666666665,
#  'KMP Film Invest': 1.5,
#  'Rogue Marble': 1.5,
#  'Earth Canada Productions': 6.0,
#  'Hammerhead Productions': 3.5,
#  'ScreenWest': 1.0,
#  'Heyday films': 2.0,
#  'Internationale Filmproduktion Blackbird Erste': 1.0,
#  'Baumgarten Management and Productions (BMP)': 3.0,
#  'Wild Bunch': 1.6666666666666667,
#  'Top Rope': 2.0,
#  'MHF Zweite Academy Film': 3.5,
#  'Marvel Knights': 4.0,
#  'SGF Entertainment': 3.0,
#  'Collision Entertainment': 2.0,
#  'Abandon Entertainment': 2.0,
#  'Foxtor Productions': 2.0,
#  'Castel Film Romania': 1.5,
#  'ASAF': 1.0,
#  'Luna Pictures': 1.0,
#  'Kanzaman': 2.5,
#  'Art In Motion': 2.0,
#  'Blue Askew': 6.0,
#  'Internationale Filmproduktion Stella-del-SÃ¼d': 2.0,
#  'CinÃ©CinÃ©ma': 1.75,
#  'Babylon': 2.0,
#  'Blueprint Pictures': 2.0,
#  'Twins Financing': 2.0,
#  'The Kennedy/Marshall Company': 2.5,
#  'Depth of Field': 3.3333333333333335,
#  'Type A Films': 4.5,
#  'Ott Medien': 2.0,
#  'Alta Loma Entertainment': 3.0,
#  'Internationale Filmproduktion': 3.0,
#  'Gravier Productions': 3.0,
#  'Antena 3 Films': 3.0,
#  'TelevisiÃ³ de Catalunya (TV3)': 3.0,
#  'Antena 3 TelevisiÃ³n': 3.0,
#  'Casey Silver Productions': 1.75,
#  'Huayi Brothers': 3.0,
#  'InVenture Entertainment': 2.0,
#  'Nu-Image Films': 2.0,
#  'Lietuvos Kinostudija': 1.0,
#  'Scout Productions': 1.0,
#  'Castelao Producciones': 1.5,
#  'Grosvenor Park Productions': 2.5,
#  'Bedford Falls Company, The': 1.6666666666666667,
#  'Defiance Productions': 1.0,
#  'Pistachio Pictures': 1.0,
#  'Cohen/Pearl Productions': 1.0,
#  'Ascendant Pictures': 2.3333333333333335,
#  'Rising Star': 3.1666666666666665,
#  'VIP Medienfonds 4': 3.3333333333333335,
#  'Outlander Productions': 1.0,
#  'Ten Thirteen Productions': 7.0,
#  'Crying Box Productions': 7.0,
#  'Rifkin-Eberts': 1.0,
#  'Toff Guy Films': 1.0,
#  'VN Productions': 2.0,
#  'Virtual Studios': 2.857142857142857,
#  'Initial Entertainment Group': 2.0,
#  'International Production Company': 3.0,
#  'Blue Star Pictures': 2.5,
#  'Odd Lot Entertainment': 1.6666666666666667,
#  'Media Magik Entertainment': 3.0,
#  'Dark Lot Entertainment': 2.0,
#  'UTV Motion Pictures': 2.0,
#  'Intrepid Pictures': 2.2,
#  'South Pacific Pictures': 4.0,
#  'Spice Factory': 4.0,
#  'The Australian Film Commission': 4.0,
#  'Darren Star Productions': 4.0,
#  'Universal Pictures Corporation': 4.0,
#  'Neal Street Productions': 3.0,
#  'Evamere Entertainment': 2.0,
#  'Michaels-Goldwyn': 2.0,
#  'Ecosse Films': 2.0,
#  '2 Entertain': 2.0,
#  'Guy Walks into a Bar Productions': 1.5,
#  'Deep River Productions': 3.0,
#  'Andale Pictures': 1.0,
#  'IDEA Filmproduktions': 2.0,
#  'Starz Media': 2.0,
#  'Odyssey Entertainment': 3.5,
#  'Studiopolis': 2.0,
#  'Vanguard Animation': 2.0,
#  'Art Linson Productions': 2.3333333333333335,
#  '3 in the Box': 2.0,
#  'New Wave Entertainment': 4.0,
#  'Management 360': 3.0,
#  'Terra Firma Films': 4.0,
#  'Superfinger Entertainment': 4.0,
#  'GreeneStreet Films': 2.0,
#  'Midnight Picture Show': 4.0,
#  'Paradox Entertainment': 2.75,
#  'First Foot Films': 2.0,
#  'Ixtlan Productions': 1.0,
#  'Emperor Motion Pictures': 2.5,
#  'Global Entertainment Group': 1.0,
#  'Sherazade Film Development': 2.0,
#  'Corduroy Films': 2.0,
#  'Exodus Film Group': 1.0,
#  'Exodus Productions': 1.0,
#  'Intandem Films': 7.0,
#  'Aramid Entertainment Fund': 7.0,
#  'Lipsync Productions': 7.0,
#  'Motel Movies': 1.0,
#  'Scared Productions': 2.0,
#  'Nu Image Entertainment GmbH': 2.0,
#  'Vendome Pictures': 2.0,
#  'Film Rites': 4.333333333333333,
#  'Yellow Bird': 6.0,
#  'Virgin Produced': 2.0,
#  'Many Rivers Productions': 1.0,
#  'Boy of the Year': 1.0,
#  'K/O Camera Toys': 2.0,
#  'Lennox House Films': 2.0,
#  'Random Films': 3.0,
#  'Total Entertainment': 8.0,
#  'TSBD Canada Productions': 8.0,
#  'Zohar International': 8.0,
#  'Fox Searchlight': 2.6666666666666665,
#  'Bay Films': 4.0,
#  'France 3 CinÃ©ma': 1.5,
#  'La Petite Reine': 2.0,
#  'Studio 37': 2.0,
#  'uFilm': 2.0,
#  'Jouror Productions': 2.0,
#  'Blind Wink': 1.0,
#  'Film 4': 2.0,
#  'Contrafilm': 2.7142857142857144,
#  'Hungarian National Film Office': 2.0,
#  'Lazio Film Commission': 2.0,
#  'Nouvelles Ã‰ditions de Films (NEF)': 4.5,
#  'New Legacy': 2.5,
#  'TOKYOPOP': 1.0,
#  'Denver and Delilah Productions': 2.0,
#  'Tailor Made': 1.0,
#  'Mango Farms': 1.0,
#  'Gambit Pictures': 3.0,
#  'Electric Shepherd Productions': 3.0,
#  'Mark Canton Productions': 1.6666666666666667,
#  ...}

# %%
cnt
# Out:
# Counter({'Universal Studios': 16,
#          'Amblin Entertainment': 70,
#          'Legendary Pictures': 84,
#          'Fuji Television Network': 5,
#          'Dentsu': 27,
#          'Village Roadshow Pictures': 169,
#          'Kennedy Miller Productions': 6,
#          'Summit Entertainment': 120,
#          'Mandeville Films': 12,
#          'Red Wagon Entertainment': 8,
#          'NeoReel': 8,
#          'Lucasfilm': 32,
#          'Truenorth Productions': 5,
#          'Bad Robot': 28,
#          'Universal Pictures': 452,
#          'Original Film': 75,
#          'Media Rights Capital': 25,
#          'One Race Films': 6,
#          'Regency Enterprises': 123,
#          'Appian Way': 26,
#          'CatchPlay': 2,
#          'Anonymous Content': 28,
#          'New Regency Pictures': 65,
#          'Paramount Pictures': 350,
#          'Skydance Productions': 28,
#          'Twentieth Century Fox Film Corporation': 328,
#          'Scott Free Productions': 65,
#          'Mid Atlantic Films': 17,
#          'International Traders': 4,
#          'TSG Entertainment': 53,
#          'Illumination Entertainment': 9,
#          'Walt Disney Pictures': 242,
#          'Pixar Animation Studios': 23,
#          'Walt Disney Studios Motion Pictures': 12,
#          'Columbia Pictures': 320,
#          'Danjaq': 1,
#          'B24': 1,
#          'Dune Entertainment': 136,
#          'Anarchos Productions': 11,
#          'Warner Bros.': 465,
#          'DNA Films': 28,
#          'Universal Pictures International (UPI)': 2,
#          'Film4': 34,
#          'Happy Madison Productions': 65,
#          'Marvel Studios': 37,
#          'Prime Focus': 6,
#          'Revolution Sun Studios': 15,
#          'Double Feature Films': 24,
#          'The Weinstein Company': 68,
#          'FilmColony': 6,
#          'M6 Films': 7,
#          'Canal+': 39,
#          'EuropaCorp': 38,
#          'CinÃ©+': 6,
#          'Genre Films': 5,
#          'Beagle Pug Films': 1,
#          'Allison Shearmur Productions': 1,
#          'Studio Babelsberg': 63,
#          'StudioCanal': 52,
#          'Lionsgate': 96,
#          'Color Force': 39,
#          'Babieka': 5,
#          'A113': 1,
#          'Escape Artists': 35,
#          'Riche-Ludwig Productions': 1,
#          'New Line Cinema': 287,
#          'Flynn Picture Company': 3,
#          'Focus Features': 49,
#          'Trigger Street Productions': 5,
#          'Michael De Luca Productions': 12,
#          'Plan B Entertainment': 35,
#          'China Movie Channel': 5,
#          'TC Productions': 12,
#          'Fuzzy Door Productions': 3,
#          'Marv Films': 11,
#          'Cloudy Productions': 4,
#          'Participant Media': 35,
#          'Open Road Films': 15,
#          'Rocklin / Faust': 1,
#          'Entertainment One Features': 1,
#          'Gotham Group': 9,
#          'Temple Hill Entertainment': 34,
#          'Sony Pictures Entertainment (SPE)': 18,
#          'Alpha Core': 2,
#          'Gold Circle Films': 20,
#          'Brownstone Productions': 5,
#          'DreamWorks SKG': 160,
#          'Fox 2000 Pictures': 122,
#          'Marc Platt Productions': 28,
#          'Scholastic Entertainment': 1,
#          'Element Pictures': 3,
#          'No Trace Camping': 3,
#          'A24': 7,
#          'Duperele Films': 1,
#          'Buena Vista': 8,
#          'Vertigo Entertainment': 35,
#          'Energy Entertainment': 7,
#          'RatPac-Dune Entertainment': 15,
#          'Wildgaze Films': 3,
#          'Irish Film Board': 4,
#          'Item 7': 1,
#          'Parallel Film Productions': 1,
#          'Cube Vision': 9,
#          'Broken Chair Flickz': 3,
#          'Atmosphere Entertainment MM': 20,
#          'Goldmann Pictures': 11,
#          'Davis Entertainment': 43,
#          'Wigram Productions': 12,
#          'Lakeshore Entertainment': 62,
#          'Sidney Kimmel Entertainment': 24,
#          'Sierra/Affinity': 4,
#          'Bazelevs Production': 12,
#          'Versus Pictures': 2,
#          'DreamWorks Animation': 78,
#          'Killer Films': 4,
#          'Number 9 Films': 1,
#          'Waverly Films': 9,
#          'Working Title Films': 73,
#          'Walden Media': 68,
#          'Cross Creek Pictures': 16,
#          'Free State Pictures': 3,
#          'Alcon Entertainment': 43,
#          'DMG Entertainment': 4,
#          'Ehman Productions': 2,
#          'PeaPie Films': 1,
#          '3 Arts Entertainment': 13,
#          'Endgame Entertainment': 22,
#          'Ram Bergman Productions': 4,
#          'Mad Chance': 13,
#          'OddLot Entertainment': 1,
#          'Huayi Brothers Media': 2,
#          'Pretty Pictures': 3,
#          'ArtÃ©mis Productions': 3,
#          'Le Tax Shelter du Gouvernement FÃ©dÃ©ral de Belgique': 3,
#          'Taxshelter. be': 3,
#          'Forward Pass': 10,
#          'Thunder Road Pictures': 19,
#          'Black Label Media': 1,
#          'Marvel Entertainment': 18,
#          'Constantin Film.': 2,
#          'Moving Picture Company (MPC)': 41,
#          'Chernin Entertainment': 19,
#          'Feigco Entertainment': 4,
#          'Kramer & Sigman Films': 1,
#          'Zaftig Films': 1,
#          'Fox International Productions': 5,
#          'Infinite Frameworks Studios': 3,
#          'Imagine Entertainment': 73,
#          'Spring Creek Productions': 21,
#          'Roth Films': 25,
#          'K. JAM Media': 6,
#          'Metro-Goldwyn-Mayer (MGM)': 132,
#          'Chartoff-Winkler Productions': 3,
#          'Apatow Productions': 59,
#          'Entertainment One': 6,
#          'Moonlighting Films': 10,
#          'Raindog Films': 4,
#          'Anton Capital Entertainment (ACE)': 2,
#          'Berlanti Productions': 1,
#          'Blue Sky Studios': 22,
#          'Twentieth Century Fox Animation': 25,
#          'LStar Capital': 13,
#          'The Cantillon Company': 1,
#          'The Shuman Company': 1,
#          'Sony Pictures': 11,
#          'Point Grey Pictures': 8,
#          'Good Universe': 9,
#          'Sony Pictures Animation': 29,
#          'Groundswell Productions': 8,
#          'CBS Films': 24,
#          'TriStar Pictures': 39,
#          'Sony Pictures Entertainment': 10,
#          'ImageMovers': 15,
#          'BenderSpink': 18,
#          'David Dobkin Productions': 3,
#          'Ghost House Pictures': 22,
#          'Worldview Entertainment': 5,
#          'Blumhouse Productions': 31,
#          'Blue-Tongue Films': 4,
#          'STX Entertainment': 2,
#          'Ahimsa Films': 2,
#          'Gary Sanchez Productions': 20,
#          'Red Granite Pictures': 15,
#          'Onyx Films': 5,
#          'Orange Studios': 3,
#          'CityMation': 3,
#          'On Entertainment': 3,
#          'Zippcast Films': 3,
#          'Amazon Studios': 2,
#          'Film Art Media': 2,
#          'Apollo Media': 2,
#          'Wonderland Sound and Vision': 13,
#          'Vast Entertainment': 2,
#          'Alliance Films': 10,
#          'IM Global': 16,
#          'Automatik Entertainment': 7,
#          'Sony Pictures Releasing': 12,
#          'Sony Pictures Home Entertainment': 7,
#          'Closest to the Hole Productions': 6,
#          'Miramax Films': 107,
#          'Screen Gems': 79,
#          'Blinding Edge Pictures': 17,
#          'Infinitum Nihil': 11,
#          'Head Gear Films': 2,
#          'Bold Films': 5,
#          'Living Films': 6,
#          'Brothers Dowdle Productions': 2,
#          'BBC Films': 49,
#          'Origin Pictures': 8,
#          'Little Stranger': 1,
#          'MTV Films': 37,
#          'Platinum Dunes': 36,
#          'Insurge Pictures': 12,
#          'Iron Horse Entertainment (II)': 6,
#          'Inimitable Pictures': 1,
#          'ShivHans Pictures': 1,
#          'Ingenious Media': 42,
#          'Gran Via Productions': 16,
#          'Route One Films': 9,
#          'Nickelodeon Movies': 47,
#          'Nickelodeon Animation Studios': 7,
#          'United Plankton Pictures': 7,
#          'Disruption Entertainment': 9,
#          'Sunswept Entertainment': 47,
#          'Silver Pictures': 45,
#          'TF1 Films Production': 16,
#          'Instituto de la CinematografÃ\xada y de las Artes Audiovisuales (ICAA)': 6,
#          'Pacific Standard': 4,
#          'TriStar Productions': 5,
#          'Columbia TriStar': 6,
#          'Clinica Estetico': 8,
#          'Scott Rudin Productions': 74,
#          'Ruby Films': 4,
#          'PathÃ©': 9,
#          'Metanoia Films': 2,
#          'Vinyl Films': 10,
#          'RatPac Entertainment': 7,
#          'Smokehouse Pictures': 15,
#          'Shangri-La Entertainment': 10,
#          'QED International': 11,
#          'Dune Films': 10,
#          'Venture Forth': 3,
#          'Wildwood Enterprises': 15,
#          'Treehouse Pictures': 10,
#          'Hasbro Studios': 4,
#          'Allspark Pictures': 4,
#          'Syncopy': 17,
#          'Lynda Obst Productions': 5,
#          'Bulletproof Cupid': 4,
#          '87Eleven': 3,
#          'DefyNite Films': 2,
#          'MJW Films': 2,
#          'WingNut Films': 58,
#          '3Foot7': 8,
#          'Walt Disney Animation Studios': 23,
#          'Black Bear Pictures': 3,
#          'Bristol Automotive': 3,
#          'Dayday Films': 3,
#          'Le Grisbi Productions': 1,
#          'M Productions': 1,
#          'Crave Films': 5,
#          '1492 Pictures': 65,
#          '21 Laps Entertainment': 46,
#          "Donners' Company": 19,
#          'Bad Hat Harry Productions': 10,
#          'Sierra / Affinity': 1,
#          'Di Bonaventura Pictures': 35,
#          'Hasbro': 17,
#          'Fox Searchlight Pictures': 71,
#          'Indian Paintbrush': 16,
#          'Mace Neufeld Productions': 8,
#          'Marvel Enterprises': 22,
#          'Avi Arad Productions': 4,
#          'Matt Tolmach Productions': 4,
#          'Viz Media': 3,
#          'Province of British Columbia Production Services Tax Credit': 15,
#          'Malpaso Productions': 26,
#          'Mad Chance Productions': 2,
#          'Volcano Films': 4,
#          'Toho Company': 1,
#          'Irish Dreamtime': 3,
#          'Relativity Media': 246,
#          'SPD Films': 3,
#          'Mad Hatter Entertainment': 11,
#          'Davis-Films': 29,
#          'Nu Image Films': 31,
#          'LionsGate': 5,
#          'Millennium Films': 43,
#          'Ex3 Productions': 3,
#          'DC Comics': 20,
#          'Lin Pictures': 17,
#          'Warner Bros. Animation': 15,
#          'Outlaw Sinema': 4,
#          'Pendle Mountain Productions': 2,
#          'WideAwake': 5,
#          'Lucamar Productions': 3,
#          'Hollywood Gang Productions': 6,
#          'Nimar Studios': 10,
#          'Tonik Productions': 2,
#          'Asis Productions': 2,
#          'Cannell Studios': 3,
#          'Jersey Films': 16,
#          '1984 Private Defense Contractors': 15,
#          'Exclusive Media Group': 24,
#          'Heyday Films': 68,
#          'Echo Films': 3,
#          "We're Not Brothers Productions": 1,
#          'Cinelou Films': 1,
#          'Aldamisa Entertainment': 10,
#          'Kilburn Media': 1,
#          'Fetisov Teterin Films': 1,
#          'Why Not Productions': 7,
#          '5150 Action': 3,
#          'Stoney Lake Entertainment': 2,
#          'Imagenation Abu Dhabi FZ': 34,
#          'FilmNation Entertainment': 13,
#          'Before the Door Pictures': 7,
#          'Washington Square Films': 7,
#          'Radical Studios': 2,
#          'Protozoa Pictures': 7,
#          'Big Kid Pictures': 8,
#          'Team Downey': 2,
#          'Karz Entertainment': 12,
#          'Gulfstream Pictures': 1,
#          'Offspring Entertainment': 17,
#          'Rainforest Films': 13,
#          'Ghoulardi Film Company': 8,
#          'Etalon film': 4,
#          'Screen Australia': 5,
#          'Screen Queensland': 1,
#          'Blacklab Entertainment': 1,
#          'Wolfhound Pictures': 1,
#          'Strike Entertainment': 12,
#          'Straight Up Films': 1,
#          'LBI Productions': 3,
#          '20th Century Fox': 48,
#          'Troublemaker Studios': 20,
#          'AR Films': 9,
#          'Demarest Films': 9,
#          'Conundrum Entertainment': 18,
#          'Obelisk Productions': 3,
#          'Jolie Pas': 1,
#          'Harpo Films': 7,
#          'Celador Films': 4,
#          'Cloud Eight Films': 4,
#          'Impact Pictures': 22,
#          'Don Carmody Productions': 9,
#          'FilmDistrict': 15,
#          'Constantin Film International': 1,
#          'Overbrook Entertainment': 19,
#          'Crescendo Productions': 4,
#          'Goldenlight Films': 2,
#          'Reliance Entertainment': 19,
#          'Bandito Brothers': 6,
#          'Touchstone Pictures': 144,
#          'Electronic Arts': 3,
#          'Laika Entertainment': 6,
#          'Silverwood Films': 2,
#          'Electric City Entertainment': 7,
#          'Tim Burton Productions': 34,
#          'Grindstone Entertainment Group': 10,
#          'Emmett/Furla Films': 19,
#          'Oasis Films': 2,
#          'Aperture Entertainment': 2,
#          'Broken Road Productions': 11,
#          'DisneyToon Studios': 12,
#          'Prana Studios': 6,
#          'Prana Animation Studios': 9,
#          'Albert S. Ruddy Productions': 4,
#          'Likely Story': 3,
#          'Annapurna Pictures': 13,
#          'Fake Empire': 4,
#          'Bluegrass Films': 8,
#          'Porchlight Films': 2,
#          'Screen NSW': 2,
#          'Qwerty Films': 2,
#          'TF1 Droits Audiovisuels': 2,
#          'Scope Pictures': 3,
#          'The Safran Company': 6,
#          'Evergreen Media Group': 3,
#          'Hopscotch Films': 2,
#          'D8': 2,
#          'Weed Road Pictures': 16,
#          'HanWay Films': 6,
#          'Snoot Entertainment': 2,
#          'Hopscotch Features': 6,
#          'Seven West Media': 3,
#          'Fear of God Films': 3,
#          'Seven Group Holdings': 3,
#          'Jim Henson Company, The': 10,
#          'Screen Gems, Inc.': 5,
#          'Olive Bridge Entertainment': 8,
#          'Scottish Screen': 8,
#          'UK Film Council': 52,
#          'Nick Wechsler Productions': 13,
#          'Creative Scotland': 3,
#          'Warner Bros. Interactive Entertainment': 2,
#          'Rob Thomas Productions': 2,
#          'Hearst Entertainment Productions': 3,
#          'LightWorkers Media': 3,
#          'Mandalay Pictures': 21,
#          'Affirm Films': 10,
#          'Sahara Productions': 2,
#          'Silvatar Media': 2,
#          'The Combine': 3,
#          'Boxing Cat Films': 6,
#          'Disney': 3,
#          'Provident Films': 3,
#          'Pure Flix Entertainment': 6,
#          'FourBoys Entertainment': 3,
#          'Panay Films': 3,
#          'Winkler Films': 3,
#          'Max Films Productions': 3,
#          'Morag Loves Company': 3,
#          'Ingenious Film Partners': 54,
#          'Lightstorm Entertainment': 2,
#          'A Band Apart': 10,
#          'Zehnte Babelsberg': 2,
#          'Visiona Romantica': 2,
#          'Sketch Films': 7,
#          'UW3 Film Productions': 5,
#          'Spyglass Entertainment': 78,
#          'MavroCine Pictures GmbH & Co. KG': 2,
#          'The Halcyon Company': 2,
#          'Key Creatives': 5,
#          'Block / Hanson': 2,
#          'Canadian Film or Video Production Tax Credit (CPTC)': 6,
#          'Internationale Filmproduktion Blackbird Dritte': 7,
#          'Watermark': 4,
#          'Dune Entertainment III': 49,
#          'Green Hat Films': 14,
#          'IFP Westcoast Erste': 2,
#          'Lawrence Gordon Productions': 20,
#          'Centropolis Entertainment': 15,
#          'The Mark Gordon Company': 7,
#          'Farewell Productions': 1,
#          'Focus Films': 7,
#          'Starz Animation': 6,
#          'Arc Productions': 3,
#          'Panorama Films': 3,
#          'Skylark Productions': 7,
#          'Left Tackle Pictures': 3,
#          'Zucker/Netter Productions': 3,
#          'Maverick Films': 19,
#          'Imprint Entertainment': 10,
#          'Flower Films (II)': 18,
#          'Internationale Filmproduktion Blackswan': 6,
#          'Kontsept Film Company': 6,
#          'Kurtzman/Orci': 6,
#          'American Empirical Pictures': 5,
#          'Museum Canada Productions': 8,
#          'Walt Disney': 26,
#          'Goldcrest Pictures': 14,
#          'Grand Army Entertainment': 4,
#          'Scion Films': 31,
#          'Inferno Distribution': 6,
#          'Stage 6 Films': 18,
#          'Hachiko': 4,
#          'Film Department, The': 3,
#          'Evil Twins': 3,
#          'Warp Films': 3,
#          'Darko Entertainment': 2,
#          'Radar Pictures': 25,
#          'Radical Media': 6,
#          'Constantin Film Produktion': 29,
#          'Mandate Pictures': 28,
#          'Buckaroo Entertainment': 6,
#          'Curse Productions': 4,
#          'Mystery Clock Cinema': 1,
#          'Kaplan/Perrone Entertainment': 5,
#          'Liberty Films UK': 1,
#          'Lunar Industries': 1,
#          'Xingu Films': 1,
#          'Limelight Fund': 1,
#          'Jerry Bruckheimer Films': 76,
#          'Whamaphram Productions': 1,
#          'Wintergreen Productions': 13,
#          'Pan EuropÃ©enne Production': 2,
#          'Virtual Films': 3,
#          'Wild West Picture Show Productions': 10,
#          'Stuber Productions': 16,
#          'Sighvatsson Films': 1,
#          'Palomar Pictures (II)': 4,
#          '2929 Productions': 16,
#          'Dimension Films': 95,
#          'Chockstone Pictures': 7,
#          'Easy There Tiger Productions': 3,
#          'Montecito Picture Company, The': 6,
#          'Outpost Studios': 1,
#          'Fox Atomic': 11,
#          'Dark Castle Entertainment': 21,
#          'Studio Babelsberg StudioBabelsberg Motion Pictures': 1,
#          'Studio Canal': 37,
#          'Fortis Films': 8,
#          'Practical Pictures': 6,
#          'Parallel Zide': 6,
#          'Bagdasarian Productions': 10,
#          'Smokewood Entertainment Group': 1,
#          'Andell Entertainment': 6,
#          'Rogue Pictures': 20,
#          'Phantom Four': 2,
#          'The Montecito Picture Company': 11,
#          'De Line Pictures': 25,
#          'Bernard Gayle Productions': 4,
#          'Section Eight': 15,
#          'Jaffe / Braunstein Enterprise': 2,
#          'Gunn Films': 11,
#          'Paramount Vantage': 26,
#          'Misher Films': 7,
#          'Case 39 Productions': 2,
#          'Medienproduktion Prometheus Filmgesellschaft': 4,
#          'Portobello Studios': 4,
#          'Furst Films': 1,
#          'Pictures in Paradise': 4,
#          'Pacific Film and Television Commission': 3,
#          'Australian Film Finance Corporation (AFFC)': 3,
#          'Camp / Thompson Pictures': 2,
#          'Icon Productions': 10,
#          'Infinity Features Entertainment': 1,
#          'Langley Productions': 2,
#          'Thunder Road Productions': 2,
#          'Fuqua Films': 2,
#          'Twisted Pictures': 12,
#          'GK Films': 23,
#          'Mike Zoss Productions': 15,
#          'Rogue': 7,
#          'Tooley Productions': 3,
#          '20th Century Fox Home Entertainment': 2,
#          'WWE Studios': 9,
#          'Midnight Sun Pictures': 2,
#          'Vidhu Vinod Chopra Productions': 2,
#          'Smoke House': 6,
#          'Goldsmith-Thomas Productions': 1,
#          'Mosaic Media Group': 23,
#          'Sid & Marty Krofft Pictures': 4,
#          'Revelations Entertainment': 1,
#          'Ilion Animation Studios': 2,
#          'Hand Made Films': 2,
#          'Ocean Pictures': 2,
#          'Tapestry Films': 12,
#          'HimenÃ³ptero': 1,
#          'Telecinco Cinema': 4,
#          'Mod Producciones': 1,
#          'Canal+ EspaÃ±a': 6,
#          'Chris Brinker Productions': 7,
#          'Saturn Films': 40,
#          'Edward R. Pressman Film': 25,
#          'Polsky Films': 9,
#          'Stars Road Entertainment': 2,
#          'Farah Films & Management': 1,
#          'Tezuka Production Company Ltd.': 2,
#          'Imagi Animation Studios': 3,
#          'Atlas Entertainment': 14,
#          'X-Filme Creative Pool': 4,
#          'One Race Productions': 14,
#          'Dentsu Inc.': 3,
#          'Spectacle Entertainment Group': 7,
#          'Trancas International Films': 2,
#          "It's a Laugh Productions": 4,
#          'Millar Gough Ink': 4,
#          'Josephson Entertainment': 13,
#          'New Upstairs Productions': 4,
#          'Upstairs Canada Productions': 4,
#          'Saga Film': 3,
#          'Chambara Pictures': 3,
#          'Smartest Man Productions': 2,
#          'Paul Schiff Productions': 4,
#          'Laura Bickford Productions': 1,
#          'Medienproduktion Poseidon Filmgesellschaft': 1,
#          'PathÃ© Renn Productions': 7,
#          'This Is That Productions': 9,
#          '26 Films': 7,
#          'Mark Johnson Productions': 3,
#          'Curmudgeon Films': 3,
#          'DreamWorks': 7,
#          'Top Shelf Productions': 1,
#          'Hyde Park Films': 17,
#          'Czech Anglo Productions': 2,
#          'Wandering Star Pictures': 2,
#          'Seed Productions': 4,
#          'Edmonds Entertainment Group (EEG)': 3,
#          'Epidemic Pictures': 3,
#          'Isle of Man Film': 10,
#          'Freestyle Releasing': 4,
#          'CinemaNX': 6,
#          'Warner Bros. Pictures': 30,
#          'Echo Lake Productions': 2,
#          'Premiere Picture': 2,
#          'Cold Spring Pictures': 6,
#          "Butcher's Run Films": 2,
#          'Informant Media': 2,
#          'Castle Rock Entertainment': 46,
#          'Banter': 6,
#          'Ozla Pictures': 3,
#          'Great Scott Productions Pty. Ltd.': 3,
#          'Team Todd': 8,
#          'Zanuck Company, The': 15,
#          'Phoenix Pictures': 22,
#          'Sikelia Productions': 7,
#          'LivePlanet': 8,
#          'Sean Bailey Productions': 2,
#          'Darlow Smithson Productions': 2,
#          'Lions Gate': 4,
#          'Peninsula Films': 7,
#          'Italian Tax Credit': 2,
#          'The Zanuck Company': 19,
#          'Junction Entertainment': 10,
#          'Everyman Pictures': 14,
#          'Dreamworks Pictures': 2,
#          'Firm Films': 17,
#          'Prospect Park': 1,
#          'Millbrook Farm Productions': 1,
#          'DC Entertainment': 12,
#          'Overnight Films': 3,
#          'Kennedy/Marshall Company, The': 21,
#          'Industrial Light & Magic (ILM)': 3,
#          'Bedlam Productions': 3,
#          'See-Saw Films': 3,
#          'Aegis Film Fund': 6,
#          'Bedford Falls Productions': 7,
#          'Polish Film Institute': 3,
#          'Exclusive Films': 3,
#          'Monolith Films': 3,
#          'On the Road': 3,
#          'Tree Line Films': 9,
#          'Pink Machine': 3,
#          'Red Om Films': 3,
#          'Madhouse Entertainment': 4,
#          'Octagon Films': 2,
#          'Birnbaum/Barber': 2,
#          'Bona Fide Productions': 8,
#          'River Road Entertainment': 20,
#          'Road Rebel': 6,
#          'Linson Entertainment': 6,
#          'Rice Films': 2,
#          'Necropia': 6,
#          'Tequila Gang': 6,
#          'Serendipity Productions': 2,
#          'Jerry Weintraub Productions': 9,
#          'China Film Group': 3,
#          'Matador Pictures': 2,
#          'Magic Light Pictures': 2,
#          'Cinema Four': 2,
#          'Runteam Ltd.': 3,
#          'R.P. Productions': 3,
#          'France 2 CinÃ©ma': 16,
#          'FidÃ©litÃ© Films': 4,
#          'Hwy61': 4,
#          'Katalyst Films': 7,
#          'Aversano Films': 1,
#          'Home Box Office (HBO)': 9,
#          'HBO Films': 8,
#          'Oops Doughnuts Productions': 2,
#          'Frontier Pictures': 2,
#          'Three Strange Angels': 11,
#          'United Artists': 21,
#          'New Crime Productions': 4,
#          'Hammer Film Productions': 7,
#          'EFTI': 3,
#          'Overture Films': 5,
#          'Animal Logic': 10,
#          'Cruel and Unusual Films': 17,
#          'Battle Mountain Films': 3,
#          'Village Roadshow Pictures Asia': 5,
#          'PathÃ© Pictures International': 4,
#          'Stone Productions': 1,
#          'Mimran Schur Pictures': 1,
#          'Chako Film Company': 2,
#          'Intellectual Properties Worldwide': 4,
#          'Oceana Media Finance': 1,
#          'Pantheon Entertainment Corporation': 1,
#          'Innocence Productions': 1,
#          'Prescience': 6,
#          'Omega Entertainment': 1,
#          'Twentieth Century Fox': 2,
#          'Mayhem Pictures': 6,
#          'Reliance BIG Entertainment': 11,
#          'Hydraulx': 1,
#          'Rat Entertainment': 7,
#          'Transmission Pictures': 1,
#          'Pioneer Pictures': 2,
#          'Gracie Films': 8,
#          'Robert Simonds Productions': 26,
#          'Spy Next Door': 4,
#          'Mosaic': 5,
#          'Henceforth': 2,
#          'Projection Pictures': 2,
#          'London Boulevard': 2,
#          'American Film Company': 2,
#          'Parabolic Pictures': 4,
#          'Birdsong Pictures': 3,
#          'Penn Station Entertainment': 6,
#          'Lions Gate Family Entertainment': 3,
#          'Crest Animation Productions': 3,
#          'Rhythm and Hues': 2,
#          'Picnic Basket': 2,
#          'Maguire Entertainment': 4,
#          'Omnilab Media': 7,
#          'Ambience Entertainment': 7,
#          'Night Chronicles': 1,
#          'Serendipity Point Films': 4,
#          'Furry Vengeance Productions': 2,
#          'platinum studios': 8,
#          'Long Distance Films': 5,
#          'HighRoad Entertainment': 3,
#          'Prelude Pictures': 3,
#          'Lone Runner Entertainment': 3,
#          'Kenio Films': 3,
#          'Perfect Game, The': 3,
#          'Boram Entertainment Inc.': 3,
#          'Ealing Studios': 3,
#          'Fragile Films': 3,
#          'Quickfire Films': 3,
#          'Lions Gate Films': 51,
#          'The Tyler Perry Company': 6,
#          'PVR Cinemas': 2,
#          'Hari Om Entertainment Co.': 2,
#          'Blockbuster Movie Entertainers': 2,
#          'Fast Track Productions': 1,
#          'The Saul Zaentz Company': 18,
#          'Asymmetrical Productions': 2,
#          'Les Films Alain Sarde': 2,
#          'Babbo Inc.': 2,
#          'The Picture Factory': 2,
#          'Stanley Kubrick Productions': 3,
#          'Pacific Data Images (PDI)': 11,
#          'Little Bird': 7,
#          'NPV Entertainment': 47,
#          'Alphaville Films': 19,
#          'Imhotep Productions': 3,
#          'Walt Disney Feature Animation': 20,
#          'Toho-Towa': 18,
#          'Mutual Film Company': 17,
#          'British Broadcasting Corporation (BBC)': 12,
#          'Liveplanet': 3,
#          'Zide-Perry Productions': 16,
#          'BrownHouse Productions': 3,
#          'Bottom of the Ninth Productions': 3,
#          'Bazmark Films': 6,
#          'Swanford Films': 4,
#          'KC Medien': 4,
#          'Revolution Studios': 66,
#          'Columbia Pictures Corporation': 127,
#          'Black and Blu Entertainment': 3,
#          'Finestkind': 3,
#          'Red Hour Productions': 1,
#          'Neal H. Moritz Productions': 4,
#          'Gold/Miller Productions': 6,
#          'Wayans Bros. Entertainment': 9,
#          'Brad Grey Pictures': 12,
#          'Outlaw Productions (I)': 2,
#          'WV Films II': 3,
#          'Cruise/Wagner Productions': 25,
#          'Canal Plus': 12,
#          'Sogecine': 2,
#          'Las Producciones del Escorpion': 2,
#          'Lucky Red': 7,
#          'Universal Cartoon Studios': 4,
#          'Paramount Animation': 11,
#          'View Askew Productions': 14,
#          'Miramax': 19,
#          'Simon Fields Productions': 1,
#          'Cruise-Wagner Productions': 2,
#          'Current Entertainment': 12,
#          'Immortal Entertainment': 4,
#          'Metropolitan Filmexport': 11,
#          'Red Wagon Productions': 6,
#          'Beacon Communications': 7,
#          'Jonathan Krane Group': 1,
#          'Industry Entertainment': 11,
#          'Epsilon Motion Pictures': 58,
#          'Square USA': 5,
#          'Chris Lee Productions': 6,
#          'American Zoetrope': 13,
#          'Cinerenta Medienbeteiligungs KG': 5,
#          'Cinerenta-Cinebeta': 2,
#          'VCL Communications': 2,
#          'Underworld Entertainment': 2,
#          'AZL Productions KG': 4,
#          'David Brown Productions': 5,
#          'MFP Munich Film Partners': 4,
#          'Phase 1 Productions': 4,
#          'Intermedia Films': 31,
#          'Dee Gee Entertainment': 3,
#          'Prufrock Pictures': 3,
#          'Fireworks Pictures': 2,
#          'USA Films': 3,
#          'Sean S. Cunningham Films': 5,
#          'Crystal Lake Entertainment': 5,
#          'Newmarket Capital Group': 7,
#          'Lawrence Bender Productions': 12,
#          'Pistolero Productions LLC': 2,
#          'Bel Air Entertainment': 12,
#          'IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG': 10,
#          'Kopelson Entertainment': 5,
#          'Bungalow Productions': 5,
#          'Silver Lion Films': 5,
#          'Vision View Entertainment': 5,
#          'American Entertainment Partners L.P.': 1,
#          'David Kirschner Productions': 3,
#          'Franchise Pictures': 37,
#          'Morgan Creek Productions': 35,
#          'Tribeca Productions': 18,
#          'New Redemption Pictures': 2,
#          'GHS Productions KG': 1,
#          'Munich Film Partners & Company (MFP) GHS Productions': 1,
#          'Nides/McCormick Productions': 1,
#          'Horseshoe Bay Productions': 2,
#          'Merlin Films': 4,
#          'Native Pictures Productions': 2,
#          'Darkwoods Productions': 4,
#          'Storm King Productions': 3,
#          'Animationwerks': 3,
#          'Ardustry Entertainment': 9,
#          'Mediastream Film GmbH & Co. Productions KG': 5,
#          'Cort/Madden Productions': 4,
#          'Cheyenne Enterprises': 22,
#          'Empire Pictures': 1,
#          'Hyde Park Entertainment': 8,
#          'Ufland': 1,
#          'Trackform Film Productions': 1,
#          "Mel's Cite du Cinema": 15,
#          'Dino De Laurentiis Company': 9,
#          'Tollin/Robbins Productions': 6,
#          'Crystal Sky Worldwide': 2,
#          'MDP Worldwide': 2,
#          'ApolloMedia Distribution': 3,
#          'Carousel Picture Company, The': 2,
#          'Signature Entertainment': 2,
#          'Dan Films': 3,
#          'CP Medien AG': 3,
#          'TPS Star': 3,
#          'Grive Productions': 8,
#          'Eon Productions': 8,
#          'Internationale Filmproduktion Richter': 2,
#          'Playtone': 10,
#          'Littlestar': 2,
#          'China Film Co-Production Corporation': 16,
#          'Sommers Company, The': 9,
#          'Valhalla Motion Pictures': 12,
#          'MVL Incredible Productions': 3,
#          'Gerber Pictures': 8,
#          'Double Nickel Entertainment': 2,
#          'Dark Horse Entertainment': 14,
#          'Hypnotic': 7,
#          'Kickstart Productions': 1,
#          'Europa Corp': 2,
#          'Achte Babelsberg Film': 1,
#          'The Department of Trade and Industry of South Africa': 2,
#          'Kingsgate Films': 3,
#          'Grosvenor Park Media Ltd.': 13,
#          'Voltage Pictures': 8,
#          'Film Capital Europe Funds (FCEF )': 3,
#          'Stillking Films': 23,
#          'Ozumi Films': 6,
#          'Propeler': 6,
#          'Red Hour Films': 17,
#          'Internationale Filmproduktion Stella-del-Sud Second': 2,
#          'K/O Paper Products': 8,
#          'KMP Film Invest': 3,
#          'Rogue Marble': 3,
#          'Earth Canada Productions': 6,
#          'Hammerhead Productions': 7,
#          'ScreenWest': 1,
#          'Heyday films': 2,
#          'Internationale Filmproduktion Blackbird Erste': 1,
#          'Baumgarten Management and Productions (BMP)': 3,
#          'Wild Bunch': 5,
#          'Top Rope': 2,
#          'MHF Zweite Academy Film': 7,
#          'Marvel Knights': 8,
#          'SGF Entertainment': 3,
#          'Collision Entertainment': 2,
#          'Abandon Entertainment': 2,
#          'Foxtor Productions': 2,
#          'Castel Film Romania': 3,
#          'ASAF': 1,
#          'Luna Pictures': 1,
#          'Kanzaman': 10,
#          'Art In Motion': 2,
#          'Blue Askew': 6,
#          'Internationale Filmproduktion Stella-del-SÃ¼d': 2,
#          'CinÃ©CinÃ©ma': 7,
#          'Babylon': 2,
#          'Blueprint Pictures': 4,
#          'Twins Financing': 4,
#          'The Kennedy/Marshall Company': 10,
#          'Depth of Field': 10,
#          'Type A Films': 9,
#          'Ott Medien': 2,
#          'Alta Loma Entertainment': 3,
#          'Internationale Filmproduktion': 3,
#          'Gravier Productions': 3,
#          'Antena 3 Films': 3,
#          'TelevisiÃ³ de Catalunya (TV3)': 3,
#          'Antena 3 TelevisiÃ³n': 3,
#          'Casey Silver Productions': 7,
#          'Huayi Brothers': 3,
#          'InVenture Entertainment': 2,
#          'Nu-Image Films': 2,
#          'Lietuvos Kinostudija': 1,
#          'Scout Productions': 1,
#          'Castelao Producciones': 3,
#          'Grosvenor Park Productions': 5,
#          'Bedford Falls Company, The': 5,
#          'Defiance Productions': 1,
#          'Pistachio Pictures': 1,
#          'Cohen/Pearl Productions': 1,
#          'Ascendant Pictures': 7,
#          'Rising Star': 19,
#          'VIP Medienfonds 4': 10,
#          'Outlander Productions': 1,
#          'Ten Thirteen Productions': 7,
#          'Crying Box Productions': 7,
#          'Rifkin-Eberts': 1,
#          'Toff Guy Films': 1,
#          'VN Productions': 2,
#          'Virtual Studios': 20,
#          'Initial Entertainment Group': 2,
#          'International Production Company': 9,
#          'Blue Star Pictures': 5,
#          'Odd Lot Entertainment': 5,
#          'Media Magik Entertainment': 6,
#          'Dark Lot Entertainment': 2,
#          'UTV Motion Pictures': 2,
#          'Intrepid Pictures': 11,
#          'South Pacific Pictures': 4,
#          'Spice Factory': 4,
#          'The Australian Film Commission': 4,
#          'Darren Star Productions': 4,
#          'Universal Pictures Corporation': 4,
#          'Neal Street Productions': 12,
#          'Evamere Entertainment': 2,
#          'Michaels-Goldwyn': 2,
#          'Ecosse Films': 8,
#          '2 Entertain': 4,
#          'Guy Walks into a Bar Productions': 3,
#          'Deep River Productions': 6,
#          'Andale Pictures': 1,
#          'IDEA Filmproduktions': 2,
#          'Starz Media': 2,
#          'Odyssey Entertainment': 7,
#          'Studiopolis': 2,
#          'Vanguard Animation': 2,
#          'Art Linson Productions': 7,
#          '3 in the Box': 2,
#          'New Wave Entertainment': 4,
#          'Management 360': 6,
#          'Terra Firma Films': 4,
#          'Superfinger Entertainment': 4,
#          'GreeneStreet Films': 8,
#          'Midnight Picture Show': 4,
#          'Paradox Entertainment': 11,
#          'First Foot Films': 2,
#          'Ixtlan Productions': 1,
#          'Emperor Motion Pictures': 5,
#          'Global Entertainment Group': 1,
#          'Sherazade Film Development': 2,
#          'Corduroy Films': 2,
#          'Exodus Film Group': 1,
#          'Exodus Productions': 1,
#          'Intandem Films': 7,
#          'Aramid Entertainment Fund': 7,
#          'Lipsync Productions': 7,
#          'Motel Movies': 1,
#          'Scared Productions': 2,
#          'Nu Image Entertainment GmbH': 4,
#          'Vendome Pictures': 4,
#          'Film Rites': 13,
#          'Yellow Bird': 6,
#          'Virgin Produced': 10,
#          'Many Rivers Productions': 1,
#          'Boy of the Year': 1,
#          'K/O Camera Toys': 2,
#          'Lennox House Films': 2,
#          'Random Films': 3,
#          'Total Entertainment': 8,
#          'TSBD Canada Productions': 8,
#          'Zohar International': 8,
#          'Fox Searchlight': 8,
#          'Bay Films': 4,
#          'France 3 CinÃ©ma': 3,
#          'La Petite Reine': 2,
#          'Studio 37': 4,
#          'uFilm': 2,
#          'Jouror Productions': 4,
#          'Blind Wink': 1,
#          'Film 4': 2,
#          'Contrafilm': 19,
#          'Hungarian National Film Office': 2,
#          'Lazio Film Commission': 2,
#          'Nouvelles Ã‰ditions de Films (NEF)': 9,
#          'New Legacy': 5,
#          'TOKYOPOP': 1,
#          'Denver and Delilah Productions': 2,
#          'Tailor Made': 1,
#          'Mango Farms': 1,
#          'Gambit Pictures': 3,
#          'Electric Shepherd Productions': 3,
#          'Mark Canton Productions': 5,
#          ...})

# %%
max(mean_words_in_title, key=mean_words_in_title.get)
# Out:
# 'Four By Two Productions'

# %%
mean_words_in_title['Four By Two Productions']
# Out:
# 12.0

# %%
data5[data5.production_companies.str.contains('Four By Two Productions')]['original_title']
# Out:
# 1449    Borat: Cultural Learnings of America for Make ...
# Name: original_title, dtype: object

# %%
answer_ls.append(5)

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
words_in_titles = pd.DataFrame(data3.original_title.str.split(' ').tolist()).stack()
words_in_titles
# Out:
# 0     0    Jurassic
#       1       World
# 1     0         Mad
#       1        Max:
#       2        Fury
#              ...
# 1888  0     Hanging
#       1          Up
# 1889  0         The
#       1          In
#       2       Crowd
# Length: 5138, dtype: object

# %%
words = {}
for item in words_in_titles:
    word = item.lower()
    if word not in words:
        words[word] = 1
    else:
        words[word] += 1
words
# Out:
# {'jurassic': 2,
#  'world': 9,
#  'mad': 1,
#  'max:': 1,
#  'fury': 2,
#  'road': 7,
#  'insurgent': 1,
#  'star': 8,
#  'wars:': 3,
#  'the': 599,
#  'force': 1,
#  'awakens': 1,
#  'furious': 5,
#  '7': 1,
#  'revenant': 1,
#  'terminator': 3,
#  'genisys': 1,
#  'martian': 1,
#  'minions': 1,
#  'inside': 2,
#  'out': 8,
#  'spectre': 1,
#  'jupiter': 1,
#  'ascending': 1,
#  'ex': 1,
#  'machina': 1,
#  'pixels': 1,
#  'avengers:': 1,
#  'age': 5,
#  'of': 185,
#  'ultron': 1,
#  'hateful': 1,
#  'eight': 2,
#  'taken': 3,
#  '3': 16,
#  'ant-man': 1,
#  'cinderella': 3,
#  'hunger': 4,
#  'games:': 3,
#  'mockingjay': 2,
#  '-': 10,
#  'part': 12,
#  '2': 48,
#  'tomorrowland': 1,
#  'southpaw': 1,
#  'san': 1,
#  'andreas': 1,
#  'fifty': 1,
#  'shades': 1,
#  'grey': 2,
#  'big': 16,
#  'short': 1,
#  'mission:': 4,
#  'impossible': 4,
#  'rogue': 1,
#  'nation': 2,
#  'ted': 2,
#  'kingsman:': 1,
#  'secret': 7,
#  'service': 1,
#  'spotlight': 1,
#  'maze': 2,
#  'runner:': 1,
#  'scorch': 1,
#  'trials': 1,
#  'chappie': 1,
#  'pitch': 4,
#  'perfect': 7,
#  'bridge': 2,
#  'spies': 1,
#  'goosebumps': 1,
#  'room': 3,
#  'good': 10,
#  'dinosaur': 2,
#  'run': 4,
#  'all': 7,
#  'night': 14,
#  'brooklyn': 1,
#  'straight': 1,
#  'outta': 1,
#  'compton': 1,
#  'last': 13,
#  'witch': 5,
#  'hunter': 3,
#  'man': 27,
#  'from': 7,
#  'u.n.c.l.e.': 1,
#  'adaline': 1,
#  'hardcore': 1,
#  'henry': 1,
#  'home': 7,
#  'paper': 1,
#  'towns': 1,
#  'carol': 2,
#  'intern': 1,
#  'everest': 1,
#  'point': 3,
#  'break': 1,
#  'burnt': 1,
#  'self/less': 1,
#  'mortdecai': 1,
#  'danish': 1,
#  'girl': 7,
#  'blackhat': 1,
#  'sicario': 1,
#  'fantastic': 3,
#  'four': 6,
#  'spy': 7,
#  'focus': 2,
#  'hitman:': 1,
#  'agent': 3,
#  '47': 2,
#  'in': 46,
#  'heart': 3,
#  'sea': 3,
#  'creed': 1,
#  'trainwreck': 1,
#  'eye': 4,
#  'sky': 4,
#  'legend': 9,
#  'pan': 2,
#  'peanuts': 1,
#  'movie': 19,
#  'concussion': 1,
#  'before': 2,
#  'longest': 2,
#  'ride': 3,
#  'hotel': 6,
#  'transylvania': 2,
#  'love': 16,
#  'coopers': 1,
#  'walk': 7,
#  'vacation': 2,
#  'poltergeist': 1,
#  'child': 1,
#  '44': 1,
#  'gift': 2,
#  "daddy's": 2,
#  'little': 10,
#  'prince': 5,
#  'dressmaker': 1,
#  'duff': 1,
#  'sinister': 1,
#  'paul': 3,
#  'blart:': 2,
#  'mall': 2,
#  'cop': 3,
#  'entourage': 1,
#  'wedding': 7,
#  'ringer': 1,
#  'visit': 1,
#  'black': 13,
#  'mass': 1,
#  'krampus': 1,
#  'no': 6,
#  'escape': 5,
#  'woman': 4,
#  'gold': 2,
#  'sisters': 1,
#  'project': 2,
#  'almanac': 1,
#  'transporter': 4,
#  'refueled': 1,
#  'crimson': 1,
#  'peak': 1,
#  'magic': 2,
#  'mike': 2,
#  'xxl': 1,
#  'paranormal': 4,
#  'activity:': 2,
#  'ghost': 6,
#  'dimension': 1,
#  'trumbo': 1,
#  'their': 1,
#  'eyes': 4,
#  'spongebob': 2,
#  'movie:': 1,
#  'sponge': 1,
#  'water': 6,
#  'max': 3,
#  'gunman': 1,
#  'hot': 2,
#  'pursuit': 2,
#  'insidious:': 1,
#  'chapter': 1,
#  'lady': 3,
#  'van': 3,
#  'victor': 1,
#  'frankenstein': 2,
#  'ricki': 1,
#  'and': 48,
#  'flash': 1,
#  'guy': 3,
#  'while': 1,
#  "we're": 1,
#  'young': 4,
#  'get': 7,
#  'hard': 3,
#  'suffragette': 1,
#  'we': 9,
#  'are': 3,
#  'your': 6,
#  'friends': 3,
#  'boy': 8,
#  'aloha': 1,
#  'our': 4,
#  'brand': 1,
#  'is': 7,
#  'crisis': 1,
#  'rock': 5,
#  'kasbah': 1,
#  'a': 59,
#  'woods': 3,
#  'unfinished': 2,
#  'business': 2,
#  'or': 4,
#  'white': 8,
#  'jem': 1,
#  'holograms': 1,
#  'interstellar': 1,
#  'guardians': 2,
#  'galaxy': 2,
#  'captain': 4,
#  'america:': 3,
#  'winter': 1,
#  'soldier': 1,
#  'john': 5,
#  'wick': 1,
#  '1': 5,
#  'hobbit:': 3,
#  'battle': 3,
#  'five': 2,
#  'armies': 1,
#  'hero': 1,
#  '6': 2,
#  'imitation': 1,
#  'game': 10,
#  'runner': 4,
#  'birdman': 1,
#  'gone': 4,
#  'at': 8,
#  'museum:': 2,
#  'tomb': 4,
#  'divergent': 1,
#  'x-men:': 3,
#  'days': 9,
#  'future': 1,
#  'past': 1,
#  'lucy': 1,
#  'teenage': 2,
#  'mutant': 2,
#  'ninja': 2,
#  'turtles': 1,
#  'sex': 3,
#  'tape': 1,
#  'nightcrawler': 1,
#  'transformers:': 3,
#  'extinction': 2,
#  'grand': 2,
#  'budapest': 1,
#  'dawn': 7,
#  'planet': 7,
#  'apes': 3,
#  'equalizer': 1,
#  'horrible': 2,
#  'bosses': 2,
#  'amazing': 2,
#  'spider-man': 5,
#  'edge': 3,
#  'tomorrow': 3,
#  'interview': 1,
#  'american': 9,
#  'sniper': 1,
#  'exodus:': 1,
#  'gods': 2,
#  'kings': 2,
#  'godzilla': 1,
#  'maleficent': 1,
#  'november': 2,
#  'ouija': 1,
#  'how': 8,
#  'to': 32,
#  'train': 3,
#  'dragon': 6,
#  'expendables': 3,
#  'lego': 1,
#  'seventh': 1,
#  'son': 3,
#  'theory': 1,
#  'everything': 3,
#  "let's": 1,
#  'be': 6,
#  'cops': 1,
#  'dracula': 2,
#  'untold': 1,
#  'penguins': 1,
#  'madagascar': 3,
#  'into': 6,
#  '300:': 1,
#  'rise': 7,
#  'an': 6,
#  'empire': 3,
#  'giver': 1,
#  '22': 1,
#  'jump': 2,
#  'street': 7,
#  'among': 1,
#  'tombstones': 1,
#  'paddington': 1,
#  'cake': 1,
#  'chef': 1,
#  'purge:': 1,
#  'anarchy': 1,
#  'left': 1,
#  'behind': 3,
#  'most': 3,
#  'violent': 1,
#  'year': 8,
#  'hercules': 2,
#  'noah': 1,
#  'judge': 1,
#  'blended': 1,
#  'neighbors': 1,
#  'if': 3,
#  'i': 19,
#  'stay': 3,
#  'step': 6,
#  'up': 11,
#  'fault': 1,
#  'stars': 1,
#  'along': 3,
#  'inherent': 1,
#  'vice': 2,
#  'jack': 4,
#  'ryan:': 1,
#  'shadow': 1,
#  'recruit': 1,
#  'non-stop': 1,
#  'predestination': 1,
#  'robocop': 1,
#  'transcendence': 1,
#  'other': 3,
#  'mr.': 9,
#  'peabody': 1,
#  '&': 38,
#  'sherman': 1,
#  'sin': 3,
#  'city:': 1,
#  'dame': 1,
#  'kill': 5,
#  'for': 15,
#  'rio': 2,
#  'dumb': 2,
#  'dumber': 1,
#  'monuments': 1,
#  'men': 10,
#  'unbroken': 1,
#  'selma': 1,
#  'pompeii': 1,
#  'best': 4,
#  'me': 16,
#  'annie': 1,
#  'st.': 2,
#  'vincent': 1,
#  'need': 1,
#  'speed': 2,
#  'hundred-foot': 1,
#  'journey': 4,
#  'boxtrolls': 1,
#  'storm': 2,
#  'planes:': 1,
#  'fire': 8,
#  'rescue': 2,
#  'sabotage': 1,
#  'deed': 1,
#  'as': 2,
#  'above,': 1,
#  'so': 1,
#  'below': 2,
#  'foxcatcher': 1,
#  'endless': 1,
#  'rover': 1,
#  'suite': 1,
#  'franã§aise': 1,
#  'annabelle': 1,
#  'i,': 2,
#  'that': 3,
#  'awkward': 1,
#  'moment': 1,
#  'brick': 1,
#  'mansions': 1,
#  'tammy': 1,
#  "winter's": 1,
#  'tale': 7,
#  'guest': 1,
#  'diviner': 1,
#  'alexander': 2,
#  'terrible,': 1,
#  'horrible,': 1,
#  'good,': 1,
#  'very': 2,
#  'bad': 8,
#  'day': 14,
#  'this': 4,
#  'where': 2,
#  'leave': 1,
#  'you': 13,
#  'about': 6,
#  'million': 2,
#  'dollar': 2,
#  'arm': 1,
#  'under': 1,
#  'skin': 1,
#  'veronica': 1,
#  'mars': 4,
#  'god': 1,
#  'when': 5,
#  'stands': 1,
#  'tall': 1,
#  'pyramid': 1,
#  'messenger': 1,
#  'dolphin': 2,
#  'muppets': 2,
#  'wanted': 3,
#  'heaven': 4,
#  'real': 3,
#  "moms'": 1,
#  'earth': 6,
#  'echo': 1,
#  'gambler': 1,
#  'seduction': 1,
#  "god's": 1,
#  'not': 4,
#  'dead': 9,
#  "devil's": 2,
#  'due': 2,
#  'avatar': 1,
#  'inglourious': 1,
#  'basterds': 1,
#  'underworld:': 3,
#  'lycans': 1,
#  'harry': 10,
#  'potter': 9,
#  'half-blood': 1,
#  'trek': 2,
#  'salvation': 1,
#  'district': 1,
#  '9': 2,
#  'sherlock': 2,
#  'holmes': 1,
#  '(500)': 1,
#  'summer': 2,
#  'hangover': 3,
#  'watchmen': 1,
#  '2012': 1,
#  'angels': 2,
#  'demons': 1,
#  'princess': 3,
#  'frog': 1,
#  'blind': 1,
#  'side': 3,
#  'zombieland': 1,
#  'twilight': 5,
#  'saga:': 4,
#  'new': 6,
#  'moon': 3,
#  "he's": 1,
#  'just': 6,
#  'g.i.': 1,
#  'joe:': 1,
#  'cobra': 1,
#  'proposal': 1,
#  'ugly': 2,
#  'truth': 1,
#  'cloudy': 2,
#  'with': 14,
#  'chance': 2,
#  'meatballs': 2,
#  'fox': 1,
#  'coraline': 1,
#  'smithsonian': 1,
#  '17': 1,
#  'again': 3,
#  'christmas': 4,
#  'lovely': 1,
#  'bones': 3,
#  'hachi:': 1,
#  "dog's": 1,
#  'law': 1,
#  'abiding': 1,
#  'citizen': 1,
#  'box': 1,
#  'crank:': 1,
#  'high': 5,
#  'voltage': 1,
#  'pandorum': 1,
#  'drag': 1,
#  'hell': 2,
#  'knowing': 1,
#  'g-force': 1,
#  'taking': 2,
#  'pelham': 1,
#  'invention': 1,
#  'lying': 1,
#  'confessions': 3,
#  'shopaholic': 1,
#  'gamer': 1,
#  'nobody': 1,
#  'couples': 1,
#  'retreat': 1,
#  'brothers': 5,
#  'monsters': 3,
#  'vs': 1,
#  'aliens': 3,
#  'julie': 1,
#  'julia': 1,
#  'chloe': 1,
#  'public': 1,
#  'enemies': 1,
#  "jennifer's": 1,
#  'body': 2,
#  'orphan': 1,
#  'steve': 2,
#  'final': 6,
#  'destination': 6,
#  'alvin': 3,
#  'chipmunks:': 2,
#  'squeakquel': 1,
#  'bride': 2,
#  'wars': 1,
#  'precious': 1,
#  'state': 3,
#  'play': 1,
#  'unborn': 1,
#  'you,': 2,
#  'informant!': 1,
#  'race': 3,
#  'mountain': 3,
#  'case': 2,
#  '39': 1,
#  'boat': 2,
#  'rocked': 1,
#  'daybreakers': 1,
#  'happens': 2,
#  'push': 1,
#  "brooklyn's": 1,
#  'finest': 1,
#  'saw': 5,
#  'vi': 1,
#  'victoria': 1,
#  'serious': 1,
#  'getaway': 2,
#  'whiteout': 1,
#  'phillip': 1,
#  'morris': 1,
#  '12': 2,
#  'rounds': 1,
#  'idiots': 1,
#  'revenge': 3,
#  'fallen': 2,
#  'who': 4,
#  'stare': 1,
#  'goats': 1,
#  'assassin': 1,
#  'bandslam': 1,
#  "it's": 1,
#  'complicated': 1,
#  'land': 5,
#  'lost': 5,
#  'invictus': 1,
#  '51': 1,
#  'one': 4,
#  'my': 13,
#  'bloody': 1,
#  'valentine': 1,
#  'old': 4,
#  'dogs': 5,
#  'agora': 1,
#  'boondock': 1,
#  'saints': 2,
#  'ii:': 3,
#  'lieutenant:': 1,
#  'port': 1,
#  'call': 2,
#  'orleans': 1,
#  'armored': 1,
#  'cirque': 1,
#  'du': 1,
#  'freak:': 1,
#  "vampire's": 1,
#  'assistant': 1,
#  'education': 1,
#  'funny': 2,
#  'people': 4,
#  'air': 1,
#  'astro': 1,
#  'international': 1,
#  'fast': 6,
#  'capitalism:': 1,
#  'story': 7,
#  'halloween': 2,
#  'ii': 10,
#  'hannah': 1,
#  'montana:': 1,
#  'attic': 1,
#  'fourth': 1,
#  'kind': 1,
#  'solitary': 1,
#  'duplicity': 1,
#  'bright': 1,
#  'adventureland': 1,
#  'extract': 1,
#  'life': 11,
#  'ruins': 1,
#  "sister's": 1,
#  'keeper': 1,
#  'soloist': 1,
#  'friday': 5,
#  '13th': 1,
#  'brown': 1,
#  'surrogates': 1,
#  'fighter:': 1,
#  'chun-li': 1,
#  'obsessed': 1,
#  'solomon': 1,
#  'kane': 1,
#  'x-men': 2,
#  'origins:': 1,
#  'wolverine': 2,
#  'town': 2,
#  'orson': 1,
#  'welles': 1,
#  'shorts': 1,
#  'sorority': 1,
#  'row': 1,
#  'joneses': 1,
#  'post': 1,
#  'grad': 1,
#  'crazy': 1,
#  'did': 3,
#  'hear': 1,
#  'morgans?': 1,
#  'grudge': 4,
#  "mao's": 1,
#  'dancer': 2,
#  'inception': 1,
#  'iron': 4,
#  'alice': 1,
#  'wonderland': 2,
#  'swan': 1,
#  'deathly': 2,
#  'hallows:': 2,
#  'despicable': 2,
#  'shutter': 1,
#  'island': 5,
#  'tron:': 1,
#  'legacy': 2,
#  'tangled': 1,
#  'toy': 1,
#  'salt': 1,
#  '127': 1,
#  'hours': 2,
#  'easy': 1,
#  'chronicles': 6,
#  'narnia:': 3,
#  'voyage': 1,
#  'treader': 1,
#  'kick-ass': 1,
#  'tourist': 1,
#  'persia:': 1,
#  'sands': 1,
#  'time': 7,
#  'robin': 1,
#  'hood': 3,
#  'true': 3,
#  'grit': 1,
#  'clash': 1,
#  'titans': 3,
#  "sorcerer's": 1,
#  'apprentice': 1,
#  'social': 1,
#  'network': 1,
#  'scott': 1,
#  'pilgrim': 1,
#  'vs.': 4,
#  'fockers': 2,
#  'predators': 1,
#  'percy': 2,
#  'jackson': 1,
#  'olympians:': 1,
#  'lightning': 1,
#  'thief': 2,
#  'unstoppable': 1,
#  'shrek': 4,
#  'forever': 1,
#  'after': 5,
#  'dear': 1,
#  'a-team': 1,
#  'red': 7,
#  'machete': 2,
#  'grown': 2,
#  'ups': 2,
#  'book': 4,
#  'eli': 1,
#  'date': 4,
#  'eclipse': 1,
#  'megamind': 1,
#  'airbender': 1,
#  'guys': 2,
#  '3d': 5,
#  "king's": 2,
#  'speech': 1,
#  'drugs': 1,
#  'way': 2,
#  'back': 5,
#  'repo': 1,
#  'knight': 3,
#  'eat': 1,
#  'pray': 1,
#  'bounty': 1,
#  'leap': 1,
#  'green': 3,
#  'zone': 2,
#  "gulliver's": 1,
#  'travels': 1,
#  'back-up': 1,
#  'plan': 3,
#  'charlie': 3,
#  'cloud': 2,
#  'switch': 1,
#  'runaways': 1,
#  "valentine's": 1,
#  "don't": 4,
#  'afraid': 1,
#  'dark': 11,
#  'karate': 1,
#  'kid': 4,
#  'wild': 3,
#  'target': 1,
#  'writer': 1,
#  'next': 6,
#  'three': 4,
#  'nightmare': 1,
#  'on': 12,
#  'elm': 1,
#  'fighter': 1,
#  'him': 1,
#  'greek': 2,
#  'jonah': 1,
#  'hex': 1,
#  'vampires': 1,
#  'suck': 1,
#  'killers': 1,
#  'legion': 2,
#  'city': 7,
#  'nanny': 3,
#  'mcphee': 2,
#  'bang': 1,
#  'tub': 1,
#  'machine': 3,
#  'let': 2,
#  'guardians:': 1,
#  'owls': 1,
#  "ga'hoole": 1,
#  'takers': 1,
#  'burlesque': 1,
#  'company': 2,
#  'going': 2,
#  'distance': 1,
#  'never': 8,
#  'go': 4,
#  'know': 4,
#  'it': 6,
#  'centurion': 1,
#  'stone': 2,
#  'diary': 5,
#  'wimpy': 3,
#  'piranha': 2,
#  'morning': 1,
#  'glory': 2,
#  'conviction': 1,
#  'tooth': 1,
#  'fairy': 1,
#  'fair': 2,
#  'dinner': 1,
#  'schmucks': 1,
#  'skyline': 1,
#  'debt': 1,
#  'cats': 2,
#  ':': 1,
#  'kitty': 1,
#  'galore': 1,
#  'macgruber': 1,
#  'do': 1,
#  'door': 2,
#  "she's": 2,
#  'league': 2,
#  'london': 2,
#  'boulevard': 1,
#  'hereafter': 1,
#  'soul': 2,
#  'take': 3,
#  'conspirator': 1,
#  'death': 3,
#  'funeral': 1,
#  'marmaduke': 1,
#  'wall': 2,
#  'street:': 1,
#  'money': 3,
#  'sleeps': 1,
#  'must': 4,
#  'crazies': 1,
#  'alpha': 1,
#  'omega': 1,
#  'yogi': 1,
#  'bear': 1,
#  'country': 3,
#  'strong': 1,
#  'tomorrow,': 1,
#  'war': 10,
#  'began': 1,
#  'extraordinary': 2,
#  'measures': 1,
#  'devil': 3,
#  "barney's": 1,
#  'version': 1,
#  'darkness': 2,
#  'furry': 1,
#  'vengeance': 2,
#  'dylan': 1,
#  'dog:': 1,
#  "warrior's": 1,
#  'burke': 1,
#  'hare': 1,
#  'why': 2,
#  'married': 2,
#  'too?': 1,
#  'resident': 5,
#  'evil:': 4,
#  'afterlife': 1,
#  'action': 2,
#  'replayy': 1,
#  'secretariat': 1,
#  'lord': 4,
#  'rings:': 3,
#  'fellowship': 1,
#  'ring': 3,
#  "philosopher's": 1,
#  'mulholland': 1,
#  'drive': 3,
#  'monsters,': 1,
#  'inc.': 1,
#  'a.i.': 1,
#  'artificial': 1,
#  'intelligence': 1,
#  'bridget': 2,
#  "jones's": 1,
#  "ocean's": 3,
#  'eleven': 1,
#  'pearl': 2,
#  'harbor': 1,
#  'mummy': 1,
#  'returns': 1,
#  'atlantis:': 1,
#  'lara': 2,
#  'croft:': 1,
#  'raider': 1,
#  'beautiful': 1,
#  'mind': 3,
#  'pie': 1,
#  'diaries': 3,
#  'moulin': 1,
#  'rouge!': 1,
#  'royal': 2,
#  'tenenbaums': 1,
#  'blow': 1,
#  'enemy': 2,
#  'gates': 1,
#  'hawk': 1,
#  'down': 7,
#  'legally': 2,
#  'blonde': 3,
#  "knight's": 1,
#  'zoolander': 1,
#  'another': 2,
#  'teen': 1,
#  'scary': 5,
#  'rush': 5,
#  'hour': 4,
#  'training': 1,
#  'others': 1,
#  'jimmy': 1,
#  'neutron:': 1,
#  'genius': 1,
#  'jay': 1,
#  'silent': 3,
#  'bob': 1,
#  'strike': 1,
#  'serendipity': 1,
#  'vanilla': 1,
#  'kiss': 1,
#  'swordfish': 1,
#  'shallow': 1,
#  'hal': 1,
#  'antitrust': 1,
#  'fantasy:': 1,
#  'spirits': 1,
#  'within': 1,
#  'original': 1,
#  'dr.': 1,
#  'dolittle': 1,
#  'lines': 1,
#  'jeepers': 2,
#  'creepers': 2,
#  'castle': 2,
#  'came': 2,
#  'spider': 1,
#  'planner': 1,
#  'rat': 1,
#  'gosford': 1,
#  'park': 3,
#  'jason': 2,
#  'x': 3,
#  'mexican': 1,
#  'joy': 1,
#  'am': 3,
#  'sam': 1,
#  'k-pax': 1,
#  'say': 2,
#  'word': 1,
#  'crocodile': 1,
#  'dundee': 1,
#  'los': 2,
#  'angeles': 2,
#  'frailty': 1,
#  'angel': 1,
#  'hearts': 1,
#  'atlantis': 1,
#  'glass': 1,
#  'house': 13,
#  '15': 1,
#  'minutes': 3,
#  'hardball': 1,
#  'evolution': 2,
#  'ali': 1,
#  'score': 1,
#  'joe': 2,
#  'dirt': 1,
#  'exit': 1,
#  'wounds': 1,
#  'tailor': 1,
#  'panama': 1,
#  'sweet': 2,
#  'tomcats': 1,
#  'majestic': 1,
#  '3000': 2,
#  'miles': 1,
#  'graceland': 1,
#  'ghosts': 2,
#  'saving': 2,
#  'silverman': 1,
#  'riding': 2,
#  'cars': 3,
#  'boys': 3,
#  'osmosis': 1,
#  'jones': 2,
#  'head': 2,
#  'over': 5,
#  'heels': 1,
#  'save': 1,
#  'dance': 1,
#  'kids': 3,
#  'bandits': 1,
#  'animal': 1,
#  'knockaround': 1,
#  'crazy/beautiful': 1,
#  'driven': 1,
#  'cold': 3,
#  'outlaws': 1,
#  'hannibal': 2,
#  'domestic': 1,
#  'disturbance': 1,
#  'catch': 3,
#  "keeble's": 1,
#  'move': 1,
#  'monkeybone': 1,
#  'corky': 1,
#  'romano': 1,
#  'iii': 5,
#  'musketeer': 1,
#  "cat's": 1,
#  'meow': 1,
#  'sugar': 1,
#  'spice': 1,
#  'wash': 1,
#  'baby': 4,
#  'wallâ·e': 1,
#  'indiana': 1,
#  'kingdom': 5,
#  'crystal': 1,
#  ...}

# %%
len(words)
# Out:
# 2462

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
data5[data5.vote_average >= data5.vote_average.nlargest(len(data5)//100).min()].original_title.tolist()
# Out:
# ['Inside Out',
#  'Spotlight',
#  'Room',
#  'Interstellar',
#  'Guardians of the Galaxy',
#  'Big Hero 6',
#  'The Imitation Game',
#  'Gone Girl',
#  'The Grand Budapest Hotel',
#  'The Theory of Everything',
#  'The Fault in Our Stars',
#  'Mr. Nobody',
#  '3 Idiots',
#  'Inception',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Dark Knight',
#  'The Lord of the Rings: The Two Towers',
#  'The Pianist',
#  'The Lord of the Rings: The Return of the King',
#  'The Wolf of Wall Street',
#  'Her',
#  '12 Years a Slave',
#  'Prisoners',
#  'Dallas Buyers Club',
#  'The Prestige',
#  'Eternal Sunshine of the Spotless Mind',
#  'There Will Be Blood',
#  'Memento']

# %%
data5[data5['vote_average'] > data5.quantile(0.99, numeric_only=True)['vote_average']].original_title.tolist()
# Out:
# ['Inside Out',
#  'Room',
#  'Interstellar',
#  'Guardians of the Galaxy',
#  'The Imitation Game',
#  'Gone Girl',
#  'The Grand Budapest Hotel',
#  'Inception',
#  'The Dark Knight',
#  'The Pianist',
#  'The Lord of the Rings: The Return of the King',
#  'The Wolf of Wall Street',
#  '12 Years a Slave',
#  'Memento']

# %%
data5.iloc[6]
# Out:
# imdb_id                                                         tt1340138
# popularity                                                        8.65436
# budget                                                          155000000
# revenue                                                         440603537
# original_title                                         Terminator Genisys
# cast                    Arnold Schwarzenegger|Jason Clarke|Emilia Clar...
# director                                                      Alan Taylor
# tagline                                                  Reset the future
# overview                The year is 2029. John Connor, leader of the r...
# runtime                                                               125
# genres                          Science Fiction|Action|Thriller|Adventure
# production_companies              Paramount Pictures|Skydance Productions
# release_date                                                    6/23/2015
# vote_count                                                           2598
# vote_average                                                          5.8
# release_year                                                         2015
# profit                                                          285603537
# month                                                                   6
# title_lenght                                                           18
# number_of_words                                                         2
# Name: 6, dtype: object

# %%
answer_ls.append(1)

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
def pairs_of_items(string, pairs_list, separator):
    temp = string.split(separator)
    if separator not in string:
        return pairs_list
    for i in range(0, len(temp)):
        for j in range(i + 1, len(temp)):
            pair = temp[i] + ' & ' + temp[j]
            if (pair) in pairs_list:
                pairs_list[pair] += 1
            else:
                pairs_list[pair] = 1
    return pairs_list

actors = 'Arnold Schwarzenegger|Jason Clarke|Emilia Clar'
pairs = {}
pairs = pairs_of_items(actors, pairs, '|')
pairs
# Out:
# {'Arnold Schwarzenegger & Jason Clarke': 1,
#  'Arnold Schwarzenegger & Emilia Clar': 1,
#  'Jason Clarke & Emilia Clar': 1}

# %%
a = 'Arnold Schwarzenegger|Jason Clarke|Emilia Clar'.split('|')
a
# Out:
# ['Arnold Schwarzenegger', 'Jason Clarke', 'Emilia Clar']

# %%
pairs = {}
for item in data5.cast:
    pairs = pairs_of_items(item, pairs, '|')
pairs
# Out:
# {'Chris Pratt & Bryce Dallas Howard': 1,
#  'Chris Pratt & Irrfan Khan': 1,
#  "Chris Pratt & Vincent D'Onofrio": 1,
#  'Chris Pratt & Nick Robinson': 1,
#  'Bryce Dallas Howard & Irrfan Khan': 1,
#  "Bryce Dallas Howard & Vincent D'Onofrio": 1,
#  'Bryce Dallas Howard & Nick Robinson': 1,
#  "Irrfan Khan & Vincent D'Onofrio": 1,
#  'Irrfan Khan & Nick Robinson': 1,
#  "Vincent D'Onofrio & Nick Robinson": 1,
#  'Tom Hardy & Charlize Theron': 1,
#  'Tom Hardy & Hugh Keays-Byrne': 1,
#  'Tom Hardy & Nicholas Hoult': 1,
#  'Tom Hardy & Josh Helman': 1,
#  'Charlize Theron & Hugh Keays-Byrne': 1,
#  'Charlize Theron & Nicholas Hoult': 1,
#  'Charlize Theron & Josh Helman': 1,
#  'Hugh Keays-Byrne & Nicholas Hoult': 1,
#  'Hugh Keays-Byrne & Josh Helman': 1,
#  'Nicholas Hoult & Josh Helman': 1,
#  'Shailene Woodley & Theo James': 2,
#  'Shailene Woodley & Kate Winslet': 2,
#  'Shailene Woodley & Ansel Elgort': 2,
#  'Shailene Woodley & Miles Teller': 2,
#  'Theo James & Kate Winslet': 2,
#  'Theo James & Ansel Elgort': 1,
#  'Theo James & Miles Teller': 2,
#  'Kate Winslet & Ansel Elgort': 1,
#  'Kate Winslet & Miles Teller': 2,
#  'Ansel Elgort & Miles Teller': 1,
#  'Harrison Ford & Mark Hamill': 1,
#  'Harrison Ford & Carrie Fisher': 1,
#  'Harrison Ford & Adam Driver': 1,
#  'Harrison Ford & Daisy Ridley': 1,
#  'Mark Hamill & Carrie Fisher': 1,
#  'Mark Hamill & Adam Driver': 1,
#  'Mark Hamill & Daisy Ridley': 1,
#  'Carrie Fisher & Adam Driver': 1,
#  'Carrie Fisher & Daisy Ridley': 1,
#  'Adam Driver & Daisy Ridley': 1,
#  'Vin Diesel & Paul Walker': 3,
#  'Vin Diesel & Jason Statham': 1,
#  'Vin Diesel & Michelle Rodriguez': 3,
#  'Vin Diesel & Dwayne Johnson': 3,
#  'Paul Walker & Jason Statham': 1,
#  'Paul Walker & Michelle Rodriguez': 3,
#  'Paul Walker & Dwayne Johnson': 3,
#  'Jason Statham & Michelle Rodriguez': 1,
#  'Jason Statham & Dwayne Johnson': 1,
#  'Michelle Rodriguez & Dwayne Johnson': 1,
#  'Leonardo DiCaprio & Tom Hardy': 2,
#  'Leonardo DiCaprio & Will Poulter': 1,
#  'Leonardo DiCaprio & Domhnall Gleeson': 1,
#  'Leonardo DiCaprio & Paul Anderson': 1,
#  'Tom Hardy & Will Poulter': 1,
#  'Tom Hardy & Domhnall Gleeson': 1,
#  'Tom Hardy & Paul Anderson': 1,
#  'Will Poulter & Domhnall Gleeson': 1,
#  'Will Poulter & Paul Anderson': 1,
#  'Domhnall Gleeson & Paul Anderson': 1,
#  'Arnold Schwarzenegger & Jason Clarke': 1,
#  'Arnold Schwarzenegger & Emilia Clarke': 1,
#  'Arnold Schwarzenegger & Jai Courtney': 1,
#  'Arnold Schwarzenegger & J.K. Simmons': 1,
#  'Jason Clarke & Emilia Clarke': 1,
#  'Jason Clarke & Jai Courtney': 1,
#  'Jason Clarke & J.K. Simmons': 1,
#  'Emilia Clarke & Jai Courtney': 1,
#  'Emilia Clarke & J.K. Simmons': 1,
#  'Jai Courtney & J.K. Simmons': 1,
#  'Matt Damon & Jessica Chastain': 1,
#  'Matt Damon & Kristen Wiig': 1,
#  'Matt Damon & Jeff Daniels': 1,
#  'Matt Damon & Michael PeÃ±a': 1,
#  'Jessica Chastain & Kristen Wiig': 1,
#  'Jessica Chastain & Jeff Daniels': 1,
#  'Jessica Chastain & Michael PeÃ±a': 1,
#  'Kristen Wiig & Jeff Daniels': 1,
#  'Kristen Wiig & Michael PeÃ±a': 1,
#  'Jeff Daniels & Michael PeÃ±a': 1,
#  'Sandra Bullock & Jon Hamm': 1,
#  'Sandra Bullock & Michael Keaton': 1,
#  'Sandra Bullock & Allison Janney': 1,
#  'Sandra Bullock & Steve Coogan': 1,
#  'Jon Hamm & Michael Keaton': 1,
#  'Jon Hamm & Allison Janney': 1,
#  'Jon Hamm & Steve Coogan': 1,
#  'Michael Keaton & Allison Janney': 1,
#  'Michael Keaton & Steve Coogan': 1,
#  'Allison Janney & Steve Coogan': 1,
#  'Amy Poehler & Phyllis Smith': 1,
#  'Amy Poehler & Richard Kind': 1,
#  'Amy Poehler & Bill Hader': 1,
#  'Amy Poehler & Lewis Black': 1,
#  'Phyllis Smith & Richard Kind': 1,
#  'Phyllis Smith & Bill Hader': 1,
#  'Phyllis Smith & Lewis Black': 1,
#  'Richard Kind & Bill Hader': 1,
#  'Richard Kind & Lewis Black': 1,
#  'Bill Hader & Lewis Black': 1,
#  'Daniel Craig & Christoph Waltz': 1,
#  'Daniel Craig & LÃ©a Seydoux': 1,
#  'Daniel Craig & Ralph Fiennes': 2,
#  'Daniel Craig & Monica Bellucci': 1,
#  'Christoph Waltz & LÃ©a Seydoux': 1,
#  'Christoph Waltz & Ralph Fiennes': 1,
#  'Christoph Waltz & Monica Bellucci': 1,
#  'LÃ©a Seydoux & Ralph Fiennes': 1,
#  'LÃ©a Seydoux & Monica Bellucci': 1,
#  'Ralph Fiennes & Monica Bellucci': 1,
#  'Mila Kunis & Channing Tatum': 1,
#  'Mila Kunis & Sean Bean': 1,
#  'Mila Kunis & Eddie Redmayne': 1,
#  'Mila Kunis & Douglas Booth': 1,
#  'Channing Tatum & Sean Bean': 1,
#  'Channing Tatum & Eddie Redmayne': 1,
#  'Channing Tatum & Douglas Booth': 1,
#  'Sean Bean & Eddie Redmayne': 1,
#  'Sean Bean & Douglas Booth': 1,
#  'Eddie Redmayne & Douglas Booth': 1,
#  'Domhnall Gleeson & Alicia Vikander': 1,
#  'Domhnall Gleeson & Oscar Isaac': 1,
#  'Domhnall Gleeson & Sonoya Mizuno': 1,
#  'Domhnall Gleeson & Corey Johnson': 1,
#  'Alicia Vikander & Oscar Isaac': 1,
#  'Alicia Vikander & Sonoya Mizuno': 1,
#  'Alicia Vikander & Corey Johnson': 1,
#  'Oscar Isaac & Sonoya Mizuno': 1,
#  'Oscar Isaac & Corey Johnson': 1,
#  'Sonoya Mizuno & Corey Johnson': 1,
#  'Adam Sandler & Michelle Monaghan': 1,
#  'Adam Sandler & Peter Dinklage': 1,
#  'Adam Sandler & Josh Gad': 1,
#  'Adam Sandler & Kevin James': 5,
#  'Michelle Monaghan & Peter Dinklage': 1,
#  'Michelle Monaghan & Josh Gad': 1,
#  'Michelle Monaghan & Kevin James': 1,
#  'Peter Dinklage & Josh Gad': 1,
#  'Peter Dinklage & Kevin James': 1,
#  'Josh Gad & Kevin James': 1,
#  'Robert Downey Jr. & Chris Hemsworth': 2,
#  'Robert Downey Jr. & Mark Ruffalo': 3,
#  'Robert Downey Jr. & Chris Evans': 2,
#  'Robert Downey Jr. & Scarlett Johansson': 3,
#  'Chris Hemsworth & Mark Ruffalo': 1,
#  'Chris Hemsworth & Chris Evans': 1,
#  'Chris Hemsworth & Scarlett Johansson': 2,
#  'Mark Ruffalo & Chris Evans': 1,
#  'Mark Ruffalo & Scarlett Johansson': 2,
#  'Chris Evans & Scarlett Johansson': 3,
#  'Samuel L. Jackson & Kurt Russell': 1,
#  'Samuel L. Jackson & Jennifer Jason Leigh': 1,
#  'Samuel L. Jackson & Walton Goggins': 1,
#  'Samuel L. Jackson & DemiÃ¡n Bichir': 1,
#  'Kurt Russell & Jennifer Jason Leigh': 1,
#  'Kurt Russell & Walton Goggins': 1,
#  'Kurt Russell & DemiÃ¡n Bichir': 1,
#  'Jennifer Jason Leigh & Walton Goggins': 1,
#  'Jennifer Jason Leigh & DemiÃ¡n Bichir': 1,
#  'Walton Goggins & DemiÃ¡n Bichir': 1,
#  'Liam Neeson & Forest Whitaker': 1,
#  'Liam Neeson & Maggie Grace': 3,
#  'Liam Neeson & Famke Janssen': 3,
#  'Liam Neeson & Dougray Scott': 1,
#  'Forest Whitaker & Maggie Grace': 1,
#  'Forest Whitaker & Famke Janssen': 1,
#  'Forest Whitaker & Dougray Scott': 1,
#  'Maggie Grace & Famke Janssen': 2,
#  'Maggie Grace & Dougray Scott': 1,
#  'Famke Janssen & Dougray Scott': 1,
#  'Paul Rudd & Michael Douglas': 1,
#  'Paul Rudd & Evangeline Lilly': 1,
#  'Paul Rudd & Corey Stoll': 1,
#  'Paul Rudd & Bobby Cannavale': 1,
#  'Michael Douglas & Evangeline Lilly': 1,
#  'Michael Douglas & Corey Stoll': 1,
#  'Michael Douglas & Bobby Cannavale': 1,
#  'Evangeline Lilly & Corey Stoll': 1,
#  'Evangeline Lilly & Bobby Cannavale': 1,
#  'Corey Stoll & Bobby Cannavale': 1,
#  'Lily James & Cate Blanchett': 1,
#  'Lily James & Richard Madden': 1,
#  'Lily James & Helena Bonham Carter': 1,
#  'Lily James & Holliday Grainger': 1,
#  'Cate Blanchett & Richard Madden': 1,
#  'Cate Blanchett & Helena Bonham Carter': 1,
#  'Cate Blanchett & Holliday Grainger': 1,
#  'Richard Madden & Helena Bonham Carter': 1,
#  'Richard Madden & Holliday Grainger': 1,
#  'Helena Bonham Carter & Holliday Grainger': 1,
#  'Jennifer Lawrence & Josh Hutcherson': 4,
#  'Jennifer Lawrence & Liam Hemsworth': 4,
#  'Jennifer Lawrence & Woody Harrelson': 4,
#  'Jennifer Lawrence & Elizabeth Banks': 3,
#  'Josh Hutcherson & Liam Hemsworth': 4,
#  'Josh Hutcherson & Woody Harrelson': 4,
#  'Josh Hutcherson & Elizabeth Banks': 3,
#  'Liam Hemsworth & Woody Harrelson': 4,
#  'Liam Hemsworth & Elizabeth Banks': 3,
#  'Woody Harrelson & Elizabeth Banks': 3,
#  'Britt Robertson & George Clooney': 1,
#  'Britt Robertson & Raffey Cassidy': 1,
#  'Britt Robertson & Thomas Robinson': 1,
#  'Britt Robertson & Hugh Laurie': 1,
#  'George Clooney & Raffey Cassidy': 1,
#  'George Clooney & Thomas Robinson': 1,
#  'George Clooney & Hugh Laurie': 1,
#  'Raffey Cassidy & Thomas Robinson': 1,
#  'Raffey Cassidy & Hugh Laurie': 1,
#  'Thomas Robinson & Hugh Laurie': 1,
#  'Jake Gyllenhaal & Rachel McAdams': 1,
#  'Jake Gyllenhaal & Forest Whitaker': 1,
#  'Jake Gyllenhaal & Oona Laurence': 1,
#  'Jake Gyllenhaal & 50 Cent': 1,
#  'Rachel McAdams & Forest Whitaker': 1,
#  'Rachel McAdams & Oona Laurence': 1,
#  'Rachel McAdams & 50 Cent': 1,
#  'Forest Whitaker & Oona Laurence': 1,
#  'Forest Whitaker & 50 Cent': 1,
#  'Oona Laurence & 50 Cent': 1,
#  'Dwayne Johnson & Alexandra Daddario': 1,
#  'Dwayne Johnson & Carla Gugino': 2,
#  'Dwayne Johnson & Ioan Gruffudd': 1,
#  'Dwayne Johnson & Archie Panjabi': 1,
#  'Alexandra Daddario & Carla Gugino': 1,
#  'Alexandra Daddario & Ioan Gruffudd': 1,
#  'Alexandra Daddario & Archie Panjabi': 1,
#  'Carla Gugino & Ioan Gruffudd': 1,
#  'Carla Gugino & Archie Panjabi': 1,
#  'Ioan Gruffudd & Archie Panjabi': 1,
#  'Dakota Johnson & Jamie Dornan': 1,
#  'Dakota Johnson & Jennifer Ehle': 1,
#  'Dakota Johnson & Eloise Mumford': 1,
#  'Dakota Johnson & Victor Rasuk': 1,
#  'Jamie Dornan & Jennifer Ehle': 1,
#  'Jamie Dornan & Eloise Mumford': 1,
#  'Jamie Dornan & Victor Rasuk': 1,
#  'Jennifer Ehle & Eloise Mumford': 1,
#  'Jennifer Ehle & Victor Rasuk': 1,
#  'Eloise Mumford & Victor Rasuk': 1,
#  'Christian Bale & Steve Carell': 1,
#  'Christian Bale & Ryan Gosling': 1,
#  'Christian Bale & Brad Pitt': 1,
#  'Christian Bale & Melissa Leo': 2,
#  'Steve Carell & Ryan Gosling': 2,
#  'Steve Carell & Brad Pitt': 1,
#  'Steve Carell & Melissa Leo': 1,
#  'Ryan Gosling & Brad Pitt': 1,
#  'Ryan Gosling & Melissa Leo': 1,
#  'Brad Pitt & Melissa Leo': 1,
#  'Tom Cruise & Jeremy Renner': 2,
#  'Tom Cruise & Simon Pegg': 2,
#  'Tom Cruise & Rebecca Ferguson': 1,
#  'Tom Cruise & Ving Rhames': 3,
#  'Jeremy Renner & Simon Pegg': 2,
#  'Jeremy Renner & Rebecca Ferguson': 1,
#  'Jeremy Renner & Ving Rhames': 1,
#  'Simon Pegg & Rebecca Ferguson': 1,
#  'Simon Pegg & Ving Rhames': 1,
#  'Rebecca Ferguson & Ving Rhames': 1,
#  'Mark Wahlberg & Seth MacFarlane': 2,
#  'Mark Wahlberg & Amanda Seyfried': 1,
#  'Mark Wahlberg & Jessica Barth': 1,
#  'Mark Wahlberg & Giovanni Ribisi': 3,
#  'Seth MacFarlane & Amanda Seyfried': 1,
#  'Seth MacFarlane & Jessica Barth': 1,
#  'Seth MacFarlane & Giovanni Ribisi': 2,
#  'Amanda Seyfried & Jessica Barth': 1,
#  'Amanda Seyfried & Giovanni Ribisi': 1,
#  'Jessica Barth & Giovanni Ribisi': 1,
#  'Taron Egerton & Colin Firth': 1,
#  'Taron Egerton & Samuel L. Jackson': 1,
#  'Taron Egerton & Michael Caine': 1,
#  'Taron Egerton & Mark Strong': 1,
#  'Colin Firth & Samuel L. Jackson': 1,
#  'Colin Firth & Michael Caine': 1,
#  'Colin Firth & Mark Strong': 1,
#  'Samuel L. Jackson & Michael Caine': 1,
#  'Samuel L. Jackson & Mark Strong': 1,
#  'Michael Caine & Mark Strong': 1,
#  'Mark Ruffalo & Michael Keaton': 1,
#  'Mark Ruffalo & Rachel McAdams': 1,
#  'Mark Ruffalo & Liev Schreiber': 1,
#  'Mark Ruffalo & John Slattery': 1,
#  'Michael Keaton & Rachel McAdams': 1,
#  'Michael Keaton & Liev Schreiber': 1,
#  'Michael Keaton & John Slattery': 1,
#  'Rachel McAdams & Liev Schreiber': 1,
#  'Rachel McAdams & John Slattery': 1,
#  'Liev Schreiber & John Slattery': 1,
#  "Dylan O'Brien & Kaya Scodelario": 2,
#  "Dylan O'Brien & Thomas Brodie-Sangster": 1,
#  "Dylan O'Brien & Giancarlo Esposito": 1,
#  "Dylan O'Brien & Aidan Gillen": 1,
#  'Kaya Scodelario & Thomas Brodie-Sangster': 1,
#  'Kaya Scodelario & Giancarlo Esposito': 1,
#  'Kaya Scodelario & Aidan Gillen': 1,
#  'Thomas Brodie-Sangster & Giancarlo Esposito': 1,
#  'Thomas Brodie-Sangster & Aidan Gillen': 1,
#  'Giancarlo Esposito & Aidan Gillen': 1,
#  'Sharlto Copley & Dev Patel': 1,
#  'Sharlto Copley & Ninja': 1,
#  'Sharlto Copley & Yolandi Visser': 1,
#  'Sharlto Copley & Jose Pablo Cantillo': 1,
#  'Dev Patel & Ninja': 1,
#  'Dev Patel & Yolandi Visser': 1,
#  'Dev Patel & Jose Pablo Cantillo': 1,
#  'Ninja & Yolandi Visser': 1,
#  'Ninja & Jose Pablo Cantillo': 1,
#  'Yolandi Visser & Jose Pablo Cantillo': 1,
#  'Anna Kendrick & Rebel Wilson': 2,
#  'Anna Kendrick & Hailee Steinfeld': 1,
#  'Anna Kendrick & Brittany Snow': 2,
#  'Anna Kendrick & Skylar Astin': 2,
#  'Rebel Wilson & Hailee Steinfeld': 1,
#  'Rebel Wilson & Brittany Snow': 1,
#  'Rebel Wilson & Skylar Astin': 1,
#  'Hailee Steinfeld & Brittany Snow': 1,
#  'Hailee Steinfeld & Skylar Astin': 1,
#  'Brittany Snow & Skylar Astin': 1,
#  'Tom Hanks & Mark Rylance': 1,
#  'Tom Hanks & Amy Ryan': 1,
#  'Tom Hanks & Alan Alda': 1,
#  'Tom Hanks & Sebastian Koch': 1,
#  'Mark Rylance & Amy Ryan': 1,
#  'Mark Rylance & Alan Alda': 1,
#  'Mark Rylance & Sebastian Koch': 1,
#  'Amy Ryan & Alan Alda': 1,
#  'Amy Ryan & Sebastian Koch': 1,
#  'Alan Alda & Sebastian Koch': 1,
#  'Jack Black & Dylan Minnette': 1,
#  'Jack Black & Odeya Rush': 1,
#  'Jack Black & Amy Ryan': 1,
#  'Jack Black & Jillian Bell': 1,
#  'Dylan Minnette & Odeya Rush': 1,
#  'Dylan Minnette & Amy Ryan': 1,
#  'Dylan Minnette & Jillian Bell': 1,
#  'Odeya Rush & Amy Ryan': 1,
#  'Odeya Rush & Jillian Bell': 1,
#  'Amy Ryan & Jillian Bell': 1,
#  'Brie Larson & Jacob Tremblay': 1,
#  'Brie Larson & Joan Allen': 1,
#  'Brie Larson & Sean Bridgers': 1,
#  'Brie Larson & William H. Macy': 1,
#  'Jacob Tremblay & Joan Allen': 1,
#  'Jacob Tremblay & Sean Bridgers': 1,
#  'Jacob Tremblay & William H. Macy': 1,
#  'Joan Allen & Sean Bridgers': 1,
#  'Joan Allen & William H. Macy': 1,
#  'Sean Bridgers & William H. Macy': 1,
#  'Raymond Ochoa & Jack Bright': 1,
#  'Raymond Ochoa & Jeffrey Wright': 1,
#  'Raymond Ochoa & Frances McDormand': 1,
#  'Raymond Ochoa & Maleah Nipay-Padilla': 1,
#  'Jack Bright & Jeffrey Wright': 1,
#  'Jack Bright & Frances McDormand': 1,
#  'Jack Bright & Maleah Nipay-Padilla': 1,
#  'Jeffrey Wright & Frances McDormand': 1,
#  'Jeffrey Wright & Maleah Nipay-Padilla': 1,
#  'Frances McDormand & Maleah Nipay-Padilla': 1,
#  'Liam Neeson & Ed Harris': 1,
#  'Liam Neeson & Joel Kinnaman': 1,
#  'Liam Neeson & Boyd Holbrook': 2,
#  'Liam Neeson & Bruce McGill': 1,
#  'Ed Harris & Joel Kinnaman': 1,
#  'Ed Harris & Boyd Holbrook': 1,
#  'Ed Harris & Bruce McGill': 1,
#  'Joel Kinnaman & Boyd Holbrook': 1,
#  'Joel Kinnaman & Bruce McGill': 1,
#  'Boyd Holbrook & Bruce McGill': 1,
#  'Saoirse Ronan & Domhnall Gleeson': 1,
#  'Saoirse Ronan & Emory Cohen': 1,
#  'Saoirse Ronan & Emily Bett Rickards': 1,
#  "Saoirse Ronan & Eileen O'Higgins": 1,
#  'Domhnall Gleeson & Emory Cohen': 1,
#  'Domhnall Gleeson & Emily Bett Rickards': 1,
#  "Domhnall Gleeson & Eileen O'Higgins": 1,
#  'Emory Cohen & Emily Bett Rickards': 1,
#  "Emory Cohen & Eileen O'Higgins": 1,
#  "Emily Bett Rickards & Eileen O'Higgins": 1,
#  "O'Shea Jackson Jr. & Corey Hawkins": 1,
#  "O'Shea Jackson Jr. & Jason Mitchell": 1,
#  "O'Shea Jackson Jr. & Neil Brown Jr.": 1,
#  "O'Shea Jackson Jr. & Aldis Hodge": 1,
#  'Corey Hawkins & Jason Mitchell': 1,
#  'Corey Hawkins & Neil Brown Jr.': 1,
#  'Corey Hawkins & Aldis Hodge': 1,
#  'Jason Mitchell & Neil Brown Jr.': 1,
#  'Jason Mitchell & Aldis Hodge': 1,
#  'Neil Brown Jr. & Aldis Hodge': 1,
#  'Vin Diesel & Rose Leslie': 1,
#  'Vin Diesel & Michael Caine': 1,
#  'Vin Diesel & Elijah Wood': 1,
#  'Vin Diesel & Ã“lafur Darri Ã“lafsson': 1,
#  'Rose Leslie & Michael Caine': 1,
#  'Rose Leslie & Elijah Wood': 1,
#  'Rose Leslie & Ã“lafur Darri Ã“lafsson': 1,
#  'Michael Caine & Elijah Wood': 1,
#  'Michael Caine & Ã“lafur Darri Ã“lafsson': 1,
#  'Elijah Wood & Ã“lafur Darri Ã“lafsson': 1,
#  'Henry Cavill & Armie Hammer': 1,
#  'Henry Cavill & Alicia Vikander': 1,
#  'Henry Cavill & Elizabeth Debicki': 1,
#  'Henry Cavill & Luca Calvani': 1,
#  'Armie Hammer & Alicia Vikander': 1,
#  'Armie Hammer & Elizabeth Debicki': 1,
#  'Armie Hammer & Luca Calvani': 1,
#  'Alicia Vikander & Elizabeth Debicki': 1,
#  'Alicia Vikander & Luca Calvani': 1,
#  'Elizabeth Debicki & Luca Calvani': 1,
#  'Blake Lively & Michiel Huisman': 1,
#  'Blake Lively & Harrison Ford': 1,
#  'Blake Lively & Ellen Burstyn': 1,
#  'Blake Lively & Kathy Baker': 1,
#  'Michiel Huisman & Harrison Ford': 1,
#  'Michiel Huisman & Ellen Burstyn': 1,
#  'Michiel Huisman & Kathy Baker': 1,
#  'Harrison Ford & Ellen Burstyn': 1,
#  'Harrison Ford & Kathy Baker': 1,
#  'Ellen Burstyn & Kathy Baker': 1,
#  'Sharlto Copley & Haley Bennett': 1,
#  'Sharlto Copley & Danila Kozlovskiy': 1,
#  'Sharlto Copley & Tim Roth': 1,
#  'Sharlto Copley & Andrei Dementiev': 1,
#  'Haley Bennett & Danila Kozlovskiy': 1,
#  'Haley Bennett & Tim Roth': 1,
#  'Haley Bennett & Andrei Dementiev': 1,
#  'Danila Kozlovskiy & Tim Roth': 1,
#  'Danila Kozlovskiy & Andrei Dementiev': 1,
#  'Tim Roth & Andrei Dementiev': 1,
#  'Jim Parsons & Rihanna': 1,
#  'Jim Parsons & Steve Martin': 1,
#  'Jim Parsons & Jennifer Lopez': 1,
#  'Jim Parsons & Matt Jones': 1,
#  'Rihanna & Steve Martin': 1,
#  'Rihanna & Jennifer Lopez': 1,
#  'Rihanna & Matt Jones': 1,
#  'Steve Martin & Jennifer Lopez': 1,
#  'Steve Martin & Matt Jones': 1,
#  'Jennifer Lopez & Matt Jones': 1,
#  'Nat Wolff & Cara Delevingne': 1,
#  'Nat Wolff & Halston Sage': 1,
#  'Nat Wolff & Justice Smith': 1,
#  'Nat Wolff & Austin Abrams': 1,
#  'Cara Delevingne & Halston Sage': 1,
#  'Cara Delevingne & Justice Smith': 1,
#  'Cara Delevingne & Austin Abrams': 1,
#  'Halston Sage & Justice Smith': 1,
#  'Halston Sage & Austin Abrams': 1,
#  'Justice Smith & Austin Abrams': 1,
#  'Cate Blanchett & Rooney Mara': 1,
#  'Cate Blanchett & Kyle Chandler': 1,
#  'Cate Blanchett & Sarah Paulson': 1,
#  'Cate Blanchett & Jake Lacy': 1,
#  'Rooney Mara & Kyle Chandler': 1,
#  'Rooney Mara & Sarah Paulson': 1,
#  'Rooney Mara & Jake Lacy': 1,
#  'Kyle Chandler & Sarah Paulson': 1,
#  'Kyle Chandler & Jake Lacy': 1,
#  'Sarah Paulson & Jake Lacy': 1,
#  'Robert De Niro & Anne Hathaway': 1,
#  'Robert De Niro & Rene Russo': 1,
#  'Robert De Niro & Anders Holm': 1,
#  'Robert De Niro & JoJo Kushner': 1,
#  'Anne Hathaway & Rene Russo': 1,
#  'Anne Hathaway & Anders Holm': 1,
#  'Anne Hathaway & JoJo Kushner': 1,
#  'Rene Russo & Anders Holm': 1,
#  'Rene Russo & JoJo Kushner': 1,
#  'Anders Holm & JoJo Kushner': 1,
#  'Jason Clarke & Jake Gyllenhaal': 1,
#  'Jason Clarke & Josh Brolin': 1,
#  'Jason Clarke & John Hawkes': 1,
#  'Jason Clarke & Sam Worthington': 1,
#  'Jake Gyllenhaal & Josh Brolin': 1,
#  'Jake Gyllenhaal & John Hawkes': 1,
#  'Jake Gyllenhaal & Sam Worthington': 1,
#  'Josh Brolin & John Hawkes': 1,
#  'Josh Brolin & Sam Worthington': 1,
#  'John Hawkes & Sam Worthington': 1,
#  'Edgar RamÃ\xadrez & Luke Bracey': 1,
#  'Edgar RamÃ\xadrez & Teresa Palmer': 1,
#  'Edgar RamÃ\xadrez & Delroy Lindo': 2,
#  'Edgar RamÃ\xadrez & Ray Winstone': 1,
#  'Luke Bracey & Teresa Palmer': 1,
#  'Luke Bracey & Delroy Lindo': 1,
#  'Luke Bracey & Ray Winstone': 1,
#  'Teresa Palmer & Delroy Lindo': 1,
#  'Teresa Palmer & Ray Winstone': 1,
#  'Delroy Lindo & Ray Winstone': 1,
#  'Bradley Cooper & Sienna Miller': 2,
#  'Bradley Cooper & Lily James': 1,
#  'Bradley Cooper & Alicia Vikander': 1,
#  'Bradley Cooper & Uma Thurman': 1,
#  'Sienna Miller & Lily James': 1,
#  'Sienna Miller & Alicia Vikander': 1,
#  'Sienna Miller & Uma Thurman': 1,
#  'Lily James & Alicia Vikander': 1,
#  'Lily James & Uma Thurman': 1,
#  'Alicia Vikander & Uma Thurman': 1,
#  'Ryan Reynolds & Ben Kingsley': 1,
#  'Ryan Reynolds & Natalie Martinez': 1,
#  'Ryan Reynolds & Matthew Goode': 1,
#  'Ryan Reynolds & Michelle Dockery': 1,
#  'Ben Kingsley & Natalie Martinez': 1,
#  'Ben Kingsley & Matthew Goode': 1,
#  'Ben Kingsley & Michelle Dockery': 1,
#  'Natalie Martinez & Matthew Goode': 1,
#  'Natalie Martinez & Michelle Dockery': 1,
#  'Matthew Goode & Michelle Dockery': 1,
#  'Johnny Depp & Gwyneth Paltrow': 1,
#  'Johnny Depp & Ewan McGregor': 1,
#  'Johnny Depp & Paul Bettany': 3,
#  'Johnny Depp & Olivia Munn': 1,
#  'Gwyneth Paltrow & Ewan McGregor': 1,
#  'Gwyneth Paltrow & Paul Bettany': 1,
#  'Gwyneth Paltrow & Olivia Munn': 1,
#  'Ewan McGregor & Paul Bettany': 1,
#  'Ewan McGregor & Olivia Munn': 1,
#  'Paul Bettany & Olivia Munn': 1,
#  'Eddie Redmayne & Alicia Vikander': 1,
#  'Eddie Redmayne & Matthias Schoenaerts': 1,
#  'Eddie Redmayne & Amber Heard': 1,
#  'Eddie Redmayne & Ben Whishaw': 1,
#  'Alicia Vikander & Matthias Schoenaerts': 1,
#  'Alicia Vikander & Amber Heard': 1,
#  'Alicia Vikander & Ben Whishaw': 1,
#  'Matthias Schoenaerts & Amber Heard': 1,
#  'Matthias Schoenaerts & Ben Whishaw': 1,
#  'Amber Heard & Ben Whishaw': 1,
#  'Chris Hemsworth & Leehom Wang': 1,
#  'Chris Hemsworth & Tang Wei': 1,
#  'Chris Hemsworth & Viola Davis': 1,
#  'Chris Hemsworth & Holt McCallany': 1,
#  'Leehom Wang & Tang Wei': 1,
#  'Leehom Wang & Viola Davis': 1,
#  'Leehom Wang & Holt McCallany': 1,
#  'Tang Wei & Viola Davis': 1,
#  'Tang Wei & Holt McCallany': 1,
#  'Viola Davis & Holt McCallany': 1,
#  'Emily Blunt & Benicio del Toro': 1,
#  'Emily Blunt & Josh Brolin': 1,
#  'Emily Blunt & Victor Garber': 1,
#  'Emily Blunt & Jon Bernthal': 1,
#  'Benicio del Toro & Josh Brolin': 1,
#  'Benicio del Toro & Victor Garber': 1,
#  'Benicio del Toro & Jon Bernthal': 1,
#  'Josh Brolin & Victor Garber': 1,
#  'Josh Brolin & Jon Bernthal': 1,
#  'Victor Garber & Jon Bernthal': 1,
#  'Miles Teller & Kate Mara': 1,
#  'Miles Teller & Michael B. Jordan': 2,
#  'Miles Teller & Jamie Bell': 1,
#  'Miles Teller & Toby Kebbell': 1,
#  'Kate Mara & Michael B. Jordan': 1,
#  'Kate Mara & Jamie Bell': 1,
#  'Kate Mara & Toby Kebbell': 1,
#  'Michael B. Jordan & Jamie Bell': 1,
#  'Michael B. Jordan & Toby Kebbell': 1,
#  'Jamie Bell & Toby Kebbell': 1,
#  'Melissa McCarthy & Jason Statham': 1,
#  'Melissa McCarthy & Rose Byrne': 1,
#  'Melissa McCarthy & Miranda Hart': 1,
#  'Melissa McCarthy & Bobby Cannavale': 1,
#  'Jason Statham & Rose Byrne': 1,
#  'Jason Statham & Miranda Hart': 1,
#  'Jason Statham & Bobby Cannavale': 1,
#  'Rose Byrne & Miranda Hart': 1,
#  'Rose Byrne & Bobby Cannavale': 2,
#  'Miranda Hart & Bobby Cannavale': 1,
#  'Will Smith & Margot Robbie': 1,
#  'Will Smith & Rodrigo Santoro': 1,
#  'Will Smith & Robert Taylor': 1,
#  'Will Smith & Gerald McRaney': 1,
#  'Margot Robbie & Rodrigo Santoro': 1,
#  'Margot Robbie & Robert Taylor': 1,
#  'Margot Robbie & Gerald McRaney': 1,
#  'Rodrigo Santoro & Robert Taylor': 1,
#  'Rodrigo Santoro & Gerald McRaney': 1,
#  'Robert Taylor & Gerald McRaney': 1,
#  'Rupert Friend & Zachary Quinto': 1,
#  'Rupert Friend & Hannah Ware': 1,
#  'Rupert Friend & Emilio Rivera': 1,
#  'Rupert Friend & Rolf Kanies': 1,
#  'Zachary Quinto & Hannah Ware': 1,
#  'Zachary Quinto & Emilio Rivera': 1,
#  'Zachary Quinto & Rolf Kanies': 1,
#  'Hannah Ware & Emilio Rivera': 1,
#  'Hannah Ware & Rolf Kanies': 1,
#  'Emilio Rivera & Rolf Kanies': 1,
#  'Chris Hemsworth & Benjamin Walker': 1,
#  'Chris Hemsworth & Cillian Murphy': 1,
#  'Chris Hemsworth & Brendan Gleeson': 1,
#  'Chris Hemsworth & Ben Whishaw': 1,
#  'Benjamin Walker & Cillian Murphy': 1,
#  'Benjamin Walker & Brendan Gleeson': 1,
#  'Benjamin Walker & Ben Whishaw': 1,
#  'Cillian Murphy & Brendan Gleeson': 1,
#  'Cillian Murphy & Ben Whishaw': 1,
#  'Brendan Gleeson & Ben Whishaw': 1,
#  'Michael B. Jordan & Sylvester Stallone': 1,
#  'Michael B. Jordan & Graham McTavish': 1,
#  'Michael B. Jordan & Tessa Thompson': 1,
#  'Michael B. Jordan & Phylicia RashÄd': 1,
#  'Sylvester Stallone & Graham McTavish': 1,
#  'Sylvester Stallone & Tessa Thompson': 1,
#  'Sylvester Stallone & Phylicia RashÄd': 1,
#  'Graham McTavish & Tessa Thompson': 1,
#  'Graham McTavish & Phylicia RashÄd': 1,
#  'Tessa Thompson & Phylicia RashÄd': 1,
#  'Amy Schumer & Bill Hader': 1,
#  'Amy Schumer & Brie Larson': 1,
#  'Amy Schumer & Colin Quinn': 1,
#  'Amy Schumer & Vanessa Bayer': 1,
#  'Bill Hader & Brie Larson': 1,
#  'Bill Hader & Colin Quinn': 1,
#  'Bill Hader & Vanessa Bayer': 1,
#  'Brie Larson & Colin Quinn': 1,
#  'Brie Larson & Vanessa Bayer': 1,
#  'Colin Quinn & Vanessa Bayer': 1,
#  'Helen Mirren & Aaron Paul': 1,
#  'Helen Mirren & Alan Rickman': 1,
#  'Helen Mirren & Iain Glen': 1,
#  'Helen Mirren & Barkhad Abdi': 1,
#  'Aaron Paul & Alan Rickman': 1,
#  'Aaron Paul & Iain Glen': 1,
#  'Aaron Paul & Barkhad Abdi': 1,
#  'Alan Rickman & Iain Glen': 1,
#  'Alan Rickman & Barkhad Abdi': 1,
#  'Iain Glen & Barkhad Abdi': 1,
#  'Tom Hardy & Emily Browning': 1,
#  'Tom Hardy & Christopher Eccleston': 1,
#  'Tom Hardy & David Thewlis': 1,
#  'Tom Hardy & Taron Egerton': 1,
#  'Emily Browning & Christopher Eccleston': 1,
#  'Emily Browning & David Thewlis': 1,
#  'Emily Browning & Taron Egerton': 1,
#  'Christopher Eccleston & David Thewlis': 1,
#  'Christopher Eccleston & Taron Egerton': 1,
#  'David Thewlis & Taron Egerton': 1,
#  'Levi Miller & Garrett Hedlund': 1,
#  'Levi Miller & Hugh Jackman': 1,
#  'Levi Miller & Rooney Mara': 1,
#  'Levi Miller & Amanda Seyfried': 1,
#  'Garrett Hedlund & Hugh Jackman': 1,
#  'Garrett Hedlund & Rooney Mara': 1,
#  'Garrett Hedlund & Amanda Seyfried': 1,
#  'Hugh Jackman & Rooney Mara': 1,
#  'Hugh Jackman & Amanda Seyfried': 2,
#  'Rooney Mara & Amanda Seyfried': 1,
#  'Noah Schnapp & Bill Melendez': 1,
#  'Noah Schnapp & Venus Schultheis': 1,
#  'Noah Schnapp & Hadley Belle Miller': 1,
#  'Noah Schnapp & Madisyn Shipman': 1,
#  'Bill Melendez & Venus Schultheis': 1,
#  'Bill Melendez & Hadley Belle Miller': 1,
#  'Bill Melendez & Madisyn Shipman': 1,
#  'Venus Schultheis & Hadley Belle Miller': 1,
#  'Venus Schultheis & Madisyn Shipman': 1,
#  'Hadley Belle Miller & Madisyn Shipman': 1,
#  'Will Smith & Bitsie Tulloch': 1,
#  'Will Smith & Gugu Mbatha-Raw': 1,
#  'Will Smith & Alec Baldwin': 1,
#  'Will Smith & Matthew Willig': 1,
#  'Bitsie Tulloch & Gugu Mbatha-Raw': 1,
#  'Bitsie Tulloch & Alec Baldwin': 1,
#  'Bitsie Tulloch & Matthew Willig': 1,
#  'Gugu Mbatha-Raw & Alec Baldwin': 1,
#  'Gugu Mbatha-Raw & Matthew Willig': 1,
#  'Alec Baldwin & Matthew Willig': 1,
#  'Joseph Gordon-Levitt & Seth Rogen': 2,
#  'Joseph Gordon-Levitt & Anthony Mackie': 1,
#  'Joseph Gordon-Levitt & Lizzy Caplan': 1,
#  'Joseph Gordon-Levitt & Jillian Bell': 1,
#  'Seth Rogen & Anthony Mackie': 1,
#  'Seth Rogen & Lizzy Caplan': 2,
#  'Seth Rogen & Jillian Bell': 1,
#  'Anthony Mackie & Lizzy Caplan': 1,
#  'Anthony Mackie & Jillian Bell': 1,
#  'Lizzy Caplan & Jillian Bell': 1,
#  'Scott Eastwood & Britt Robertson': 1,
#  'Scott Eastwood & Lolita Davidovich': 1,
#  'Scott Eastwood & Melissa Benoist': 1,
#  'Scott Eastwood & Jack Huston': 1,
#  'Britt Robertson & Lolita Davidovich': 1,
#  'Britt Robertson & Melissa Benoist': 1,
#  'Britt Robertson & Jack Huston': 1,
#  'Lolita Davidovich & Melissa Benoist': 1,
#  'Lolita Davidovich & Jack Huston': 1,
#  'Melissa Benoist & Jack Huston': 1,
#  'Adam Sandler & Andy Samberg': 2,
#  'Adam Sandler & Selena Gomez': 2,
#  'Adam Sandler & Steve Buscemi': 3,
#  'Andy Samberg & Selena Gomez': 1,
#  'Andy Samberg & Kevin James': 1,
#  'Andy Samberg & Steve Buscemi': 1,
#  'Selena Gomez & Kevin James': 1,
#  'Selena Gomez & Steve Buscemi': 1,
#  'Kevin James & Steve Buscemi': 1,
#  'Steve Martin & Diane Keaton': 1,
#  'Steve Martin & John Goodman': 1,
#  'Steve Martin & Alan Arkin': 1,
#  'Steve Martin & Olivia Wilde': 1,
#  'Diane Keaton & John Goodman': 1,
#  'Diane Keaton & Alan Arkin': 1,
#  'Diane Keaton & Olivia Wilde': 1,
#  'John Goodman & Alan Arkin': 1,
#  'John Goodman & Olivia Wilde': 1,
#  'Alan Arkin & Olivia Wilde': 1,
#  'Joseph Gordon-Levitt & Ben Kingsley': 1,
#  'Joseph Gordon-Levitt & Charlotte Le Bon': 1,
#  'Joseph Gordon-Levitt & Ben Schwartz': 1,
#  'Joseph Gordon-Levitt & James Badge Dale': 1,
#  'Ben Kingsley & Charlotte Le Bon': 1,
#  'Ben Kingsley & Ben Schwartz': 1,
#  'Ben Kingsley & James Badge Dale': 1,
#  'Charlotte Le Bon & Ben Schwartz': 1,
#  'Charlotte Le Bon & James Badge Dale': 1,
#  'Ben Schwartz & James Badge Dale': 1,
#  'Ed Helms & Christina Applegate': 1,
#  'Ed Helms & Skyler Gisondo': 1,
#  'Ed Helms & Steele Stebbins': 1,
#  'Ed Helms & Chris Hemsworth': 1,
#  'Christina Applegate & Skyler Gisondo': 1,
#  'Christina Applegate & Steele Stebbins': 1,
#  'Christina Applegate & Chris Hemsworth': 1,
#  'Skyler Gisondo & Steele Stebbins': 1,
#  'Skyler Gisondo & Chris Hemsworth': 1,
#  'Steele Stebbins & Chris Hemsworth': 1,
#  'Sam Rockwell & Rosemarie DeWitt': 1,
#  'Sam Rockwell & Saxon Sharbino': 1,
#  'Sam Rockwell & Kyle Catlett': 1,
#  'Sam Rockwell & Kennedi Clements': 1,
#  'Rosemarie DeWitt & Saxon Sharbino': 1,
#  'Rosemarie DeWitt & Kyle Catlett': 1,
#  'Rosemarie DeWitt & Kennedi Clements': 1,
#  'Saxon Sharbino & Kyle Catlett': 1,
#  'Saxon Sharbino & Kennedi Clements': 1,
#  'Kyle Catlett & Kennedi Clements': 1,
#  'Tom Hardy & Gary Oldman': 1,
#  'Tom Hardy & Noomi Rapace': 1,
#  'Tom Hardy & Joel Kinnaman': 1,
#  'Tom Hardy & Paddy Considine': 1,
#  'Gary Oldman & Noomi Rapace': 1,
#  'Gary Oldman & Joel Kinnaman': 1,
#  'Gary Oldman & Paddy Considine': 1,
#  'Noomi Rapace & Joel Kinnaman': 1,
#  'Noomi Rapace & Paddy Considine': 1,
#  'Joel Kinnaman & Paddy Considine': 1,
#  'Jason Bateman & Rebecca Hall': 1,
#  'Jason Bateman & Joel Edgerton': 1,
#  'Jason Bateman & David Denman': 1,
#  'Jason Bateman & Beau Knapp': 1,
#  'Rebecca Hall & Joel Edgerton': 1,
#  'Rebecca Hall & David Denman': 1,
#  'Rebecca Hall & Beau Knapp': 1,
#  'Joel Edgerton & David Denman': 1,
#  'Joel Edgerton & Beau Knapp': 1,
#  'David Denman & Beau Knapp': 1,
#  'Will Ferrell & Mark Wahlberg': 2,
#  'Will Ferrell & Linda Cardellini': 1,
#  'Will Ferrell & Thomas Haden Church': 1,
#  'Will Ferrell & Hannibal Buress': 1,
#  'Mark Wahlberg & Linda Cardellini': 1,
#  'Mark Wahlberg & Thomas Haden Church': 1,
#  'Mark Wahlberg & Hannibal Buress': 1,
#  'Linda Cardellini & Thomas Haden Church': 1,
#  'Linda Cardellini & Hannibal Buress': 1,
#  'Thomas Haden Church & Hannibal Buress': 1,
#  'Jeff Bridges & Rachel McAdams': 1,
#  'Jeff Bridges & Paul Rudd': 1,
#  'Jeff Bridges & Marion Cotillard': 1,
#  'Jeff Bridges & James Franco': 1,
#  'Rachel McAdams & Paul Rudd': 1,
#  'Rachel McAdams & Marion Cotillard': 1,
#  'Rachel McAdams & James Franco': 1,
#  'Paul Rudd & Marion Cotillard': 1,
#  'Paul Rudd & James Franco': 1,
#  'Marion Cotillard & James Franco': 1,
#  'Kate Winslet & Liam Hemsworth': 1,
#  'Kate Winslet & Caroline Goodall': 1,
#  'Kate Winslet & Judy Davis': 1,
#  'Kate Winslet & Hayley Magnus': 1,
#  'Liam Hemsworth & Caroline Goodall': 1,
#  'Liam Hemsworth & Judy Davis': 1,
#  'Liam Hemsworth & Hayley Magnus': 1,
#  'Caroline Goodall & Judy Davis': 1,
#  'Caroline Goodall & Hayley Magnus': 1,
#  'Judy Davis & Hayley Magnus': 1,
#  'Mae Whitman & Robbie Amell': 1,
#  'Mae Whitman & Bella Thorne': 1,
#  'Mae Whitman & Bianca A. Santos': 1,
#  'Mae Whitman & Skyler Samuels': 1,
#  'Robbie Amell & Bella Thorne': 1,
#  'Robbie Amell & Bianca A. Santos': 1,
#  'Robbie Amell & Skyler Samuels': 1,
#  'Bella Thorne & Bianca A. Santos': 1,
#  'Bella Thorne & Skyler Samuels': 1,
#  'Bianca A. Santos & Skyler Samuels': 1,
#  'Shannyn Sossamon & James Ransone': 1,
#  'Shannyn Sossamon & Tate Ellington': 1,
#  'Shannyn Sossamon & Nicholas King': 1,
#  'Shannyn Sossamon & Lucas Jade Zumann': 1,
#  'James Ransone & Tate Ellington': 1,
#  'James Ransone & Nicholas King': 1,
#  'James Ransone & Lucas Jade Zumann': 1,
#  'Tate Ellington & Nicholas King': 1,
#  'Tate Ellington & Lucas Jade Zumann': 1,
#  'Nicholas King & Lucas Jade Zumann': 1,
#  'Kevin James & Raini Rodriguez': 2,
#  'Kevin James & Eduardo VerÃ¡stegui': 1,
#  'Kevin James & Daniella Alonso': 1,
#  'Kevin James & Neal McDonough': 1,
#  'Raini Rodriguez & Eduardo VerÃ¡stegui': 1,
#  'Raini Rodriguez & Daniella Alonso': 1,
#  'Raini Rodriguez & Neal McDonough': 1,
#  'Eduardo VerÃ¡stegui & Daniella Alonso': 1,
#  'Eduardo VerÃ¡stegui & Neal McDonough': 1,
#  'Daniella Alonso & Neal McDonough': 1,
#  'Jeremy Piven & Adrian Grenier': 1,
#  'Jeremy Piven & Jerry Ferrara': 1,
#  'Jeremy Piven & Kevin Connolly': 1,
#  'Jeremy Piven & Kevin Dillon': 1,
#  'Adrian Grenier & Jerry Ferrara': 1,
#  'Adrian Grenier & Kevin Connolly': 1,
#  'Adrian Grenier & Kevin Dillon': 1,
#  'Jerry Ferrara & Kevin Connolly': 1,
#  'Jerry Ferrara & Kevin Dillon': 1,
#  'Kevin Connolly & Kevin Dillon': 1,
#  'Kevin Hart & Josh Gad': 1,
#  'Kevin Hart & Kaley Cuoco': 1,
#  'Kevin Hart & Affion Crockett': 1,
#  'Kevin Hart & Jorge Garcia': 1,
#  'Josh Gad & Kaley Cuoco': 1,
#  'Josh Gad & Affion Crockett': 1,
#  'Josh Gad & Jorge Garcia': 1,
#  'Kaley Cuoco & Affion Crockett': 1,
#  'Kaley Cuoco & Jorge Garcia': 1,
#  'Affion Crockett & Jorge Garcia': 1,
#  'Olivia DeJonge & Ed Oxenbould': 1,
#  'Olivia DeJonge & Kathryn Hahn': 1,
#  'Olivia DeJonge & Benjamin Kanes': 1,
#  'Olivia DeJonge & Deanna Dunagan': 1,
#  'Ed Oxenbould & Kathryn Hahn': 1,
#  'Ed Oxenbould & Benjamin Kanes': 1,
#  'Ed Oxenbould & Deanna Dunagan': 1,
#  'Kathryn Hahn & Benjamin Kanes': 1,
#  'Kathryn Hahn & Deanna Dunagan': 1,
#  'Benjamin Kanes & Deanna Dunagan': 1,
#  'Johnny Depp & Joel Edgerton': 1,
#  'Johnny Depp & Benedict Cumberbatch': 1,
#  'Johnny Depp & Dakota Johnson': 1,
#  'Johnny Depp & Kevin Bacon': 1,
#  'Joel Edgerton & Benedict Cumberbatch': 1,
#  'Joel Edgerton & Dakota Johnson': 1,
#  'Joel Edgerton & Kevin Bacon': 1,
#  'Benedict Cumberbatch & Dakota Johnson': 1,
#  'Benedict Cumberbatch & Kevin Bacon': 1,
#  'Dakota Johnson & Kevin Bacon': 1,
#  'Adam Scott & Toni Collette': 1,
#  'Adam Scott & Allison Tolman': 1,
#  'Adam Scott & David Koechner': 1,
#  'Adam Scott & Emjay Anthony': 1,
#  'Toni Collette & Allison Tolman': 1,
#  'Toni Collette & David Koechner': 1,
#  'Toni Collette & Emjay Anthony': 1,
#  'Allison Tolman & David Koechner': 1,
#  'Allison Tolman & Emjay Anthony': 1,
#  'David Koechner & Emjay Anthony': 1,
#  'Owen Wilson & Lake Bell': 1,
#  'Owen Wilson & Pierce Brosnan': 1,
#  'Owen Wilson & Sterling Jerins': 1,
#  'Owen Wilson & Spencer Garrett': 1,
#  'Lake Bell & Pierce Brosnan': 1,
#  'Lake Bell & Sterling Jerins': 1,
#  'Lake Bell & Spencer Garrett': 1,
#  'Pierce Brosnan & Sterling Jerins': 1,
#  'Pierce Brosnan & Spencer Garrett': 1,
#  'Sterling Jerins & Spencer Garrett': 1,
#  'Helen Mirren & Ryan Reynolds': 1,
#  'Helen Mirren & Tatiana Maslany': 1,
#  'Helen Mirren & Katie Holmes': 1,
#  'Helen Mirren & Max Irons': 1,
#  'Ryan Reynolds & Tatiana Maslany': 1,
#  'Ryan Reynolds & Katie Holmes': 1,
#  'Ryan Reynolds & Max Irons': 1,
#  'Tatiana Maslany & Katie Holmes': 1,
#  'Tatiana Maslany & Max Irons': 1,
#  'Katie Holmes & Max Irons': 1,
#  'Tina Fey & Amy Poehler': 2,
#  'Tina Fey & John Leguizamo': 1,
#  'Tina Fey & Ike Barinholtz': 1,
#  'Tina Fey & Maya Rudolph': 1,
#  'Amy Poehler & John Leguizamo': 1,
#  'Amy Poehler & Ike Barinholtz': 1,
#  'Amy Poehler & Maya Rudolph': 1,
#  'John Leguizamo & Ike Barinholtz': 1,
#  'John Leguizamo & Maya Rudolph': 1,
#  'Ike Barinholtz & Maya Rudolph': 1,
#  'Jonny Weston & Virginia Gardner': 1,
#  "Jonny Weston & Sofia Black-D'Elia": 1,
#  'Jonny Weston & Sam Lerner': 1,
#  'Jonny Weston & Allen Evangelista': 1,
#  "Virginia Gardner & Sofia Black-D'Elia": 1,
#  'Virginia Gardner & Sam Lerner': 1,
#  'Virginia Gardner & Allen Evangelista': 1,
#  "Sofia Black-D'Elia & Sam Lerner": 1,
#  "Sofia Black-D'Elia & Allen Evangelista": 1,
#  'Sam Lerner & Allen Evangelista': 1,
#  'Ed Skrein & Ray Stevenson': 1,
#  'Ed Skrein & Loan Chabanol': 1,
#  'Ed Skrein & Gabriella Wright': 1,
#  'Ed Skrein & Tatjana PajkoviÄ‡': 1,
#  'Ray Stevenson & Loan Chabanol': 1,
#  'Ray Stevenson & Gabriella Wright': 1,
#  'Ray Stevenson & Tatjana PajkoviÄ‡': 1,
#  'Loan Chabanol & Gabriella Wright': 1,
#  'Loan Chabanol & Tatjana PajkoviÄ‡': 1,
#  'Gabriella Wright & Tatjana PajkoviÄ‡': 1,
#  'Mia Wasikowska & Jessica Chastain': 1,
#  'Mia Wasikowska & Tom Hiddleston': 1,
#  'Mia Wasikowska & Charlie Hunnam': 1,
#  'Mia Wasikowska & Jim Beaver': 1,
#  'Jessica Chastain & Tom Hiddleston': 1,
#  'Jessica Chastain & Charlie Hunnam': 1,
#  'Jessica Chastain & Jim Beaver': 1,
#  'Tom Hiddleston & Charlie Hunnam': 1,
#  'Tom Hiddleston & Jim Beaver': 1,
#  'Charlie Hunnam & Jim Beaver': 1,
#  'Channing Tatum & Matt Bomer': 1,
#  'Channing Tatum & Joe Manganiello': 1,
#  'Channing Tatum & Kevin Nash': 1,
#  'Channing Tatum & Adam RodrÃ\xadguez': 1,
#  'Matt Bomer & Joe Manganiello': 1,
#  'Matt Bomer & Kevin Nash': 1,
#  'Matt Bomer & Adam RodrÃ\xadguez': 1,
#  'Joe Manganiello & Kevin Nash': 1,
#  'Joe Manganiello & Adam RodrÃ\xadguez': 1,
#  'Kevin Nash & Adam RodrÃ\xadguez': 1,
#  'Chris J. Murray & Brit Shaw': 1,
#  'Chris J. Murray & Ivy George': 1,
#  'Chris J. Murray & Lauren Frandsen': 1,
#  'Chris J. Murray & Tyler Craig': 1,
#  'Brit Shaw & Ivy George': 1,
#  'Brit Shaw & Lauren Frandsen': 1,
#  'Brit Shaw & Tyler Craig': 1,
#  'Ivy George & Lauren Frandsen': 1,
#  'Ivy George & Tyler Craig': 1,
#  'Lauren Frandsen & Tyler Craig': 1,
#  'Bryan Cranston & Diane Lane': 1,
#  'Bryan Cranston & Helen Mirren': 1,
#  'Bryan Cranston & Elle Fanning': 1,
#  'Bryan Cranston & Louis C.K.': 1,
#  'Diane Lane & Helen Mirren': 1,
#  'Diane Lane & Elle Fanning': 1,
#  'Diane Lane & Louis C.K.': 1,
#  'Helen Mirren & Elle Fanning': 1,
#  'Helen Mirren & Louis C.K.': 1,
#  'Elle Fanning & Louis C.K.': 1,
#  'Chiwetel Ejiofor & Nicole Kidman': 1,
#  'Chiwetel Ejiofor & Julia Roberts': 1,
#  'Chiwetel Ejiofor & Dean Norris': 1,
#  'Chiwetel Ejiofor & Lyndon Smith': 1,
#  'Nicole Kidman & Julia Roberts': 1,
#  'Nicole Kidman & Dean Norris': 1,
#  'Nicole Kidman & Lyndon Smith': 1,
#  'Julia Roberts & Dean Norris': 1,
#  'Julia Roberts & Lyndon Smith': 1,
#  'Dean Norris & Lyndon Smith': 1,
#  'Tom Kenny & Bill Fagerbakke': 2,
#  'Tom Kenny & Rodger Bumpass': 2,
#  'Tom Kenny & Clancy Brown': 2,
#  'Tom Kenny & Carolyn Lawrence': 2,
#  'Bill Fagerbakke & Rodger Bumpass': 1,
#  'Bill Fagerbakke & Clancy Brown': 1,
#  'Bill Fagerbakke & Carolyn Lawrence': 2,
#  'Rodger Bumpass & Clancy Brown': 1,
#  'Rodger Bumpass & Carolyn Lawrence': 2,
#  'Clancy Brown & Carolyn Lawrence': 2,
#  'Thomas Haden Church & Josh Wiggins': 1,
#  'Thomas Haden Church & Lauren Graham': 1,
#  'Thomas Haden Church & Robbie Amell': 1,
#  'Thomas Haden Church & Mia Xitlali': 1,
#  'Josh Wiggins & Lauren Graham': 1,
#  'Josh Wiggins & Robbie Amell': 1,
#  'Josh Wiggins & Mia Xitlali': 1,
#  'Lauren Graham & Robbie Amell': 1,
#  'Lauren Graham & Mia Xitlali': 1,
#  'Robbie Amell & Mia Xitlali': 1,
#  'Sean Penn & Jasmine Trinca': 1,
#  'Sean Penn & Javier Bardem': 1,
#  'Sean Penn & Ray Winstone': 1,
#  'Sean Penn & Mark Rylance': 1,
#  'Jasmine Trinca & Javier Bardem': 1,
#  'Jasmine Trinca & Ray Winstone': 1,
#  'Jasmine Trinca & Mark Rylance': 1,
#  'Javier Bardem & Ray Winstone': 1,
#  'Javier Bardem & Mark Rylance': 1,
#  'Ray Winstone & Mark Rylance': 1,
#  'Reese Witherspoon & SofÃ\xada Vergara': 1,
#  ...}

# %%
max(pairs,key = pairs.get)
# Out:
# 'Daniel Radcliffe & Rupert Grint'

# %%
pairs['Daniel Radcliffe & Rupert Grint']
# Out:
# 8

# %%
answer_ls.append(5)

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# (У какого из режиссеров самый высокий процент фильмов со сборами выше бюджета?)
#
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data6_profitable = data5[data5.profit > 0]
data6.profit.min()
# Out:
# 2000000

# %%
filmography = pd.DataFrame(data5.director.str.split('|').tolist()).stack().value_counts()
filmography
# Out:
# Steven Soderbergh    13
# Ridley Scott         12
# Clint Eastwood       12
# Robert Rodriguez     11
# Steven Spielberg     10
#                      ..
# Peter Sollett         1
# Callan Brunker        1
# Christian Duguay      1
# R.J. Cutler           1
# Mimi Leder            1
# Length: 998, dtype: int64

# %%
filmography_profitable = pd.DataFrame(data6.director.str.split('|').tolist()).stack().value_counts()
filmography_profitable
# Out:
# Ridley Scott         12
# Steven Soderbergh    10
# Clint Eastwood       10
# Steven Spielberg     10
# Tim Burton            9
#                      ..
# Steve Purcell         1
# Gavin O'Connor        1
# Shane Black           1
# Brandon Camp          1
# James Mather          1
# Length: 814, dtype: int64

# %%
profitability = {}
for item in filmography.index:
    if item not in filmography_profitable:
        profitability[item] = 0
        continue
    profitability[item] = filmography_profitable[item] / filmography[item]
profitability
# Out:
# {'Steven Soderbergh': 0.7692307692307693,
#  'Ridley Scott': 1.0,
#  'Clint Eastwood': 0.8333333333333334,
#  'Robert Rodriguez': 0.7272727272727273,
#  'Steven Spielberg': 1.0,
#  'Shawn Levy': 0.9,
#  'Peter Farrelly': 0.8,
#  'Tim Burton': 1.0,
#  'Bobby Farrelly': 0.7777777777777778,
#  'Ron Howard': 0.75,
#  'Antoine Fuqua': 1.0,
#  'Michael Bay': 1.0,
#  'Peter Jackson': 1.0,
#  'M. Night Shyamalan': 0.875,
#  'Christopher Nolan': 1.0,
#  'Adam Shankman': 0.875,
#  'Brett Ratner': 1.0,
#  'Gore Verbinski': 0.75,
#  'Todd Phillips': 0.875,
#  'Dennis Dugan': 0.8571428571428571,
#  'Quentin Tarantino': 0.8571428571428571,
#  'Lasse HallstrÃ¶m': 0.7142857142857143,
#  'Marc Forster': 0.7142857142857143,
#  'Paul W.S. Anderson': 0.8571428571428571,
#  'Steve Carr': 0.8333333333333334,
#  'Tim Story': 1.0,
#  'Peter Segal': 1.0,
#  'Peter Berg': 0.8333333333333334,
#  'Louis Leterrier': 1.0,
#  'Andy Fickman': 1.0,
#  'Francis Lawrence': 1.0,
#  'Raja Gosnell': 1.0,
#  'Rob Cohen': 0.6666666666666666,
#  'Danny Boyle': 0.8333333333333334,
#  'Zack Snyder': 1.0,
#  'Martin Scorsese': 0.8333333333333334,
#  'Robert Zemeckis': 1.0,
#  'Sam Raimi': 1.0,
#  'Robert Luketic': 0.8333333333333334,
#  'Adam McKay': 1.0,
#  'Joel Coen': 1.0,
#  'Brian Robbins': 0.5,
#  'Tony Scott': 0.8333333333333334,
#  'David Fincher': 1.0,
#  'Paul Weitz': 0.6,
#  'Nancy Meyers': 1.0,
#  'F. Gary Gray': 1.0,
#  'Lilly Wachowski': 0.8,
#  'Jon Turteltaub': 1.0,
#  'Oliver Stone': 1.0,
#  'Chris Columbus': 0.8,
#  'J.J. Abrams': 1.0,
#  'Mark Waters': 0.8,
#  'John Singleton': 1.0,
#  'James Mangold': 1.0,
#  'Roland Emmerich': 1.0,
#  'Michael Mann': 0.6,
#  'Renny Harlin': 0.2,
#  'Guillermo del Toro': 1.0,
#  'Jay Roach': 0.8,
#  'Doug Liman': 1.0,
#  'Ken Kwapis': 0.8,
#  'Aaron Seltzer': 0.8,
#  'Lana Wachowski': 0.8,
#  'Wes Craven': 0.6,
#  'Sam Mendes': 1.0,
#  'David R. Ellis': 0.8,
#  'Jason Friedberg': 0.8,
#  'Paul Greengrass': 0.8,
#  'Peyton Reed': 0.8,
#  'Judd Apatow': 0.8,
#  'Martin Campbell': 0.8,
#  'Joel Schumacher': 0.6,
#  'John Moore': 0.8,
#  'D.J. Caruso': 0.8,
#  'Andrzej Bartkowiak': 0.6,
#  'Cameron Crowe': 0.4,
#  'Carlos Saldanha': 1.0,
#  'Lee Tamahori': 0.4,
#  'Jon Favreau': 1.0,
#  'Simon West': 0.8,
#  'Justin Lin': 0.8,
#  'David Dobkin': 0.8,
#  'Guy Ritchie': 1.0,
#  'Joe Wright': 0.6,
#  'Jaume Collet-Serra': 1.0,
#  'Bryan Singer': 1.0,
#  'Wes Anderson': 0.8,
#  'Ethan Coen': 1.0,
#  'Malcolm D. Lee': 1.0,
#  'Nick Cassavetes': 1.0,
#  'George Clooney': 1.0,
#  'Bill Condon': 0.75,
#  'Olivier Megaton': 1.0,
#  'Paul McGuigan': 0.5,
#  'Brian Helgeland': 0.75,
#  'Frank Coraci': 0.75,
#  'Mikael HÃ¥fstrÃ¶m': 1.0,
#  'Gavin Hood': 0.75,
#  'Tarsem Singh': 1.0,
#  'Donald Petrie': 1.0,
#  'Keenen Ivory Wayans': 1.0,
#  'Boaz Yakin': 1.0,
#  'Barry Levinson': 0.25,
#  'Jon M. Chu': 0.75,
#  'Rob Letterman': 1.0,
#  'Christopher Miller': 1.0,
#  'NimrÃ³d Antal': 0.75,
#  'James Wan': 0.75,
#  'Eric Darnell': 1.0,
#  'Mark Neveldine': 0.75,
#  'John Lee Hancock': 0.75,
#  'David Ayer': 0.75,
#  'Alejandro GonzÃ¡lez IÃ±Ã¡rritu': 1.0,
#  'Kevin Smith': 1.0,
#  'Jason Reitman': 1.0,
#  'Rob Marshall': 1.0,
#  'Edward Zwick': 1.0,
#  'David Twohy': 1.0,
#  'Alexander Payne': 1.0,
#  'Matthew Vaughn': 1.0,
#  'Richard Linklater': 0.5,
#  'Andy Tennant': 1.0,
#  'David Bowers': 0.5,
#  'Len Wiseman': 1.0,
#  'Rob Minkoff': 1.0,
#  'David Yates': 1.0,
#  'Rob Zombie': 0.75,
#  'Marcus Nispel': 0.5,
#  'Brian Taylor': 0.75,
#  'David Gordon Green': 0.5,
#  'David Cronenberg': 0.75,
#  'James McTeigue': 0.75,
#  'Barry Sonnenfeld': 0.75,
#  'John Erick Dowdle': 1.0,
#  'Gary Fleder': 0.75,
#  'Brad Bird': 1.0,
#  'McG': 0.75,
#  'Tom McGrath': 1.0,
#  'Darren Aronofsky': 0.75,
#  'Nicholas Stoller': 1.0,
#  'Robert Schwentke': 0.75,
#  'Andrew Adamson': 1.0,
#  'Phil Lord': 1.0,
#  'Anne Fletcher': 1.0,
#  'Luke Greenfield': 1.0,
#  'David Frankel': 0.75,
#  'Garry Marshall': 1.0,
#  'Dominic Sena': 0.75,
#  'Gus Van Sant': 0.6666666666666666,
#  'Chris Weitz': 1.0,
#  'Conrad Vernon': 1.0,
#  'Ben Stiller': 1.0,
#  'Jonathan Mostow': 1.0,
#  'Lee Unkrich': 1.0,
#  'Stephen Sommers': 1.0,
#  'Seth Gordon': 1.0,
#  'Michael Lembeck': 0.6666666666666666,
#  'Tom Tykwer': 1.0,
#  'Brad Anderson': 0.6666666666666666,
#  'Joe Johnston': 1.0,
#  'Catherine Hardwicke': 0.6666666666666666,
#  'Patrick Lussier': 0.6666666666666666,
#  'Thomas Carter': 1.0,
#  'Baz Luhrmann': 0.6666666666666666,
#  'Pierre Morel': 0.3333333333333333,
#  'Sylvester Stallone': 1.0,
#  'Jesse Dylan': 1.0,
#  'Neil Burger': 1.0,
#  'Tom Hooper': 1.0,
#  'Greg Mottola': 1.0,
#  'Chris Renaud': 1.0,
#  'Jeff Tremaine': 1.0,
#  'Jonathan Liebesman': 1.0,
#  'John Madden': 0.6666666666666666,
#  'Kelly Asbury': 1.0,
#  'Betty Thomas': 0.6666666666666666,
#  'Stephen Daldry': 1.0,
#  'Roger Donaldson': 0.3333333333333333,
#  'Marc Lawrence': 1.0,
#  'George Miller': 1.0,
#  'Pete Docter': 1.0,
#  'Jimmy Hayward': 0.6666666666666666,
#  'Matt Reeves': 1.0,
#  'Peter Chelsom': 1.0,
#  'John Woo': 0.6666666666666666,
#  'Kathryn Bigelow': 0.6666666666666666,
#  'Pierre Coffin': 1.0,
#  'Robert Redford': 0.3333333333333333,
#  'Dean DeBlois': 1.0,
#  'Tyler Perry': 1.0,
#  'Paul Haggis': 1.0,
#  'Mike Newell': 0.6666666666666666,
#  'Todd Haynes': 0.6666666666666666,
#  'Tim Hill': 1.0,
#  'Uwe Boll': 0.3333333333333333,
#  'Glenn Ficarra': 0.6666666666666666,
#  'Stephen Frears': 1.0,
#  'Gregory Hoblit': 0.3333333333333333,
#  'Craig Brewer': 0.6666666666666666,
#  'Woody Allen': 1.0,
#  'Ang Lee': 1.0,
#  'Alfonso CuarÃ³n': 0.6666666666666666,
#  'Frank Miller': 0.3333333333333333,
#  'Chris Sanders': 1.0,
#  'Paul Thomas Anderson': 0.3333333333333333,
#  'Burr Steers': 0.6666666666666666,
#  'Tom Shadyac': 0.3333333333333333,
#  'Will Gluck': 1.0,
#  'Kenneth Branagh': 0.6666666666666666,
#  'Sean Anders': 0.6666666666666666,
#  'Andrew Stanton': 1.0,
#  'Joe Carnahan': 1.0,
#  'Brian Levant': 0.6666666666666666,
#  'John Requa': 0.6666666666666666,
#  'Ruben Fleischer': 1.0,
#  'Walter Hill': 0,
#  'Mike Mitchell': 1.0,
#  'Paul Feig': 1.0,
#  'Jake Kasdan': 0.6666666666666666,
#  'Rob Reiner': 0.6666666666666666,
#  'Neil LaBute': 0.6666666666666666,
#  'Tom Dey': 0.6666666666666666,
#  'Breck Eisner': 0.6666666666666666,
#  'David S. Goyer': 0.6666666666666666,
#  'Thor Freudenthal': 1.0,
#  'Brad Peyton': 1.0,
#  'Chris Wedge': 1.0,
#  'Allen Hughes': 0.6666666666666666,
#  'Wayne Wang': 0.6666666666666666,
#  'Andrew Niccol': 0.6666666666666666,
#  'Kevin Macdonald': 1.0,
#  'Scott Cooper': 0.6666666666666666,
#  'David O. Russell': 0.6666666666666666,
#  'Marc Webb': 1.0,
#  'Harald Zwart': 1.0,
#  'Bennett Miller': 0.6666666666666666,
#  'Gil Kenan': 0.6666666666666666,
#  'Steve Martino': 1.0,
#  'John Wells': 0.6666666666666666,
#  'Ben Affleck': 1.0,
#  'Vicky Jenson': 0.6666666666666666,
#  'John Stockwell': 0.6666666666666666,
#  'Tony Gilroy': 0.6666666666666666,
#  'Neill Blomkamp': 1.0,
#  'Sam Fell': 0.3333333333333333,
#  'Baltasar KormÃ¡kur': 1.0,
#  'Roman Polanski': 1.0,
#  'Michael Moore': 0.6666666666666666,
#  'David Koepp': 0.3333333333333333,
#  'Alexandre Aja': 1.0,
#  'Steve Pink': 1.0,
#  'Jim Sheridan': 0.6666666666666666,
#  'Steven Brill': 1.0,
#  'Wolfgang Petersen': 1.0,
#  'Iain Softley': 0.6666666666666666,
#  'William Friedkin': 0.3333333333333333,
#  'Randall Wallace': 1.0,
#  'Jonathan Levine': 1.0,
#  'Scott Frank': 0.5,
#  'Tim Johnson': 1.0,
#  'Denis Villeneuve': 1.0,
#  'Jean-Marc VallÃ©e': 0.5,
#  'Jason Moore': 1.0,
#  'Stephen Gaghan': 0.5,
#  'Steven Quale': 1.0,
#  'John A. Davis': 1.0,
#  'Scott Waugh': 1.0,
#  'Scott Stewart': 1.0,
#  'Courtney Solomon': 0,
#  'Rian Johnson': 0.5,
#  'Brian Koppelman': 0,
#  'J.C. Chandor': 0,
#  'Bille Woodruff': 1.0,
#  'Frank Oz': 1.0,
#  'Lone Scherfig': 1.0,
#  'George Lucas': 1.0,
#  'Simon Curtis': 1.0,
#  'George Tillman, Jr.': 1.0,
#  'John Whitesell': 1.0,
#  'Luis Mandoki': 0,
#  'Kevin Lima': 1.0,
#  'Chris Williams': 1.0,
#  'Howard Deutch': 0.5,
#  'Pete Travis': 0.5,
#  'Gary Ross': 1.0,
#  'John Musker': 0.5,
#  'Mark Romanek': 0.5,
#  'Philip Kaufman': 0,
#  'Bibo Bergeron': 0.5,
#  'David Slade': 1.0,
#  'Mark Steven Johnson': 1.0,
#  'Walter Salles': 0,
#  'David Zucker': 1.0,
#  'Takashi Shimizu': 1.0,
#  'Simon J. Smith': 1.0,
#  'Mel Gibson': 1.0,
#  'Chris Miller': 1.0,
#  'Michael Caton-Jones': 0,
#  'Jonathan Demme': 1.0,
#  'Jon Avnet': 0.5,
#  'Salim Akil': 1.0,
#  'Hayden Schlossberg': 1.0,
#  'Shana Feste': 1.0,
#  'Martin McDonagh': 1.0,
#  'Neil Marshall': 0,
#  'Shekhar Kapur': 0.5,
#  'Peter Howitt': 0.5,
#  'Duncan Jones': 1.0,
#  'Chris Buck': 1.0,
#  'John Hamburg': 1.0,
#  'Timur Bekmambetov': 1.0,
#  'Richard Loncraine': 1.0,
#  'Craig Gillespie': 1.0,
#  'Elizabeth Banks': 1.0,
#  'Kirk Jones': 1.0,
#  'Joshua Michael Stern': 0.5,
#  'Bill Paxton': 0.5,
#  'Christopher McQuarrie': 1.0,
#  'Simon Wells': 0.5,
#  'Genndy Tartakovsky': 1.0,
#  'Carl Franklin': 1.0,
#  'Robert Iscove': 0.5,
#  'Sofia Coppola': 1.0,
#  'Stuart Beattie': 0.5,
#  'John Dahl': 0.5,
#  'Kevin Munroe': 0.5,
#  'James Bobin': 1.0,
#  'GÃ¡bor CsupÃ³': 0.5,
#  'Jean-Jacques Annaud': 0.5,
#  'Nigel Cole': 1.0,
#  'Michel Gondry': 1.0,
#  'John Hillcoat': 0.5,
#  'Michael Spierig': 0.5,
#  'David Silverman': 1.0,
#  'Andrew Davis': 0,
#  'Joseph Kosinski': 1.0,
#  'Reginald Hudlin': 0,
#  'Phillip Noyce': 1.0,
#  'Darren Lynn Bousman': 1.0,
#  'Michael Patrick King': 1.0,
#  'Mark Osborne': 1.0,
#  'Geoffrey Sax': 0.5,
#  'Peter Spierig': 0.5,
#  'Ken Scott': 0.5,
#  'Kevin Greutert': 1.0,
#  'Nick Park': 1.0,
#  'Roger Kumble': 1.0,
#  'Phyllida Lloyd': 1.0,
#  'Danny Leiner': 1.0,
#  'Gabriele Muccino': 1.0,
#  'Jay Russell': 1.0,
#  'John Lasseter': 1.0,
#  'James Gunn': 1.0,
#  'James L. Brooks': 0,
#  'Mira Nair': 0.5,
#  'Jessie Nelson': 1.0,
#  'Ron Clements': 0.5,
#  'Evan Goldberg': 0.5,
#  'Denzel Washington': 1.0,
#  'Alan Taylor': 1.0,
#  'P.J. Hogan': 1.0,
#  'Anthony Russo': 1.0,
#  'Charles Stone III': 0.5,
#  'Josh Trank': 1.0,
#  'Wes Ball': 1.0,
#  'Edgar Wright': 0,
#  'Michael Apted': 1.0,
#  'Christian Alvart': 0.5,
#  'Daniel Espinosa': 0.5,
#  'Michael Dowse': 0,
#  'Eric Brevig': 1.0,
#  'Gina Prince-Bythewood': 1.0,
#  'Henry Joost': 1.0,
#  'Charles Martin Smith': 1.0,
#  'Ariel Schulman': 1.0,
#  'Kevin Rodney Sullivan': 1.0,
#  'Andrew Dominik': 0.5,
#  'Nora Ephron': 1.0,
#  'Werner Herzog': 0,
#  'Mike Nichols': 1.0,
#  'Jonathan Lynn': 0.5,
#  'Clark Johnson': 1.0,
#  'Camille Delamarre': 1.0,
#  'Brad Silberling': 0.5,
#  'Mike Tollin': 0.5,
#  'Noam Murro': 1.0,
#  'Frank Darabont': 0.5,
#  'Larry Charles': 1.0,
#  'Anthony Stacchi': 1.0,
#  'Byron Howard': 1.0,
#  'Joe Nussbaum': 0.5,
#  'Alex Proyas': 1.0,
#  'Michael J. Bassett': 0.5,
#  'Spike Lee': 0.5,
#  'Spike Jonze': 1.0,
#  'Roger Michell': 1.0,
#  'Kirk De Micco': 1.0,
#  'Gary Winick': 1.0,
#  'James Cameron': 1.0,
#  'Brad Furman': 1.0,
#  'Lee Daniels': 1.0,
#  'Ivan Reitman': 1.0,
#  'Rod Lurie': 0,
#  'Peter Weir': 0.5,
#  'Karyn Kusama': 0.5,
#  'David Levien': 0,
#  'Jon Hurwitz': 1.0,
#  'Mike Binder': 1.0,
#  'Don Hall': 0.5,
#  'Kyle Balda': 1.0,
#  'Seth MacFarlane': 1.0,
#  'Joss Whedon': 1.0,
#  'Eli Roth': 0.5,
#  'Victor Salva': 1.0,
#  'Daniel Barnz': 0.5,
#  'Richard Curtis': 0.5,
#  'Peter Lord': 1.0,
#  'Peter Hewitt': 0.5,
#  'Rupert Wyatt': 1.0,
#  'David Wain': 0.5,
#  'Mark Dindal': 1.0,
#  'Rob Bowman': 0.5,
#  'Joe Russo': 1.0,
#  'Albert Hughes': 1.0,
#  'Richard LaGravenese': 1.0,
#  'Harold Ramis': 1.0,
#  'John Luessenhop': 1.0,
#  'Peter Hyams': 0,
#  'Julian Jarrold': 0.5,
#  'Oliver Hirschbiegel': 0.5,
#  'Tom Vaughan': 0.5,
#  'Mathieu Kassovitz': 1.0,
#  'Alejandro AmenÃ¡bar': 0.5,
#  'James Wong': 1.0,
#  'Brian De Palma': 0,
#  'Taylor Hackford': 1.0,
#  'Luc Besson': 1.0,
#  'Richard Donner': 0.5,
#  'Jay Chandrasekhar': 0.5,
#  'Seth Rogen': 0.5,
#  'Bruce Beresford': 0,
#  'Scott Derrickson': 1.0,
#  'Walt Becker': 1.0,
#  'Scott Hicks': 0.5,
#  'Nick Hurran': 0,
#  'Henry Selick': 0.5,
#  'Miguel Arteta': 1.0,
#  'Stewart Hendler': 0.5,
#  'Rachid Bouchareb': 1.0,
#  'Douglas McGrath': 1.0,
#  'Rusty Cundieff': 1.0,
#  'Jan de Bont': 1.0,
#  'Stuart Baird': 1.0,
#  'Jennifer Lee': 1.0,
#  'Paul Verhoeven': 1.0,
#  'Nicholas Jarecki': 1.0,
#  'David Lynch': 1.0,
#  'Don McKellar': 0,
#  'Frederik Du Chau': 1.0,
#  'Steven Zaillian': 0,
#  'Lars von Trier': 1.0,
#  'Rodrigo GarcÃ\xada': 0,
#  'William Monahan': 0,
#  'Dennie Gordon': 1.0,
#  'Michael Cristofer': 0,
#  'George Nolfi': 1.0,
#  'Russell Crowe': 0,
#  "Matthew O'Callaghan": 1.0,
#  'Jake Schreier': 1.0,
#  'Sergey Bodrov': 1.0,
#  'Jay Duplass': 0,
#  'Susanne Bier': 0,
#  'Lee Sternthal': 1.0,
#  'Kevin Costner': 1.0,
#  'David Schwimmer': 1.0,
#  'Tommy Lee Jones': 0,
#  'Rich Moore': 1.0,
#  'Benny Chan': 1.0,
#  'Dean Wright': 0,
#  'Steve Bendelack': 1.0,
#  'Mike Thurmeier': 1.0,
#  'Christopher B. Landon': 1.0,
#  'Steven Knight': 0,
#  'Michael Winterbottom': 1.0,
#  'David Mackenzie': 0,
#  'Glen Morgan': 1.0,
#  'Martin Brest': 0,
#  'Trish Sie': 1.0,
#  'Stephen Kay': 1.0,
#  'Steven Shainberg': 0,
#  'Michael Davis': 0,
#  'Simon Hunter': 0,
#  'Ralph Zondag': 1.0,
#  'Griffin Dunne': 1.0,
#  'Hironobu Sakaguchi': 0,
#  'Lorna Cook': 1.0,
#  'Peter Billingsley': 1.0,
#  'Anthony Hemingway': 0,
#  'Steve McQueen': 1.0,
#  'Bryan Bertino': 1.0,
#  'Jonathan M. Goldstein': 1.0,
#  'Will Speck': 1.0,
#  'Jeff Nichols': 1.0,
#  'Danny Cannon': 0,
#  'John Landis': 0,
#  'Doug Atchison': 1.0,
#  'Benson Lee': 0,
#  'Ericson Core': 1.0,
#  'Mark Levin': 1.0,
#  'Lenny Abrahamson': 1.0,
#  'Rupert Sanders': 1.0,
#  'Danny Pang': 0,
#  'Etan Cohen': 1.0,
#  'Sarah Gavron': 1.0,
#  'David Barrett': 0,
#  'Gary McKendry': 0,
#  'Tommy Wirkola': 1.0,
#  'Vipul Amrutlal Shah': 0,
#  'Francine McDougall': 1.0,
#  'James Duffy': 1.0,
#  'Justin Zackham': 0,
#  'Florent-Emilio Siri': 1.0,
#  'Sharon Maguire': 1.0,
#  'Steve Antin': 1.0,
#  'Jan Pinkava': 1.0,
#  'RyÃ»hei Kitamura': 0,
#  'Robert B. Weide': 0,
#  'David E. Talbert': 1.0,
#  'Ben Garant': 1.0,
#  'Nicolas Winding Refn': 1.0,
#  'Michael Dougherty': 1.0,
#  'Daniel Barber': 1.0,
#  'Brian Klugman': 1.0,
#  'Oxide Pang Chun': 0,
#  'James Marsh': 1.0,
#  'Jason Eisener': 0,
#  'Julie Anne Robinson': 0,
#  'Troy Duffy': 1.0,
#  'Sylvain White': 1.0,
#  'Dewey Nicks': 0,
#  'Ben Falcone': 1.0,
#  'Jane Campion': 0,
#  'Curtis Hanson': 1.0,
#  'Mark Linfield': 1.0,
#  'Henry Alex Rubin': 0,
#  'Paul King': 1.0,
#  'J. Mackye Gruber': 1.0,
#  'Jerry Zucker': 1.0,
#  'Raman Hui': 1.0,
#  'James Isaac': 1.0,
#  'Anthony Silverston': 1.0,
#  'William Brent Bell': 1.0,
#  'Ash Brannon': 1.0,
#  'GrÃ©gory Levasseur': 1.0,
#  'Mark Mylod': 1.0,
#  'Jeff Wadlow': 1.0,
#  'Liam Lynch': 0,
#  'Dan Cutforth': 1.0,
#  'David Moreau': 1.0,
#  'Mark Helfrich': 1.0,
#  'Eric Bress': 1.0,
#  'James Cox': 0,
#  'Uli Edel': 0,
#  'Mark Pellington': 1.0,
#  'Todd Edwards': 1.0,
#  'Matt Bettinelli-Olpin': 1.0,
#  'Rob Thomas': 0,
#  'Feng Xiaogang': 1.0,
#  'Giuseppe Tornatore': 1.0,
#  'Angela Robinson': 1.0,
#  'Paul Abascal': 0,
#  'Mike Flanagan': 1.0,
#  'Xavier Gens': 1.0,
#  'Jared Hess': 1.0,
#  'Peter Webber': 1.0,
#  'David McNally': 1.0,
#  'Eric Leighton': 1.0,
#  'Steve Oedekerk': 1.0,
#  'Peter Bogdanovich': 0,
#  'Emmett Malloy': 0,
#  'Harold Becker': 0,
#  'Patrick Tatopoulos': 1.0,
#  'Ethan Maniquis': 1.0,
#  'Peter Cattaneo': 0,
#  'David Soren': 1.0,
#  'Jeff Schaffer': 0,
#  'Akiva Goldsman': 0,
#  'Corey Yuen Kwai': 1.0,
#  'Gary Chapman': 0,
#  'Wally Pfister': 1.0,
#  'Scott Walker': 0,
#  'John Stevenson': 1.0,
#  'Jonathan Dayton': 1.0,
#  'Steve Trenbirth': 1.0,
#  'Justin Chadwick': 0,
#  'Neil Nightingale': 1.0,
#  'Tate Taylor': 1.0,
#  'Alastair Fothergill': 1.0,
#  'Will Graham': 1.0,
#  'Demian Lichtenstein': 0,
#  'Patty Jenkins': 1.0,
#  'Sidney Lumet': 1.0,
#  'Craig Mazin': 0,
#  'David Raynr': 0,
#  'Anthony Minghella': 1.0,
#  'Steve Box': 1.0,
#  'Jorge Blanco': 1.0,
#  'Klay Hall': 1.0,
#  'John Sanford': 0,
#  'Terry George': 1.0,
#  'Mike Johnson': 1.0,
#  'Ben Younger': 1.0,
#  'Peter Ramsey': 1.0,
#  'Robert Pulcini': 1.0,
#  'John Curran': 0,
#  'Jon Erwin': 1.0,
#  'Scott Speer': 1.0,
#  'Joel Zwick': 1.0,
#  'Christophe Gans': 1.0,
#  'Paolo Sorrentino': 0,
#  'Wayne Kramer': 0,
#  'John Maybury': 0,
#  'Bruce Hunt': 0,
#  'George Armitage': 0,
#  'Doug Ellin': 1.0,
#  'Mark Duplass': 0,
#  'Brad Lewis': 1.0,
#  'Jonathan Frakes': 1.0,
#  'Marcus Raboy': 1.0,
#  'Kirk Wise': 1.0,
#  'Juan Carlos Fresnadillo': 1.0,
#  'Christopher Spencer': 1.0,
#  'Christopher Guest': 1.0,
#  'Ron Underwood': 0,
#  'Mike Judge': 1.0,
#  'Daniel Sackheim': 0,
#  'Donovan Cook': 1.0,
#  'Cody Cameron': 1.0,
#  'David Leland': 0,
#  'Andy Muschietti': 1.0,
#  'Frank Marshall': 1.0,
#  'Miguel Sapochnik': 0,
#  'John Boorman': 1.0,
#  'Dean Israelite': 1.0,
#  'Les Mayfield': 0,
#  'Ryan Coogler': 1.0,
#  'Christopher Erskin': 1.0,
#  'Alister Grierson': 1.0,
#  'Charles Herman-Wurmfeld': 1.0,
#  'Simon Wincer': 1.0,
#  'Alan Parker': 0,
#  'Kris Pearn': 1.0,
#  'Hoyt Yeatman': 1.0,
#  'Ole Bornedal': 1.0,
#  'Jim Jarmusch': 1.0,
#  'Jennifer Flackett': 1.0,
#  'Ari Sandel': 1.0,
#  'Brenda Chapman': 1.0,
#  'Jon Kasdan': 1.0,
#  'John Schultz': 1.0,
#  'Richard Shepard': 1.0,
#  'Derek Cianfrance': 1.0,
#  'Ron Shelton': 0,
#  'Dean Parisot': 1.0,
#  'Fred Savage': 1.0,
#  'David Hackl': 1.0,
#  "Pat O'Connor": 1.0,
#  'Jonathan van Tulleken': 1.0,
#  'Pitof': 0,
#  'Colin Strause': 1.0,
#  'Tom Hanks': 1.0,
#  'John McTiernan': 0,
#  'Dan Gilroy': 1.0,
#  'Juan Antonio Bayona': 1.0,
#  'Edward Norton': 1.0,
#  'Joel Gallen': 1.0,
#  'Robert De Niro': 0,
#  'Chris Sivertson': 0,
#  'Aleksander Bach': 1.0,
#  'Rawson Marshall Thurber': 1.0,
#  'Troy Miller': 1.0,
#  'Dan Rush': 0,
#  'Chris Rock': 1.0,
#  'Susannah Grant': 0,
#  'Wong Kar-wai': 1.0,
#  'Morten Tyldum': 1.0,
#  'Rick Rosenthal': 1.0,
#  'Vic Armstrong': 1.0,
#  'Doug Lefler': 0,
#  'Adam Wingard': 0,
#  'Chris Noonan': 1.0,
#  'Howard McCain': 0,
#  'John Michael McDonagh': 1.0,
#  'Lee Toland Krieger': 1.0,
#  'BjÃ¶rn Stein': 1.0,
#  'Garth Jennings': 1.0,
#  'Jonathan Teplitzky': 1.0,
#  'Shane Acker': 1.0,
#  'Patrick Hughes': 1.0,
#  'Antony Hoffman': 0,
#  'Andrew Erwin': 1.0,
#  'Drew Goddard': 1.0,
#  'Joe Ranft': 1.0,
#  'Greg Coolidge': 1.0,
#  'Jim Gillespie': 0,
#  'Gary Trousdale': 1.0,
#  'George A. Romero': 1.0,
#  'John Frankenheimer': 0,
#  'Harmony Korine': 1.0,
#  'Dan St. Pierre': 0,
#  'Robert Stevenhagen': 0,
#  'Ernest R. Dickerson': 0,
#  'Marcos MartÃ\xadnez': 1.0,
#  'Phil Joanou': 1.0,
#  'Joel Edgerton': 1.0,
#  'Don Michael Paul': 0,
#  'John Carpenter': 0,
#  'Don Scardino': 0,
#  'Gareth Edwards': 1.0,
#  'Steve Hickner': 1.0,
#  'David M. Rosenthal': 1.0,
#  'Zal Batmanglij': 0,
#  'Des McAnuff': 0,
#  'Sanjay Gadhvi': 1.0,
#  'E. Elias Merhige': 0,
#  'Bruce A. Evans': 1.0,
#  'Tom Gormican': 1.0,
#  'Russell Mulcahy': 1.0,
#  'Michael Sucsy': 1.0,
#  'Ed Gass-Donnelly': 1.0,
#  'JosÃ© Padilha': 1.0,
#  'William Malone': 0,
#  'Michael Hoffman': 1.0,
#  'Dave Green': 1.0,
#  'Ric Roman Waugh': 1.0,
#  'Stephen Hopkins': 1.0,
#  'Anthony Bell': 1.0,
#  'Roland JoffÃ©': 0,
#  'Amma Asante': 1.0,
#  'Guillaume Canet': 0,
#  'Andrew Douglas': 1.0,
#  'Don Bluth': 0,
#  'Jaco Van Dormael': 0,
#  'Kevin Allen': 1.0,
#  'Sean Penn': 1.0,
#  'James Watkins': 1.0,
#  'Sam Miller': 1.0,
#  'Rupert Wainwright': 1.0,
#  'Mike McCoy': 1.0,
#  'John Polson': 1.0,
#  'Dan Bradley': 0,
#  'Todd Strauss-Schulson': 1.0,
#  'Kirsten Sheridan': 1.0,
#  'Thomas Bezucha': 0,
#  'Joe Dante': 0,
#  'Peter Landesman': 1.0,
#  'Dave Meyers': 1.0,
#  'Jim Fall': 1.0,
#  'Tyler Gillett': 1.0,
#  'Colin Trevorrow': 1.0,
#  'Jonathan Hensleigh': 1.0,
#  'Grant Heslov': 1.0,
#  'Chris Gorak': 1.0,
#  'Olatunde Osunsanmi': 1.0,
#  'Richard Eyre': 1.0,
#  'James Mather': 1.0,
#  'FranÃ§ois Ozon': 1.0,
#  'Todd Lincoln ': 0,
#  'Sam Taylor-Johnson': 1.0,
#  'Noah Baumbach': 0,
#  'Michael Cuesta': 0,
#  'Roger Allers': 1.0,
#  'Diane Keaton': 0,
#  'Rob Pritts': 1.0,
#  'Terry Gilliam': 1.0,
#  'Loveleen Tandan': 1.0,
#  'Gary Goldman': 0,
#  'Gregory Plotkin': 1.0,
#  'Barbet Schroeder': 1.0,
#  'Josh Schwartz': 0,
#  'Stephen Herek': 0,
#  'Christian E. Christiansen': 1.0,
#  'Alan Poul': 1.0,
#  'Ronald F. Maxwell': 0,
#  'Mark Rosman': 1.0,
#  'Rob Schmidt': 1.0,
#  'Angelina Jolie': 1.0,
#  'Julie Taymor': 1.0,
#  'Beeban Kidron': 0,
#  'Toby Wilkins': 1.0,
#  'Nicholas Hytner': 1.0,
#  'Ben Gluck': 1.0,
#  'Javier Abad': 1.0,
#  'Alejandro Monteverde': 0,
#  'Stephen Chbosky': 1.0,
#  'Jorma Taccone': 0,
#  'Brian A Miller': 1.0,
#  'Stephen J. Anderson': 1.0,
#  'Leigh Whannell': 1.0,
#  'Michael Haneke': 0,
#  'John Crowley': 1.0,
#  'Joseph Kahn': 1.0,
#  'Ronny Yu': 1.0,
#  'Stephen Anderson': 0,
#  'Anthony Leondis': 1.0,
#  'Mary Lambert': 0,
#  'Jim Field Smith': 1.0,
#  'Graham Annable': 1.0,
#  'Josh Gordon': 1.0,
#  'Troy Nixey': 1.0,
#  'Richard Kelly': 1.0,
#  'Niki Caro': 0,
#  'Kevin Reynolds': 0,
#  'Tony Goldwyn': 0,
#  'Jane Lipsitz': 1.0,
#  'Christine Jeffs': 1.0,
#  'Billy Ray': 1.0,
#  'Greg Strause': 1.0,
#  'Fyodor Bondarchuk': 1.0,
#  'Bonnie Hunt': 1.0,
#  'Ilya Naishuller': 1.0,
#  'Tom McCarthy': 1.0,
#  'Nathan Greno': 1.0,
#  'Chris Carter': 1.0,
#  'John R. Leonetti': 1.0,
#  'Michael Rymer': 1.0,
#  'Douglas Aarniokoski': 0,
#  'DJ Pooh': 1.0,
#  'Gary Shore': 1.0,
#  'Ryan Murphy': 1.0,
#  'Todd Graff': 0,
#  'John Carney': 1.0,
#  'Jeremy Garelick': 1.0,
#  'Dustin Hoffman': 1.0,
#  'Shane Black': 1.0,
#  'Cory Edwards': 1.0,
#  'Dan Scanlon': 1.0,
#  'Ciaran Foy': 1.0,
#  'Steve Purcell': 1.0,
#  'Michael McCullers': 1.0,
#  "Gavin O'Connor": 1.0,
#  'Brandon Camp': 1.0,
#  'Nima Nourizadeh': 1.0,
#  'Brendan Malloy': 0,
#  'Jim Sonzero': 0,
#  'Chris Nahon': 1.0,
#  'Samuel Bayer': 1.0,
#  'Davis Guggenheim': 0,
#  "Steve 'Spaz' Williams": 0,
#  'Stiles White': 1.0,
#  'Steve Shill': 1.0,
#  'David Mamet': 0,
#  'James Gray': 1.0,
#  'Juan Diego Solanas': 0,
#  'Alex Kurtzman': 0,
#  'Xavier Palud': 1.0,
#  'Marcel Langenegger': 0,
#  'Lawrence Kasdan': 1.0,
#  'Michel Hazanavicius': 1.0,
#  'John Gulager': 1.0,
#  'Valerie Faris': 1.0,
#  'Jill Culton': 1.0,
#  'Paul Schrader': 0,
#  'Carl Rinsch': 0,
#  'Jesse Peretz': 1.0,
#  'Joe Cornish': 0,
#  'Paul Tibbitt': 1.0,
#  'Jonas Elmer': 1.0,
#  'Stephen Hillenburg': 1.0,
#  'Nanette Burstein': 1.0,
#  'Fede Alvarez': 1.0,
#  'Charles Shyer': 0,
#  'James Foley': 1.0,
#  'Bob Peterson': 1.0,
#  'Ava DuVernay': 1.0,
#  'Joseph Ruben': 1.0,
#  'Gonzalo LÃ³pez-Gallego': 1.0,
#  'Guy Ferland': 1.0,
#  'Clare Kilner': 1.0,
#  'John Bonito': 1.0,
#  'Terry Zwigoff': 1.0,
#  'Kurt Wimmer': 0,
#  'Marco Schnabel': 0,
#  'Sydney Pollack': 1.0,
#  'Joby Harold': 0,
#  'Sngmoo Lee': 0,
#  'Robin Budd': 1.0,
#  'Terrence Malick': 1.0,
#  'Adrian Lyne': 1.0,
#  'Jeff Newitt': 1.0,
#  'Matthew Robinson': 1.0,
#  'Anand Tucker': 1.0,
#  'Harold Cronk': 1.0,
#  'Alejandro Agresti': 1.0,
#  'Atom Egoyan': 0,
#  'Don Mancini': 1.0,
#  'Jean-FranÃ§ois Richet': 1.0,
#  'Josh Boone': 1.0,
#  'David MichÃ´d': 0,
#  'MÃ¥ns MÃ¥rlind': 1.0,
#  'Phil Traill': 1.0,
#  'Kasi Lemmons': 0,
#  'Ricky Gervais': 1.0,
#  'Kimberly Peirce': 1.0,
#  'Jon Lucas': 1.0,
#  'Saul Dibb': 0,
#  'John Francis Daley': 1.0,
#  'Patrik Forsberg': 1.0,
#  'Amy Heckerling': 0,
#  'Scott Moore': 1.0,
#  'Asger Leth': 1.0,
#  'Sara Sugarman': 1.0,
#  'Chad Stahelski': 1.0,
#  'Roberts Gannaway': 1.0,
#  'Tony Bill': 0,
#  'Robert Altman': 1.0,
#  'Oliver Parker': 1.0,
#  'Roger Spottiswoode': 1.0,
#  'Gregory Jacobs': 1.0,
#  'Gregory Poirier': 1.0,
#  'Tony Leech': 1.0,
#  'David Leitch': 1.0,
#  'Fred Wolf': 1.0,
#  'Joe Roth': 0,
#  'Mike Disa': 0,
#  'Rajkumar Hirani': 1.0,
#  'Trey Parker': 1.0,
#  'Alex Garland': 1.0,
#  'Steve Beck': 1.0,
#  "Tommy O'Haver": 0,
#  'Paul Johansson': 0,
#  'Jon Amiel': 1.0,
#  'Chuck Russell': 1.0,
#  'John Herzfeld': 0,
#  'Susanna White': 1.0,
#  'Keanu Reeves': 0,
#  'William Dear': 0,
#  'Fernando Meirelles': 1.0,
#  'Jason Winer': 1.0,
#  'Peter Hedges': 1.0,
#  'Florian Henckel von Donnersmarck': 1.0,
#  'Will Finn': 0,
#  'Philip G. Atwell': 1.0,
#  'Liz Friedlander': 1.0,
#  'Liev Schreiber': 0,
#  'Stephen Norrington': 1.0,
#  'Sean McNamara': 1.0,
#  'John Patrick Shanley': 1.0,
#  'Floria Sigismondi': 0,
#  'J.B. Rogers': 1.0,
#  'Asif Kapadia': 0,
#  'Mark Andrews': 1.0,
#  'Elizabeth Allen Rosenbaum': 1.0,
#  'Jocelyn Moorhouse': 1.0,
#  'Kerry Conran': 0,
#  'Kevin Bray': 1.0,
#  'Derrick Borte': 0,
#  'Dito Montiel': 0,
#  'Mark Herman': 1.0,
#  'Ted Demme': 1.0,
#  'Max Joseph': 1.0,
#  'Tamra Davis': 1.0,
#  'Stephen T. Kay': 0,
#  'Chris Koch': 0,
#  'Jonathan Glazer': 0,
#  'Shari Springer Berman': 1.0,
#  'Mabrouk El Mechri': 0,
#  'Bruce Robinson': 0,
#  'Chris Butler': 1.0,
#  'Stephen St. Leger': 1.0,
#  'Stefen Fangmeier': 1.0,
#  'Alexander Witt': 1.0,
#  'Richard J. Lewis': 0,
#  'Peter Sohn': 1.0,
#  'Mort Nathan': 0,
#  'Penny Marshall': 0,
#  'Lexi Alexander': 0,
#  'Nick Hamm': 1.0,
#  'Matthijs van Heijningen Jr.': 0,
#  'Greg Berlanti': 1.0,
#  'Karey Kirkpatrick': 1.0,
#  'Theodore Melfi': 1.0,
#  'Paul Weiland': 1.0,
#  'Mary Harron': 1.0,
#  'Mennan Yapo': 1.0,
#  'Lawrence Guterman': 1.0,
#  'James DeMonaco': 1.0,
#  'Jack Sholder': 0,
#  'Motonori Sakakibara': 0,
#  'Barry Cook': 1.0,
#  'Robert Stromberg': 1.0,
#  'Jennifer Yuh': 1.0,
#  'Peter Sollett': 1.0,
#  'Callan Brunker': 1.0,
#  'Christian Duguay': 0,
#  'R.J. Cutler': 1.0,
#  'Mimi Leder': 1.0}

# %%
max(profitability,key = profitability.get)
# Out:
# 'Ridley Scott'

# %%
profitability['Ridley Scott']
# Out:
# 1.0

# %%
directors = ['Quentin Tarantino', 'Steven Soderbergh', 'Robert Rodriguez', 'Christopher Nolan', 'Clint Eastwood']
for director, value in profitability.items():
    if director in directors:
        print(director, item)
# Out:
# Steven Soderbergh 1.0
# Clint Eastwood 1.0
# Robert Rodriguez 1.0
# Christopher Nolan 1.0
# Quentin Tarantino 1.0

# %%
for director, value in profitability.items():
    if director in directors:
        print(director, value)
        #print (filmography[director])
        #print (filmography_profitable[director])
        #print (filmography_profitable[director] / filmography[director])
# Out:
# Steven Soderbergh 0.7692307692307693
# Clint Eastwood 0.8333333333333334
# Robert Rodriguez 0.7272727272727273
# Christopher Nolan 1.0
# Quentin Tarantino 0.8571428571428571

# %%
answer_ls.append(4)

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 35

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id  Answer
# 0    1       4
# 1    2       2
# 2    3       3
# 3    4       2
# 4    5       1
# 5    6       5
# 6    7       2
# 7    8       1
# 8    9       4
# 9   10       5
# 10  11       3
# 11  12       1
# 12  13       3
# 13  14       4
# 14  15       5
# 15  16       1
# 16  17       3
# 17  18       3
# 18  19       2
# 19  20       1
# 20  21       4
# 21  22       2
# 22  23       3
# 23  24       1
# 24  25       5
# 25  26       1
# 26  27       4
# 27  28       2
# 28  29       5
# 29  30       2
# 30  31       5
# 31  32       5
# 32  33       1
# 33  34       5
# 34  35       4
